# %%
import pandas as pd
import pickle
import numpy as np
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import load_model, Model
from keras.layers import Flatten, Dense, Dropout, Activation, Input, LSTM, Reshape, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.layers import LeakyReLU
#!pip install np_utils
from keras import utils

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score

# set random seeds

# removed the import statement for set_session from tensorflow.compat.v1.keras.backend
np.random.seed(1)
tf.random.set_seed(2)

# limit gpu usage for keras with tensorflow 1
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth = True
# set_session(tf.compat.v1.Session(config=config))

# If you need to use set_session, try this instead:
# from tensorflow.python.keras.backend import set_session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

# Define the target directory in Google Drive for the unzipped files
# This path is derived from the np.loadtxt calls in a subsequent cell (RmH5_HJyoLmZ)
UNZIPPED_DATA_DIR = '/content/drive/MyDrive/LOBCNN/data/'

# Check if the unzipped data directory already exists and contains files
# This is a more robust check to confirm data readiness in Google Drive
if not os.path.exists(UNZIPPED_DATA_DIR) or not os.listdir(UNZIPPED_DATA_DIR):
    print(f"Data not found in {UNZIPPED_DATA_DIR}. Attempting to download and unzip.")

    # Create the target directory if it doesn't exist
    os.makedirs(UNZIPPED_DATA_DIR, exist_ok=True)

    # Define a temporary path for the downloaded zip file in /content/
    TEMP_ZIP_PATH = '/content/data.zip'

    # Download the data.zip file to /content/
    # !wget -q https://raw.githubusercontent.com/zcakhaa/DeepLOB-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books/master/data/data.zip -O {TEMP_ZIP_PATH}

    # Unzip the downloaded file directly into the target directory in Google Drive
    with zipfile.ZipFile(TEMP_ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(UNZIPPED_DATA_DIR)

    # Optionally, remove the temporary zip file to save space
    os.remove(TEMP_ZIP_PATH)

    print('Data downloaded and unzipped to Google Drive.')
else:
    print('Data already existed and is ready in Google Drive.')
# Out:
# Data already existed and is ready in Google Drive.

# %%
def prepare_x(data):
    df1 = data[:40, :].T
    return np.array(df1)

def get_label(data):
    lob = data[-5:, :].T
    return lob

def data_classification(X, Y, T):
    [N, D] = X.shape
    df = np.array(X)
    dY = np.array(Y)
    dataY = dY[T - 1:N]
    dataX = np.zeros((N - T + 1, T, D))
    for i in range(T, N + 1):
        dataX[i - T] = df[i - T:i, :]
    return dataX.reshape(dataX.shape + (1,)), dataY

def prepare_x_y(data, k, T):
    x = prepare_x(data)
    y = get_label(data)
    x, y = data_classification(x, y, T=T)
    y = y[:,k] - 1
    y = utils.to_categorical(y, 3)
    return x, y

# %%
# Assuming UNZIPPED_DATA_DIR is defined in a previous cell (e.g., vxrZwaTErwd3) and contains the path
# to the unzipped files in Google Drive.

# Make sure UNZIPPED_DATA_DIR is defined. If this cell is run independently,
# uncomment and define it here or ensure the cell defining it runs first.
# UNZIPPED_DATA_DIR = '/content/drive/MyDrive/data/'

dec_data = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Train_Dst_NoAuction_DecPre_CF_7.txt'))
dec_train = dec_data[:, :int(np.floor(dec_data.shape[1] * 0.8))]
dec_val = dec_data[:, int(np.floor(dec_data.shape[1] * 0.8)):]

dec_test1 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_7.txt'))
dec_test2 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_8.txt'))
dec_test3 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_9.txt'))
dec_test = np.hstack((dec_test1, dec_test2, dec_test3))

k = 4 # which prediction horizon
T = 100 # the length of a single input
n_hiddens = 64

trainX_CNN, trainY_CNN = prepare_x_y(dec_train, k, T)
valX_CNN, valY_CNN = prepare_x_y(dec_val, k, T)
testX_CNN, testY_CNN = prepare_x_y(dec_test, k, T)

print(trainX_CNN.shape, trainY_CNN.shape)
print(valX_CNN.shape, valY_CNN.shape)
print(testX_CNN.shape, testY_CNN.shape)
# Out:
# (203701, 100, 40, 1) (203701, 3)
# (50851, 100, 40, 1) (50851, 3)
# (139488, 100, 40, 1) (139488, 3)

# %%
def create_deeplob(T, NF, number_of_lstm):
    input_lmd = Input(shape=(T, NF, 1))

    # build the convolutional block
    conv_first1 = Conv2D(32, (1, 2), strides=(1, 2))(input_lmd)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)

    conv_first1 = Conv2D(32, (1, 2), strides=(1, 2))(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)

    conv_first1 = Conv2D(32, (1, 10))(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)

    # build the inception module
    convsecond_1 = Conv2D(64, (1, 1), padding='same')(conv_first1)
    convsecond_1 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_1)
    convsecond_1 = Conv2D(64, (3, 1), padding='same')(convsecond_1)
    convsecond_1 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_1)

    convsecond_2 = Conv2D(64, (1, 1), padding='same')(conv_first1)
    convsecond_2 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_2)
    convsecond_2 = Conv2D(64, (5, 1), padding='same')(convsecond_2)
    convsecond_2 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_2)

    convsecond_3 = MaxPooling2D((3, 1), strides=(1, 1), padding='same')(conv_first1)
    convsecond_3 = Conv2D(64, (1, 1), padding='same')(convsecond_3)
    convsecond_3 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_3)

    convsecond_output = keras.layers.concatenate([convsecond_1, convsecond_2, convsecond_3], axis=3)
    conv_reshape = Reshape((int(convsecond_output.shape[1]), int(convsecond_output.shape[3])))(convsecond_output)
    conv_reshape = keras.layers.Dropout(0.2, noise_shape=(None, 1, int(conv_reshape.shape[2])))(conv_reshape, training=True)

    # build the last LSTM layer
    # If GPU is not available, change CuDNNLSTM to LSTM
    conv_lstm = LSTM(number_of_lstm)(conv_reshape)

    # build the output layer
    out = Dense(3, activation='softmax')(conv_lstm)
    model = Model(inputs=input_lmd, outputs=out)
    adam = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

deeplob = create_deeplob(trainX_CNN.shape[1], trainX_CNN.shape[2], n_hiddens)
deeplob.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 100, 40,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 100, 20,   │         96 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 100, 20,   │          0 │ conv2d[0][0]      │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 100, 20,   │      4,128 │ leaky_re_lu[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 100, 20,   │          0 │ conv2d_1[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 100, 20,   │      4,128 │ leaky_re_lu_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 100, 20,   │          0 │ conv2d_2[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 100, 10,   │      2,080 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 100, 10,   │          0 │ conv2d_3[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 100, 10,   │      4,128 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 100, 10,   │          0 │ conv2d_4[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 100, 10,   │      4,128 │ leaky_re_lu_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 100, 10,   │          0 │ conv2d_5[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 100, 1,    │     10,272 │ leaky_re_lu_5[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 100, 1,    │          0 │ conv2d_6[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 100, 1,    │      4,128 │ leaky_re_lu_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 100, 1,    │          0 │ conv2d_7[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 100, 1,    │      4,128 │ leaky_re_lu_7[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 100, 1,    │          0 │ conv2d_8[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 100, 1,    │      2,112 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 100, 1,    │      2,112 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 100, 1,    │          0 │ conv2d_9[0][0]    │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 100, 1,    │          0 │ conv2d_11[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 100, 1,    │          0 │ leaky_re_lu_8[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 100, 1,    │     12,352 │ leaky_re_lu_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 100, 1,    │     20,544 │ leaky_re_lu_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 100, 1,    │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 100, 1,    │          0 │ conv2d_10[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 100, 1,    │          0 │ conv2d_12[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 100, 1,    │          0 │ conv2d_13[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 100, 1,    │          0 │ leaky_re_lu_10[0… │
# │ (Concatenate)       │ 192)              │            │ leaky_re_lu_12[0… │
# │                     │                   │            │ leaky_re_lu_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 100, 192)  │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 100, 192)  │          0 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 64)        │     65,792 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │        195 │ lstm[0][0]        │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 142,435 (556.39 KB)
#  Trainable params: 142,435 (556.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_filepath = '/content/drive/MyDrive/LOBCNN/models/weights_best.weights.h5'

model = create_deeplob(trainX_CNN.shape[1], trainX_CNN.shape[2], n_hiddens)  # Implement this function based on your model loading logic
if os.path.exists(checkpoint_filepath):
    model.load_weights(checkpoint_filepath)
else:
    print("No saved weights found. Starting training from scratch.")
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='auto',
        save_best_only=True)
    model.fit(trainX_CNN, trainY_CNN, validation_data=(valX_CNN, valY_CNN), epochs=200, batch_size=128, verbose=1, callbacks=[model_checkpoint_callback])
# Out:
# No saved weights found. Starting training from scratch.
# Epoch 1/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.4228 - loss: 1.0213 - val_accuracy: 0.3723 - val_loss: 1.0903
# Epoch 2/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.4626 - loss: 0.9279 - val_accuracy: 0.3658 - val_loss: 1.0902
# Epoch 3/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.4773 - loss: 0.9051 - val_accuracy: 0.4024 - val_loss: 1.0579
# Epoch 4/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.4983 - loss: 0.8846 - val_accuracy: 0.4866 - val_loss: 0.9389
# Epoch 5/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.5581 - loss: 0.8453 - val_accuracy: 0.5420 - val_loss: 0.9170
# Epoch 6/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.6036 - loss: 0.8057 - val_accuracy: 0.5472 - val_loss: 0.9091
# Epoch 7/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.6468 - loss: 0.7585 - val_accuracy: 0.5644 - val_loss: 0.8951
# Epoch 8/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.6795 - loss: 0.7199 - val_accuracy: 0.5881 - val_loss: 0.8631
# Epoch 9/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7031 - loss: 0.6835 - val_accuracy: 0.5973 - val_loss: 0.8631
# Epoch 10/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7212 - loss: 0.6563 - val_accuracy: 0.6334 - val_loss: 0.8107
# Epoch 11/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7348 - loss: 0.6339 - val_accuracy: 0.6393 - val_loss: 0.8034
# Epoch 12/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7466 - loss: 0.6136 - val_accuracy: 0.6422 - val_loss: 0.7986
# Epoch 13/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7558 - loss: 0.5965 - val_accuracy: 0.6527 - val_loss: 0.7845
# Epoch 14/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7640 - loss: 0.5822 - val_accuracy: 0.6586 - val_loss: 0.7729
# Epoch 15/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7718 - loss: 0.5680 - val_accuracy: 0.6590 - val_loss: 0.7738
# Epoch 16/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7766 - loss: 0.5571 - val_accuracy: 0.6627 - val_loss: 0.7791
# Epoch 17/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7818 - loss: 0.5467 - val_accuracy: 0.6636 - val_loss: 0.7824
# Epoch 18/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7859 - loss: 0.5375 - val_accuracy: 0.6678 - val_loss: 0.7703
# Epoch 19/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7910 - loss: 0.5282 - val_accuracy: 0.6731 - val_loss: 0.7661
# Epoch 20/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.7944 - loss: 0.5205 - val_accuracy: 0.6666 - val_loss: 0.7830
# Epoch 21/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.7987 - loss: 0.5125 - val_accuracy: 0.6733 - val_loss: 0.7706
# Epoch 22/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8019 - loss: 0.5056 - val_accuracy: 0.6730 - val_loss: 0.7719
# Epoch 23/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8048 - loss: 0.4988 - val_accuracy: 0.6713 - val_loss: 0.7781
# Epoch 24/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8086 - loss: 0.4924 - val_accuracy: 0.6840 - val_loss: 0.7512
# Epoch 25/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8112 - loss: 0.4862 - val_accuracy: 0.6763 - val_loss: 0.7739
# Epoch 26/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8132 - loss: 0.4809 - val_accuracy: 0.6794 - val_loss: 0.7667
# Epoch 27/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8163 - loss: 0.4755 - val_accuracy: 0.6816 - val_loss: 0.7710
# Epoch 28/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8180 - loss: 0.4712 - val_accuracy: 0.6834 - val_loss: 0.7645
# Epoch 29/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8205 - loss: 0.4662 - val_accuracy: 0.6849 - val_loss: 0.7668
# Epoch 30/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8223 - loss: 0.4619 - val_accuracy: 0.6867 - val_loss: 0.7598
# Epoch 31/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8240 - loss: 0.4571 - val_accuracy: 0.6872 - val_loss: 0.7565
# Epoch 32/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8262 - loss: 0.4531 - val_accuracy: 0.6876 - val_loss: 0.7551
# Epoch 33/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8281 - loss: 0.4486 - val_accuracy: 0.6882 - val_loss: 0.7563
# Epoch 34/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8304 - loss: 0.4441 - val_accuracy: 0.6895 - val_loss: 0.7568
# Epoch 35/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8326 - loss: 0.4403 - val_accuracy: 0.6886 - val_loss: 0.7596
# Epoch 36/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8344 - loss: 0.4364 - val_accuracy: 0.6874 - val_loss: 0.7685
# Epoch 37/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8364 - loss: 0.4322 - val_accuracy: 0.6874 - val_loss: 0.7728
# Epoch 38/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8378 - loss: 0.4282 - val_accuracy: 0.6888 - val_loss: 0.7691
# Epoch 39/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8393 - loss: 0.4254 - val_accuracy: 0.6856 - val_loss: 0.7796
# Epoch 40/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8403 - loss: 0.4217 - val_accuracy: 0.6854 - val_loss: 0.7840
# Epoch 41/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8427 - loss: 0.4176 - val_accuracy: 0.6864 - val_loss: 0.7836
# Epoch 42/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8440 - loss: 0.4144 - val_accuracy: 0.6845 - val_loss: 0.7993
# Epoch 43/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8456 - loss: 0.4111 - val_accuracy: 0.6820 - val_loss: 0.8064
# Epoch 44/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8462 - loss: 0.4092 - val_accuracy: 0.6837 - val_loss: 0.7967
# Epoch 45/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8482 - loss: 0.4055 - val_accuracy: 0.6820 - val_loss: 0.8108
# Epoch 46/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8486 - loss: 0.4036 - val_accuracy: 0.6800 - val_loss: 0.8160
# Epoch 47/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8508 - loss: 0.3987 - val_accuracy: 0.6803 - val_loss: 0.8198
# Epoch 48/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8518 - loss: 0.3956 - val_accuracy: 0.6767 - val_loss: 0.8407
# Epoch 49/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8529 - loss: 0.3932 - val_accuracy: 0.6773 - val_loss: 0.8419
# Epoch 50/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8547 - loss: 0.3898 - val_accuracy: 0.6806 - val_loss: 0.8344
# Epoch 51/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8567 - loss: 0.3864 - val_accuracy: 0.6826 - val_loss: 0.8358
# Epoch 52/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8567 - loss: 0.3842 - val_accuracy: 0.6786 - val_loss: 0.8418
# Epoch 53/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8585 - loss: 0.3808 - val_accuracy: 0.6841 - val_loss: 0.8411
# Epoch 54/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8593 - loss: 0.3790 - val_accuracy: 0.6830 - val_loss: 0.8321
# Epoch 55/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8607 - loss: 0.3757 - val_accuracy: 0.6823 - val_loss: 0.8392
# Epoch 56/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8617 - loss: 0.3723 - val_accuracy: 0.6797 - val_loss: 0.8522
# Epoch 57/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8629 - loss: 0.3702 - val_accuracy: 0.6810 - val_loss: 0.8465
# Epoch 58/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8646 - loss: 0.3665 - val_accuracy: 0.6781 - val_loss: 0.8726
# Epoch 59/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8649 - loss: 0.3653 - val_accuracy: 0.6766 - val_loss: 0.8724
# Epoch 60/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8665 - loss: 0.3626 - val_accuracy: 0.6780 - val_loss: 0.8782
# Epoch 61/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8672 - loss: 0.3602 - val_accuracy: 0.6788 - val_loss: 0.8787
# Epoch 62/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8682 - loss: 0.3578 - val_accuracy: 0.6784 - val_loss: 0.8820
# Epoch 63/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8693 - loss: 0.3550 - val_accuracy: 0.6771 - val_loss: 0.8937
# Epoch 64/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8701 - loss: 0.3530 - val_accuracy: 0.6779 - val_loss: 0.8818
# Epoch 65/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8710 - loss: 0.3514 - val_accuracy: 0.6772 - val_loss: 0.8923
# Epoch 66/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8717 - loss: 0.3495 - val_accuracy: 0.6767 - val_loss: 0.8944
# Epoch 67/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8732 - loss: 0.3465 - val_accuracy: 0.6757 - val_loss: 0.9128
# Epoch 68/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8728 - loss: 0.3450 - val_accuracy: 0.6752 - val_loss: 0.9188
# Epoch 69/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8743 - loss: 0.3428 - val_accuracy: 0.6753 - val_loss: 0.9126
# Epoch 70/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8751 - loss: 0.3401 - val_accuracy: 0.6708 - val_loss: 0.9316
# Epoch 71/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8759 - loss: 0.3382 - val_accuracy: 0.6696 - val_loss: 0.9319
# Epoch 72/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8775 - loss: 0.3365 - val_accuracy: 0.6744 - val_loss: 0.9363
# Epoch 73/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8772 - loss: 0.3354 - val_accuracy: 0.6724 - val_loss: 0.9361
# Epoch 74/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8781 - loss: 0.3331 - val_accuracy: 0.6695 - val_loss: 0.9476
# Epoch 75/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8795 - loss: 0.3305 - val_accuracy: 0.6740 - val_loss: 0.9272
# Epoch 76/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8801 - loss: 0.3289 - val_accuracy: 0.6708 - val_loss: 0.9506
# Epoch 77/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8808 - loss: 0.3270 - val_accuracy: 0.6707 - val_loss: 0.9583
# Epoch 78/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.8807 - loss: 0.3256 - val_accuracy: 0.6707 - val_loss: 0.9515
# Epoch 79/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8813 - loss: 0.3243 - val_accuracy: 0.6681 - val_loss: 0.9708
# Epoch 80/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8830 - loss: 0.3213 - val_accuracy: 0.6712 - val_loss: 0.9706
# Epoch 81/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8831 - loss: 0.3197 - val_accuracy: 0.6711 - val_loss: 0.9632
# Epoch 82/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8829 - loss: 0.3191 - val_accuracy: 0.6672 - val_loss: 0.9796
# Epoch 83/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8839 - loss: 0.3173 - val_accuracy: 0.6692 - val_loss: 0.9768
# Epoch 84/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8850 - loss: 0.3149 - val_accuracy: 0.6672 - val_loss: 0.9998
# Epoch 85/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8862 - loss: 0.3128 - val_accuracy: 0.6704 - val_loss: 0.9812
# Epoch 86/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8870 - loss: 0.3112 - val_accuracy: 0.6707 - val_loss: 0.9791
# Epoch 87/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8869 - loss: 0.3102 - val_accuracy: 0.6750 - val_loss: 0.9886
# Epoch 88/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8875 - loss: 0.3094 - val_accuracy: 0.6694 - val_loss: 0.9959
# Epoch 89/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8885 - loss: 0.3070 - val_accuracy: 0.6687 - val_loss: 0.9819
# Epoch 90/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8887 - loss: 0.3055 - val_accuracy: 0.6693 - val_loss: 1.0015
# Epoch 91/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8890 - loss: 0.3046 - val_accuracy: 0.6681 - val_loss: 1.0058
# Epoch 92/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8898 - loss: 0.3031 - val_accuracy: 0.6667 - val_loss: 1.0217
# Epoch 93/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8907 - loss: 0.3010 - val_accuracy: 0.6683 - val_loss: 1.0181
# Epoch 94/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8906 - loss: 0.3007 - val_accuracy: 0.6702 - val_loss: 1.0079
# Epoch 95/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8922 - loss: 0.2980 - val_accuracy: 0.6656 - val_loss: 0.9950
# Epoch 96/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8922 - loss: 0.2976 - val_accuracy: 0.6687 - val_loss: 1.0039
# Epoch 97/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8931 - loss: 0.2952 - val_accuracy: 0.6641 - val_loss: 1.0226
# Epoch 98/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8940 - loss: 0.2938 - val_accuracy: 0.6662 - val_loss: 1.0379
# Epoch 99/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8939 - loss: 0.2934 - val_accuracy: 0.6651 - val_loss: 1.0406
# Epoch 100/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8944 - loss: 0.2906 - val_accuracy: 0.6645 - val_loss: 1.0173
# Epoch 101/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8955 - loss: 0.2897 - val_accuracy: 0.6688 - val_loss: 1.0369
# Epoch 102/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8956 - loss: 0.2890 - val_accuracy: 0.6650 - val_loss: 1.0619
# Epoch 103/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8962 - loss: 0.2878 - val_accuracy: 0.6671 - val_loss: 1.0421
# Epoch 104/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8960 - loss: 0.2866 - val_accuracy: 0.6653 - val_loss: 1.0600
# Epoch 105/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8962 - loss: 0.2860 - val_accuracy: 0.6636 - val_loss: 1.0650
# Epoch 106/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8977 - loss: 0.2837 - val_accuracy: 0.6649 - val_loss: 1.0482
# Epoch 107/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8976 - loss: 0.2831 - val_accuracy: 0.6657 - val_loss: 1.0521
# Epoch 108/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8986 - loss: 0.2806 - val_accuracy: 0.6648 - val_loss: 1.0830
# Epoch 109/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8986 - loss: 0.2803 - val_accuracy: 0.6611 - val_loss: 1.0993
# Epoch 110/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8993 - loss: 0.2783 - val_accuracy: 0.6649 - val_loss: 1.0965
# Epoch 111/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9001 - loss: 0.2779 - val_accuracy: 0.6610 - val_loss: 1.0878
# Epoch 112/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9003 - loss: 0.2760 - val_accuracy: 0.6634 - val_loss: 1.0988
# Epoch 113/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.8999 - loss: 0.2764 - val_accuracy: 0.6598 - val_loss: 1.1070
# Epoch 114/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9010 - loss: 0.2749 - val_accuracy: 0.6602 - val_loss: 1.1067
# Epoch 115/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9013 - loss: 0.2734 - val_accuracy: 0.6673 - val_loss: 1.0955
# Epoch 116/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9021 - loss: 0.2722 - val_accuracy: 0.6610 - val_loss: 1.1337
# Epoch 117/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9023 - loss: 0.2714 - val_accuracy: 0.6623 - val_loss: 1.1074
# Epoch 118/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9017 - loss: 0.2715 - val_accuracy: 0.6580 - val_loss: 1.1257
# Epoch 119/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9031 - loss: 0.2683 - val_accuracy: 0.6585 - val_loss: 1.1434
# Epoch 120/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9037 - loss: 0.2672 - val_accuracy: 0.6598 - val_loss: 1.1346
# Epoch 121/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9041 - loss: 0.2669 - val_accuracy: 0.6589 - val_loss: 1.1569
# Epoch 122/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9042 - loss: 0.2661 - val_accuracy: 0.6597 - val_loss: 1.1469
# Epoch 123/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9043 - loss: 0.2646 - val_accuracy: 0.6599 - val_loss: 1.1176
# Epoch 124/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9053 - loss: 0.2637 - val_accuracy: 0.6589 - val_loss: 1.1593
# Epoch 125/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9052 - loss: 0.2625 - val_accuracy: 0.6602 - val_loss: 1.1506
# Epoch 126/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9059 - loss: 0.2613 - val_accuracy: 0.6610 - val_loss: 1.1478
# Epoch 127/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9059 - loss: 0.2610 - val_accuracy: 0.6605 - val_loss: 1.1420
# Epoch 128/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.9060 - loss: 0.2609 - val_accuracy: 0.6575 - val_loss: 1.1759
# Epoch 129/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.9076 - loss: 0.2579 - val_accuracy: 0.6585 - val_loss: 1.1756
# Epoch 130/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.9066 - loss: 0.2586 - val_accuracy: 0.6569 - val_loss: 1.1773
# Epoch 131/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9069 - loss: 0.2577 - val_accuracy: 0.6577 - val_loss: 1.1533
# Epoch 132/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9082 - loss: 0.2554 - val_accuracy: 0.6577 - val_loss: 1.1735
# Epoch 133/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9082 - loss: 0.2552 - val_accuracy: 0.6594 - val_loss: 1.1756
# Epoch 134/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9088 - loss: 0.2538 - val_accuracy: 0.6573 - val_loss: 1.1861
# Epoch 135/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9085 - loss: 0.2541 - val_accuracy: 0.6561 - val_loss: 1.1988
# Epoch 136/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9095 - loss: 0.2512 - val_accuracy: 0.6514 - val_loss: 1.2328
# Epoch 137/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9100 - loss: 0.2502 - val_accuracy: 0.6525 - val_loss: 1.2282
# Epoch 138/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9096 - loss: 0.2514 - val_accuracy: 0.6550 - val_loss: 1.2007
# Epoch 139/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9102 - loss: 0.2500 - val_accuracy: 0.6592 - val_loss: 1.1989
# Epoch 140/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9106 - loss: 0.2485 - val_accuracy: 0.6581 - val_loss: 1.2145
# Epoch 141/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9114 - loss: 0.2470 - val_accuracy: 0.6562 - val_loss: 1.2201
# Epoch 142/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9113 - loss: 0.2471 - val_accuracy: 0.6545 - val_loss: 1.2377
# Epoch 143/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9116 - loss: 0.2458 - val_accuracy: 0.6564 - val_loss: 1.2070
# Epoch 144/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9114 - loss: 0.2474 - val_accuracy: 0.6583 - val_loss: 1.2070
# Epoch 145/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9123 - loss: 0.2434 - val_accuracy: 0.6543 - val_loss: 1.2291
# Epoch 146/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9128 - loss: 0.2430 - val_accuracy: 0.6554 - val_loss: 1.2330
# Epoch 147/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9133 - loss: 0.2414 - val_accuracy: 0.6532 - val_loss: 1.2373
# Epoch 148/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9127 - loss: 0.2413 - val_accuracy: 0.6526 - val_loss: 1.2440
# Epoch 149/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9145 - loss: 0.2391 - val_accuracy: 0.6516 - val_loss: 1.2679
# Epoch 150/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9140 - loss: 0.2398 - val_accuracy: 0.6539 - val_loss: 1.2180
# Epoch 151/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9138 - loss: 0.2395 - val_accuracy: 0.6572 - val_loss: 1.2525
# Epoch 152/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9146 - loss: 0.2382 - val_accuracy: 0.6499 - val_loss: 1.2940
# Epoch 153/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9155 - loss: 0.2363 - val_accuracy: 0.6528 - val_loss: 1.2466
# Epoch 154/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9151 - loss: 0.2372 - val_accuracy: 0.6520 - val_loss: 1.2621
# Epoch 155/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9155 - loss: 0.2361 - val_accuracy: 0.6546 - val_loss: 1.2581
# Epoch 156/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9154 - loss: 0.2347 - val_accuracy: 0.6541 - val_loss: 1.2389
# Epoch 157/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9159 - loss: 0.2336 - val_accuracy: 0.6532 - val_loss: 1.2737
# Epoch 158/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9156 - loss: 0.2334 - val_accuracy: 0.6529 - val_loss: 1.2641
# Epoch 159/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9164 - loss: 0.2332 - val_accuracy: 0.6534 - val_loss: 1.2561
# Epoch 160/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9162 - loss: 0.2331 - val_accuracy: 0.6528 - val_loss: 1.2907
# Epoch 161/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9168 - loss: 0.2310 - val_accuracy: 0.6525 - val_loss: 1.2767
# Epoch 162/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9169 - loss: 0.2306 - val_accuracy: 0.6519 - val_loss: 1.2895
# Epoch 163/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9170 - loss: 0.2309 - val_accuracy: 0.6514 - val_loss: 1.2760
# Epoch 164/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9177 - loss: 0.2289 - val_accuracy: 0.6488 - val_loss: 1.2916
# Epoch 165/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9181 - loss: 0.2282 - val_accuracy: 0.6521 - val_loss: 1.2777
# Epoch 166/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9182 - loss: 0.2274 - val_accuracy: 0.6539 - val_loss: 1.2538
# Epoch 167/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9183 - loss: 0.2275 - val_accuracy: 0.6568 - val_loss: 1.2479
# Epoch 168/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9185 - loss: 0.2256 - val_accuracy: 0.6539 - val_loss: 1.2606
# Epoch 169/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9189 - loss: 0.2243 - val_accuracy: 0.6524 - val_loss: 1.2912
# Epoch 170/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9192 - loss: 0.2237 - val_accuracy: 0.6501 - val_loss: 1.3072
# Epoch 171/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9193 - loss: 0.2243 - val_accuracy: 0.6533 - val_loss: 1.2740
# Epoch 172/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9195 - loss: 0.2220 - val_accuracy: 0.6525 - val_loss: 1.3032
# Epoch 173/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9195 - loss: 0.2228 - val_accuracy: 0.6563 - val_loss: 1.2624
# Epoch 174/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9203 - loss: 0.2216 - val_accuracy: 0.6492 - val_loss: 1.3344
# Epoch 175/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9209 - loss: 0.2209 - val_accuracy: 0.6541 - val_loss: 1.3042
# Epoch 176/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9206 - loss: 0.2204 - val_accuracy: 0.6498 - val_loss: 1.3360
# Epoch 177/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9211 - loss: 0.2199 - val_accuracy: 0.6521 - val_loss: 1.3449
# Epoch 178/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9211 - loss: 0.2193 - val_accuracy: 0.6458 - val_loss: 1.3301
# Epoch 179/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9212 - loss: 0.2187 - val_accuracy: 0.6476 - val_loss: 1.3179
# Epoch 180/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9218 - loss: 0.2172 - val_accuracy: 0.6476 - val_loss: 1.3448
# Epoch 181/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9218 - loss: 0.2168 - val_accuracy: 0.6484 - val_loss: 1.3084
# Epoch 182/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9230 - loss: 0.2146 - val_accuracy: 0.6444 - val_loss: 1.3606
# Epoch 183/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9224 - loss: 0.2155 - val_accuracy: 0.6478 - val_loss: 1.3282
# Epoch 184/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9227 - loss: 0.2139 - val_accuracy: 0.6454 - val_loss: 1.3651
# Epoch 185/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9229 - loss: 0.2131 - val_accuracy: 0.6500 - val_loss: 1.3309
# Epoch 186/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9230 - loss: 0.2133 - val_accuracy: 0.6521 - val_loss: 1.3083
# Epoch 187/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9224 - loss: 0.2144 - val_accuracy: 0.6470 - val_loss: 1.3466
# Epoch 188/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9236 - loss: 0.2123 - val_accuracy: 0.6487 - val_loss: 1.3364
# Epoch 189/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9235 - loss: 0.2112 - val_accuracy: 0.6472 - val_loss: 1.3475
# Epoch 190/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9230 - loss: 0.2123 - val_accuracy: 0.6467 - val_loss: 1.3340
# Epoch 191/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9245 - loss: 0.2100 - val_accuracy: 0.6511 - val_loss: 1.3350
# Epoch 192/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9245 - loss: 0.2092 - val_accuracy: 0.6472 - val_loss: 1.3788
# Epoch 193/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9246 - loss: 0.2091 - val_accuracy: 0.6487 - val_loss: 1.3637
# Epoch 194/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9247 - loss: 0.2083 - val_accuracy: 0.6489 - val_loss: 1.3752
# Epoch 195/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9248 - loss: 0.2081 - val_accuracy: 0.6505 - val_loss: 1.3602
# Epoch 196/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9251 - loss: 0.2074 - val_accuracy: 0.6453 - val_loss: 1.3939
# Epoch 197/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9251 - loss: 0.2069 - val_accuracy: 0.6473 - val_loss: 1.3565
# Epoch 198/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9256 - loss: 0.2065 - val_accuracy: 0.6476 - val_loss: 1.3468
# Epoch 199/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9251 - loss: 0.2068 - val_accuracy: 0.6495 - val_loss: 1.3508
# Epoch 200/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.9265 - loss: 0.2038 - val_accuracy: 0.6500 - val_loss: 1.3600

# %%
print(accuracy_score(np.argmax(testY_CNN, axis=1), np.argmax(model.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step
# 0.7296039802707043

# %%
print(classification_report(np.argmax(testY_CNN, axis=1), np.argmax(model.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72     47915
#            1       0.77      0.75      0.76     48050
#            2       0.69      0.73      0.71     43523
#
#     accuracy                           0.73    139488
#    macro avg       0.73      0.73      0.73    139488
# weighted avg       0.73      0.73      0.73    139488

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = model.predict(testX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(testY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step

# %%
print(accuracy_score(np.argmax(trainY_CNN, axis=1), np.argmax(model.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step
# 0.9278157691911183

# %%
print(classification_report(np.argmax(trainY_CNN, axis=1), np.argmax(model.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94     84426
#            1       0.89      0.87      0.88     36210
#            2       0.93      0.95      0.94     83065
#
#     accuracy                           0.93    203701
#    macro avg       0.92      0.92      0.92    203701
# weighted avg       0.93      0.93      0.93    203701

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = model.predict(trainX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(trainY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TEST DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = model.predict(testX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    """
    Implements trading strategy using the FI-2010 paper's methodology

    Args:
        predictions: numpy array of model predictions (n_samples, 3)
        dec_data: numpy array of decoded price data
        budget: amount to invest per trade
        prob_threshold: probability threshold for trading
        k: prediction horizon (number of steps to look ahead)
        alpha: threshold for determining price movement direction
    """
    # Get normalized ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        # Calculate m+ (future average) according to paper
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        # Calculate actual price movement using paper's method
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:  # not stable
            # Determine actual direction using same threshold as training
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)

            # Long trade (UP prediction)
            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })

            # Short trade (DOWN prediction)
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        # Print performance metrics
        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_test,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 73771
# Win rate: 0.49%
# Total profit: $630.01
# Average profit per trade: $0.0085
#
# Direction Analysis:
#
# UP trades:
# Count: 36774
# Win rate: 0.49%
# Total profit: $535.25
# Average profit: $0.0146
#
# DOWN trades:
# Count: 36997
# Win rate: 0.49%
# Total profit: $94.75
# Average profit: $0.0026
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 70203
# Win rate: 0.49%
# Total profit: $627.76
# Average profit per trade: $0.0089
#
# Direction Analysis:
#
# UP trades:
# Count: 34948
# Win rate: 0.49%
# Total profit: $533.51
# Average profit: $0.0153
#
# DOWN trades:
# Count: 35255
# Win rate: 0.49%
# Total profit: $94.25
# Average profit: $0.0027
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 65635
# Win rate: 0.48%
# Total profit: $621.17
# Average profit per trade: $0.0095
#
# Direction Analysis:
#
# UP trades:
# Count: 32639
# Win rate: 0.47%
# Total profit: $538.88
# Average profit: $0.0165
#
# DOWN trades:
# Count: 32996
# Win rate: 0.49%
# Total profit: $82.29
# Average profit: $0.0025
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 58554
# Win rate: 0.48%
# Total profit: $624.41
# Average profit per trade: $0.0107
#
# Direction Analysis:
#
# UP trades:
# Count: 29059
# Win rate: 0.45%
# Total profit: $518.85
# Average profit: $0.0179
#
# DOWN trades:
# Count: 29495
# Win rate: 0.50%
# Total profit: $105.55
# Average profit: $0.0036
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 43936
# Win rate: 0.49%
# Total profit: $615.39
# Average profit per trade: $0.0140
#
# Direction Analysis:
#
# UP trades:
# Count: 21784
# Win rate: 0.48%
# Total profit: $496.12
# Average profit: $0.0228
#
# DOWN trades:
# Count: 22152
# Win rate: 0.50%
# Total profit: $119.26
# Average profit: $0.0054
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000    630.007241       73771  0.489352    0.008540        36774
# 1   0.850000    627.761172       70203  0.491432    0.008942        34948
# 2   0.900000    621.168214       65635  0.479927    0.009464        32639
# 3   0.950000    624.405101       58554  0.476483    0.010664        29059
# 4   0.990000    615.385416       43936  0.489348    0.014006        21784
#
#    short_trades
# 0         36997
# 1         35255
# 2         32996
# 3         29495
# 4         22152

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TRAIN DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = model.predict(trainX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    """
    Implements trading strategy using the FI-2010 paper's methodology

    Args:
        predictions: numpy array of model predictions (n_samples, 3)
        dec_data: numpy array of decoded price data
        budget: amount to invest per trade
        prob_threshold: probability threshold for trading
        k: prediction horizon (number of steps to look ahead)
        alpha: threshold for determining price movement direction
    """
    # Get normalized ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        # Calculate m+ (future average) according to paper
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        # Calculate actual price movement using paper's method
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:  # not stable
            # Determine actual direction using same threshold as training
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)

            # Long trade (UP prediction)
            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })

            # Short trade (DOWN prediction)
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        # Print performance metrics
        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_train,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 146904
# Win rate: 0.70%
# Total profit: $-305.67
# Average profit per trade: $-0.0021
#
# Direction Analysis:
#
# UP trades:
# Count: 74317
# Win rate: 0.72%
# Total profit: $39.90
# Average profit: $0.0005
#
# DOWN trades:
# Count: 72587
# Win rate: 0.69%
# Total profit: $-345.57
# Average profit: $-0.0048
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 142318
# Win rate: 0.71%
# Total profit: $-305.60
# Average profit per trade: $-0.0021
#
# Direction Analysis:
#
# UP trades:
# Count: 72131
# Win rate: 0.72%
# Total profit: $40.58
# Average profit: $0.0006
#
# DOWN trades:
# Count: 70187
# Win rate: 0.69%
# Total profit: $-346.17
# Average profit: $-0.0049
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 135861
# Win rate: 0.71%
# Total profit: $-342.63
# Average profit per trade: $-0.0025
#
# Direction Analysis:
#
# UP trades:
# Count: 68977
# Win rate: 0.73%
# Total profit: $2.50
# Average profit: $0.0000
#
# DOWN trades:
# Count: 66884
# Win rate: 0.69%
# Total profit: $-345.13
# Average profit: $-0.0052
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 125013
# Win rate: 0.70%
# Total profit: $-298.67
# Average profit per trade: $-0.0024
#
# Direction Analysis:
#
# UP trades:
# Count: 63724
# Win rate: 0.73%
# Total profit: $48.28
# Average profit: $0.0008
#
# DOWN trades:
# Count: 61289
# Win rate: 0.67%
# Total profit: $-346.95
# Average profit: $-0.0057
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 99231
# Win rate: 0.70%
# Total profit: $-322.65
# Average profit per trade: $-0.0033
#
# Direction Analysis:
#
# UP trades:
# Count: 51214
# Win rate: 0.71%
# Total profit: $26.47
# Average profit: $0.0005
#
# DOWN trades:
# Count: 48017
# Win rate: 0.69%
# Total profit: $-349.12
# Average profit: $-0.0073
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000   -305.668092      146904  0.702500   -0.002081        74317
# 1   0.850000   -305.595018      142318  0.707570   -0.002147        72131
# 2   0.900000   -342.633322      135861  0.707341   -0.002522        68977
# 3   0.950000   -298.668560      125013  0.702327   -0.002389        63724
# 4   0.990000   -322.652444       99231  0.700386   -0.003252        51214
#
#    short_trades
# 0         72587
# 1         70187
# 2         66884
# 3         61289
# 4         48017

# %%
def calculate_perturbation_volume(original, perturbed):
    original_flat = original.reshape(original.shape[0], -1)
    perturbed_flat = perturbed.reshape(perturbed.shape[0], -1)
    perturbation = np.linalg.norm(original_flat - perturbed_flat, ord=2, axis=1)
    avg_perturbation = np.mean(perturbation)
    return avg_perturbation

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
num_iterations = 5
step_size = 0.01

# Define your model
model = model

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def fgsm_attack(images, labels, epsilon):
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
    gradient = tape.gradient(loss, images)
    signed_grad = tf.sign(gradient)

    signed_masked = signed_grad.numpy()
    signed_masked[:, :99, :, :] = 0
    signed_masked[:, 99:, ::2, :] = 0
    signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

    perturbed_images = images + epsilon * signed_masked
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images
"""
with tf.GradientTape() as tape: automatically tracks operations for gradient calculation
tape.watch(images): Explicitly tells the gradient tape to watch the images tensor for gradient calculation
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions):
Calculates the loss between the true labels and the model's predictions
Uses categorical cross-entropy loss because this is a classification problem
from_logits=False indicates that the predictions are already probabilities (softmax has been applied)
gradient = tape.gradient(loss, images)
Calculates the gradient of the loss with respect to the input images
This tells us how to change the input to maximize the loss (i.e., make the model more likely to misclassify)
signed_grad = tf.sign(gradient)
Applies the sign function to the gradient to get the direction of the gradient
signed_masked[:, :99, :, :] = 0:
Sets the gradients for the first 99 time steps to zero
This ensures we only perturb the last time step (t=99), which is what the model primarily bases its prediction on
Within the last time step (t=99), this sets gradients for every other feature to zero
The ::2 slice is accessing only even indices, which likely correspond to price data in the LOB
This ensures we only perturb volume data and not price data, making the attack more realistic
signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32):
Converts the masked gradient signs back to a TensorFlow tensor for further operations
perturbed_images = images + epsilon * signed_masked:
Creates adversarial examples by adding the perturbation to the original images
The perturbation is the sign of the gradient scaled by epsilon
perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
Clips the perturbed values to ensure they stay within valid range [0,1]
"""
def pgd_attack(images, labels, epsilon, trainX_CNN, start_idx, end_idx):
    perturbed_images = tf.identity(images)

    for _ in range(num_iterations):
        # Gradient step
        with tf.GradientTape() as tape:
            tape.watch(perturbed_images)
            predictions = model(perturbed_images)
            loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
        gradient = tape.gradient(loss, perturbed_images)
        signed_grad = tf.sign(gradient)

        # Apply masking to gradient
        signed_masked = signed_grad.numpy()
        signed_masked[:, :99, :, :] = 0
        signed_masked[:, 99:, ::2, :] = 0
        signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

        # Apply gradient step
        perturbed_images = perturbed_images + step_size * signed_masked

        # Step 1: Apply volume constraint
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

    return perturbed_images

def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon, trainX_CNN, start_idx, end_idx)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)

    # Calculate and plot ROC curve
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 1e-06
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1e-06: 0.21351449275362316
# Average accuracy of FGSM attack for epsilon value 1e-06: 0.7090289855072464
# Average perturbation volume for PGD attack with epsilon 1e-06: 2.2691731452941895
# Average perturbation volume for FGSM attack with epsilon 1e-06: 4.471045485843206e-06
# Average precision of PGD attack for epsilon value 1e-06: 0.1738769755531976
# Average recall of PGD attack for epsilon value 1e-06: 0.21647593185366157
# Average precision of FGSM attack for epsilon value 1e-06: 0.7091753883063167
# Average recall of FGSM attack for epsilon value 1e-06: 0.7079729557536836
# ROC AUC of PGD attack for epsilon value 1e-06: 0.34572027336012184
# ROC AUC of FGSM attack for epsilon value 1e-06: 0.8572457211649179
#
# Classification Report for PGD Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27     47512
#            1       0.06      0.02      0.03     47269
#            2       0.22      0.32      0.26     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.17      0.22      0.19    138000
# weighted avg       0.17      0.21      0.18    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.73      0.66      0.69     47512
#            1       0.71      0.79      0.75     47269
#            2       0.70      0.67      0.68     43219
#
#     accuracy                           0.71    138000
#    macro avg       0.71      0.71      0.71    138000
# weighted avg       0.71      0.71      0.71    138000
#
# Epsilon value: 1e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1e-05: 0.21417391304347835
# Average accuracy of FGSM attack for epsilon value 1e-05: 0.7085434782608695
# Average perturbation volume for PGD attack with epsilon 1e-05: 2.2691729068756104
# Average perturbation volume for FGSM attack with epsilon 1e-05: 4.47205820819363e-05
# Average precision of PGD attack for epsilon value 1e-05: 0.17554952713890826
# Average recall of PGD attack for epsilon value 1e-05: 0.2171367046736703
# Average precision of FGSM attack for epsilon value 1e-05: 0.7086841564779917
# Average recall of FGSM attack for epsilon value 1e-05: 0.707488720504495
# ROC AUC of PGD attack for epsilon value 1e-05: 0.3463046092578371
# ROC AUC of FGSM attack for epsilon value 1e-05: 0.8568165203390199
#
# Classification Report for PGD Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27     47512
#            1       0.07      0.02      0.03     47269
#            2       0.22      0.32      0.26     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.18      0.22      0.19    138000
# weighted avg       0.17      0.21      0.19    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.73      0.66      0.69     47512
#            1       0.70      0.79      0.75     47269
#            2       0.69      0.67      0.68     43219
#
#     accuracy                           0.71    138000
#    macro avg       0.71      0.71      0.71    138000
# weighted avg       0.71      0.71      0.71    138000
#
# Epsilon value: 0.0001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.0001: 0.21390579710144927
# Average accuracy of FGSM attack for epsilon value 0.0001: 0.7038840579710145
# Average perturbation volume for PGD attack with epsilon 0.0001: 2.269170045852661
# Average perturbation volume for FGSM attack with epsilon 0.0001: 0.0004470630956348032
# Average precision of PGD attack for epsilon value 0.0001: 0.17458172543150252
# Average recall of PGD attack for epsilon value 0.0001: 0.21687299912224114
# Average precision of FGSM attack for epsilon value 0.0001: 0.7039187031008401
# Average recall of FGSM attack for epsilon value 0.0001: 0.702844169297436
# ROC AUC of PGD attack for epsilon value 0.0001: 0.34607963298075617
# ROC AUC of FGSM attack for epsilon value 0.0001: 0.8525583611859016
#
# Classification Report for PGD Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27     47512
#            1       0.06      0.02      0.03     47269
#            2       0.22      0.32      0.26     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.17      0.22      0.19    138000
# weighted avg       0.17      0.21      0.18    138000
#
#
# Classification Report for FGSM Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.72      0.65      0.69     47512
#            1       0.70      0.79      0.74     47269
#            2       0.69      0.66      0.68     43219
#
#     accuracy                           0.70    138000
#    macro avg       0.70      0.70      0.70    138000
# weighted avg       0.70      0.70      0.70    138000
#
# Epsilon value: 0.001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.001: 0.21346376811594195
# Average accuracy of FGSM attack for epsilon value 0.001: 0.6603695652173912
# Average perturbation volume for PGD attack with epsilon 0.001: 2.2691659927368164
# Average perturbation volume for FGSM attack with epsilon 0.001: 0.004455724731087685
# Average precision of PGD attack for epsilon value 0.001: 0.17436422932581097
# Average recall of PGD attack for epsilon value 0.001: 0.21640479802089088
# Average precision of FGSM attack for epsilon value 0.001: 0.6594741947604313
# Average recall of FGSM attack for epsilon value 0.001: 0.659627750493494
# ROC AUC of PGD attack for epsilon value 0.001: 0.34597901920652396
# ROC AUC of FGSM attack for epsilon value 0.001: 0.8117262999937245
#
# Classification Report for PGD Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27     47512
#            1       0.06      0.02      0.03     47269
#            2       0.22      0.32      0.26     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.17      0.22      0.19    138000
# weighted avg       0.17      0.21      0.18    138000
#
#
# Classification Report for FGSM Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.64     47512
#            1       0.67      0.73      0.70     47269
#            2       0.64      0.63      0.64     43219
#
#     accuracy                           0.66    138000
#    macro avg       0.66      0.66      0.66    138000
# weighted avg       0.66      0.66      0.66    138000

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.01, 0.1, 1, 10]
num_iterations = 5
step_size = 0.01

# Define your model
model = model

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def fgsm_attack(images, labels, epsilon):
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
    gradient = tape.gradient(loss, images)
    signed_grad = tf.sign(gradient)

    signed_masked = signed_grad.numpy()
    signed_masked[:, :99, :, :] = 0
    signed_masked[:, 99:, ::2, :] = 0
    signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

    perturbed_images = images + epsilon * signed_masked
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images

def pgd_attack(images, labels, epsilon, trainX_CNN, start_idx, end_idx):
    perturbed_images = tf.identity(images)

    for _ in range(num_iterations):
        # Gradient step
        with tf.GradientTape() as tape:
            tape.watch(perturbed_images)
            predictions = model(perturbed_images)
            loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
        gradient = tape.gradient(loss, perturbed_images)
        signed_grad = tf.sign(gradient)

        # Apply masking to gradient
        signed_masked = signed_grad.numpy()
        signed_masked[:, :99, :, :] = 0
        signed_masked[:, 99:, ::2, :] = 0
        signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

        # Apply gradient step
        perturbed_images = perturbed_images + step_size * signed_masked

        # Step 1: Apply volume constraint
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

        # Step 2: Apply L2 norm constraint (projection step)
        delta = perturbed_images - images  # Calculate current perturbation

        # Reshape to flatten all dimensions except batch
        delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

        # Calculate L2 norm on the flattened dimensions
        norm = tf.norm(delta_flat, axis=1, keepdims=True)

        # Reshape norm for broadcasting
        norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

        # Scale perturbation
        scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
        delta = delta * scaling

        perturbed_images = images + delta  # Apply constrained perturbation

        # Step 3: Apply clipping to valid range [0,1]
        perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

        # Step 4: Re-apply volume constraint after all other constraints
        # This ensures volume constraint takes precedence if there's a conflict
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

    return perturbed_images

def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon, trainX_CNN, start_idx, end_idx)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)

    # Calculate and plot ROC curve
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 0.01
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.01: 0.473891304347826
# Average accuracy of FGSM attack for epsilon value 0.01: 0.477195652173913
# Average perturbation volume for PGD attack with epsilon 0.01: 2.2640035152435303
# Average perturbation volume for FGSM attack with epsilon 0.01: 0.040287889540195465
# Average precision of PGD attack for epsilon value 0.01: 0.4800315512013335
# Average recall of PGD attack for epsilon value 0.01: 0.4753890841875748
# Average precision of FGSM attack for epsilon value 0.01: 0.4905785735230088
# Average recall of FGSM attack for epsilon value 0.01: 0.48129872154167036
# ROC AUC of PGD attack for epsilon value 0.01: 0.6281976213639232
# ROC AUC of FGSM attack for epsilon value 0.01: 0.6742355039764945
#
# Classification Report for PGD Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.47      0.51      0.49     47512
#            1       0.53      0.38      0.45     47269
#            2       0.44      0.53      0.48     43219
#
#     accuracy                           0.47    138000
#    macro avg       0.48      0.48      0.47    138000
# weighted avg       0.48      0.47      0.47    138000
#
#
# Classification Report for FGSM Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.47      0.61      0.53     47512
#            1       0.54      0.21      0.30     47269
#            2       0.46      0.63      0.53     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.48      0.45    138000
# weighted avg       0.49      0.48      0.45    138000
#
# Epsilon value: 0.1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.1: 0.46493478260869575
# Average accuracy of FGSM attack for epsilon value 0.1: 0.4694927536231884
# Average perturbation volume for PGD attack with epsilon 0.1: 2.2640786170959473
# Average perturbation volume for FGSM attack with epsilon 0.1: 0.32431164383888245
# Average precision of PGD attack for epsilon value 0.1: 0.47154503354082716
# Average recall of PGD attack for epsilon value 0.1: 0.46642663301571924
# Average precision of FGSM attack for epsilon value 0.1: 0.47021369903871996
# Average recall of FGSM attack for epsilon value 0.1: 0.47618808185145084
# ROC AUC of PGD attack for epsilon value 0.1: 0.6197226134875166
# ROC AUC of FGSM attack for epsilon value 0.1: 0.647221753217643
#
# Classification Report for PGD Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.46      0.50      0.48     47512
#            1       0.52      0.38      0.44     47269
#            2       0.43      0.52      0.47     43219
#
#     accuracy                           0.46    138000
#    macro avg       0.47      0.47      0.46    138000
# weighted avg       0.47      0.46      0.46    138000
#
#
# Classification Report for FGSM Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.46      0.64      0.54     47512
#            1       0.47      0.07      0.13     47269
#            2       0.48      0.71      0.57     43219
#
#     accuracy                           0.47    138000
#    macro avg       0.47      0.48      0.41    138000
# weighted avg       0.47      0.47      0.41    138000
#
# Epsilon value: 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1: 0.36539130434782613
# Average accuracy of FGSM attack for epsilon value 1: 0.40353623188405807
# Average perturbation volume for PGD attack with epsilon 1: 2.2655630111694336
# Average perturbation volume for FGSM attack with epsilon 1: 3.050981044769287
# Average precision of PGD attack for epsilon value 1: 0.37500409357064507
# Average recall of PGD attack for epsilon value 1: 0.3673053238861383
# Average precision of FGSM attack for epsilon value 1: 0.4469429794828874
# Average recall of FGSM attack for epsilon value 1: 0.4111559657496471
# ROC AUC of PGD attack for epsilon value 1: 0.5161213880851068
# ROC AUC of FGSM attack for epsilon value 1: 0.5918549653132055
#
# Classification Report for PGD Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.36      0.42      0.39     47512
#            1       0.42      0.24      0.31     47269
#            2       0.34      0.44      0.38     43219
#
#     accuracy                           0.37    138000
#    macro avg       0.38      0.37      0.36    138000
# weighted avg       0.38      0.37      0.36    138000
#
#
# Classification Report for FGSM Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.41      0.48      0.45     47512
#            1       0.54      0.07      0.13     47269
#            2       0.39      0.68      0.49     43219
#
#     accuracy                           0.40    138000
#    macro avg       0.45      0.41      0.36    138000
# weighted avg       0.45      0.40      0.35    138000
#
# Epsilon value: 10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 10: 0.21362318840579708
# Average accuracy of FGSM attack for epsilon value 10: 0.4033623188405797
# Average perturbation volume for PGD attack with epsilon 10: 2.2691702842712402
# Average perturbation volume for FGSM attack with epsilon 10: 3.051870346069336
# Average precision of PGD attack for epsilon value 10: 0.17468685981916
# Average recall of PGD attack for epsilon value 10: 0.21656156024971293
# Average precision of FGSM attack for epsilon value 10: 0.44838273175129606
# Average recall of FGSM attack for epsilon value 10: 0.4109081434608268
# ROC AUC of PGD attack for epsilon value 10: 0.34574743266322716
# ROC AUC of FGSM attack for epsilon value 10: 0.5916549897956886
#
# Classification Report for PGD Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27     47512
#            1       0.07      0.02      0.03     47269
#            2       0.22      0.32      0.26     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.17      0.22      0.19    138000
# weighted avg       0.17      0.21      0.18    138000
#
#
# Classification Report for FGSM Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.41      0.48      0.45     47512
#            1       0.55      0.08      0.13     47269
#            2       0.38      0.67      0.49     43219
#
#     accuracy                           0.40    138000
#    macro avg       0.45      0.41      0.36    138000
# weighted avg       0.45      0.40      0.35    138000

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    # Define constants needed for PGD attack
    num_iterations = 5
    step_size = 0.01

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    def fgsm_attack(images, labels, epsilon):
        """Implement FGSM attack"""
        try:
            with tf.GradientTape() as tape:
                tape.watch(images)
                predictions = model(images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy()(labels, predictions)

            gradient = tape.gradient(loss, images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = images + epsilon * signed_masked
            return tf.clip_by_value(perturbed_images, 0, 1)
        except Exception as e:
            print(f"Error in FGSM attack: {str(e)}")
            return None

    def pgd_attack(images, labels, epsilon, test_data, start_idx, end_idx):
        """Implement PGD attack with volume constraint"""
        perturbed_images = tf.identity(images)

        for _ in range(num_iterations):
            # Gradient step
            with tf.GradientTape() as tape:
                tape.watch(perturbed_images)
                predictions = model(perturbed_images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
            gradient = tape.gradient(loss, perturbed_images)
            signed_grad = tf.sign(gradient)

            # Apply masking to gradient
            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            # Apply gradient step
            perturbed_images = perturbed_images + step_size * signed_masked

            # Step 1: Apply volume constraint
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

            # Step 2: Apply L2 norm constraint (projection step)
            delta = perturbed_images - images  # Calculate current perturbation

            # Reshape to flatten all dimensions except batch
            delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

            # Calculate L2 norm on the flattened dimensions
            norm = tf.norm(delta_flat, axis=1, keepdims=True)

            # Reshape norm for broadcasting
            norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

            # Scale perturbation
            scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
            delta = delta * scaling

            perturbed_images = images + delta  # Apply constrained perturbation

            # Step 3: Apply clipping to valid range [0,1]
            perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

            # Step 4: Re-apply volume constraint after all other constraints
            # This ensures volume constraint takes precedence if there's a conflict
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

        return perturbed_images

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon, testX_CNN, start_idx, end_idx)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=model,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 1e-06
# Batch 1/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 2/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 3/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 4/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 5/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 6/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 7/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 8/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 9/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 10/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 11/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 12/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 13/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 14/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 15/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 16/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 17/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 18/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 19/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 20/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 21/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 22/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 23/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 24/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 25/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 26/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 27/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 28/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 29/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 30/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 31/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 32/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 33/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 34/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 35/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 36/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 37/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 38/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 39/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 40/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 41/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 42/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 43/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 44/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 45/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 46/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 47/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 48/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 49/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 50/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 51/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 52/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 53/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 54/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 55/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 56/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 57/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 58/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 59/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 60/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 61/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 62/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 63/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 64/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 65/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 66/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 67/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 68/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 69/69 - PGD volume: 0.000001, FGSM volume: 0.000004
#
# Analyzing epsilon: 1e-05
# Batch 1/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 2/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 3/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 4/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 5/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 6/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 7/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 8/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 9/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 10/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 11/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 12/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 13/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 14/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 15/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 16/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 17/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 18/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 19/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 20/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 21/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 22/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 23/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 24/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 25/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 26/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 27/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 28/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 29/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 30/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 31/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 32/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 33/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 34/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 35/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 36/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 37/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 38/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 39/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 40/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 41/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 42/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 43/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 44/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 45/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 46/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 47/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 48/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 49/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 50/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 51/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 52/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 53/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 54/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 55/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 56/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 57/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 58/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 59/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 60/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 61/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 62/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 63/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 64/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 65/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 66/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 67/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 68/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 69/69 - PGD volume: 0.000010, FGSM volume: 0.000045
#
# Analyzing epsilon: 0.0001
# Batch 1/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 2/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 3/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 4/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 5/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 6/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 7/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 8/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 9/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 10/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 11/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 12/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 13/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 14/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 15/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 16/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 17/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 18/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 19/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 20/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 21/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 22/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 23/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 24/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 25/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 26/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 27/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 28/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 29/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 30/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 31/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 32/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 33/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 34/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 35/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 36/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 37/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 38/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 39/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 40/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 41/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 42/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 43/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 44/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 45/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 46/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 47/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 48/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 49/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 50/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 51/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 52/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 53/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 54/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 55/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 56/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 57/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 58/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 59/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 60/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 61/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 62/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 63/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 64/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 65/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 66/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 67/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 68/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 69/69 - PGD volume: 0.000100, FGSM volume: 0.000447
#
# Analyzing epsilon: 0.001
# Batch 1/69 - PGD volume: 0.001000, FGSM volume: 0.004378
# Batch 2/69 - PGD volume: 0.001000, FGSM volume: 0.004449
# Batch 3/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 4/69 - PGD volume: 0.001000, FGSM volume: 0.004463
# Batch 5/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 6/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 7/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 8/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 9/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 10/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 11/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 12/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 13/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 14/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 15/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 16/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 17/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 18/69 - PGD volume: 0.001000, FGSM volume: 0.004461
# Batch 19/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 20/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 21/69 - PGD volume: 0.001000, FGSM volume: 0.004454
# Batch 22/69 - PGD volume: 0.001000, FGSM volume: 0.004433
# Batch 23/69 - PGD volume: 0.001000, FGSM volume: 0.004454
# Batch 24/69 - PGD volume: 0.001000, FGSM volume: 0.004445
# Batch 25/69 - PGD volume: 0.001000, FGSM volume: 0.004439
# Batch 26/69 - PGD volume: 0.001000, FGSM volume: 0.004461
# Batch 27/69 - PGD volume: 0.001000, FGSM volume: 0.004446
# Batch 28/69 - PGD volume: 0.001000, FGSM volume: 0.004428
# Batch 29/69 - PGD volume: 0.001000, FGSM volume: 0.004406
# Batch 30/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 31/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 32/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 33/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 34/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 35/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 36/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 37/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 38/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 39/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 40/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 41/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 42/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 43/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 44/69 - PGD volume: 0.001000, FGSM volume: 0.004460
# Batch 45/69 - PGD volume: 0.001000, FGSM volume: 0.004446
# Batch 46/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 47/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 48/69 - PGD volume: 0.001000, FGSM volume: 0.004433
# Batch 49/69 - PGD volume: 0.001000, FGSM volume: 0.004438
# Batch 50/69 - PGD volume: 0.001000, FGSM volume: 0.004416
# Batch 51/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 52/69 - PGD volume: 0.001000, FGSM volume: 0.004444
# Batch 53/69 - PGD volume: 0.001000, FGSM volume: 0.004458
# Batch 54/69 - PGD volume: 0.001000, FGSM volume: 0.004454
# Batch 55/69 - PGD volume: 0.001000, FGSM volume: 0.004401
# Batch 56/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 57/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 58/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 59/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 60/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 61/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 62/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 63/69 - PGD volume: 0.001000, FGSM volume: 0.004460
# Batch 64/69 - PGD volume: 0.001000, FGSM volume: 0.004457
# Batch 65/69 - PGD volume: 0.001000, FGSM volume: 0.004452
# Batch 66/69 - PGD volume: 0.001000, FGSM volume: 0.004461
# Batch 67/69 - PGD volume: 0.001000, FGSM volume: 0.004454
# Batch 68/69 - PGD volume: 0.001000, FGSM volume: 0.004446
# Batch 69/69 - PGD volume: 0.001000, FGSM volume: 0.004443
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         787.2672  64438.0000    0.4919
# 0.9000         745.6298  60171.0000    0.4770
# 0.9500         535.8806  53870.0000    0.4734
# 0.9900          39.1804  40710.0000    0.4643
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         787.1434  64442.0000    0.4919
# 0.9000         745.6177  60172.0000    0.4770
# 0.9500         535.7932  53864.0000    0.4734
# 0.9900          39.1427  40702.0000    0.4644
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         786.9605  64430.0000    0.4920
# 0.9000         746.2734  60151.0000    0.4788
# 0.9500         535.6702  53857.0000    0.4735
# 0.9900          38.9578  40684.0000    0.4646
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         787.4340  64306.0000    0.4883
# 0.9000         834.9199  60071.0000    0.4811
# 0.9500         400.7998  53643.0000    0.4735
# 0.9900          14.8320  40378.0000    0.4681
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         787.1434  64444.0000    0.4919
# 0.9000         745.6514  60176.0000    0.4769
# 0.9500         535.8241  53868.0000    0.4734
# 0.9900          39.2152  40709.0000    0.4643
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         786.8115  64438.0000    0.4919
# 0.9000         746.2072  60158.0000    0.4787
# 0.9500         535.7470  53864.0000    0.4734
# 0.9900          39.1277  40695.0000    0.4644
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         788.1981  64372.0000    0.4909
# 0.9000         746.4536  60082.0000    0.4760
# 0.9500         536.6890  53715.0000    0.4729
# 0.9900          40.2747  40490.0000    0.4643
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         631.7744  65291.0000    0.4825
# 0.9000         468.1413  60673.0000    0.4747
# 0.9500         227.6844  53569.0000    0.4555
# 0.9900          16.1968  39333.0000    0.4525

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    # Define constants needed for PGD attack
    num_iterations = 5
    step_size = 0.01

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    def fgsm_attack(images, labels, epsilon):
        """Implement FGSM attack"""
        try:
            with tf.GradientTape() as tape:
                tape.watch(images)
                predictions = model(images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy()(labels, predictions)

            gradient = tape.gradient(loss, images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = images + epsilon * signed_masked
            return tf.clip_by_value(perturbed_images, 0, 1)
        except Exception as e:
            print(f"Error in FGSM attack: {str(e)}")
            return None

    def pgd_attack(images, labels, epsilon, test_data, start_idx, end_idx):
        """Implement PGD attack with volume constraint"""
        perturbed_images = tf.identity(images)

        for _ in range(num_iterations):
            # Gradient step
            with tf.GradientTape() as tape:
                tape.watch(perturbed_images)
                predictions = model(perturbed_images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
            gradient = tape.gradient(loss, perturbed_images)
            signed_grad = tf.sign(gradient)

            # Apply masking to gradient
            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            # Apply gradient step
            perturbed_images = perturbed_images + step_size * signed_masked

            # Step 1: Apply volume constraint
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

            # Step 2: Apply L2 norm constraint (projection step)
            delta = perturbed_images - images  # Calculate current perturbation

            # Reshape to flatten all dimensions except batch
            delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

            # Calculate L2 norm on the flattened dimensions
            norm = tf.norm(delta_flat, axis=1, keepdims=True)

            # Reshape norm for broadcasting
            norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

            # Scale perturbation
            scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
            delta = delta * scaling

            perturbed_images = images + delta  # Apply constrained perturbation

            # Step 3: Apply clipping to valid range [0,1]
            perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

            # Step 4: Re-apply volume constraint after all other constraints
            # This ensures volume constraint takes precedence if there's a conflict
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

        return perturbed_images

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon, testX_CNN, start_idx, end_idx)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

epsilon_values = [0.01, 0.1, 1, 10]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=model,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 0.01
# Batch 1/69 - PGD volume: 0.010000, FGSM volume: 0.036027
# Batch 2/69 - PGD volume: 0.010000, FGSM volume: 0.040888
# Batch 3/69 - PGD volume: 0.010000, FGSM volume: 0.042967
# Batch 4/69 - PGD volume: 0.010000, FGSM volume: 0.042893
# Batch 5/69 - PGD volume: 0.010000, FGSM volume: 0.043251
# Batch 6/69 - PGD volume: 0.010000, FGSM volume: 0.043437
# Batch 7/69 - PGD volume: 0.010000, FGSM volume: 0.043841
# Batch 8/69 - PGD volume: 0.010000, FGSM volume: 0.043706
# Batch 9/69 - PGD volume: 0.010000, FGSM volume: 0.043584
# Batch 10/69 - PGD volume: 0.010000, FGSM volume: 0.043927
# Batch 11/69 - PGD volume: 0.010000, FGSM volume: 0.042918
# Batch 12/69 - PGD volume: 0.010000, FGSM volume: 0.043049
# Batch 13/69 - PGD volume: 0.010000, FGSM volume: 0.042523
# Batch 14/69 - PGD volume: 0.010000, FGSM volume: 0.043245
# Batch 15/69 - PGD volume: 0.010000, FGSM volume: 0.043069
# Batch 16/69 - PGD volume: 0.010000, FGSM volume: 0.043742
# Batch 17/69 - PGD volume: 0.010000, FGSM volume: 0.040403
# Batch 18/69 - PGD volume: 0.010000, FGSM volume: 0.036276
# Batch 19/69 - PGD volume: 0.010000, FGSM volume: 0.035864
# Batch 20/69 - PGD volume: 0.010000, FGSM volume: 0.035278
# Batch 21/69 - PGD volume: 0.010000, FGSM volume: 0.036215
# Batch 22/69 - PGD volume: 0.010000, FGSM volume: 0.035955
# Batch 23/69 - PGD volume: 0.010000, FGSM volume: 0.035290
# Batch 24/69 - PGD volume: 0.010000, FGSM volume: 0.037197
# Batch 25/69 - PGD volume: 0.010000, FGSM volume: 0.037284
# Batch 26/69 - PGD volume: 0.010000, FGSM volume: 0.036751
# Batch 27/69 - PGD volume: 0.010000, FGSM volume: 0.036095
# Batch 28/69 - PGD volume: 0.010000, FGSM volume: 0.035517
# Batch 29/69 - PGD volume: 0.010000, FGSM volume: 0.038482
# Batch 30/69 - PGD volume: 0.010000, FGSM volume: 0.043386
# Batch 31/69 - PGD volume: 0.010000, FGSM volume: 0.042588
# Batch 32/69 - PGD volume: 0.010000, FGSM volume: 0.043020
# Batch 33/69 - PGD volume: 0.010000, FGSM volume: 0.042371
# Batch 34/69 - PGD volume: 0.010000, FGSM volume: 0.043899
# Batch 35/69 - PGD volume: 0.010000, FGSM volume: 0.043952
# Batch 36/69 - PGD volume: 0.010000, FGSM volume: 0.043744
# Batch 37/69 - PGD volume: 0.010000, FGSM volume: 0.043455
# Batch 38/69 - PGD volume: 0.010000, FGSM volume: 0.043780
# Batch 39/69 - PGD volume: 0.010000, FGSM volume: 0.043498
# Batch 40/69 - PGD volume: 0.010000, FGSM volume: 0.043087
# Batch 41/69 - PGD volume: 0.010000, FGSM volume: 0.043443
# Batch 42/69 - PGD volume: 0.010000, FGSM volume: 0.043334
# Batch 43/69 - PGD volume: 0.010000, FGSM volume: 0.043006
# Batch 44/69 - PGD volume: 0.010000, FGSM volume: 0.043242
# Batch 45/69 - PGD volume: 0.010000, FGSM volume: 0.040851
# Batch 46/69 - PGD volume: 0.010000, FGSM volume: 0.035966
# Batch 47/69 - PGD volume: 0.010000, FGSM volume: 0.036239
# Batch 48/69 - PGD volume: 0.010000, FGSM volume: 0.036147
# Batch 49/69 - PGD volume: 0.010000, FGSM volume: 0.035389
# Batch 50/69 - PGD volume: 0.010000, FGSM volume: 0.035735
# Batch 51/69 - PGD volume: 0.010000, FGSM volume: 0.036411
# Batch 52/69 - PGD volume: 0.010000, FGSM volume: 0.036257
# Batch 53/69 - PGD volume: 0.010000, FGSM volume: 0.035801
# Batch 54/69 - PGD volume: 0.010000, FGSM volume: 0.036386
# Batch 55/69 - PGD volume: 0.010000, FGSM volume: 0.038150
# Batch 56/69 - PGD volume: 0.010000, FGSM volume: 0.043533
# Batch 57/69 - PGD volume: 0.010000, FGSM volume: 0.043470
# Batch 58/69 - PGD volume: 0.010000, FGSM volume: 0.043702
# Batch 59/69 - PGD volume: 0.010000, FGSM volume: 0.044058
# Batch 60/69 - PGD volume: 0.010000, FGSM volume: 0.044115
# Batch 61/69 - PGD volume: 0.010000, FGSM volume: 0.043451
# Batch 62/69 - PGD volume: 0.010000, FGSM volume: 0.043450
# Batch 63/69 - PGD volume: 0.010000, FGSM volume: 0.043564
# Batch 64/69 - PGD volume: 0.010000, FGSM volume: 0.036273
# Batch 65/69 - PGD volume: 0.010000, FGSM volume: 0.036520
# Batch 66/69 - PGD volume: 0.010000, FGSM volume: 0.036386
# Batch 67/69 - PGD volume: 0.010000, FGSM volume: 0.036354
# Batch 68/69 - PGD volume: 0.010000, FGSM volume: 0.035627
# Batch 69/69 - PGD volume: 0.010000, FGSM volume: 0.036316
#
# Analyzing epsilon: 0.1
# Batch 1/69 - PGD volume: 0.088198, FGSM volume: 0.313809
# Batch 2/69 - PGD volume: 0.087925, FGSM volume: 0.329607
# Batch 3/69 - PGD volume: 0.087487, FGSM volume: 0.333444
# Batch 4/69 - PGD volume: 0.087928, FGSM volume: 0.336119
# Batch 5/69 - PGD volume: 0.087852, FGSM volume: 0.328583
# Batch 6/69 - PGD volume: 0.087079, FGSM volume: 0.335466
# Batch 7/69 - PGD volume: 0.086546, FGSM volume: 0.340811
# Batch 8/69 - PGD volume: 0.087576, FGSM volume: 0.332701
# Batch 9/69 - PGD volume: 0.086922, FGSM volume: 0.331342
# Batch 10/69 - PGD volume: 0.087361, FGSM volume: 0.335639
# Batch 11/69 - PGD volume: 0.087410, FGSM volume: 0.328040
# Batch 12/69 - PGD volume: 0.088882, FGSM volume: 0.325859
# Batch 13/69 - PGD volume: 0.090405, FGSM volume: 0.324762
# Batch 14/69 - PGD volume: 0.088791, FGSM volume: 0.326029
# Batch 15/69 - PGD volume: 0.087252, FGSM volume: 0.324375
# Batch 16/69 - PGD volume: 0.087711, FGSM volume: 0.321502
# Batch 17/69 - PGD volume: 0.088394, FGSM volume: 0.322541
# Batch 18/69 - PGD volume: 0.089575, FGSM volume: 0.318205
# Batch 19/69 - PGD volume: 0.090036, FGSM volume: 0.312445
# Batch 20/69 - PGD volume: 0.089429, FGSM volume: 0.309505
# Batch 21/69 - PGD volume: 0.090534, FGSM volume: 0.309924
# Batch 22/69 - PGD volume: 0.089350, FGSM volume: 0.313084
# Batch 23/69 - PGD volume: 0.089358, FGSM volume: 0.309243
# Batch 24/69 - PGD volume: 0.090832, FGSM volume: 0.309941
# Batch 25/69 - PGD volume: 0.089254, FGSM volume: 0.311784
# Batch 26/69 - PGD volume: 0.090956, FGSM volume: 0.302668
# Batch 27/69 - PGD volume: 0.089285, FGSM volume: 0.308309
# Batch 28/69 - PGD volume: 0.089289, FGSM volume: 0.314397
# Batch 29/69 - PGD volume: 0.087016, FGSM volume: 0.323025
# Batch 30/69 - PGD volume: 0.086649, FGSM volume: 0.339294
# Batch 31/69 - PGD volume: 0.086699, FGSM volume: 0.330694
# Batch 32/69 - PGD volume: 0.088296, FGSM volume: 0.331671
# Batch 33/69 - PGD volume: 0.087469, FGSM volume: 0.334349
# Batch 34/69 - PGD volume: 0.086271, FGSM volume: 0.333617
# Batch 35/69 - PGD volume: 0.087205, FGSM volume: 0.336484
# Batch 36/69 - PGD volume: 0.087128, FGSM volume: 0.331750
# Batch 37/69 - PGD volume: 0.087371, FGSM volume: 0.336798
# Batch 38/69 - PGD volume: 0.086257, FGSM volume: 0.331881
# Batch 39/69 - PGD volume: 0.086335, FGSM volume: 0.339067
# Batch 40/69 - PGD volume: 0.088584, FGSM volume: 0.330419
# Batch 41/69 - PGD volume: 0.089868, FGSM volume: 0.328137
# Batch 42/69 - PGD volume: 0.089963, FGSM volume: 0.327123
# Batch 43/69 - PGD volume: 0.091003, FGSM volume: 0.328364
# Batch 44/69 - PGD volume: 0.089118, FGSM volume: 0.328517
# Batch 45/69 - PGD volume: 0.087103, FGSM volume: 0.324866
# Batch 46/69 - PGD volume: 0.088932, FGSM volume: 0.316731
# Batch 47/69 - PGD volume: 0.089718, FGSM volume: 0.316285
# Batch 48/69 - PGD volume: 0.089392, FGSM volume: 0.309324
# Batch 49/69 - PGD volume: 0.089264, FGSM volume: 0.313739
# Batch 50/69 - PGD volume: 0.089458, FGSM volume: 0.312042
# Batch 51/69 - PGD volume: 0.088995, FGSM volume: 0.315885
# Batch 52/69 - PGD volume: 0.089758, FGSM volume: 0.310782
# Batch 53/69 - PGD volume: 0.089790, FGSM volume: 0.311885
# Batch 54/69 - PGD volume: 0.088968, FGSM volume: 0.314987
# Batch 55/69 - PGD volume: 0.086882, FGSM volume: 0.319540
# Batch 56/69 - PGD volume: 0.086690, FGSM volume: 0.338503
# Batch 57/69 - PGD volume: 0.087254, FGSM volume: 0.342103
# Batch 58/69 - PGD volume: 0.087530, FGSM volume: 0.341800
# Batch 59/69 - PGD volume: 0.085612, FGSM volume: 0.340814
# Batch 60/69 - PGD volume: 0.086355, FGSM volume: 0.348940
# Batch 61/69 - PGD volume: 0.085656, FGSM volume: 0.331338
# Batch 62/69 - PGD volume: 0.086788, FGSM volume: 0.332395
# Batch 63/69 - PGD volume: 0.087390, FGSM volume: 0.324596
# Batch 64/69 - PGD volume: 0.088999, FGSM volume: 0.314966
# Batch 65/69 - PGD volume: 0.089060, FGSM volume: 0.313783
# Batch 66/69 - PGD volume: 0.088264, FGSM volume: 0.315371
# Batch 67/69 - PGD volume: 0.088646, FGSM volume: 0.313029
# Batch 68/69 - PGD volume: 0.089392, FGSM volume: 0.309961
# Batch 69/69 - PGD volume: 0.089031, FGSM volume: 0.315240
#
# Analyzing epsilon: 1
# Batch 1/69 - PGD volume: 0.091183, FGSM volume: 3.113050
# Batch 2/69 - PGD volume: 0.092120, FGSM volume: 3.041738
# Batch 3/69 - PGD volume: 0.091405, FGSM volume: 3.039539
# Batch 4/69 - PGD volume: 0.092780, FGSM volume: 3.019130
# Batch 5/69 - PGD volume: 0.092222, FGSM volume: 3.014162
# Batch 6/69 - PGD volume: 0.091058, FGSM volume: 3.048240
# Batch 7/69 - PGD volume: 0.090045, FGSM volume: 3.018741
# Batch 8/69 - PGD volume: 0.091470, FGSM volume: 2.988190
# Batch 9/69 - PGD volume: 0.090848, FGSM volume: 2.973656
# Batch 10/69 - PGD volume: 0.090951, FGSM volume: 3.000045
# Batch 11/69 - PGD volume: 0.091861, FGSM volume: 3.047391
# Batch 12/69 - PGD volume: 0.093093, FGSM volume: 3.006821
# Batch 13/69 - PGD volume: 0.096019, FGSM volume: 3.027714
# Batch 14/69 - PGD volume: 0.093494, FGSM volume: 2.992897
# Batch 15/69 - PGD volume: 0.091296, FGSM volume: 2.994894
# Batch 16/69 - PGD volume: 0.091356, FGSM volume: 2.980698
# Batch 17/69 - PGD volume: 0.092269, FGSM volume: 3.084050
# Batch 18/69 - PGD volume: 0.093465, FGSM volume: 3.155196
# Batch 19/69 - PGD volume: 0.093915, FGSM volume: 3.100431
# Batch 20/69 - PGD volume: 0.092927, FGSM volume: 3.074971
# Batch 21/69 - PGD volume: 0.094236, FGSM volume: 3.071100
# Batch 22/69 - PGD volume: 0.092258, FGSM volume: 3.105221
# Batch 23/69 - PGD volume: 0.092432, FGSM volume: 3.070967
# Batch 24/69 - PGD volume: 0.094760, FGSM volume: 3.063060
# Batch 25/69 - PGD volume: 0.092603, FGSM volume: 3.084705
# Batch 26/69 - PGD volume: 0.094847, FGSM volume: 2.988594
# Batch 27/69 - PGD volume: 0.092458, FGSM volume: 3.057644
# Batch 28/69 - PGD volume: 0.092544, FGSM volume: 3.121008
# Batch 29/69 - PGD volume: 0.090139, FGSM volume: 3.087410
# Batch 30/69 - PGD volume: 0.090224, FGSM volume: 3.047992
# Batch 31/69 - PGD volume: 0.090388, FGSM volume: 3.037569
# Batch 32/69 - PGD volume: 0.092624, FGSM volume: 3.040103
# Batch 33/69 - PGD volume: 0.091986, FGSM volume: 3.062216
# Batch 34/69 - PGD volume: 0.089655, FGSM volume: 3.016872
# Batch 35/69 - PGD volume: 0.090884, FGSM volume: 2.984195
# Batch 36/69 - PGD volume: 0.090721, FGSM volume: 2.942640
# Batch 37/69 - PGD volume: 0.091175, FGSM volume: 3.013417
# Batch 38/69 - PGD volume: 0.089977, FGSM volume: 3.037505
# Batch 39/69 - PGD volume: 0.090048, FGSM volume: 3.018943
# Batch 40/69 - PGD volume: 0.093072, FGSM volume: 3.009731
# Batch 41/69 - PGD volume: 0.094917, FGSM volume: 2.997468
# Batch 42/69 - PGD volume: 0.095527, FGSM volume: 2.958136
# Batch 43/69 - PGD volume: 0.097558, FGSM volume: 2.994938
# Batch 44/69 - PGD volume: 0.094098, FGSM volume: 3.021169
# Batch 45/69 - PGD volume: 0.090490, FGSM volume: 3.054186
# Batch 46/69 - PGD volume: 0.092333, FGSM volume: 3.141325
# Batch 47/69 - PGD volume: 0.094171, FGSM volume: 3.136855
# Batch 48/69 - PGD volume: 0.092445, FGSM volume: 3.065678
# Batch 49/69 - PGD volume: 0.092705, FGSM volume: 3.113646
# Batch 50/69 - PGD volume: 0.092844, FGSM volume: 3.095425
# Batch 51/69 - PGD volume: 0.092266, FGSM volume: 3.129669
# Batch 52/69 - PGD volume: 0.092996, FGSM volume: 3.080990
# Batch 53/69 - PGD volume: 0.092921, FGSM volume: 3.094881
# Batch 54/69 - PGD volume: 0.092501, FGSM volume: 3.121755
# Batch 55/69 - PGD volume: 0.089599, FGSM volume: 3.087250
# Batch 56/69 - PGD volume: 0.090112, FGSM volume: 3.060260
# Batch 57/69 - PGD volume: 0.091522, FGSM volume: 3.033282
# Batch 58/69 - PGD volume: 0.091906, FGSM volume: 3.008786
# Batch 59/69 - PGD volume: 0.088541, FGSM volume: 3.010704
# Batch 60/69 - PGD volume: 0.089987, FGSM volume: 2.987880
# Batch 61/69 - PGD volume: 0.088639, FGSM volume: 3.034256
# Batch 62/69 - PGD volume: 0.090188, FGSM volume: 3.038946
# Batch 63/69 - PGD volume: 0.091495, FGSM volume: 2.984537
# Batch 64/69 - PGD volume: 0.092221, FGSM volume: 3.103211
# Batch 65/69 - PGD volume: 0.092472, FGSM volume: 3.106812
# Batch 66/69 - PGD volume: 0.091458, FGSM volume: 3.119150
# Batch 67/69 - PGD volume: 0.091887, FGSM volume: 3.103022
# Batch 68/69 - PGD volume: 0.092161, FGSM volume: 3.078225
# Batch 69/69 - PGD volume: 0.092607, FGSM volume: 3.124346
#
# Analyzing epsilon: 10
# Batch 1/69 - PGD volume: 0.091183, FGSM volume: 3.113050
# Batch 2/69 - PGD volume: 0.092120, FGSM volume: 3.041738
# Batch 3/69 - PGD volume: 0.091405, FGSM volume: 3.039539
# Batch 4/69 - PGD volume: 0.092780, FGSM volume: 3.019130
# Batch 5/69 - PGD volume: 0.092222, FGSM volume: 3.014162
# Batch 6/69 - PGD volume: 0.091058, FGSM volume: 3.048240
# Batch 7/69 - PGD volume: 0.090045, FGSM volume: 3.018741
# Batch 8/69 - PGD volume: 0.091470, FGSM volume: 2.988190
# Batch 9/69 - PGD volume: 0.090848, FGSM volume: 2.973656
# Batch 10/69 - PGD volume: 0.090951, FGSM volume: 3.000045
# Batch 11/69 - PGD volume: 0.091861, FGSM volume: 3.047391
# Batch 12/69 - PGD volume: 0.093093, FGSM volume: 3.006821
# Batch 13/69 - PGD volume: 0.096019, FGSM volume: 3.027714
# Batch 14/69 - PGD volume: 0.093494, FGSM volume: 2.992897
# Batch 15/69 - PGD volume: 0.091296, FGSM volume: 2.994894
# Batch 16/69 - PGD volume: 0.091356, FGSM volume: 2.980698
# Batch 17/69 - PGD volume: 0.092269, FGSM volume: 3.084050
# Batch 18/69 - PGD volume: 0.093465, FGSM volume: 3.155196
# Batch 19/69 - PGD volume: 0.093915, FGSM volume: 3.100431
# Batch 20/69 - PGD volume: 0.092927, FGSM volume: 3.074971
# Batch 21/69 - PGD volume: 0.094236, FGSM volume: 3.071100
# Batch 22/69 - PGD volume: 0.092258, FGSM volume: 3.105221
# Batch 23/69 - PGD volume: 0.092432, FGSM volume: 3.070967
# Batch 24/69 - PGD volume: 0.094760, FGSM volume: 3.063060
# Batch 25/69 - PGD volume: 0.092603, FGSM volume: 3.084705
# Batch 26/69 - PGD volume: 0.094847, FGSM volume: 2.988594
# Batch 27/69 - PGD volume: 0.092458, FGSM volume: 3.057644
# Batch 28/69 - PGD volume: 0.092544, FGSM volume: 3.121008
# Batch 29/69 - PGD volume: 0.090139, FGSM volume: 3.087410
# Batch 30/69 - PGD volume: 0.090224, FGSM volume: 3.047992
# Batch 31/69 - PGD volume: 0.090388, FGSM volume: 3.037569
# Batch 32/69 - PGD volume: 0.092624, FGSM volume: 3.040103
# Batch 33/69 - PGD volume: 0.091986, FGSM volume: 3.062216
# Batch 34/69 - PGD volume: 0.089655, FGSM volume: 3.016872
# Batch 35/69 - PGD volume: 0.090884, FGSM volume: 2.984195
# Batch 36/69 - PGD volume: 0.090721, FGSM volume: 2.942640
# Batch 37/69 - PGD volume: 0.091175, FGSM volume: 3.013417
# Batch 38/69 - PGD volume: 0.089977, FGSM volume: 3.037505
# Batch 39/69 - PGD volume: 0.090048, FGSM volume: 3.018943
# Batch 40/69 - PGD volume: 0.093072, FGSM volume: 3.009731
# Batch 41/69 - PGD volume: 0.094917, FGSM volume: 2.997468
# Batch 42/69 - PGD volume: 0.095527, FGSM volume: 2.958136
# Batch 43/69 - PGD volume: 0.097558, FGSM volume: 2.994938
# Batch 44/69 - PGD volume: 0.094098, FGSM volume: 3.021169
# Batch 45/69 - PGD volume: 0.090490, FGSM volume: 3.054186
# Batch 46/69 - PGD volume: 0.092333, FGSM volume: 3.141325
# Batch 47/69 - PGD volume: 0.094171, FGSM volume: 3.136855
# Batch 48/69 - PGD volume: 0.092445, FGSM volume: 3.065678
# Batch 49/69 - PGD volume: 0.092705, FGSM volume: 3.113646
# Batch 50/69 - PGD volume: 0.092844, FGSM volume: 3.095425
# Batch 51/69 - PGD volume: 0.092266, FGSM volume: 3.129669
# Batch 52/69 - PGD volume: 0.092996, FGSM volume: 3.080990
# Batch 53/69 - PGD volume: 0.092921, FGSM volume: 3.094881
# Batch 54/69 - PGD volume: 0.092501, FGSM volume: 3.121755
# Batch 55/69 - PGD volume: 0.089599, FGSM volume: 3.087250
# Batch 56/69 - PGD volume: 0.090112, FGSM volume: 3.060260
# Batch 57/69 - PGD volume: 0.091522, FGSM volume: 3.033282
# Batch 58/69 - PGD volume: 0.091906, FGSM volume: 3.008786
# Batch 59/69 - PGD volume: 0.088541, FGSM volume: 3.010704
# Batch 60/69 - PGD volume: 0.089987, FGSM volume: 2.987880
# Batch 61/69 - PGD volume: 0.088639, FGSM volume: 3.034256
# Batch 62/69 - PGD volume: 0.090188, FGSM volume: 3.038946
# Batch 63/69 - PGD volume: 0.091495, FGSM volume: 2.984537
# Batch 64/69 - PGD volume: 0.092221, FGSM volume: 3.103211
# Batch 65/69 - PGD volume: 0.092472, FGSM volume: 3.106812
# Batch 66/69 - PGD volume: 0.091458, FGSM volume: 3.119150
# Batch 67/69 - PGD volume: 0.091887, FGSM volume: 3.103022
# Batch 68/69 - PGD volume: 0.092161, FGSM volume: 3.078225
# Batch 69/69 - PGD volume: 0.092607, FGSM volume: 3.124346
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         582.0735  68836.0000    0.4518
# 0.9000         454.9494  63517.0000    0.4566
# 0.9500         -67.4617  55480.0000    0.4434
# 0.9900          -1.2168  39465.0000    0.4485
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500       -1013.1934 107650.0000    0.3706
# 0.9000        -901.9518 102833.0000    0.3676
# 0.9500        -811.3446  94707.0000    0.3558
# 0.9900        -447.3088  73975.0000    0.3258
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500       -1012.7753 107937.0000    0.3669
# 0.9000        -901.2968 103135.0000    0.3636
# 0.9500        -786.9766  95089.0000    0.3576
# 0.9900        -446.0609  74722.0000    0.3265
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500       -1012.7753 107937.0000    0.3669
# 0.9000        -901.2968 103135.0000    0.3636
# 0.9500        -786.9766  95089.0000    0.3576
# 0.9900        -446.0609  74722.0000    0.3265
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         -68.1425  89244.0000    0.3911
# 0.9000        -244.1538  82484.0000    0.3952
# 0.9500        -135.4146  71552.0000    0.3913
# 0.9900         -62.6037  48877.0000    0.3867
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -232.1914 107476.0000    0.3908
# 0.9000        -227.4624 101962.0000    0.3923
# 0.9500          52.7770  92679.0000    0.3992
# 0.9900         334.1733  70810.0000    0.4053
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         247.9052 106413.0000    0.4013
# 0.9000         287.2323  99987.0000    0.4071
# 0.9500         110.0134  89166.0000    0.4004
# 0.9900         121.2641  62726.0000    0.3970
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         247.9052 106413.0000    0.4013
# 0.9000         287.2323  99987.0000    0.4071
# 0.9500         110.0134  89166.0000    0.4004
# 0.9900         121.2641  62726.0000    0.3970
