# %%
import pandas as pd
import pickle
import numpy as np
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import load_model, Model
from keras.layers import Flatten, Dense, Dropout, Activation, Input, LSTM, Reshape, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.layers import LeakyReLU
#!pip install np_utils
from keras import utils

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score

RANDOM_SEED = 0

# set random seeds
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# limit gpu usage for keras with tensorflow 1
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth = True
# set_session(tf.compat.v1.Session(config=config))

# If you need to use set_session, try this instead:
# from tensorflow.python.keras.backend import set_session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

# Define the target directory in Google Drive for the unzipped files
UNZIPPED_DATA_DIR = '/content/drive/MyDrive/LOBCNN/data/'

# Check if the unzipped data directory already exists and contains files
if not os.path.exists(UNZIPPED_DATA_DIR) or not os.listdir(UNZIPPED_DATA_DIR):
    print(f"Data not found in {UNZIPPED_DATA_DIR}. Attempting to download and unzip.")

    # Create the target directory if it doesn't exist
    os.makedirs(UNZIPPED_DATA_DIR, exist_ok=True)

    # Define a temporary path for the downloaded zip file in /content/
    TEMP_ZIP_PATH = '/content/data.zip'

    # Download the data.zip file to /content/
    # !wget -q https://raw.githubusercontent.com/zcakhaa/DeepLOB-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books/master/data/data.zip -O {TEMP_ZIP_PATH}

    # Unzip the downloaded file directly into the target directory in Google Drive
    with zipfile.ZipFile(TEMP_ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(UNZIPPED_DATA_DIR)

    # Optionally, remove the temporary zip file to save space
    os.remove(TEMP_ZIP_PATH)

    print('Data downloaded and unzipped to Google Drive.')
else:
    print('Data already existed and is ready in Google Drive.')
# Out:
# Data already existed and is ready in Google Drive.

# %%
def prepare_x(data):
    df1 = data[:40, :].T
    return np.array(df1)

def get_label(data):
    lob = data[-5:, :].T
    return lob

def data_classification(X, Y, T):
    [N, D] = X.shape
    df = np.array(X)
    dY = np.array(Y)
    dataY = dY[T - 1:N]
    dataX = np.zeros((N - T + 1, T, D))
    for i in range(T, N + 1):
        dataX[i - T] = df[i - T:i, :]
    return dataX.reshape(dataX.shape + (1,)), dataY

def prepare_x_y(data, k, T):
    x = prepare_x(data)
    y = get_label(data)
    x, y = data_classification(x, y, T=T)
    y = y[:,k] - 1
    y = utils.to_categorical(y, 3)
    return x, y


def macro_f1(y_true, y_pred):
    """Macro-averaged F1 score for multi-class classification."""
    y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)
    y_true = tf.cast(tf.argmax(y_true, axis=-1), tf.int32)

    f1_scores = []
    for i in range(3):
        y_true_i = tf.cast(tf.equal(y_true, i), tf.float32)
        y_pred_i = tf.cast(tf.equal(y_pred, i), tf.float32)

        tp = tf.reduce_sum(y_true_i * y_pred_i)
        fp = tf.reduce_sum((1.0 - y_true_i) * y_pred_i)
        fn = tf.reduce_sum(y_true_i * (1.0 - y_pred_i))

        precision = tp / (tp + fp + tf.keras.backend.epsilon())
        recall = tp / (tp + fn + tf.keras.backend.epsilon())
        f1 = 2.0 * precision * recall / (precision + recall + tf.keras.backend.epsilon())
        f1_scores.append(f1)

    return tf.reduce_mean(tf.stack(f1_scores))

# %%
dec_data = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Train_Dst_NoAuction_DecPre_CF_7.txt'))
dec_train = dec_data[:, :int(np.floor(dec_data.shape[1] * 0.8))]
dec_val = dec_data[:, int(np.floor(dec_data.shape[1] * 0.8)):]

dec_test1 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_7.txt'))
dec_test2 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_8.txt'))
dec_test3 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_9.txt'))
dec_test = np.hstack((dec_test1, dec_test2, dec_test3))

k = 4 # which prediction horizon
T = 100 # the length of a single input
n_hiddens = 64

trainX_CNN, trainY_CNN = prepare_x_y(dec_train, k, T)
valX_CNN, valY_CNN = prepare_x_y(dec_val, k, T)
testX_CNN, testY_CNN = prepare_x_y(dec_test, k, T)

print(trainX_CNN.shape, trainY_CNN.shape)
print(valX_CNN.shape, valY_CNN.shape)
print(testX_CNN.shape, testY_CNN.shape)
# Out:
# (203701, 100, 40, 1) (203701, 3)
# (50851, 100, 40, 1) (50851, 3)
# (139488, 100, 40, 1) (139488, 3)

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Dropout

def create_lstm2(T, NF, number_of_lstm):
    input_lmd = Input(shape=(T, NF))

    # build the LSTM layer
    lstm_layer = LSTM(64)(input_lmd)

    # apply dropout
    lstm_layer = Dropout(0.5)(lstm_layer, training=True)

    # build the output layer
    out = Dense(3, activation='softmax')(lstm_layer)

    model = Model(inputs=input_lmd, outputs=out)
    adam = keras.optimizers.Adam(learning_rate=0.00005) # Changed lr to learning_rate
    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', macro_f1])

    return model

# Assuming trainX_CNN.shape[1] is T, trainX_CNN.shape[2] is NF, and n_hiddens is the number of LSTM units
lstm2 = create_lstm2(trainX_CNN.shape[1], trainX_CNN.shape[2], 64)
lstm2.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100, 40)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        26,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,075 (105.76 KB)
#  Trainable params: 27,075 (105.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%time
checkpoint_filepath = f'/content/drive/MyDrive/LOBCNN/models/LSTM_2_{RANDOM_SEED}.weights.h5'

if os.path.exists(checkpoint_filepath):
    lstm2.load_weights(checkpoint_filepath)
    print("Loaded saved weights.")
else:
    print("No saved weights found. Starting training from scratch.")
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_macro_f1',
        mode='max',
        save_best_only=True)
    lstm2.fit(trainX_CNN, trainY_CNN, validation_data=(valX_CNN, valY_CNN),
              epochs=200, batch_size=128, verbose=1, callbacks=[model_checkpoint_callback])
# Out:
# No saved weights found. Starting training from scratch.
# Epoch 1/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.4187 - loss: 1.0427 - macro_f1: 0.3034 - val_accuracy: 0.3723 - val_loss: 1.0876 - val_macro_f1: 0.1731
# Epoch 2/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4270 - loss: 1.0287 - macro_f1: 0.3246 - val_accuracy: 0.3781 - val_loss: 1.0899 - val_macro_f1: 0.1859
# Epoch 3/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4390 - loss: 1.0234 - macro_f1: 0.3434 - val_accuracy: 0.4096 - val_loss: 1.0889 - val_macro_f1: 0.2523
# Epoch 4/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4456 - loss: 1.0200 - macro_f1: 0.3572 - val_accuracy: 0.4135 - val_loss: 1.0887 - val_macro_f1: 0.2599
# Epoch 5/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4497 - loss: 1.0171 - macro_f1: 0.3633 - val_accuracy: 0.4112 - val_loss: 1.0882 - val_macro_f1: 0.2554
# Epoch 6/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4562 - loss: 1.0141 - macro_f1: 0.3697 - val_accuracy: 0.4184 - val_loss: 1.0884 - val_macro_f1: 0.2653
# Epoch 7/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4666 - loss: 1.0098 - macro_f1: 0.3792 - val_accuracy: 0.4182 - val_loss: 1.0874 - val_macro_f1: 0.2721
# Epoch 8/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4719 - loss: 1.0068 - macro_f1: 0.3836 - val_accuracy: 0.4272 - val_loss: 1.0873 - val_macro_f1: 0.2855
# Epoch 9/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4766 - loss: 1.0042 - macro_f1: 0.3880 - val_accuracy: 0.4297 - val_loss: 1.0870 - val_macro_f1: 0.2850
# Epoch 10/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4802 - loss: 1.0013 - macro_f1: 0.3907 - val_accuracy: 0.4348 - val_loss: 1.0873 - val_macro_f1: 0.2929
# Epoch 11/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4847 - loss: 0.9989 - macro_f1: 0.3945 - val_accuracy: 0.4299 - val_loss: 1.0857 - val_macro_f1: 0.2904
# Epoch 12/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.4879 - loss: 0.9964 - macro_f1: 0.3963 - val_accuracy: 0.4260 - val_loss: 1.0859 - val_macro_f1: 0.2873
# Epoch 13/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4925 - loss: 0.9941 - macro_f1: 0.3991 - val_accuracy: 0.4294 - val_loss: 1.0853 - val_macro_f1: 0.2963
# Epoch 14/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4969 - loss: 0.9917 - macro_f1: 0.4028 - val_accuracy: 0.4320 - val_loss: 1.0870 - val_macro_f1: 0.2988
# Epoch 15/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.4999 - loss: 0.9894 - macro_f1: 0.4053 - val_accuracy: 0.4261 - val_loss: 1.0835 - val_macro_f1: 0.2838
# Epoch 16/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5022 - loss: 0.9865 - macro_f1: 0.4073 - val_accuracy: 0.4293 - val_loss: 1.0832 - val_macro_f1: 0.2977
# Epoch 17/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5052 - loss: 0.9838 - macro_f1: 0.4094 - val_accuracy: 0.4333 - val_loss: 1.0810 - val_macro_f1: 0.3006
# Epoch 18/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5065 - loss: 0.9815 - macro_f1: 0.4121 - val_accuracy: 0.4335 - val_loss: 1.0850 - val_macro_f1: 0.3022
# Epoch 19/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5108 - loss: 0.9788 - macro_f1: 0.4153 - val_accuracy: 0.4386 - val_loss: 1.0840 - val_macro_f1: 0.3021
# Epoch 20/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5128 - loss: 0.9765 - macro_f1: 0.4183 - val_accuracy: 0.4392 - val_loss: 1.0824 - val_macro_f1: 0.3046
# Epoch 21/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5154 - loss: 0.9741 - macro_f1: 0.4212 - val_accuracy: 0.4322 - val_loss: 1.0831 - val_macro_f1: 0.3012
# Epoch 22/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5173 - loss: 0.9713 - macro_f1: 0.4236 - val_accuracy: 0.4401 - val_loss: 1.0792 - val_macro_f1: 0.3060
# Epoch 23/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5194 - loss: 0.9695 - macro_f1: 0.4265 - val_accuracy: 0.4377 - val_loss: 1.0787 - val_macro_f1: 0.2958
# Epoch 24/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5208 - loss: 0.9669 - macro_f1: 0.4277 - val_accuracy: 0.4426 - val_loss: 1.0799 - val_macro_f1: 0.3074
# Epoch 25/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5243 - loss: 0.9642 - macro_f1: 0.4317 - val_accuracy: 0.4433 - val_loss: 1.0796 - val_macro_f1: 0.3056
# Epoch 26/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5261 - loss: 0.9619 - macro_f1: 0.4334 - val_accuracy: 0.4377 - val_loss: 1.0777 - val_macro_f1: 0.2980
# Epoch 27/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5290 - loss: 0.9601 - macro_f1: 0.4371 - val_accuracy: 0.4403 - val_loss: 1.0743 - val_macro_f1: 0.3028
# Epoch 28/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5293 - loss: 0.9585 - macro_f1: 0.4377 - val_accuracy: 0.4388 - val_loss: 1.0728 - val_macro_f1: 0.2997
# Epoch 29/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5307 - loss: 0.9566 - macro_f1: 0.4391 - val_accuracy: 0.4409 - val_loss: 1.0756 - val_macro_f1: 0.3092
# Epoch 30/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5325 - loss: 0.9545 - macro_f1: 0.4416 - val_accuracy: 0.4400 - val_loss: 1.0734 - val_macro_f1: 0.3036
# Epoch 31/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5341 - loss: 0.9526 - macro_f1: 0.4431 - val_accuracy: 0.4416 - val_loss: 1.0738 - val_macro_f1: 0.3076
# Epoch 32/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5361 - loss: 0.9516 - macro_f1: 0.4461 - val_accuracy: 0.4405 - val_loss: 1.0734 - val_macro_f1: 0.3079
# Epoch 33/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5367 - loss: 0.9500 - macro_f1: 0.4465 - val_accuracy: 0.4399 - val_loss: 1.0720 - val_macro_f1: 0.3097
# Epoch 34/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5383 - loss: 0.9481 - macro_f1: 0.4486 - val_accuracy: 0.4414 - val_loss: 1.0710 - val_macro_f1: 0.3119
# Epoch 35/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5399 - loss: 0.9464 - macro_f1: 0.4508 - val_accuracy: 0.4382 - val_loss: 1.0706 - val_macro_f1: 0.3112
# Epoch 36/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5407 - loss: 0.9446 - macro_f1: 0.4522 - val_accuracy: 0.4399 - val_loss: 1.0700 - val_macro_f1: 0.3108
# Epoch 37/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5421 - loss: 0.9438 - macro_f1: 0.4536 - val_accuracy: 0.4410 - val_loss: 1.0699 - val_macro_f1: 0.3132
# Epoch 38/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5434 - loss: 0.9423 - macro_f1: 0.4566 - val_accuracy: 0.4361 - val_loss: 1.0685 - val_macro_f1: 0.3121
# Epoch 39/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5449 - loss: 0.9413 - macro_f1: 0.4577 - val_accuracy: 0.4423 - val_loss: 1.0703 - val_macro_f1: 0.3135
# Epoch 40/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5453 - loss: 0.9392 - macro_f1: 0.4594 - val_accuracy: 0.4418 - val_loss: 1.0690 - val_macro_f1: 0.3153
# Epoch 41/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5472 - loss: 0.9381 - macro_f1: 0.4605 - val_accuracy: 0.4405 - val_loss: 1.0680 - val_macro_f1: 0.3144
# Epoch 42/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5478 - loss: 0.9367 - macro_f1: 0.4616 - val_accuracy: 0.4412 - val_loss: 1.0690 - val_macro_f1: 0.3140
# Epoch 43/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5488 - loss: 0.9358 - macro_f1: 0.4642 - val_accuracy: 0.4376 - val_loss: 1.0699 - val_macro_f1: 0.3126
# Epoch 44/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5493 - loss: 0.9338 - macro_f1: 0.4654 - val_accuracy: 0.4461 - val_loss: 1.0650 - val_macro_f1: 0.3165
# Epoch 45/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5507 - loss: 0.9332 - macro_f1: 0.4672 - val_accuracy: 0.4441 - val_loss: 1.0655 - val_macro_f1: 0.3173
# Epoch 46/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5517 - loss: 0.9319 - macro_f1: 0.4690 - val_accuracy: 0.4433 - val_loss: 1.0668 - val_macro_f1: 0.3168
# Epoch 47/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5520 - loss: 0.9311 - macro_f1: 0.4701 - val_accuracy: 0.4434 - val_loss: 1.0662 - val_macro_f1: 0.3182
# Epoch 48/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5543 - loss: 0.9291 - macro_f1: 0.4721 - val_accuracy: 0.4434 - val_loss: 1.0651 - val_macro_f1: 0.3150
# Epoch 49/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5548 - loss: 0.9284 - macro_f1: 0.4728 - val_accuracy: 0.4464 - val_loss: 1.0685 - val_macro_f1: 0.3165
# Epoch 50/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.5552 - loss: 0.9268 - macro_f1: 0.4739 - val_accuracy: 0.4497 - val_loss: 1.0630 - val_macro_f1: 0.3221
# Epoch 51/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5573 - loss: 0.9257 - macro_f1: 0.4765 - val_accuracy: 0.4453 - val_loss: 1.0644 - val_macro_f1: 0.3206
# Epoch 52/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5574 - loss: 0.9243 - macro_f1: 0.4778 - val_accuracy: 0.4479 - val_loss: 1.0644 - val_macro_f1: 0.3220
# Epoch 53/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5585 - loss: 0.9230 - macro_f1: 0.4789 - val_accuracy: 0.4490 - val_loss: 1.0614 - val_macro_f1: 0.3212
# Epoch 54/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5582 - loss: 0.9219 - macro_f1: 0.4795 - val_accuracy: 0.4494 - val_loss: 1.0649 - val_macro_f1: 0.3204
# Epoch 55/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5608 - loss: 0.9209 - macro_f1: 0.4825 - val_accuracy: 0.4479 - val_loss: 1.0654 - val_macro_f1: 0.3203
# Epoch 56/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5610 - loss: 0.9185 - macro_f1: 0.4837 - val_accuracy: 0.4489 - val_loss: 1.0608 - val_macro_f1: 0.3214
# Epoch 57/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5623 - loss: 0.9180 - macro_f1: 0.4855 - val_accuracy: 0.4512 - val_loss: 1.0639 - val_macro_f1: 0.3210
# Epoch 58/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5645 - loss: 0.9163 - macro_f1: 0.4883 - val_accuracy: 0.4514 - val_loss: 1.0612 - val_macro_f1: 0.3216
# Epoch 59/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5640 - loss: 0.9156 - macro_f1: 0.4880 - val_accuracy: 0.4510 - val_loss: 1.0616 - val_macro_f1: 0.3232
# Epoch 60/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5650 - loss: 0.9139 - macro_f1: 0.4891 - val_accuracy: 0.4507 - val_loss: 1.0628 - val_macro_f1: 0.3228
# Epoch 61/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5662 - loss: 0.9134 - macro_f1: 0.4908 - val_accuracy: 0.4497 - val_loss: 1.0578 - val_macro_f1: 0.3234
# Epoch 62/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5664 - loss: 0.9119 - macro_f1: 0.4917 - val_accuracy: 0.4515 - val_loss: 1.0630 - val_macro_f1: 0.3238
# Epoch 63/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5667 - loss: 0.9106 - macro_f1: 0.4926 - val_accuracy: 0.4515 - val_loss: 1.0610 - val_macro_f1: 0.3215
# Epoch 64/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5681 - loss: 0.9098 - macro_f1: 0.4946 - val_accuracy: 0.4527 - val_loss: 1.0603 - val_macro_f1: 0.3249
# Epoch 65/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5696 - loss: 0.9090 - macro_f1: 0.4960 - val_accuracy: 0.4500 - val_loss: 1.0633 - val_macro_f1: 0.3218
# Epoch 66/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5703 - loss: 0.9077 - macro_f1: 0.4976 - val_accuracy: 0.4524 - val_loss: 1.0590 - val_macro_f1: 0.3264
# Epoch 67/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5706 - loss: 0.9065 - macro_f1: 0.4980 - val_accuracy: 0.4537 - val_loss: 1.0576 - val_macro_f1: 0.3258
# Epoch 68/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5721 - loss: 0.9054 - macro_f1: 0.5001 - val_accuracy: 0.4537 - val_loss: 1.0622 - val_macro_f1: 0.3259
# Epoch 69/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5724 - loss: 0.9043 - macro_f1: 0.4999 - val_accuracy: 0.4543 - val_loss: 1.0588 - val_macro_f1: 0.3267
# Epoch 70/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5731 - loss: 0.9027 - macro_f1: 0.5017 - val_accuracy: 0.4525 - val_loss: 1.0596 - val_macro_f1: 0.3251
# Epoch 71/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5733 - loss: 0.9028 - macro_f1: 0.5013 - val_accuracy: 0.4578 - val_loss: 1.0547 - val_macro_f1: 0.3290
# Epoch 72/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5739 - loss: 0.9007 - macro_f1: 0.5036 - val_accuracy: 0.4558 - val_loss: 1.0544 - val_macro_f1: 0.3289
# Epoch 73/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5753 - loss: 0.8999 - macro_f1: 0.5045 - val_accuracy: 0.4561 - val_loss: 1.0565 - val_macro_f1: 0.3276
# Epoch 74/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5760 - loss: 0.8990 - macro_f1: 0.5057 - val_accuracy: 0.4563 - val_loss: 1.0565 - val_macro_f1: 0.3309
# Epoch 75/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5767 - loss: 0.8978 - macro_f1: 0.5061 - val_accuracy: 0.4540 - val_loss: 1.0592 - val_macro_f1: 0.3278
# Epoch 76/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5773 - loss: 0.8969 - macro_f1: 0.5068 - val_accuracy: 0.4543 - val_loss: 1.0568 - val_macro_f1: 0.3288
# Epoch 77/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5783 - loss: 0.8955 - macro_f1: 0.5085 - val_accuracy: 0.4539 - val_loss: 1.0571 - val_macro_f1: 0.3303
# Epoch 78/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5787 - loss: 0.8946 - macro_f1: 0.5095 - val_accuracy: 0.4545 - val_loss: 1.0584 - val_macro_f1: 0.3300
# Epoch 79/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5788 - loss: 0.8942 - macro_f1: 0.5084 - val_accuracy: 0.4579 - val_loss: 1.0563 - val_macro_f1: 0.3301
# Epoch 80/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5790 - loss: 0.8938 - macro_f1: 0.5100 - val_accuracy: 0.4503 - val_loss: 1.0596 - val_macro_f1: 0.3226
# Epoch 81/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5808 - loss: 0.8918 - macro_f1: 0.5118 - val_accuracy: 0.4560 - val_loss: 1.0578 - val_macro_f1: 0.3298
# Epoch 82/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5804 - loss: 0.8909 - macro_f1: 0.5118 - val_accuracy: 0.4550 - val_loss: 1.0582 - val_macro_f1: 0.3281
# Epoch 83/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5819 - loss: 0.8902 - macro_f1: 0.5130 - val_accuracy: 0.4563 - val_loss: 1.0560 - val_macro_f1: 0.3306
# Epoch 84/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5818 - loss: 0.8894 - macro_f1: 0.5135 - val_accuracy: 0.4553 - val_loss: 1.0569 - val_macro_f1: 0.3338
# Epoch 85/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5823 - loss: 0.8888 - macro_f1: 0.5136 - val_accuracy: 0.4574 - val_loss: 1.0557 - val_macro_f1: 0.3311
# Epoch 86/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5821 - loss: 0.8880 - macro_f1: 0.5133 - val_accuracy: 0.4552 - val_loss: 1.0555 - val_macro_f1: 0.3317
# Epoch 87/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5843 - loss: 0.8869 - macro_f1: 0.5161 - val_accuracy: 0.4589 - val_loss: 1.0545 - val_macro_f1: 0.3347
# Epoch 88/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5828 - loss: 0.8872 - macro_f1: 0.5151 - val_accuracy: 0.4588 - val_loss: 1.0549 - val_macro_f1: 0.3365
# Epoch 89/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5844 - loss: 0.8859 - macro_f1: 0.5161 - val_accuracy: 0.4596 - val_loss: 1.0547 - val_macro_f1: 0.3343
# Epoch 90/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5854 - loss: 0.8846 - macro_f1: 0.5168 - val_accuracy: 0.4555 - val_loss: 1.0581 - val_macro_f1: 0.3312
# Epoch 91/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5862 - loss: 0.8838 - macro_f1: 0.5180 - val_accuracy: 0.4576 - val_loss: 1.0553 - val_macro_f1: 0.3332
# Epoch 92/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5863 - loss: 0.8831 - macro_f1: 0.5186 - val_accuracy: 0.4571 - val_loss: 1.0574 - val_macro_f1: 0.3335
# Epoch 93/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5873 - loss: 0.8827 - macro_f1: 0.5194 - val_accuracy: 0.4574 - val_loss: 1.0557 - val_macro_f1: 0.3387
# Epoch 94/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5876 - loss: 0.8810 - macro_f1: 0.5199 - val_accuracy: 0.4592 - val_loss: 1.0543 - val_macro_f1: 0.3378
# Epoch 95/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5887 - loss: 0.8814 - macro_f1: 0.5211 - val_accuracy: 0.4552 - val_loss: 1.0570 - val_macro_f1: 0.3333
# Epoch 96/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5881 - loss: 0.8805 - macro_f1: 0.5197 - val_accuracy: 0.4607 - val_loss: 1.0536 - val_macro_f1: 0.3376
# Epoch 97/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5881 - loss: 0.8792 - macro_f1: 0.5207 - val_accuracy: 0.4555 - val_loss: 1.0571 - val_macro_f1: 0.3268
# Epoch 98/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5908 - loss: 0.8785 - macro_f1: 0.5235 - val_accuracy: 0.4582 - val_loss: 1.0556 - val_macro_f1: 0.3327
# Epoch 99/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5900 - loss: 0.8785 - macro_f1: 0.5225 - val_accuracy: 0.4580 - val_loss: 1.0539 - val_macro_f1: 0.3346
# Epoch 100/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5909 - loss: 0.8776 - macro_f1: 0.5233 - val_accuracy: 0.4590 - val_loss: 1.0534 - val_macro_f1: 0.3352
# Epoch 101/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5906 - loss: 0.8771 - macro_f1: 0.5235 - val_accuracy: 0.4610 - val_loss: 1.0523 - val_macro_f1: 0.3363
# Epoch 102/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5905 - loss: 0.8765 - macro_f1: 0.5225 - val_accuracy: 0.4595 - val_loss: 1.0528 - val_macro_f1: 0.3345
# Epoch 103/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5912 - loss: 0.8756 - macro_f1: 0.5241 - val_accuracy: 0.4605 - val_loss: 1.0540 - val_macro_f1: 0.3350
# Epoch 104/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5940 - loss: 0.8737 - macro_f1: 0.5269 - val_accuracy: 0.4613 - val_loss: 1.0512 - val_macro_f1: 0.3354
# Epoch 105/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5923 - loss: 0.8743 - macro_f1: 0.5248 - val_accuracy: 0.4596 - val_loss: 1.0529 - val_macro_f1: 0.3354
# Epoch 106/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5927 - loss: 0.8737 - macro_f1: 0.5259 - val_accuracy: 0.4601 - val_loss: 1.0541 - val_macro_f1: 0.3385
# Epoch 107/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5949 - loss: 0.8715 - macro_f1: 0.5278 - val_accuracy: 0.4640 - val_loss: 1.0503 - val_macro_f1: 0.3342
# Epoch 108/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5940 - loss: 0.8710 - macro_f1: 0.5270 - val_accuracy: 0.4618 - val_loss: 1.0511 - val_macro_f1: 0.3369
# Epoch 109/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5952 - loss: 0.8706 - macro_f1: 0.5290 - val_accuracy: 0.4531 - val_loss: 1.0587 - val_macro_f1: 0.3294
# Epoch 110/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5955 - loss: 0.8700 - macro_f1: 0.5295 - val_accuracy: 0.4651 - val_loss: 1.0509 - val_macro_f1: 0.3347
# Epoch 111/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5970 - loss: 0.8694 - macro_f1: 0.5303 - val_accuracy: 0.4628 - val_loss: 1.0508 - val_macro_f1: 0.3316
# Epoch 112/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5968 - loss: 0.8679 - macro_f1: 0.5308 - val_accuracy: 0.4636 - val_loss: 1.0509 - val_macro_f1: 0.3354
# Epoch 113/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5966 - loss: 0.8690 - macro_f1: 0.5298 - val_accuracy: 0.4612 - val_loss: 1.0522 - val_macro_f1: 0.3333
# Epoch 114/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5977 - loss: 0.8676 - macro_f1: 0.5316 - val_accuracy: 0.4611 - val_loss: 1.0508 - val_macro_f1: 0.3369
# Epoch 115/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5982 - loss: 0.8664 - macro_f1: 0.5321 - val_accuracy: 0.4596 - val_loss: 1.0528 - val_macro_f1: 0.3311
# Epoch 116/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5998 - loss: 0.8656 - macro_f1: 0.5336 - val_accuracy: 0.4597 - val_loss: 1.0519 - val_macro_f1: 0.3371
# Epoch 117/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5979 - loss: 0.8660 - macro_f1: 0.5323 - val_accuracy: 0.4586 - val_loss: 1.0537 - val_macro_f1: 0.3338
# Epoch 118/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.5992 - loss: 0.8644 - macro_f1: 0.5334 - val_accuracy: 0.4587 - val_loss: 1.0519 - val_macro_f1: 0.3337
# Epoch 119/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6001 - loss: 0.8637 - macro_f1: 0.5349 - val_accuracy: 0.4612 - val_loss: 1.0526 - val_macro_f1: 0.3355
# Epoch 120/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.5992 - loss: 0.8652 - macro_f1: 0.5330 - val_accuracy: 0.4602 - val_loss: 1.0499 - val_macro_f1: 0.3368
# Epoch 121/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6014 - loss: 0.8626 - macro_f1: 0.5363 - val_accuracy: 0.4626 - val_loss: 1.0494 - val_macro_f1: 0.3365
# Epoch 122/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6026 - loss: 0.8613 - macro_f1: 0.5379 - val_accuracy: 0.4614 - val_loss: 1.0498 - val_macro_f1: 0.3356
# Epoch 123/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6025 - loss: 0.8611 - macro_f1: 0.5377 - val_accuracy: 0.4595 - val_loss: 1.0512 - val_macro_f1: 0.3430
# Epoch 124/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6013 - loss: 0.8623 - macro_f1: 0.5354 - val_accuracy: 0.4617 - val_loss: 1.0491 - val_macro_f1: 0.3375
# Epoch 125/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6018 - loss: 0.8616 - macro_f1: 0.5365 - val_accuracy: 0.4620 - val_loss: 1.0492 - val_macro_f1: 0.3378
# Epoch 126/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6034 - loss: 0.8594 - macro_f1: 0.5388 - val_accuracy: 0.4623 - val_loss: 1.0490 - val_macro_f1: 0.3357
# Epoch 127/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6033 - loss: 0.8603 - macro_f1: 0.5376 - val_accuracy: 0.4637 - val_loss: 1.0489 - val_macro_f1: 0.3397
# Epoch 128/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6044 - loss: 0.8576 - macro_f1: 0.5400 - val_accuracy: 0.4616 - val_loss: 1.0479 - val_macro_f1: 0.3375
# Epoch 129/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6044 - loss: 0.8575 - macro_f1: 0.5395 - val_accuracy: 0.4626 - val_loss: 1.0473 - val_macro_f1: 0.3400
# Epoch 130/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6052 - loss: 0.8565 - macro_f1: 0.5408 - val_accuracy: 0.4622 - val_loss: 1.0485 - val_macro_f1: 0.3344
# Epoch 131/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6049 - loss: 0.8562 - macro_f1: 0.5404 - val_accuracy: 0.4590 - val_loss: 1.0521 - val_macro_f1: 0.3398
# Epoch 132/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6065 - loss: 0.8553 - macro_f1: 0.5417 - val_accuracy: 0.4619 - val_loss: 1.0487 - val_macro_f1: 0.3432
# Epoch 133/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6066 - loss: 0.8553 - macro_f1: 0.5415 - val_accuracy: 0.4597 - val_loss: 1.0551 - val_macro_f1: 0.3343
# Epoch 134/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6073 - loss: 0.8545 - macro_f1: 0.5432 - val_accuracy: 0.4621 - val_loss: 1.0484 - val_macro_f1: 0.3391
# Epoch 135/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6079 - loss: 0.8541 - macro_f1: 0.5439 - val_accuracy: 0.4606 - val_loss: 1.0491 - val_macro_f1: 0.3345
# Epoch 136/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6071 - loss: 0.8535 - macro_f1: 0.5432 - val_accuracy: 0.4619 - val_loss: 1.0479 - val_macro_f1: 0.3361
# Epoch 137/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6083 - loss: 0.8534 - macro_f1: 0.5440 - val_accuracy: 0.4620 - val_loss: 1.0494 - val_macro_f1: 0.3318
# Epoch 138/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6085 - loss: 0.8521 - macro_f1: 0.5444 - val_accuracy: 0.4580 - val_loss: 1.0568 - val_macro_f1: 0.3364
# Epoch 139/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6106 - loss: 0.8505 - macro_f1: 0.5468 - val_accuracy: 0.4591 - val_loss: 1.0491 - val_macro_f1: 0.3385
# Epoch 140/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6093 - loss: 0.8508 - macro_f1: 0.5448 - val_accuracy: 0.4582 - val_loss: 1.0559 - val_macro_f1: 0.3372
# Epoch 141/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6109 - loss: 0.8497 - macro_f1: 0.5481 - val_accuracy: 0.4605 - val_loss: 1.0508 - val_macro_f1: 0.3359
# Epoch 142/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6113 - loss: 0.8486 - macro_f1: 0.5479 - val_accuracy: 0.4612 - val_loss: 1.0517 - val_macro_f1: 0.3327
# Epoch 143/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6109 - loss: 0.8500 - macro_f1: 0.5465 - val_accuracy: 0.4646 - val_loss: 1.0477 - val_macro_f1: 0.3386
# Epoch 144/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6113 - loss: 0.8489 - macro_f1: 0.5481 - val_accuracy: 0.4634 - val_loss: 1.0459 - val_macro_f1: 0.3372
# Epoch 145/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6118 - loss: 0.8468 - macro_f1: 0.5485 - val_accuracy: 0.4632 - val_loss: 1.0464 - val_macro_f1: 0.3388
# Epoch 146/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6127 - loss: 0.8474 - macro_f1: 0.5495 - val_accuracy: 0.4641 - val_loss: 1.0477 - val_macro_f1: 0.3346
# Epoch 147/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6103 - loss: 0.8495 - macro_f1: 0.5445 - val_accuracy: 0.4642 - val_loss: 1.0475 - val_macro_f1: 0.3385
# Epoch 148/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6119 - loss: 0.8470 - macro_f1: 0.5481 - val_accuracy: 0.4637 - val_loss: 1.0484 - val_macro_f1: 0.3411
# Epoch 149/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6134 - loss: 0.8452 - macro_f1: 0.5505 - val_accuracy: 0.4664 - val_loss: 1.0464 - val_macro_f1: 0.3410
# Epoch 150/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6140 - loss: 0.8456 - macro_f1: 0.5511 - val_accuracy: 0.4633 - val_loss: 1.0489 - val_macro_f1: 0.3328
# Epoch 151/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6143 - loss: 0.8438 - macro_f1: 0.5518 - val_accuracy: 0.4628 - val_loss: 1.0480 - val_macro_f1: 0.3393
# Epoch 152/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6134 - loss: 0.8444 - macro_f1: 0.5497 - val_accuracy: 0.4642 - val_loss: 1.0472 - val_macro_f1: 0.3414
# Epoch 153/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6143 - loss: 0.8443 - macro_f1: 0.5522 - val_accuracy: 0.4615 - val_loss: 1.0492 - val_macro_f1: 0.3367
# Epoch 154/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6154 - loss: 0.8425 - macro_f1: 0.5529 - val_accuracy: 0.4638 - val_loss: 1.0483 - val_macro_f1: 0.3391
# Epoch 155/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6152 - loss: 0.8436 - macro_f1: 0.5529 - val_accuracy: 0.4660 - val_loss: 1.0477 - val_macro_f1: 0.3390
# Epoch 156/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6159 - loss: 0.8413 - macro_f1: 0.5529 - val_accuracy: 0.4647 - val_loss: 1.0490 - val_macro_f1: 0.3355
# Epoch 157/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6162 - loss: 0.8422 - macro_f1: 0.5529 - val_accuracy: 0.4639 - val_loss: 1.0494 - val_macro_f1: 0.3367
# Epoch 158/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6159 - loss: 0.8430 - macro_f1: 0.5528 - val_accuracy: 0.4648 - val_loss: 1.0472 - val_macro_f1: 0.3406
# Epoch 159/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6174 - loss: 0.8403 - macro_f1: 0.5557 - val_accuracy: 0.4612 - val_loss: 1.0470 - val_macro_f1: 0.3374
# Epoch 160/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6189 - loss: 0.8397 - macro_f1: 0.5564 - val_accuracy: 0.4645 - val_loss: 1.0474 - val_macro_f1: 0.3403
# Epoch 161/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6182 - loss: 0.8393 - macro_f1: 0.5564 - val_accuracy: 0.4655 - val_loss: 1.0460 - val_macro_f1: 0.3404
# Epoch 162/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6181 - loss: 0.8387 - macro_f1: 0.5561 - val_accuracy: 0.4600 - val_loss: 1.0511 - val_macro_f1: 0.3289
# Epoch 163/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6187 - loss: 0.8384 - macro_f1: 0.5573 - val_accuracy: 0.4649 - val_loss: 1.0476 - val_macro_f1: 0.3381
# Epoch 164/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6182 - loss: 0.8386 - macro_f1: 0.5558 - val_accuracy: 0.4672 - val_loss: 1.0455 - val_macro_f1: 0.3399
# Epoch 165/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6192 - loss: 0.8369 - macro_f1: 0.5577 - val_accuracy: 0.4630 - val_loss: 1.0467 - val_macro_f1: 0.3402
# Epoch 166/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6205 - loss: 0.8373 - macro_f1: 0.5590 - val_accuracy: 0.4629 - val_loss: 1.0471 - val_macro_f1: 0.3381
# Epoch 167/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6206 - loss: 0.8354 - macro_f1: 0.5588 - val_accuracy: 0.4628 - val_loss: 1.0510 - val_macro_f1: 0.3397
# Epoch 168/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6199 - loss: 0.8369 - macro_f1: 0.5584 - val_accuracy: 0.4598 - val_loss: 1.0507 - val_macro_f1: 0.3366
# Epoch 169/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6199 - loss: 0.8373 - macro_f1: 0.5575 - val_accuracy: 0.4627 - val_loss: 1.0471 - val_macro_f1: 0.3370
# Epoch 170/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6209 - loss: 0.8346 - macro_f1: 0.5598 - val_accuracy: 0.4622 - val_loss: 1.0495 - val_macro_f1: 0.3305
# Epoch 171/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6209 - loss: 0.8343 - macro_f1: 0.5590 - val_accuracy: 0.4624 - val_loss: 1.0489 - val_macro_f1: 0.3336
# Epoch 172/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6217 - loss: 0.8336 - macro_f1: 0.5606 - val_accuracy: 0.4653 - val_loss: 1.0478 - val_macro_f1: 0.3379
# Epoch 173/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6203 - loss: 0.8356 - macro_f1: 0.5563 - val_accuracy: 0.4614 - val_loss: 1.0493 - val_macro_f1: 0.3393
# Epoch 174/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6232 - loss: 0.8322 - macro_f1: 0.5621 - val_accuracy: 0.4643 - val_loss: 1.0485 - val_macro_f1: 0.3356
# Epoch 175/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6129 - loss: 0.8458 - macro_f1: 0.5472 - val_accuracy: 0.4631 - val_loss: 1.0503 - val_macro_f1: 0.3326
# Epoch 176/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6222 - loss: 0.8328 - macro_f1: 0.5607 - val_accuracy: 0.4645 - val_loss: 1.0485 - val_macro_f1: 0.3357
# Epoch 177/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6224 - loss: 0.8322 - macro_f1: 0.5610 - val_accuracy: 0.4613 - val_loss: 1.0529 - val_macro_f1: 0.3320
# Epoch 178/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6237 - loss: 0.8306 - macro_f1: 0.5635 - val_accuracy: 0.4612 - val_loss: 1.0528 - val_macro_f1: 0.3269
# Epoch 179/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6222 - loss: 0.8325 - macro_f1: 0.5607 - val_accuracy: 0.4645 - val_loss: 1.0485 - val_macro_f1: 0.3404
# Epoch 180/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6242 - loss: 0.8309 - macro_f1: 0.5632 - val_accuracy: 0.4624 - val_loss: 1.0504 - val_macro_f1: 0.3341
# Epoch 181/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6033 - loss: 0.8594 - macro_f1: 0.5257 - val_accuracy: 0.4556 - val_loss: 1.0573 - val_macro_f1: 0.3261
# Epoch 182/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6180 - loss: 0.8406 - macro_f1: 0.5512 - val_accuracy: 0.4625 - val_loss: 1.0487 - val_macro_f1: 0.3397
# Epoch 183/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6250 - loss: 0.8301 - macro_f1: 0.5652 - val_accuracy: 0.4639 - val_loss: 1.0492 - val_macro_f1: 0.3379
# Epoch 184/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6263 - loss: 0.8285 - macro_f1: 0.5667 - val_accuracy: 0.4666 - val_loss: 1.0472 - val_macro_f1: 0.3409
# Epoch 185/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6256 - loss: 0.8279 - macro_f1: 0.5655 - val_accuracy: 0.4642 - val_loss: 1.0494 - val_macro_f1: 0.3408
# Epoch 186/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6258 - loss: 0.8275 - macro_f1: 0.5656 - val_accuracy: 0.4664 - val_loss: 1.0471 - val_macro_f1: 0.3367
# Epoch 187/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6258 - loss: 0.8286 - macro_f1: 0.5657 - val_accuracy: 0.4659 - val_loss: 1.0470 - val_macro_f1: 0.3380
# Epoch 188/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6259 - loss: 0.8281 - macro_f1: 0.5655 - val_accuracy: 0.4662 - val_loss: 1.0469 - val_macro_f1: 0.3378
# Epoch 189/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.6257 - loss: 0.8279 - macro_f1: 0.5650 - val_accuracy: 0.4657 - val_loss: 1.0493 - val_macro_f1: 0.3371
# Epoch 190/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6278 - loss: 0.8259 - macro_f1: 0.5678 - val_accuracy: 0.4659 - val_loss: 1.0476 - val_macro_f1: 0.3415
# Epoch 191/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6264 - loss: 0.8278 - macro_f1: 0.5660 - val_accuracy: 0.4667 - val_loss: 1.0497 - val_macro_f1: 0.3369
# Epoch 192/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6266 - loss: 0.8277 - macro_f1: 0.5654 - val_accuracy: 0.4640 - val_loss: 1.0475 - val_macro_f1: 0.3357
# Epoch 193/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6278 - loss: 0.8249 - macro_f1: 0.5679 - val_accuracy: 0.4631 - val_loss: 1.0511 - val_macro_f1: 0.3334
# Epoch 194/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6275 - loss: 0.8257 - macro_f1: 0.5667 - val_accuracy: 0.4654 - val_loss: 1.0474 - val_macro_f1: 0.3390
# Epoch 195/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6285 - loss: 0.8249 - macro_f1: 0.5677 - val_accuracy: 0.4621 - val_loss: 1.0506 - val_macro_f1: 0.3379
# Epoch 196/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6290 - loss: 0.8245 - macro_f1: 0.5689 - val_accuracy: 0.4654 - val_loss: 1.0506 - val_macro_f1: 0.3376
# Epoch 197/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6293 - loss: 0.8233 - macro_f1: 0.5702 - val_accuracy: 0.4647 - val_loss: 1.0470 - val_macro_f1: 0.3371
# Epoch 198/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6294 - loss: 0.8237 - macro_f1: 0.5691 - val_accuracy: 0.4639 - val_loss: 1.0489 - val_macro_f1: 0.3407
# Epoch 199/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.6295 - loss: 0.8223 - macro_f1: 0.5697 - val_accuracy: 0.4657 - val_loss: 1.0504 - val_macro_f1: 0.3412
# Epoch 200/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.6269 - loss: 0.8280 - macro_f1: 0.5662 - val_accuracy: 0.4657 - val_loss: 1.0509 - val_macro_f1: 0.3396
# CPU times: user 1h 17min 21s, sys: 7min 12s, total: 1h 24min 34s
# Wall time: 51min 4s

# %%
print(accuracy_score(np.argmax(testY_CNN, axis=1), np.argmax(lstm2.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step
# 0.47705895847671487

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = lstm2.predict(testX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(testY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score
print(classification_report(np.argmax(testY_CNN, axis=1), np.argmax(lstm2.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.50      0.52      0.51     47915
#            1       0.52      0.28      0.37     48050
#            2       0.44      0.64      0.52     43523
#
#     accuracy                           0.48    139488
#    macro avg       0.49      0.48      0.47    139488
# weighted avg       0.49      0.48      0.47    139488

# %%
print(accuracy_score(np.argmax(trainY_CNN, axis=1), np.argmax(lstm2.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step
# 0.6411554189719245

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = lstm2.predict(trainX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(trainY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score
print(classification_report(np.argmax(trainY_CNN, axis=1), np.argmax(lstm2.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67     84426
#            1       0.68      0.30      0.42     36210
#            2       0.62      0.75      0.68     83065
#
#     accuracy                           0.64    203701
#    macro avg       0.65      0.58      0.59    203701
# weighted avg       0.65      0.64      0.63    203701

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TEST DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = lstm2.predict(testX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    """
    Implements trading strategy using the FI-2010 paper's methodology

    Args:
        predictions: numpy array of model predictions (n_samples, 3)
        dec_data: numpy array of decoded price data
        budget: amount to invest per trade
        prob_threshold: probability threshold for trading
        k: prediction horizon (number of steps to look ahead)
        alpha: threshold for determining price movement direction
    """
    # Get normalized ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        # Calculate m+ (future average) according to paper
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        # Calculate actual price movement using paper's method
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:  # not stable
            # Determine actual direction using same threshold as training
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)

            # Long trade (UP prediction)
            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })

            # Short trade (DOWN prediction)
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        # Print performance metrics
        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_test,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 14293
# Win rate: 0.55%
# Total profit: $161.14
# Average profit per trade: $0.0113
#
# Direction Analysis:
#
# UP trades:
# Count: 7902
# Win rate: 0.61%
# Total profit: $-11.87
# Average profit: $-0.0015
#
# DOWN trades:
# Count: 6391
# Win rate: 0.47%
# Total profit: $173.02
# Average profit: $0.0271
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 10064
# Win rate: 0.58%
# Total profit: $165.58
# Average profit per trade: $0.0165
#
# Direction Analysis:
#
# UP trades:
# Count: 5539
# Win rate: 0.60%
# Total profit: $-10.87
# Average profit: $-0.0020
#
# DOWN trades:
# Count: 4525
# Win rate: 0.55%
# Total profit: $176.45
# Average profit: $0.0390
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 6224
# Win rate: 0.53%
# Total profit: $33.52
# Average profit per trade: $0.0054
#
# Direction Analysis:
#
# UP trades:
# Count: 3395
# Win rate: 0.59%
# Total profit: $35.92
# Average profit: $0.0106
#
# DOWN trades:
# Count: 2829
# Win rate: 0.46%
# Total profit: $-2.40
# Average profit: $-0.0008
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 2883
# Win rate: 0.52%
# Total profit: $-0.72
# Average profit per trade: $-0.0003
#
# Direction Analysis:
#
# UP trades:
# Count: 1475
# Win rate: 0.61%
# Total profit: $1.91
# Average profit: $0.0013
#
# DOWN trades:
# Count: 1408
# Win rate: 0.43%
# Total profit: $-2.64
# Average profit: $-0.0019
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 428
# Win rate: 0.47%
# Total profit: $-0.52
# Average profit per trade: $-0.0012
#
# Direction Analysis:
#
# UP trades:
# Count: 196
# Win rate: 1.02%
# Total profit: $-0.23
# Average profit: $-0.0012
#
# DOWN trades:
# Count: 232
# Win rate: 0.00%
# Total profit: $-0.29
# Average profit: $-0.0013
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000    161.143577       14293  0.545722    0.011274         7902
# 1   0.850000    165.583986       10064  0.576312    0.016453         5539
# 2   0.900000     33.523325        6224  0.530206    0.005386         3395
# 3   0.950000     -0.723887        2883  0.520291   -0.000251         1475
# 4   0.990000     -0.520283         428  0.467290   -0.001216          196
#
#    short_trades
# 0          6391
# 1          4525
# 2          2829
# 3          1408
# 4           232

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TRAIN DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = lstm2.predict(trainX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    """
    Implements trading strategy using the FI-2010 paper's methodology

    Args:
        predictions: numpy array of model predictions (n_samples, 3)
        dec_data: numpy array of decoded price data
        budget: amount to invest per trade
        prob_threshold: probability threshold for trading
        k: prediction horizon (number of steps to look ahead)
        alpha: threshold for determining price movement direction
    """
    # Get normalized ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        # Calculate m+ (future average) according to paper
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        # Calculate actual price movement using paper's method
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:  # not stable
            # Determine actual direction using same threshold as training
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)

            # Long trade (UP prediction)
            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })

            # Short trade (DOWN prediction)
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        # Print performance metrics
        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_train,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 35965
# Win rate: 0.65%
# Total profit: $74.51
# Average profit per trade: $0.0021
#
# Direction Analysis:
#
# UP trades:
# Count: 18913
# Win rate: 0.63%
# Total profit: $20.72
# Average profit: $0.0011
#
# DOWN trades:
# Count: 17052
# Win rate: 0.68%
# Total profit: $53.80
# Average profit: $0.0032
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 26188
# Win rate: 0.64%
# Total profit: $60.15
# Average profit per trade: $0.0023
#
# Direction Analysis:
#
# UP trades:
# Count: 13740
# Win rate: 0.62%
# Total profit: $13.30
# Average profit: $0.0010
#
# DOWN trades:
# Count: 12448
# Win rate: 0.66%
# Total profit: $46.85
# Average profit: $0.0038
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 16960
# Win rate: 0.56%
# Total profit: $29.55
# Average profit per trade: $0.0017
#
# Direction Analysis:
#
# UP trades:
# Count: 8751
# Win rate: 0.51%
# Total profit: $3.76
# Average profit: $0.0004
#
# DOWN trades:
# Count: 8209
# Win rate: 0.61%
# Total profit: $25.79
# Average profit: $0.0031
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 8126
# Win rate: 0.59%
# Total profit: $9.62
# Average profit per trade: $0.0012
#
# Direction Analysis:
#
# UP trades:
# Count: 4107
# Win rate: 0.71%
# Total profit: $1.63
# Average profit: $0.0004
#
# DOWN trades:
# Count: 4019
# Win rate: 0.47%
# Total profit: $7.98
# Average profit: $0.0020
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 1191
# Win rate: 0.84%
# Total profit: $2.95
# Average profit per trade: $0.0025
#
# Direction Analysis:
#
# UP trades:
# Count: 560
# Win rate: 1.07%
# Total profit: $0.72
# Average profit: $0.0013
#
# DOWN trades:
# Count: 631
# Win rate: 0.63%
# Total profit: $2.23
# Average profit: $0.0035
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000     74.514548       35965  0.653413    0.002072        18913
# 1   0.850000     60.152935       26188  0.637697    0.002297        13740
# 2   0.900000     29.549483       16960  0.560142    0.001742         8751
# 3   0.950000      9.617102        8126  0.590697    0.001183         4107
# 4   0.990000      2.951292        1191  0.839631    0.002478          560
#
#    short_trades
# 0         17052
# 1         12448
# 2          8209
# 3          4019
# 4           631

# %%
def calculate_perturbation_volume(original, perturbed):
    original_flat = original.reshape(original.shape[0], -1)
    perturbed_flat = perturbed.reshape(perturbed.shape[0], -1)
    perturbation = np.linalg.norm(original_flat - perturbed_flat, ord=2, axis=1)
    avg_perturbation = np.mean(perturbation)
    return avg_perturbation

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES (LOW)"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
num_iterations = 5
step_size = 0.01

# Define your model
model = lstm2

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}
avg_accuracies3 = {}
perturbed_volumes3 = {}
avg_precision3 = {}
avg_recall3 = {}
avg_roc_auc3 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def fgsm_attack(images, labels, epsilon):
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
    gradient = tape.gradient(loss, images)
    signed_grad = tf.sign(gradient)

    signed_masked = signed_grad.numpy()
    signed_masked[:, :99, :, :] = 0
    signed_masked[:, 99:, ::2, :] = 0
    signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

    perturbed_images = images + epsilon * signed_masked
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images

def pgd_attack(images, labels, epsilon, trainX_CNN, start_idx, end_idx):
    perturbed_images = tf.identity(images)

    for _ in range(num_iterations):
        # Gradient step
        with tf.GradientTape() as tape:
            tape.watch(perturbed_images)
            predictions = model(perturbed_images)
            loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
        gradient = tape.gradient(loss, perturbed_images)
        signed_grad = tf.sign(gradient)

        # Apply masking to gradient
        signed_masked = signed_grad.numpy()
        signed_masked[:, :99, :, :] = 0
        signed_masked[:, 99:, ::2, :] = 0
        signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

        # Apply gradient step
        perturbed_images = perturbed_images + step_size * signed_masked

        # Step 1: Apply volume constraint
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

    return perturbed_images

def random_noise_attack(images, epsilon, trainX_CNN, start_idx, end_idx):
    """Random noise baseline attack: uniform noise within [-epsilon, epsilon]."""
    noise = tf.random.uniform(tf.shape(images), -epsilon, epsilon)
    noise = noise.numpy()
    noise[:, :99, :, :] = 0
    noise[:, 99:, ::2, :] = 0
    noise = tf.convert_to_tensor(noise, dtype=tf.float32)
    perturbed_images = images + noise
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    # Apply volume constraint
    perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)
    return perturbed_images


def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_accuracy3 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    total_perturbation3 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []
    all_predicted_labels3 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []
    epsilon_pred_probs_random = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon, trainX_CNN, start_idx, end_idx)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)
        perturbed_images3 = random_noise_attack(batch_images, epsilon, trainX_CNN, start_idx, end_idx)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())
        perturbation3 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images3.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2
        total_perturbation3 += perturbation3

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()
        X_perturbed3 = perturbed_images3.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)
        adversarial_probs3 = model.predict(X_perturbed3)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)
        adversarial_predictions3 = np.argmax(adversarial_probs3, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)
        epsilon_pred_probs_random.append(adversarial_probs3)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)
        all_predicted_labels3.extend(adversarial_predictions3)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2
        accuracy3 = accuracy_score(true_labels_batch, adversarial_predictions3)
        total_accuracy3 += accuracy3

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    average_accuracy3 = total_accuracy3 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches
    avg_perturbation3 = total_perturbation3 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)
    epsilon_pred_probs_random = np.vstack(epsilon_pred_probs_random)

    # Calculate and plot ROC curve

    # Compute macro-average ROC AUC for Random Noise
    fpr3 = dict()
    tpr3 = dict()
    roc_auc3_per_class = dict()
    for i in range(3):
        fpr3[i], tpr3[i], _ = roc_curve(epsilon_true_labels_onehot[:, i], epsilon_pred_probs_random[:, i])
        roc_auc3_per_class[i] = auc(fpr3[i], tpr3[i])
    all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(3)]))
    mean_tpr3 = np.zeros_like(all_fpr3)
    for i in range(3):
        mean_tpr3 += np.interp(all_fpr3, fpr3[i], tpr3[i])
    mean_tpr3 /= 3
    roc_auc3 = auc(all_fpr3, mean_tpr3)
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2
    avg_roc_auc3[epsilon] = roc_auc3

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')
    precision3 = precision_score(all_true_labels, all_predicted_labels3, average='macro')
    recall3 = recall_score(all_true_labels, all_predicted_labels3, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2
    avg_precision3[epsilon] = precision3
    avg_recall3[epsilon] = recall3

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)
    random_report = classification_report(all_true_labels, all_predicted_labels3, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    avg_accuracies3[epsilon] = average_accuracy3
    print(f"Average accuracy of Random Noise attack for epsilon value {epsilon}: {average_accuracy3}")
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2
    perturbed_volumes3[epsilon] = avg_perturbation3
    print(f"Average perturbation volume for Random Noise attack with epsilon {epsilon}: {avg_perturbation3}")

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")
    print(f"Average precision of Random Noise attack for epsilon value {epsilon}: {precision3}")
    print(f"Average recall of Random Noise attack for epsilon value {epsilon}: {recall3}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")
    print(f"ROC AUC of Random Noise attack for epsilon value {epsilon}: {roc_auc3}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))
    print(f"\nClassification Report for Random Noise Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels3))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 1e-06
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 1e-06: 0.3191666666666666
# Average accuracy of FGSM attack for epsilon value 1e-06: 0.48262318840579704
# Average accuracy of Random Noise attack for epsilon value 1e-06: 0.3906376811594204
# Average perturbation volume for PGD attack with epsilon 1e-06: 2.2732956409454346
# Average perturbation volume for FGSM attack with epsilon 1e-06: 4.471045031095855e-06
# Average perturbation volume for Random Noise attack with epsilon 1e-06: 2.264003276824951
# Average precision of PGD attack for epsilon value 1e-06: 0.3209768960627306
# Average recall of PGD attack for epsilon value 1e-06: 0.3199336513997931
# Average precision of FGSM attack for epsilon value 1e-06: 0.4906183691292129
# Average recall of FGSM attack for epsilon value 1e-06: 0.48661496357612594
# Average precision of Random Noise attack for epsilon value 1e-06: 0.39081704182571686
# Average recall of Random Noise attack for epsilon value 1e-06: 0.39200435189167165
# ROC AUC of PGD attack for epsilon value 1e-06: 0.49175886370517025
# ROC AUC of FGSM attack for epsilon value 1e-06: 0.6828178599759458
# ROC AUC of Random Noise attack for epsilon value 1e-06: 0.5699490092152104
#
# Classification Report for PGD Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.32      0.47      0.38     47512
#            1       0.33      0.14      0.19     47269
#            2       0.31      0.36      0.33     43219
#
#     accuracy                           0.32    138000
#    macro avg       0.32      0.32      0.30    138000
# weighted avg       0.32      0.32      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52     47512
#            1       0.52      0.30      0.38     47269
#            2       0.44      0.63      0.52     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.49      0.47    138000
# weighted avg       0.49      0.48      0.47    138000
#
#
# Classification Report for Random Noise Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.39      0.56      0.46     47512
#            1       0.39      0.17      0.24     47269
#            2       0.39      0.45      0.42     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000
#
# Epsilon value: 1e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 1e-05: 0.31941304347826094
# Average accuracy of FGSM attack for epsilon value 1e-05: 0.48257971014492745
# Average accuracy of Random Noise attack for epsilon value 1e-05: 0.3906376811594204
# Average perturbation volume for PGD attack with epsilon 1e-05: 2.273292303085327
# Average perturbation volume for FGSM attack with epsilon 1e-05: 4.47205820819363e-05
# Average perturbation volume for Random Noise attack with epsilon 1e-05: 2.264003276824951
# Average precision of PGD attack for epsilon value 1e-05: 0.32128245039768577
# Average recall of PGD attack for epsilon value 1e-05: 0.32018028617218847
# Average precision of FGSM attack for epsilon value 1e-05: 0.4905645573117268
# Average recall of FGSM attack for epsilon value 1e-05: 0.4865720999283982
# Average precision of Random Noise attack for epsilon value 1e-05: 0.39082077404626253
# Average recall of Random Noise attack for epsilon value 1e-05: 0.39200435189167165
# ROC AUC of PGD attack for epsilon value 1e-05: 0.4917509339949365
# ROC AUC of FGSM attack for epsilon value 1e-05: 0.6827768924834481
# ROC AUC of Random Noise attack for epsilon value 1e-05: 0.5699489960890239
#
# Classification Report for PGD Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.32      0.47      0.38     47512
#            1       0.33      0.14      0.19     47269
#            2       0.31      0.36      0.33     43219
#
#     accuracy                           0.32    138000
#    macro avg       0.32      0.32      0.30    138000
# weighted avg       0.32      0.32      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52     47512
#            1       0.52      0.30      0.38     47269
#            2       0.44      0.63      0.52     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.49      0.47    138000
# weighted avg       0.49      0.48      0.47    138000
#
#
# Classification Report for Random Noise Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.39      0.56      0.46     47512
#            1       0.39      0.17      0.24     47269
#            2       0.39      0.45      0.42     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000
#
# Epsilon value: 0.0001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 0.0001: 0.31927536231884057
# Average accuracy of FGSM attack for epsilon value 0.0001: 0.4821666666666667
# Average accuracy of Random Noise attack for epsilon value 0.0001: 0.3906376811594204
# Average perturbation volume for PGD attack with epsilon 0.0001: 2.2732861042022705
# Average perturbation volume for FGSM attack with epsilon 0.0001: 0.00044705451000481844
# Average perturbation volume for Random Noise attack with epsilon 0.0001: 2.264003276824951
# Average precision of PGD attack for epsilon value 0.0001: 0.32104296827005335
# Average recall of PGD attack for epsilon value 0.0001: 0.32005722340172754
# Average precision of FGSM attack for epsilon value 0.0001: 0.4901678901827246
# Average recall of FGSM attack for epsilon value 0.0001: 0.4861584551930403
# Average precision of Random Noise attack for epsilon value 0.0001: 0.39081886429760754
# Average recall of Random Noise attack for epsilon value 0.0001: 0.3920036550058841
# ROC AUC of PGD attack for epsilon value 0.0001: 0.49175402059597056
# ROC AUC of FGSM attack for epsilon value 0.0001: 0.6823689845456143
# ROC AUC of Random Noise attack for epsilon value 0.0001: 0.5699491603225076
#
# Classification Report for PGD Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.32      0.47      0.38     47512
#            1       0.33      0.14      0.19     47269
#            2       0.31      0.36      0.33     43219
#
#     accuracy                           0.32    138000
#    macro avg       0.32      0.32      0.30    138000
# weighted avg       0.32      0.32      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.51      0.53      0.52     47512
#            1       0.52      0.30      0.38     47269
#            2       0.44      0.63      0.52     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.49      0.47    138000
# weighted avg       0.49      0.48      0.47    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.39      0.56      0.46     47512
#            1       0.39      0.17      0.24     47269
#            2       0.39      0.45      0.42     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000
#
# Epsilon value: 0.001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 0.001: 0.3191376811594204
# Average accuracy of FGSM attack for epsilon value 0.001: 0.47747101449275353
# Average accuracy of Random Noise attack for epsilon value 0.001: 0.3906086956521739
# Average perturbation volume for PGD attack with epsilon 0.001: 2.2732951641082764
# Average perturbation volume for FGSM attack with epsilon 0.001: 0.004454470239579678
# Average perturbation volume for Random Noise attack with epsilon 0.001: 2.2640039920806885
# Average precision of PGD attack for epsilon value 0.001: 0.3208765236626936
# Average recall of PGD attack for epsilon value 0.001: 0.3199035697898282
# Average precision of FGSM attack for epsilon value 0.001: 0.48563090618953114
# Average recall of FGSM attack for epsilon value 0.001: 0.4814515640353969
# Average precision of Random Noise attack for epsilon value 0.001: 0.3908052276135224
# Average recall of Random Noise attack for epsilon value 0.001: 0.39197353732931184
# ROC AUC of PGD attack for epsilon value 0.001: 0.49175570549198044
# ROC AUC of FGSM attack for epsilon value 0.001: 0.6783052541078115
# ROC AUC of Random Noise attack for epsilon value 0.001: 0.5699487695337698
#
# Classification Report for PGD Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.32      0.47      0.38     47512
#            1       0.33      0.14      0.19     47269
#            2       0.31      0.35      0.33     43219
#
#     accuracy                           0.32    138000
#    macro avg       0.32      0.32      0.30    138000
# weighted avg       0.32      0.32      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.52     47512
#            1       0.51      0.30      0.37     47269
#            2       0.44      0.62      0.51     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.48      0.47    138000
# weighted avg       0.49      0.48      0.47    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.39      0.56      0.46     47512
#            1       0.39      0.17      0.24     47269
#            2       0.39      0.45      0.42     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.01, 0.1, 1, 10]
num_iterations = 5
step_size = 0.01

# Define your model
model = lstm2

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}
avg_accuracies3 = {}
perturbed_volumes3 = {}
avg_precision3 = {}
avg_recall3 = {}
avg_roc_auc3 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def fgsm_attack(images, labels, epsilon):
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
    gradient = tape.gradient(loss, images)
    signed_grad = tf.sign(gradient)

    signed_masked = signed_grad.numpy()
    signed_masked[:, :99, :, :] = 0
    signed_masked[:, 99:, ::2, :] = 0
    signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

    perturbed_images = images + epsilon * signed_masked
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images

def pgd_attack(images, labels, epsilon, trainX_CNN, start_idx, end_idx):
    perturbed_images = tf.identity(images)

    for _ in range(num_iterations):
        # Gradient step
        with tf.GradientTape() as tape:
            tape.watch(perturbed_images)
            predictions = model(perturbed_images)
            loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
        gradient = tape.gradient(loss, perturbed_images)
        signed_grad = tf.sign(gradient)

        # Apply masking to gradient
        signed_masked = signed_grad.numpy()
        signed_masked[:, :99, :, :] = 0
        signed_masked[:, 99:, ::2, :] = 0
        signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

        # Apply gradient step
        perturbed_images = perturbed_images + step_size * signed_masked

        # Step 1: Apply volume constraint
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

        # Step 2: Apply L2 norm constraint (projection step)
        delta = perturbed_images - images  # Calculate current perturbation

        # Reshape to flatten all dimensions except batch
        delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

        # Calculate L2 norm on the flattened dimensions
        norm = tf.norm(delta_flat, axis=1, keepdims=True)

        # Reshape norm for broadcasting
        norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

        # Scale perturbation
        scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
        delta = delta * scaling

        perturbed_images = images + delta  # Apply constrained perturbation

        # Step 3: Apply clipping to valid range [0,1]
        perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

        # Step 4: Re-apply volume constraint after all other constraints
        # This ensures volume constraint takes precedence if there's a conflict
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

    return perturbed_images

def random_noise_attack(images, epsilon, trainX_CNN, start_idx, end_idx):
    """Random noise baseline attack: uniform noise within [-epsilon, epsilon]."""
    noise = tf.random.uniform(tf.shape(images), -epsilon, epsilon)
    noise = noise.numpy()
    noise[:, :99, :, :] = 0
    noise[:, 99:, ::2, :] = 0
    noise = tf.convert_to_tensor(noise, dtype=tf.float32)
    perturbed_images = images + noise
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    # Apply volume constraint
    perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)
    return perturbed_images


def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_accuracy3 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    total_perturbation3 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []
    all_predicted_labels3 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []
    epsilon_pred_probs_random = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon, trainX_CNN, start_idx, end_idx)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)
        perturbed_images3 = random_noise_attack(batch_images, epsilon, trainX_CNN, start_idx, end_idx)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())
        perturbation3 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images3.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2
        total_perturbation3 += perturbation3

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()
        X_perturbed3 = perturbed_images3.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)
        adversarial_probs3 = model.predict(X_perturbed3)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)
        adversarial_predictions3 = np.argmax(adversarial_probs3, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)
        epsilon_pred_probs_random.append(adversarial_probs3)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)
        all_predicted_labels3.extend(adversarial_predictions3)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2
        accuracy3 = accuracy_score(true_labels_batch, adversarial_predictions3)
        total_accuracy3 += accuracy3

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    average_accuracy3 = total_accuracy3 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches
    avg_perturbation3 = total_perturbation3 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)
    epsilon_pred_probs_random = np.vstack(epsilon_pred_probs_random)

    # Calculate and plot ROC curve

    # Compute macro-average ROC AUC for Random Noise
    fpr3 = dict()
    tpr3 = dict()
    roc_auc3_per_class = dict()
    for i in range(3):
        fpr3[i], tpr3[i], _ = roc_curve(epsilon_true_labels_onehot[:, i], epsilon_pred_probs_random[:, i])
        roc_auc3_per_class[i] = auc(fpr3[i], tpr3[i])
    all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(3)]))
    mean_tpr3 = np.zeros_like(all_fpr3)
    for i in range(3):
        mean_tpr3 += np.interp(all_fpr3, fpr3[i], tpr3[i])
    mean_tpr3 /= 3
    roc_auc3 = auc(all_fpr3, mean_tpr3)
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2
    avg_roc_auc3[epsilon] = roc_auc3

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')
    precision3 = precision_score(all_true_labels, all_predicted_labels3, average='macro')
    recall3 = recall_score(all_true_labels, all_predicted_labels3, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2
    avg_precision3[epsilon] = precision3
    avg_recall3[epsilon] = recall3

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)
    random_report = classification_report(all_true_labels, all_predicted_labels3, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    avg_accuracies3[epsilon] = average_accuracy3
    print(f"Average accuracy of Random Noise attack for epsilon value {epsilon}: {average_accuracy3}")
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2
    perturbed_volumes3[epsilon] = avg_perturbation3
    print(f"Average perturbation volume for Random Noise attack with epsilon {epsilon}: {avg_perturbation3}")

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")
    print(f"Average precision of Random Noise attack for epsilon value {epsilon}: {precision3}")
    print(f"Average recall of Random Noise attack for epsilon value {epsilon}: {recall3}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")
    print(f"ROC AUC of Random Noise attack for epsilon value {epsilon}: {roc_auc3}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))
    print(f"\nClassification Report for Random Noise Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels3))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 0.01
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 0.01: 0.3905
# Average accuracy of FGSM attack for epsilon value 0.01: 0.4415362318840581
# Average accuracy of Random Noise attack for epsilon value 0.01: 0.3906304347826086
# Average perturbation volume for PGD attack with epsilon 0.01: 2.2640035152435303
# Average perturbation volume for FGSM attack with epsilon 0.01: 0.040307775139808655
# Average perturbation volume for Random Noise attack with epsilon 0.01: 2.2640953063964844
# Average precision of PGD attack for epsilon value 0.01: 0.3907152596701819
# Average recall of PGD attack for epsilon value 0.01: 0.3918640833761656
# Average precision of FGSM attack for epsilon value 0.01: 0.45071780004160283
# Average recall of FGSM attack for epsilon value 0.01: 0.44530405929952416
# Average precision of Random Noise attack for epsilon value 0.01: 0.39096398018289547
# Average recall of Random Noise attack for epsilon value 0.01: 0.39197832825066853
# ROC AUC of PGD attack for epsilon value 0.01: 0.5698663033382178
# ROC AUC of FGSM attack for epsilon value 0.01: 0.6444510182456277
# ROC AUC of Random Noise attack for epsilon value 0.01: 0.5699390050045445
#
# Classification Report for PGD Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.39      0.56      0.46     47512
#            1       0.39      0.17      0.24     47269
#            2       0.39      0.45      0.42     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000
#
#
# Classification Report for FGSM Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.46      0.49      0.47     47512
#            1       0.48      0.27      0.35     47269
#            2       0.41      0.58      0.48     43219
#
#     accuracy                           0.44    138000
#    macro avg       0.45      0.45      0.43    138000
# weighted avg       0.45      0.44      0.43    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.39      0.56      0.46     47512
#            1       0.39      0.17      0.24     47269
#            2       0.39      0.45      0.42     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000
#
# Epsilon value: 0.1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 0.1: 0.38816666666666677
# Average accuracy of FGSM attack for epsilon value 0.1: 0.2311231884057971
# Average accuracy of Random Noise attack for epsilon value 0.1: 0.38965942028985506
# Average perturbation volume for PGD attack with epsilon 0.1: 2.2641100883483887
# Average perturbation volume for FGSM attack with epsilon 0.1: 0.32546836137771606
# Average perturbation volume for Random Noise attack with epsilon 0.1: 2.2743639945983887
# Average precision of PGD attack for epsilon value 0.1: 0.3887653240006188
# Average recall of PGD attack for epsilon value 0.1: 0.3894987897953342
# Average precision of FGSM attack for epsilon value 0.1: 0.2506507179121935
# Average recall of FGSM attack for epsilon value 0.1: 0.23268540595403028
# Average precision of Random Noise attack for epsilon value 0.1: 0.3898208334428162
# Average recall of Random Noise attack for epsilon value 0.1: 0.39082468970632983
# ROC AUC of PGD attack for epsilon value 0.1: 0.5687243856554696
# ROC AUC of FGSM attack for epsilon value 0.1: 0.4265431819779268
# ROC AUC of Random Noise attack for epsilon value 0.1: 0.5695226525669715
#
# Classification Report for PGD Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.39      0.55      0.46     47512
#            1       0.39      0.17      0.24     47269
#            2       0.39      0.44      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000
#
#
# Classification Report for FGSM Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.22      0.26      0.24     47512
#            1       0.32      0.15      0.20     47269
#            2       0.21      0.29      0.24     43219
#
#     accuracy                           0.23    138000
#    macro avg       0.25      0.23      0.23    138000
# weighted avg       0.25      0.23      0.23    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.39      0.56      0.46     47512
#            1       0.39      0.17      0.23     47269
#            2       0.39      0.44      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.37    138000
# weighted avg       0.39      0.39      0.37    138000
#
# Epsilon value: 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 1: 0.364427536231884
# Average accuracy of FGSM attack for epsilon value 1: 0.0076956521739130436
# Average accuracy of Random Noise attack for epsilon value 1: 0.37827536231884046
# Average perturbation volume for PGD attack with epsilon 1: 2.267022132873535
# Average perturbation volume for FGSM attack with epsilon 1: 3.0599658489227295
# Average perturbation volume for Random Noise attack with epsilon 1: 3.010068893432617
# Average precision of PGD attack for epsilon value 1: 0.36718175229296107
# Average recall of PGD attack for epsilon value 1: 0.3655367353172003
# Average precision of FGSM attack for epsilon value 1: 0.03371312029157853
# Average recall of FGSM attack for epsilon value 1: 0.0075059552016193505
# Average precision of Random Noise attack for epsilon value 1: 0.3801640675095775
# Average recall of Random Noise attack for epsilon value 1: 0.3772489213849261
# ROC AUC of PGD attack for epsilon value 1: 0.5463582140913955
# ROC AUC of FGSM attack for epsilon value 1: 0.11684234343061106
# ROC AUC of Random Noise attack for epsilon value 1: 0.55340193345295
#
# Classification Report for PGD Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.36      0.52      0.43     47512
#            1       0.38      0.16      0.23     47269
#            2       0.36      0.41      0.38     43219
#
#     accuracy                           0.36    138000
#    macro avg       0.37      0.37      0.35    138000
# weighted avg       0.37      0.36      0.35    138000
#
#
# Classification Report for FGSM Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     47512
#            1       0.10      0.02      0.03     47269
#            2       0.00      0.00      0.00     43219
#
#     accuracy                           0.01    138000
#    macro avg       0.03      0.01      0.01    138000
# weighted avg       0.03      0.01      0.01    138000
#
#
# Classification Report for Random Noise Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.37      0.59      0.46     47512
#            1       0.38      0.19      0.25     47269
#            2       0.39      0.35      0.37     43219
#
#     accuracy                           0.38    138000
#    macro avg       0.38      0.38      0.36    138000
# weighted avg       0.38      0.38      0.36    138000
#
# Epsilon value: 10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average accuracy of PGD attack for epsilon value 10: 0.31936231884057964
# Average accuracy of FGSM attack for epsilon value 10: 0.007710144927536232
# Average accuracy of Random Noise attack for epsilon value 10: 0.37184782608695643
# Average perturbation volume for PGD attack with epsilon 10: 2.2732884883880615
# Average perturbation volume for FGSM attack with epsilon 10: 3.0592594146728516
# Average perturbation volume for Random Noise attack with epsilon 10: 3.8922371864318848
# Average precision of PGD attack for epsilon value 10: 0.32117879616078804
# Average recall of PGD attack for epsilon value 10: 0.32013590970609246
# Average precision of FGSM attack for epsilon value 10: 0.03355022080481886
# Average recall of FGSM attack for epsilon value 10: 0.007518917572418922
# Average precision of Random Noise attack for epsilon value 10: 0.3742348561955984
# Average recall of Random Noise attack for epsilon value 10: 0.36931925848219055
# ROC AUC of PGD attack for epsilon value 10: 0.4917763004649864
# ROC AUC of FGSM attack for epsilon value 10: 0.11701263299769443
# ROC AUC of Random Noise attack for epsilon value 10: 0.5443853173829867
#
# Classification Report for PGD Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.32      0.47      0.38     47512
#            1       0.33      0.14      0.19     47269
#            2       0.31      0.36      0.33     43219
#
#     accuracy                           0.32    138000
#    macro avg       0.32      0.32      0.30    138000
# weighted avg       0.32      0.32      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     47512
#            1       0.10      0.02      0.03     47269
#            2       0.00      0.00      0.00     43219
#
#     accuracy                           0.01    138000
#    macro avg       0.03      0.01      0.01    138000
# weighted avg       0.03      0.01      0.01    138000
#
#
# Classification Report for Random Noise Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.37      0.60      0.45     47512
#            1       0.38      0.22      0.27     47269
#            2       0.37      0.30      0.33     43219
#
#     accuracy                           0.37    138000
#    macro avg       0.37      0.37      0.35    138000
# weighted avg       0.37      0.37      0.35    138000

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    def fgsm_attack(images, labels, epsilon):
        """Implement FGSM attack"""
        try:
            with tf.GradientTape() as tape:
                tape.watch(images)
                predictions = model(images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy()(labels, predictions)

            gradient = tape.gradient(loss, images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = images + epsilon * signed_masked
            return tf.clip_by_value(perturbed_images, 0, 1)
        except Exception as e:
            print(f"Error in FGSM attack: {str(e)}")
            return None

    def pgd_attack(images, labels, epsilon):
        perturbed_images = tf.identity(images)
        for _ in range(num_iterations):
            with tf.GradientTape() as tape:
                tape.watch(perturbed_images)
                predictions = model(perturbed_images)
                loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
            gradient = tape.gradient(loss, perturbed_images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = perturbed_images + step_size * signed_masked

            # Add projection step here with fixed norm calculation:
            delta = perturbed_images - images  # Calculate current perturbation

            # Reshape to flatten all dimensions except batch
            delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

            # Calculate L2 norm on the flattened dimensions
            norm = tf.norm(delta_flat, axis=1, keepdims=True)

            # Reshape norm for broadcasting
            norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

            # Scale perturbation
            scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
            delta = delta * scaling

            perturbed_images = images + delta  # Apply constrained perturbation
            perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
        return perturbed_images

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=lstm2,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 1e-06
# Batch 1/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 2/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 3/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 4/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 5/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 6/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 7/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 8/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 9/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 10/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 11/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 12/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 13/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 14/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 15/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 16/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 17/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 18/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 19/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 20/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 21/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 22/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 23/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 24/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 25/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 26/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 27/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 28/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 29/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 30/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 31/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 32/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 33/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 34/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 35/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 36/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 37/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 38/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 39/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 40/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 41/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 42/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 43/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 44/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 45/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 46/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 47/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 48/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 49/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 50/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 51/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 52/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 53/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 54/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 55/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 56/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 57/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 58/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 59/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 60/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 61/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 62/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 63/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 64/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 65/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 66/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 67/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 68/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 69/69 - PGD volume: 0.000001, FGSM volume: 0.000004
#
# Analyzing epsilon: 1e-05
# Batch 1/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 2/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 3/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 4/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 5/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 6/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 7/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 8/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 9/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 10/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 11/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 12/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 13/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 14/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 15/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 16/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 17/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 18/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 19/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 20/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 21/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 22/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 23/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 24/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 25/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 26/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 27/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 28/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 29/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 30/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 31/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 32/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 33/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 34/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 35/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 36/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 37/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 38/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 39/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 40/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 41/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 42/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 43/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 44/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 45/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 46/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 47/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 48/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 49/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 50/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 51/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 52/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 53/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 54/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 55/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 56/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 57/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 58/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 59/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 60/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 61/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 62/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 63/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 64/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 65/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 66/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 67/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 68/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 69/69 - PGD volume: 0.000010, FGSM volume: 0.000045
#
# Analyzing epsilon: 0.0001
# Batch 1/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 2/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 3/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 4/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 5/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 6/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 7/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 8/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 9/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 10/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 11/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 12/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 13/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 14/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 15/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 16/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 17/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 18/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 19/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 20/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 21/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 22/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 23/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 24/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 25/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 26/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 27/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 28/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 29/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 30/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 31/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 32/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 33/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 34/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 35/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 36/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 37/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 38/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 39/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 40/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 41/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 42/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 43/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 44/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 45/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 46/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 47/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 48/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 49/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 50/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 51/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 52/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 53/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 54/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 55/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 56/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 57/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 58/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 59/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 60/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 61/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 62/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 63/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 64/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 65/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 66/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 67/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 68/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 69/69 - PGD volume: 0.000100, FGSM volume: 0.000447
#
# Analyzing epsilon: 0.001
# Batch 1/69 - PGD volume: 0.000997, FGSM volume: 0.004378
# Batch 2/69 - PGD volume: 0.000999, FGSM volume: 0.004448
# Batch 3/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 4/69 - PGD volume: 0.001000, FGSM volume: 0.004463
# Batch 5/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 6/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 7/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 8/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 9/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 10/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 11/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 12/69 - PGD volume: 0.001000, FGSM volume: 0.004463
# Batch 13/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 14/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 15/69 - PGD volume: 0.001000, FGSM volume: 0.004462
# Batch 16/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 17/69 - PGD volume: 0.000999, FGSM volume: 0.004452
# Batch 18/69 - PGD volume: 0.001000, FGSM volume: 0.004458
# Batch 19/69 - PGD volume: 0.001000, FGSM volume: 0.004459
# Batch 20/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 21/69 - PGD volume: 0.001000, FGSM volume: 0.004455
# Batch 22/69 - PGD volume: 0.000997, FGSM volume: 0.004425
# Batch 23/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 24/69 - PGD volume: 0.001000, FGSM volume: 0.004435
# Batch 25/69 - PGD volume: 0.001000, FGSM volume: 0.004426
# Batch 26/69 - PGD volume: 0.000998, FGSM volume: 0.004452
# Batch 27/69 - PGD volume: 0.000996, FGSM volume: 0.004447
# Batch 28/69 - PGD volume: 0.000997, FGSM volume: 0.004425
# Batch 29/69 - PGD volume: 0.000996, FGSM volume: 0.004406
# Batch 30/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 31/69 - PGD volume: 0.000999, FGSM volume: 0.004467
# Batch 32/69 - PGD volume: 0.000999, FGSM volume: 0.004468
# Batch 33/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 34/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 35/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 36/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 37/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 38/69 - PGD volume: 0.000999, FGSM volume: 0.004467
# Batch 39/69 - PGD volume: 0.000999, FGSM volume: 0.004466
# Batch 40/69 - PGD volume: 0.000999, FGSM volume: 0.004465
# Batch 41/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 42/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 43/69 - PGD volume: 0.000997, FGSM volume: 0.004459
# Batch 44/69 - PGD volume: 0.000998, FGSM volume: 0.004460
# Batch 45/69 - PGD volume: 0.000998, FGSM volume: 0.004444
# Batch 46/69 - PGD volume: 0.001000, FGSM volume: 0.004448
# Batch 47/69 - PGD volume: 0.000999, FGSM volume: 0.004448
# Batch 48/69 - PGD volume: 0.000997, FGSM volume: 0.004424
# Batch 49/69 - PGD volume: 0.001000, FGSM volume: 0.004434
# Batch 50/69 - PGD volume: 0.000997, FGSM volume: 0.004415
# Batch 51/69 - PGD volume: 0.001000, FGSM volume: 0.004447
# Batch 52/69 - PGD volume: 0.001000, FGSM volume: 0.004437
# Batch 53/69 - PGD volume: 0.001000, FGSM volume: 0.004455
# Batch 54/69 - PGD volume: 0.000999, FGSM volume: 0.004452
# Batch 55/69 - PGD volume: 0.000999, FGSM volume: 0.004402
# Batch 56/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 57/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 58/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 59/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 60/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 61/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 62/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 63/69 - PGD volume: 0.001000, FGSM volume: 0.004460
# Batch 64/69 - PGD volume: 0.000999, FGSM volume: 0.004448
# Batch 65/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 66/69 - PGD volume: 0.001000, FGSM volume: 0.004457
# Batch 67/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 68/69 - PGD volume: 0.000999, FGSM volume: 0.004439
# Batch 69/69 - PGD volume: 0.000999, FGSM volume: 0.004441
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         186.4696  11164.0000    0.5554
# 0.9000         168.4837   7197.0000    0.5836
# 0.9500          -1.5840   3413.0000    0.4981
# 0.9900           0.1633    554.0000    0.9025
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         186.4696  11163.0000    0.5554
# 0.9000         168.4837   7196.0000    0.5837
# 0.9500          -1.5840   3413.0000    0.4981
# 0.9900           0.1633    554.0000    0.9025
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         186.4554  11162.0000    0.5555
# 0.9000         168.4837   7196.0000    0.5837
# 0.9500          -1.5937   3412.0000    0.4982
# 0.9900           0.1633    554.0000    0.9025
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         186.1295  11149.0000    0.5561
# 0.9000         168.4225   7189.0000    0.5842
# 0.9500          -1.5561   3407.0000    0.4990
# 0.9900           0.1046    551.0000    0.9074
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         186.4696  11163.0000    0.5554
# 0.9000         168.4837   7197.0000    0.5836
# 0.9500          -1.5840   3413.0000    0.4981
# 0.9900           0.1633    554.0000    0.9025
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         186.4412  11163.0000    0.5554
# 0.9000         168.4837   7196.0000    0.5837
# 0.9500          -1.5937   3412.0000    0.4982
# 0.9900           0.1633    554.0000    0.9025
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         186.2528  11159.0000    0.5556
# 0.9000         168.5295   7194.0000    0.5838
# 0.9500          -1.6057   3408.0000    0.4988
# 0.9900           0.1046    553.0000    0.9042
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         185.9881  11080.0000    0.5505
# 0.9000         168.2644   7150.0000    0.5874
# 0.9500          -1.5888   3371.0000    0.5043
# 0.9900           0.0172    546.0000    0.7326

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    def fgsm_attack(images, labels, epsilon):
        """Implement FGSM attack"""
        try:
            with tf.GradientTape() as tape:
                tape.watch(images)
                predictions = model(images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy()(labels, predictions)

            gradient = tape.gradient(loss, images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = images + epsilon * signed_masked
            return tf.clip_by_value(perturbed_images, 0, 1)
        except Exception as e:
            print(f"Error in FGSM attack: {str(e)}")
            return None

    def pgd_attack(images, labels, epsilon):
        perturbed_images = tf.identity(images)
        for _ in range(num_iterations):
            with tf.GradientTape() as tape:
                tape.watch(perturbed_images)
                predictions = model(perturbed_images)
                loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
            gradient = tape.gradient(loss, perturbed_images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = perturbed_images + step_size * signed_masked

            # Add projection step here with fixed norm calculation:
            delta = perturbed_images - images  # Calculate current perturbation

            # Reshape to flatten all dimensions except batch
            delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

            # Calculate L2 norm on the flattened dimensions
            norm = tf.norm(delta_flat, axis=1, keepdims=True)

            # Reshape norm for broadcasting
            norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

            # Scale perturbation
            scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
            delta = delta * scaling

            perturbed_images = images + delta  # Apply constrained perturbation
            perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
        return perturbed_images

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

epsilon_values = [0.01, 0.1, 1, 10]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=lstm2,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 0.01
# Batch 1/69 - PGD volume: 0.009331, FGSM volume: 0.036137
# Batch 2/69 - PGD volume: 0.009792, FGSM volume: 0.040961
# Batch 3/69 - PGD volume: 0.009968, FGSM volume: 0.043119
# Batch 4/69 - PGD volume: 0.009953, FGSM volume: 0.042936
# Batch 5/69 - PGD volume: 0.009982, FGSM volume: 0.043302
# Batch 6/69 - PGD volume: 0.009977, FGSM volume: 0.043546
# Batch 7/69 - PGD volume: 0.009964, FGSM volume: 0.043846
# Batch 8/69 - PGD volume: 0.009962, FGSM volume: 0.043746
# Batch 9/69 - PGD volume: 0.009966, FGSM volume: 0.043633
# Batch 10/69 - PGD volume: 0.009980, FGSM volume: 0.043970
# Batch 11/69 - PGD volume: 0.009937, FGSM volume: 0.042901
# Batch 12/69 - PGD volume: 0.009952, FGSM volume: 0.043143
# Batch 13/69 - PGD volume: 0.009951, FGSM volume: 0.042937
# Batch 14/69 - PGD volume: 0.009944, FGSM volume: 0.043296
# Batch 15/69 - PGD volume: 0.009950, FGSM volume: 0.043145
# Batch 16/69 - PGD volume: 0.009973, FGSM volume: 0.043756
# Batch 17/69 - PGD volume: 0.009856, FGSM volume: 0.039913
# Batch 18/69 - PGD volume: 0.009663, FGSM volume: 0.035366
# Batch 19/69 - PGD volume: 0.009650, FGSM volume: 0.035292
# Batch 20/69 - PGD volume: 0.009626, FGSM volume: 0.035175
# Batch 21/69 - PGD volume: 0.009657, FGSM volume: 0.035857
# Batch 22/69 - PGD volume: 0.009652, FGSM volume: 0.035547
# Batch 23/69 - PGD volume: 0.009639, FGSM volume: 0.034862
# Batch 24/69 - PGD volume: 0.009627, FGSM volume: 0.036774
# Batch 25/69 - PGD volume: 0.009651, FGSM volume: 0.036626
# Batch 26/69 - PGD volume: 0.009698, FGSM volume: 0.036745
# Batch 27/69 - PGD volume: 0.009677, FGSM volume: 0.036152
# Batch 28/69 - PGD volume: 0.009547, FGSM volume: 0.035090
# Batch 29/69 - PGD volume: 0.009617, FGSM volume: 0.038521
# Batch 30/69 - PGD volume: 0.009981, FGSM volume: 0.043401
# Batch 31/69 - PGD volume: 0.009965, FGSM volume: 0.042623
# Batch 32/69 - PGD volume: 0.009985, FGSM volume: 0.043045
# Batch 33/69 - PGD volume: 0.009983, FGSM volume: 0.042477
# Batch 34/69 - PGD volume: 0.009983, FGSM volume: 0.043881
# Batch 35/69 - PGD volume: 0.009980, FGSM volume: 0.044004
# Batch 36/69 - PGD volume: 0.009951, FGSM volume: 0.043856
# Batch 37/69 - PGD volume: 0.009956, FGSM volume: 0.043502
# Batch 38/69 - PGD volume: 0.009982, FGSM volume: 0.043774
# Batch 39/69 - PGD volume: 0.009962, FGSM volume: 0.043554
# Batch 40/69 - PGD volume: 0.009970, FGSM volume: 0.043139
# Batch 41/69 - PGD volume: 0.009978, FGSM volume: 0.043526
# Batch 42/69 - PGD volume: 0.009973, FGSM volume: 0.043352
# Batch 43/69 - PGD volume: 0.009968, FGSM volume: 0.043239
# Batch 44/69 - PGD volume: 0.009958, FGSM volume: 0.043375
# Batch 45/69 - PGD volume: 0.009852, FGSM volume: 0.040759
# Batch 46/69 - PGD volume: 0.009645, FGSM volume: 0.035168
# Batch 47/69 - PGD volume: 0.009622, FGSM volume: 0.035459
# Batch 48/69 - PGD volume: 0.009624, FGSM volume: 0.035971
# Batch 49/69 - PGD volume: 0.009513, FGSM volume: 0.034850
# Batch 50/69 - PGD volume: 0.009516, FGSM volume: 0.035381
# Batch 51/69 - PGD volume: 0.009671, FGSM volume: 0.035376
# Batch 52/69 - PGD volume: 0.009657, FGSM volume: 0.035714
# Batch 53/69 - PGD volume: 0.009590, FGSM volume: 0.035470
# Batch 54/69 - PGD volume: 0.009660, FGSM volume: 0.035945
# Batch 55/69 - PGD volume: 0.009574, FGSM volume: 0.038200
# Batch 56/69 - PGD volume: 0.009967, FGSM volume: 0.043493
# Batch 57/69 - PGD volume: 0.009982, FGSM volume: 0.043467
# Batch 58/69 - PGD volume: 0.009985, FGSM volume: 0.043762
# Batch 59/69 - PGD volume: 0.009989, FGSM volume: 0.044050
# Batch 60/69 - PGD volume: 0.009987, FGSM volume: 0.044158
# Batch 61/69 - PGD volume: 0.009963, FGSM volume: 0.043510
# Batch 62/69 - PGD volume: 0.009963, FGSM volume: 0.043477
# Batch 63/69 - PGD volume: 0.009960, FGSM volume: 0.043566
# Batch 64/69 - PGD volume: 0.009726, FGSM volume: 0.035578
# Batch 65/69 - PGD volume: 0.009705, FGSM volume: 0.036083
# Batch 66/69 - PGD volume: 0.009669, FGSM volume: 0.035874
# Batch 67/69 - PGD volume: 0.009701, FGSM volume: 0.035925
# Batch 68/69 - PGD volume: 0.009724, FGSM volume: 0.035420
# Batch 69/69 - PGD volume: 0.009691, FGSM volume: 0.035795
#
# Analyzing epsilon: 0.1
# Batch 1/69 - PGD volume: 0.095708, FGSM volume: 0.310877
# Batch 2/69 - PGD volume: 0.097182, FGSM volume: 0.326538
# Batch 3/69 - PGD volume: 0.097880, FGSM volume: 0.330242
# Batch 4/69 - PGD volume: 0.098091, FGSM volume: 0.336591
# Batch 5/69 - PGD volume: 0.097533, FGSM volume: 0.328243
# Batch 6/69 - PGD volume: 0.098042, FGSM volume: 0.333894
# Batch 7/69 - PGD volume: 0.098262, FGSM volume: 0.337629
# Batch 8/69 - PGD volume: 0.098123, FGSM volume: 0.336067
# Batch 9/69 - PGD volume: 0.098129, FGSM volume: 0.333145
# Batch 10/69 - PGD volume: 0.098199, FGSM volume: 0.335737
# Batch 11/69 - PGD volume: 0.097338, FGSM volume: 0.321662
# Batch 12/69 - PGD volume: 0.097555, FGSM volume: 0.328457
# Batch 13/69 - PGD volume: 0.096861, FGSM volume: 0.324740
# Batch 14/69 - PGD volume: 0.097797, FGSM volume: 0.327988
# Batch 15/69 - PGD volume: 0.097669, FGSM volume: 0.323717
# Batch 16/69 - PGD volume: 0.097193, FGSM volume: 0.328837
# Batch 17/69 - PGD volume: 0.096644, FGSM volume: 0.313720
# Batch 18/69 - PGD volume: 0.095668, FGSM volume: 0.303452
# Batch 19/69 - PGD volume: 0.095385, FGSM volume: 0.299262
# Batch 20/69 - PGD volume: 0.095616, FGSM volume: 0.306453
# Batch 21/69 - PGD volume: 0.095354, FGSM volume: 0.305887
# Batch 22/69 - PGD volume: 0.095497, FGSM volume: 0.305384
# Batch 23/69 - PGD volume: 0.095484, FGSM volume: 0.301537
# Batch 24/69 - PGD volume: 0.095221, FGSM volume: 0.300326
# Batch 25/69 - PGD volume: 0.095270, FGSM volume: 0.301218
# Batch 26/69 - PGD volume: 0.095185, FGSM volume: 0.301825
# Batch 27/69 - PGD volume: 0.095456, FGSM volume: 0.307770
# Batch 28/69 - PGD volume: 0.095711, FGSM volume: 0.306949
# Batch 29/69 - PGD volume: 0.096616, FGSM volume: 0.321547
# Batch 30/69 - PGD volume: 0.097808, FGSM volume: 0.335195
# Batch 31/69 - PGD volume: 0.097362, FGSM volume: 0.329655
# Batch 32/69 - PGD volume: 0.097573, FGSM volume: 0.327722
# Batch 33/69 - PGD volume: 0.097431, FGSM volume: 0.328306
# Batch 34/69 - PGD volume: 0.097851, FGSM volume: 0.333355
# Batch 35/69 - PGD volume: 0.098269, FGSM volume: 0.340914
# Batch 36/69 - PGD volume: 0.098268, FGSM volume: 0.338683
# Batch 37/69 - PGD volume: 0.097923, FGSM volume: 0.336586
# Batch 38/69 - PGD volume: 0.097997, FGSM volume: 0.330074
# Batch 39/69 - PGD volume: 0.098048, FGSM volume: 0.337361
# Batch 40/69 - PGD volume: 0.097466, FGSM volume: 0.329882
# Batch 41/69 - PGD volume: 0.097528, FGSM volume: 0.322400
# Batch 42/69 - PGD volume: 0.097647, FGSM volume: 0.327644
# Batch 43/69 - PGD volume: 0.097763, FGSM volume: 0.333505
# Batch 44/69 - PGD volume: 0.097753, FGSM volume: 0.328236
# Batch 45/69 - PGD volume: 0.097162, FGSM volume: 0.322119
# Batch 46/69 - PGD volume: 0.095762, FGSM volume: 0.304543
# Batch 47/69 - PGD volume: 0.095663, FGSM volume: 0.301462
# Batch 48/69 - PGD volume: 0.095432, FGSM volume: 0.303365
# Batch 49/69 - PGD volume: 0.095711, FGSM volume: 0.304347
# Batch 50/69 - PGD volume: 0.095825, FGSM volume: 0.305244
# Batch 51/69 - PGD volume: 0.095645, FGSM volume: 0.301468
# Batch 52/69 - PGD volume: 0.095573, FGSM volume: 0.304456
# Batch 53/69 - PGD volume: 0.095336, FGSM volume: 0.303800
# Batch 54/69 - PGD volume: 0.095572, FGSM volume: 0.306442
# Batch 55/69 - PGD volume: 0.096331, FGSM volume: 0.317513
# Batch 56/69 - PGD volume: 0.098125, FGSM volume: 0.333014
# Batch 57/69 - PGD volume: 0.098298, FGSM volume: 0.340572
# Batch 58/69 - PGD volume: 0.098331, FGSM volume: 0.343472
# Batch 59/69 - PGD volume: 0.098420, FGSM volume: 0.338141
# Batch 60/69 - PGD volume: 0.098667, FGSM volume: 0.351391
# Batch 61/69 - PGD volume: 0.097828, FGSM volume: 0.328114
# Batch 62/69 - PGD volume: 0.097810, FGSM volume: 0.328323
# Batch 63/69 - PGD volume: 0.097815, FGSM volume: 0.325815
# Batch 64/69 - PGD volume: 0.095736, FGSM volume: 0.302752
# Batch 65/69 - PGD volume: 0.095523, FGSM volume: 0.302981
# Batch 66/69 - PGD volume: 0.095738, FGSM volume: 0.305399
# Batch 67/69 - PGD volume: 0.095427, FGSM volume: 0.305050
# Batch 68/69 - PGD volume: 0.095348, FGSM volume: 0.304514
# Batch 69/69 - PGD volume: 0.095301, FGSM volume: 0.300631
#
# Analyzing epsilon: 1
# Batch 1/69 - PGD volume: 0.139068, FGSM volume: 3.084004
# Batch 2/69 - PGD volume: 0.153146, FGSM volume: 2.974103
# Batch 3/69 - PGD volume: 0.159968, FGSM volume: 2.985101
# Batch 4/69 - PGD volume: 0.159719, FGSM volume: 3.000122
# Batch 5/69 - PGD volume: 0.154420, FGSM volume: 2.996098
# Batch 6/69 - PGD volume: 0.160255, FGSM volume: 3.005108
# Batch 7/69 - PGD volume: 0.162973, FGSM volume: 2.959827
# Batch 8/69 - PGD volume: 0.160512, FGSM volume: 3.005918
# Batch 9/69 - PGD volume: 0.159405, FGSM volume: 2.969523
# Batch 10/69 - PGD volume: 0.158748, FGSM volume: 2.987669
# Batch 11/69 - PGD volume: 0.153264, FGSM volume: 2.965254
# Batch 12/69 - PGD volume: 0.152761, FGSM volume: 3.024277
# Batch 13/69 - PGD volume: 0.146822, FGSM volume: 3.022420
# Batch 14/69 - PGD volume: 0.154595, FGSM volume: 2.995738
# Batch 15/69 - PGD volume: 0.152740, FGSM volume: 2.978403
# Batch 16/69 - PGD volume: 0.150124, FGSM volume: 3.056498
# Batch 17/69 - PGD volume: 0.144531, FGSM volume: 2.992099
# Batch 18/69 - PGD volume: 0.135323, FGSM volume: 3.007170
# Batch 19/69 - PGD volume: 0.132622, FGSM volume: 2.968498
# Batch 20/69 - PGD volume: 0.130898, FGSM volume: 3.044550
# Batch 21/69 - PGD volume: 0.128806, FGSM volume: 3.030839
# Batch 22/69 - PGD volume: 0.132156, FGSM volume: 3.028104
# Batch 23/69 - PGD volume: 0.130883, FGSM volume: 2.993993
# Batch 24/69 - PGD volume: 0.128834, FGSM volume: 2.966223
# Batch 25/69 - PGD volume: 0.131120, FGSM volume: 2.978462
# Batch 26/69 - PGD volume: 0.128546, FGSM volume: 2.979015
# Batch 27/69 - PGD volume: 0.130985, FGSM volume: 3.052223
# Batch 28/69 - PGD volume: 0.136145, FGSM volume: 3.046475
# Batch 29/69 - PGD volume: 0.147743, FGSM volume: 3.060042
# Batch 30/69 - PGD volume: 0.162218, FGSM volume: 2.974211
# Batch 31/69 - PGD volume: 0.157754, FGSM volume: 3.007698
# Batch 32/69 - PGD volume: 0.156471, FGSM volume: 2.979447
# Batch 33/69 - PGD volume: 0.157272, FGSM volume: 2.984408
# Batch 34/69 - PGD volume: 0.157648, FGSM volume: 3.004860
# Batch 35/69 - PGD volume: 0.161122, FGSM volume: 3.032373
# Batch 36/69 - PGD volume: 0.160493, FGSM volume: 2.996553
# Batch 37/69 - PGD volume: 0.159362, FGSM volume: 2.996737
# Batch 38/69 - PGD volume: 0.158350, FGSM volume: 3.006218
# Batch 39/69 - PGD volume: 0.159580, FGSM volume: 2.992418
# Batch 40/69 - PGD volume: 0.152706, FGSM volume: 3.002640
# Batch 41/69 - PGD volume: 0.149043, FGSM volume: 2.912246
# Batch 42/69 - PGD volume: 0.153500, FGSM volume: 2.955239
# Batch 43/69 - PGD volume: 0.153934, FGSM volume: 3.030763
# Batch 44/69 - PGD volume: 0.155677, FGSM volume: 2.988608
# Batch 45/69 - PGD volume: 0.149509, FGSM volume: 3.027714
# Batch 46/69 - PGD volume: 0.135797, FGSM volume: 3.019236
# Batch 47/69 - PGD volume: 0.135513, FGSM volume: 2.988119
# Batch 48/69 - PGD volume: 0.131376, FGSM volume: 3.005998
# Batch 49/69 - PGD volume: 0.132568, FGSM volume: 3.019616
# Batch 50/69 - PGD volume: 0.134447, FGSM volume: 3.027529
# Batch 51/69 - PGD volume: 0.133336, FGSM volume: 2.984717
# Batch 52/69 - PGD volume: 0.130677, FGSM volume: 3.016992
# Batch 53/69 - PGD volume: 0.126735, FGSM volume: 3.014138
# Batch 54/69 - PGD volume: 0.135044, FGSM volume: 3.036205
# Batch 55/69 - PGD volume: 0.145012, FGSM volume: 3.065281
# Batch 56/69 - PGD volume: 0.162225, FGSM volume: 2.981961
# Batch 57/69 - PGD volume: 0.161503, FGSM volume: 2.998807
# Batch 58/69 - PGD volume: 0.163341, FGSM volume: 2.983474
# Batch 59/69 - PGD volume: 0.163657, FGSM volume: 2.972818
# Batch 60/69 - PGD volume: 0.166654, FGSM volume: 3.018428
# Batch 61/69 - PGD volume: 0.157479, FGSM volume: 2.989901
# Batch 62/69 - PGD volume: 0.156687, FGSM volume: 2.993651
# Batch 63/69 - PGD volume: 0.154936, FGSM volume: 2.982371
# Batch 64/69 - PGD volume: 0.133647, FGSM volume: 2.979370
# Batch 65/69 - PGD volume: 0.133142, FGSM volume: 2.998162
# Batch 66/69 - PGD volume: 0.134360, FGSM volume: 3.018796
# Batch 67/69 - PGD volume: 0.132131, FGSM volume: 3.022935
# Batch 68/69 - PGD volume: 0.129839, FGSM volume: 3.024124
# Batch 69/69 - PGD volume: 0.131424, FGSM volume: 2.977698
#
# Analyzing epsilon: 10
# Batch 1/69 - PGD volume: 0.139030, FGSM volume: 3.084004
# Batch 2/69 - PGD volume: 0.153346, FGSM volume: 2.974103
# Batch 3/69 - PGD volume: 0.159924, FGSM volume: 2.985101
# Batch 4/69 - PGD volume: 0.159591, FGSM volume: 3.000122
# Batch 5/69 - PGD volume: 0.153891, FGSM volume: 2.996098
# Batch 6/69 - PGD volume: 0.159709, FGSM volume: 3.005108
# Batch 7/69 - PGD volume: 0.162682, FGSM volume: 2.959827
# Batch 8/69 - PGD volume: 0.160633, FGSM volume: 3.005918
# Batch 9/69 - PGD volume: 0.159195, FGSM volume: 2.969523
# Batch 10/69 - PGD volume: 0.159042, FGSM volume: 2.987669
# Batch 11/69 - PGD volume: 0.153198, FGSM volume: 2.965254
# Batch 12/69 - PGD volume: 0.153257, FGSM volume: 3.024277
# Batch 13/69 - PGD volume: 0.146564, FGSM volume: 3.022420
# Batch 14/69 - PGD volume: 0.154720, FGSM volume: 2.995738
# Batch 15/69 - PGD volume: 0.152812, FGSM volume: 2.978403
# Batch 16/69 - PGD volume: 0.150293, FGSM volume: 3.056498
# Batch 17/69 - PGD volume: 0.144736, FGSM volume: 2.992099
# Batch 18/69 - PGD volume: 0.135365, FGSM volume: 3.007170
# Batch 19/69 - PGD volume: 0.132238, FGSM volume: 2.968498
# Batch 20/69 - PGD volume: 0.131062, FGSM volume: 3.044550
# Batch 21/69 - PGD volume: 0.128625, FGSM volume: 3.030839
# Batch 22/69 - PGD volume: 0.132029, FGSM volume: 3.028104
# Batch 23/69 - PGD volume: 0.131060, FGSM volume: 2.993993
# Batch 24/69 - PGD volume: 0.127858, FGSM volume: 2.966223
# Batch 25/69 - PGD volume: 0.131062, FGSM volume: 2.978462
# Batch 26/69 - PGD volume: 0.127943, FGSM volume: 2.979015
# Batch 27/69 - PGD volume: 0.130906, FGSM volume: 3.052223
# Batch 28/69 - PGD volume: 0.136669, FGSM volume: 3.046475
# Batch 29/69 - PGD volume: 0.147998, FGSM volume: 3.060042
# Batch 30/69 - PGD volume: 0.162417, FGSM volume: 2.974211
# Batch 31/69 - PGD volume: 0.157714, FGSM volume: 3.007698
# Batch 32/69 - PGD volume: 0.156443, FGSM volume: 2.979447
# Batch 33/69 - PGD volume: 0.157352, FGSM volume: 2.984408
# Batch 34/69 - PGD volume: 0.157046, FGSM volume: 3.004860
# Batch 35/69 - PGD volume: 0.160533, FGSM volume: 3.032373
# Batch 36/69 - PGD volume: 0.160319, FGSM volume: 2.996553
# Batch 37/69 - PGD volume: 0.159420, FGSM volume: 2.996737
# Batch 38/69 - PGD volume: 0.158043, FGSM volume: 3.006218
# Batch 39/69 - PGD volume: 0.159337, FGSM volume: 2.992418
# Batch 40/69 - PGD volume: 0.152869, FGSM volume: 3.002640
# Batch 41/69 - PGD volume: 0.149134, FGSM volume: 2.912246
# Batch 42/69 - PGD volume: 0.153315, FGSM volume: 2.955239
# Batch 43/69 - PGD volume: 0.153790, FGSM volume: 3.030763
# Batch 44/69 - PGD volume: 0.155251, FGSM volume: 2.988608
# Batch 45/69 - PGD volume: 0.149086, FGSM volume: 3.027714
# Batch 46/69 - PGD volume: 0.136002, FGSM volume: 3.019236
# Batch 47/69 - PGD volume: 0.135310, FGSM volume: 2.988119
# Batch 48/69 - PGD volume: 0.131387, FGSM volume: 3.005998
# Batch 49/69 - PGD volume: 0.132811, FGSM volume: 3.019616
# Batch 50/69 - PGD volume: 0.134591, FGSM volume: 3.027529
# Batch 51/69 - PGD volume: 0.133520, FGSM volume: 2.984717
# Batch 52/69 - PGD volume: 0.131147, FGSM volume: 3.016992
# Batch 53/69 - PGD volume: 0.127097, FGSM volume: 3.014138
# Batch 54/69 - PGD volume: 0.135116, FGSM volume: 3.036205
# Batch 55/69 - PGD volume: 0.144675, FGSM volume: 3.065281
# Batch 56/69 - PGD volume: 0.161956, FGSM volume: 2.981961
# Batch 57/69 - PGD volume: 0.161818, FGSM volume: 2.998807
# Batch 58/69 - PGD volume: 0.163222, FGSM volume: 2.983474
# Batch 59/69 - PGD volume: 0.163331, FGSM volume: 2.972818
# Batch 60/69 - PGD volume: 0.166364, FGSM volume: 3.018428
# Batch 61/69 - PGD volume: 0.157723, FGSM volume: 2.989901
# Batch 62/69 - PGD volume: 0.156317, FGSM volume: 2.993651
# Batch 63/69 - PGD volume: 0.154675, FGSM volume: 2.982371
# Batch 64/69 - PGD volume: 0.133270, FGSM volume: 2.979370
# Batch 65/69 - PGD volume: 0.133238, FGSM volume: 2.998162
# Batch 66/69 - PGD volume: 0.134156, FGSM volume: 3.018796
# Batch 67/69 - PGD volume: 0.132069, FGSM volume: 3.022935
# Batch 68/69 - PGD volume: 0.129622, FGSM volume: 3.024124
# Batch 69/69 - PGD volume: 0.131354, FGSM volume: 2.977698
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         185.6583  11019.0000    0.5536
# 0.9000         159.5972   7102.0000    0.5632
# 0.9500          -1.7677   3346.0000    0.5081
# 0.9900           0.0731    538.0000    0.7435
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         113.1088  10221.0000    0.5381
# 0.9000          83.2317   6243.0000    0.5766
# 0.9500          30.6329   2809.0000    0.6052
# 0.9900          -0.0788    420.0000    0.4762
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         155.4202  10100.0000    0.4950
# 0.9000          91.4160   5936.0000    0.5222
# 0.9500          56.4050   2586.0000    0.6961
# 0.9900          -0.1126    356.0000    0.5618
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         155.3493  10098.0000    0.5051
# 0.9000          91.6726   5922.0000    0.5404
# 0.9500          56.0928   2573.0000    0.6996
# 0.9900          -0.1772    353.0000    0.5666
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         158.4079  10643.0000    0.5356
# 0.9000         117.9304   6719.0000    0.5656
# 0.9500          -2.6125   3142.0000    0.5092
# 0.9900          -0.0337    486.0000    0.4115
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500          99.6362  11321.0000    0.4505
# 0.9000          50.1795   6445.0000    0.4655
# 0.9500          33.4825   2467.0000    0.5675
# 0.9900          -0.4341    265.0000    0.3774
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500       -1140.5184 113959.0000    0.4186
# 0.9000       -1072.5481 110164.0000    0.4275
# 0.9500        -852.5972  95810.0000    0.4509
# 0.9900        -129.8957  32913.0000    0.5135
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500       -1140.5184 113959.0000    0.4186
# 0.9000       -1072.5481 110164.0000    0.4275
# 0.9500        -852.5972  95810.0000    0.4509
# 0.9900        -129.8957  32913.0000    0.5135
