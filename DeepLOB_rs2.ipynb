# %%
import pandas as pd
import pickle
import numpy as np
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import load_model, Model
from keras.layers import Flatten, Dense, Dropout, Activation, Input, LSTM, Reshape, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.layers import LeakyReLU
#!pip install np_utils
from keras import utils

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score

RANDOM_SEED = 2

# set random seeds
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# limit gpu usage for keras with tensorflow 1
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth = True
# set_session(tf.compat.v1.Session(config=config))

# If you need to use set_session, try this instead:
# from tensorflow.python.keras.backend import set_session

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

# Define the target directory in Google Drive for the unzipped files
# This path is derived from the np.loadtxt calls in a subsequent cell (RmH5_HJyoLmZ)
UNZIPPED_DATA_DIR = '/content/drive/MyDrive/LOBCNN/data/'

# Check if the unzipped data directory already exists and contains files
# This is a more robust check to confirm data readiness in Google Drive
if not os.path.exists(UNZIPPED_DATA_DIR) or not os.listdir(UNZIPPED_DATA_DIR):
    print(f"Data not found in {UNZIPPED_DATA_DIR}. Attempting to download and unzip.")

    # Create the target directory if it doesn't exist
    os.makedirs(UNZIPPED_DATA_DIR, exist_ok=True)

    # Define a temporary path for the downloaded zip file in /content/
    TEMP_ZIP_PATH = '/content/data.zip'

    # Download the data.zip file to /content/
    # !wget -q https://raw.githubusercontent.com/zcakhaa/DeepLOB-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books/master/data/data.zip -O {TEMP_ZIP_PATH}

    # Unzip the downloaded file directly into the target directory in Google Drive
    with zipfile.ZipFile(TEMP_ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(UNZIPPED_DATA_DIR)

    # Optionally, remove the temporary zip file to save space
    os.remove(TEMP_ZIP_PATH)

    print('Data downloaded and unzipped to Google Drive.')
else:
    print('Data already existed and is ready in Google Drive.')
# Out:
# Data already existed and is ready in Google Drive.

# %%
def prepare_x(data):
    df1 = data[:40, :].T
    return np.array(df1)

def get_label(data):
    lob = data[-5:, :].T
    return lob

def data_classification(X, Y, T):
    [N, D] = X.shape
    df = np.array(X)
    dY = np.array(Y)
    dataY = dY[T - 1:N]
    dataX = np.zeros((N - T + 1, T, D))
    for i in range(T, N + 1):
        dataX[i - T] = df[i - T:i, :]
    return dataX.reshape(dataX.shape + (1,)), dataY

def prepare_x_y(data, k, T):
    x = prepare_x(data)
    y = get_label(data)
    x, y = data_classification(x, y, T=T)
    y = y[:,k] - 1
    y = utils.to_categorical(y, 3)
    return x, y


def macro_f1(y_true, y_pred):
    """Macro-averaged F1 score for multi-class classification."""
    y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)
    y_true = tf.cast(tf.argmax(y_true, axis=-1), tf.int32)

    f1_scores = []
    for i in range(3):
        y_true_i = tf.cast(tf.equal(y_true, i), tf.float32)
        y_pred_i = tf.cast(tf.equal(y_pred, i), tf.float32)

        tp = tf.reduce_sum(y_true_i * y_pred_i)
        fp = tf.reduce_sum((1.0 - y_true_i) * y_pred_i)
        fn = tf.reduce_sum(y_true_i * (1.0 - y_pred_i))

        precision = tp / (tp + fp + tf.keras.backend.epsilon())
        recall = tp / (tp + fn + tf.keras.backend.epsilon())
        f1 = 2.0 * precision * recall / (precision + recall + tf.keras.backend.epsilon())
        f1_scores.append(f1)

    return tf.reduce_mean(tf.stack(f1_scores))

# %%
# Assuming UNZIPPED_DATA_DIR is defined in a previous cell (e.g., vxrZwaTErwd3) and contains the path
# to the unzipped files in Google Drive.

# Make sure UNZIPPED_DATA_DIR is defined. If this cell is run independently,
# uncomment and define it here or ensure the cell defining it runs first.
# UNZIPPED_DATA_DIR = '/content/drive/MyDrive/data/'

dec_data = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Train_Dst_NoAuction_DecPre_CF_7.txt'))
dec_train = dec_data[:, :int(np.floor(dec_data.shape[1] * 0.8))]
dec_val = dec_data[:, int(np.floor(dec_data.shape[1] * 0.8)):]

dec_test1 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_7.txt'))
dec_test2 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_8.txt'))
dec_test3 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_9.txt'))
dec_test = np.hstack((dec_test1, dec_test2, dec_test3))

k = 4 # which prediction horizon
T = 100 # the length of a single input
n_hiddens = 64

trainX_CNN, trainY_CNN = prepare_x_y(dec_train, k, T)
valX_CNN, valY_CNN = prepare_x_y(dec_val, k, T)
testX_CNN, testY_CNN = prepare_x_y(dec_test, k, T)

print(trainX_CNN.shape, trainY_CNN.shape)
print(valX_CNN.shape, valY_CNN.shape)
print(testX_CNN.shape, testY_CNN.shape)
# Out:
# (203701, 100, 40, 1) (203701, 3)
# (50851, 100, 40, 1) (50851, 3)
# (139488, 100, 40, 1) (139488, 3)

# %%
def create_deeplob(T, NF, number_of_lstm):
    input_lmd = Input(shape=(T, NF, 1))

    # build the convolutional block
    conv_first1 = Conv2D(32, (1, 2), strides=(1, 2))(input_lmd)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)

    conv_first1 = Conv2D(32, (1, 2), strides=(1, 2))(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)

    conv_first1 = Conv2D(32, (1, 10))(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)
    conv_first1 = Conv2D(32, (4, 1), padding='same')(conv_first1)
    conv_first1 = keras.layers.LeakyReLU(alpha=0.01)(conv_first1)

    # build the inception module
    convsecond_1 = Conv2D(64, (1, 1), padding='same')(conv_first1)
    convsecond_1 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_1)
    convsecond_1 = Conv2D(64, (3, 1), padding='same')(convsecond_1)
    convsecond_1 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_1)

    convsecond_2 = Conv2D(64, (1, 1), padding='same')(conv_first1)
    convsecond_2 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_2)
    convsecond_2 = Conv2D(64, (5, 1), padding='same')(convsecond_2)
    convsecond_2 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_2)

    convsecond_3 = MaxPooling2D((3, 1), strides=(1, 1), padding='same')(conv_first1)
    convsecond_3 = Conv2D(64, (1, 1), padding='same')(convsecond_3)
    convsecond_3 = keras.layers.LeakyReLU(alpha=0.01)(convsecond_3)

    convsecond_output = keras.layers.concatenate([convsecond_1, convsecond_2, convsecond_3], axis=3)
    conv_reshape = Reshape((int(convsecond_output.shape[1]), int(convsecond_output.shape[3])))(convsecond_output)
    conv_reshape = keras.layers.Dropout(0.2, noise_shape=(None, 1, int(conv_reshape.shape[2])))(conv_reshape, training=True)

    # build the last LSTM layer
    # If GPU is not available, change CuDNNLSTM to LSTM
    conv_lstm = LSTM(number_of_lstm)(conv_reshape)

    # build the output layer
    out = Dense(3, activation='softmax')(conv_lstm)
    model = Model(inputs=input_lmd, outputs=out)
    adam = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', macro_f1])

    return model

deeplob = create_deeplob(trainX_CNN.shape[1], trainX_CNN.shape[2], n_hiddens)
deeplob.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 100, 40,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 100, 20,   │         96 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 100, 20,   │          0 │ conv2d[0][0]      │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 100, 20,   │      4,128 │ leaky_re_lu[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 100, 20,   │          0 │ conv2d_1[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 100, 20,   │      4,128 │ leaky_re_lu_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 100, 20,   │          0 │ conv2d_2[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 100, 10,   │      2,080 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 100, 10,   │          0 │ conv2d_3[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 100, 10,   │      4,128 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 100, 10,   │          0 │ conv2d_4[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 100, 10,   │      4,128 │ leaky_re_lu_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 100, 10,   │          0 │ conv2d_5[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 100, 1,    │     10,272 │ leaky_re_lu_5[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 100, 1,    │          0 │ conv2d_6[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 100, 1,    │      4,128 │ leaky_re_lu_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 100, 1,    │          0 │ conv2d_7[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 100, 1,    │      4,128 │ leaky_re_lu_7[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 100, 1,    │          0 │ conv2d_8[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 100, 1,    │      2,112 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 100, 1,    │      2,112 │ leaky_re_lu_8[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 100, 1,    │          0 │ conv2d_9[0][0]    │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 100, 1,    │          0 │ conv2d_11[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 100, 1,    │          0 │ leaky_re_lu_8[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 100, 1,    │     12,352 │ leaky_re_lu_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 100, 1,    │     20,544 │ leaky_re_lu_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 100, 1,    │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 100, 1,    │          0 │ conv2d_10[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 100, 1,    │          0 │ conv2d_12[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 100, 1,    │          0 │ conv2d_13[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 100, 1,    │          0 │ leaky_re_lu_10[0… │
# │ (Concatenate)       │ 192)              │            │ leaky_re_lu_12[0… │
# │                     │                   │            │ leaky_re_lu_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 100, 192)  │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 100, 192)  │          0 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 64)        │     65,792 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │        195 │ lstm[0][0]        │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 142,435 (556.39 KB)
#  Trainable params: 142,435 (556.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_filepath = f'/content/drive/MyDrive/LOBCNN/models/DeepLOB_{RANDOM_SEED}.weights.h5'

model = create_deeplob(trainX_CNN.shape[1], trainX_CNN.shape[2], n_hiddens)  # Implement this function based on your model loading logic
if os.path.exists(checkpoint_filepath):
    model.load_weights(checkpoint_filepath)
else:
    print("No saved weights found. Starting training from scratch.")
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_macro_f1',
        mode='max',
        save_best_only=True)
    model.fit(trainX_CNN, trainY_CNN, validation_data=(valX_CNN, valY_CNN), epochs=200, batch_size=128, verbose=1, callbacks=[model_checkpoint_callback])
# Out:
# No saved weights found. Starting training from scratch.
# Epoch 1/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - accuracy: 0.4204 - loss: 1.0251 - macro_f1: 0.2769 - val_accuracy: 0.3762 - val_loss: 1.0851 - val_macro_f1: 0.1768
# Epoch 2/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.4406 - loss: 1.0031 - macro_f1: 0.3476 - val_accuracy: 0.3844 - val_loss: 1.0785 - val_macro_f1: 0.2011
# Epoch 3/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.5220 - loss: 0.9242 - macro_f1: 0.4875 - val_accuracy: 0.3720 - val_loss: 1.0926 - val_macro_f1: 0.3011
# Epoch 4/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.5829 - loss: 0.8386 - macro_f1: 0.5770 - val_accuracy: 0.4510 - val_loss: 1.0333 - val_macro_f1: 0.3621
# Epoch 5/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.6148 - loss: 0.8001 - macro_f1: 0.6128 - val_accuracy: 0.5130 - val_loss: 0.9611 - val_macro_f1: 0.4240
# Epoch 6/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.6436 - loss: 0.7666 - macro_f1: 0.6415 - val_accuracy: 0.5465 - val_loss: 0.9259 - val_macro_f1: 0.4465
# Epoch 7/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.6665 - loss: 0.7364 - macro_f1: 0.6626 - val_accuracy: 0.5570 - val_loss: 0.9101 - val_macro_f1: 0.4538
# Epoch 8/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.6833 - loss: 0.7113 - macro_f1: 0.6775 - val_accuracy: 0.5664 - val_loss: 0.9052 - val_macro_f1: 0.4621
# Epoch 9/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.6984 - loss: 0.6884 - macro_f1: 0.6911 - val_accuracy: 0.5793 - val_loss: 0.8872 - val_macro_f1: 0.4768
# Epoch 10/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7132 - loss: 0.6677 - macro_f1: 0.7041 - val_accuracy: 0.5880 - val_loss: 0.8788 - val_macro_f1: 0.4857
# Epoch 11/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7251 - loss: 0.6483 - macro_f1: 0.7148 - val_accuracy: 0.5993 - val_loss: 0.8658 - val_macro_f1: 0.5003
# Epoch 12/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7362 - loss: 0.6309 - macro_f1: 0.7251 - val_accuracy: 0.6033 - val_loss: 0.8648 - val_macro_f1: 0.5019
# Epoch 13/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7452 - loss: 0.6154 - macro_f1: 0.7334 - val_accuracy: 0.6165 - val_loss: 0.8453 - val_macro_f1: 0.5194
# Epoch 14/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7526 - loss: 0.6018 - macro_f1: 0.7403 - val_accuracy: 0.6187 - val_loss: 0.8429 - val_macro_f1: 0.5211
# Epoch 15/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7596 - loss: 0.5887 - macro_f1: 0.7469 - val_accuracy: 0.6287 - val_loss: 0.8283 - val_macro_f1: 0.5298
# Epoch 16/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7660 - loss: 0.5772 - macro_f1: 0.7531 - val_accuracy: 0.6331 - val_loss: 0.8226 - val_macro_f1: 0.5332
# Epoch 17/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7714 - loss: 0.5667 - macro_f1: 0.7581 - val_accuracy: 0.6393 - val_loss: 0.8122 - val_macro_f1: 0.5419
# Epoch 18/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7762 - loss: 0.5575 - macro_f1: 0.7627 - val_accuracy: 0.6413 - val_loss: 0.8105 - val_macro_f1: 0.5457
# Epoch 19/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7808 - loss: 0.5486 - macro_f1: 0.7671 - val_accuracy: 0.6480 - val_loss: 0.8039 - val_macro_f1: 0.5524
# Epoch 20/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7850 - loss: 0.5405 - macro_f1: 0.7707 - val_accuracy: 0.6518 - val_loss: 0.8018 - val_macro_f1: 0.5538
# Epoch 21/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7885 - loss: 0.5334 - macro_f1: 0.7744 - val_accuracy: 0.6489 - val_loss: 0.8082 - val_macro_f1: 0.5543
# Epoch 22/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7918 - loss: 0.5261 - macro_f1: 0.7778 - val_accuracy: 0.6466 - val_loss: 0.8166 - val_macro_f1: 0.5518
# Epoch 23/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7945 - loss: 0.5195 - macro_f1: 0.7801 - val_accuracy: 0.6489 - val_loss: 0.8178 - val_macro_f1: 0.5542
# Epoch 24/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7982 - loss: 0.5131 - macro_f1: 0.7835 - val_accuracy: 0.6450 - val_loss: 0.8398 - val_macro_f1: 0.5517
# Epoch 25/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8014 - loss: 0.5069 - macro_f1: 0.7865 - val_accuracy: 0.6490 - val_loss: 0.8313 - val_macro_f1: 0.5530
# Epoch 26/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8033 - loss: 0.5015 - macro_f1: 0.7885 - val_accuracy: 0.6522 - val_loss: 0.8311 - val_macro_f1: 0.5574
# Epoch 27/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8066 - loss: 0.4950 - macro_f1: 0.7918 - val_accuracy: 0.6541 - val_loss: 0.8344 - val_macro_f1: 0.5587
# Epoch 28/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8092 - loss: 0.4899 - macro_f1: 0.7942 - val_accuracy: 0.6560 - val_loss: 0.8278 - val_macro_f1: 0.5604
# Epoch 29/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8117 - loss: 0.4846 - macro_f1: 0.7966 - val_accuracy: 0.6597 - val_loss: 0.8182 - val_macro_f1: 0.5641
# Epoch 30/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8141 - loss: 0.4796 - macro_f1: 0.7989 - val_accuracy: 0.6615 - val_loss: 0.8190 - val_macro_f1: 0.5645
# Epoch 31/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8163 - loss: 0.4748 - macro_f1: 0.8013 - val_accuracy: 0.6642 - val_loss: 0.8164 - val_macro_f1: 0.5686
# Epoch 32/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8187 - loss: 0.4704 - macro_f1: 0.8039 - val_accuracy: 0.6629 - val_loss: 0.8209 - val_macro_f1: 0.5657
# Epoch 33/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8211 - loss: 0.4653 - macro_f1: 0.8060 - val_accuracy: 0.6668 - val_loss: 0.8125 - val_macro_f1: 0.5692
# Epoch 34/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8231 - loss: 0.4607 - macro_f1: 0.8081 - val_accuracy: 0.6636 - val_loss: 0.8278 - val_macro_f1: 0.5661
# Epoch 35/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8255 - loss: 0.4567 - macro_f1: 0.8105 - val_accuracy: 0.6650 - val_loss: 0.8275 - val_macro_f1: 0.5682
# Epoch 36/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8269 - loss: 0.4519 - macro_f1: 0.8118 - val_accuracy: 0.6683 - val_loss: 0.8192 - val_macro_f1: 0.5690
# Epoch 37/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8295 - loss: 0.4478 - macro_f1: 0.8144 - val_accuracy: 0.6694 - val_loss: 0.8220 - val_macro_f1: 0.5699
# Epoch 38/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8310 - loss: 0.4440 - macro_f1: 0.8157 - val_accuracy: 0.6632 - val_loss: 0.8407 - val_macro_f1: 0.5661
# Epoch 39/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8325 - loss: 0.4409 - macro_f1: 0.8173 - val_accuracy: 0.6694 - val_loss: 0.8234 - val_macro_f1: 0.5678
# Epoch 40/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8345 - loss: 0.4361 - macro_f1: 0.8194 - val_accuracy: 0.6677 - val_loss: 0.8294 - val_macro_f1: 0.5669
# Epoch 41/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8366 - loss: 0.4320 - macro_f1: 0.8215 - val_accuracy: 0.6667 - val_loss: 0.8466 - val_macro_f1: 0.5676
# Epoch 42/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8384 - loss: 0.4284 - macro_f1: 0.8231 - val_accuracy: 0.6674 - val_loss: 0.8434 - val_macro_f1: 0.5682
# Epoch 43/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8398 - loss: 0.4244 - macro_f1: 0.8246 - val_accuracy: 0.6609 - val_loss: 0.8558 - val_macro_f1: 0.5604
# Epoch 44/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8408 - loss: 0.4214 - macro_f1: 0.8255 - val_accuracy: 0.6616 - val_loss: 0.8564 - val_macro_f1: 0.5624
# Epoch 45/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8429 - loss: 0.4180 - macro_f1: 0.8276 - val_accuracy: 0.6644 - val_loss: 0.8507 - val_macro_f1: 0.5643
# Epoch 46/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8440 - loss: 0.4143 - macro_f1: 0.8289 - val_accuracy: 0.6674 - val_loss: 0.8530 - val_macro_f1: 0.5675
# Epoch 47/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8448 - loss: 0.4121 - macro_f1: 0.8298 - val_accuracy: 0.6568 - val_loss: 0.8876 - val_macro_f1: 0.5603
# Epoch 48/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8473 - loss: 0.4085 - macro_f1: 0.8320 - val_accuracy: 0.6645 - val_loss: 0.8572 - val_macro_f1: 0.5606
# Epoch 49/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8487 - loss: 0.4054 - macro_f1: 0.8335 - val_accuracy: 0.6606 - val_loss: 0.8734 - val_macro_f1: 0.5571
# Epoch 50/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8499 - loss: 0.4024 - macro_f1: 0.8349 - val_accuracy: 0.6605 - val_loss: 0.8840 - val_macro_f1: 0.5600
# Epoch 51/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8510 - loss: 0.3995 - macro_f1: 0.8359 - val_accuracy: 0.6642 - val_loss: 0.8797 - val_macro_f1: 0.5619
# Epoch 52/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8516 - loss: 0.3981 - macro_f1: 0.8364 - val_accuracy: 0.6574 - val_loss: 0.8783 - val_macro_f1: 0.5557
# Epoch 53/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8530 - loss: 0.3948 - macro_f1: 0.8377 - val_accuracy: 0.6609 - val_loss: 0.8927 - val_macro_f1: 0.5599
# Epoch 54/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8551 - loss: 0.3912 - macro_f1: 0.8400 - val_accuracy: 0.6602 - val_loss: 0.8843 - val_macro_f1: 0.5564
# Epoch 55/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8554 - loss: 0.3890 - macro_f1: 0.8403 - val_accuracy: 0.6614 - val_loss: 0.9015 - val_macro_f1: 0.5595
# Epoch 56/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8570 - loss: 0.3859 - macro_f1: 0.8422 - val_accuracy: 0.6576 - val_loss: 0.9154 - val_macro_f1: 0.5560
# Epoch 57/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8575 - loss: 0.3845 - macro_f1: 0.8424 - val_accuracy: 0.6549 - val_loss: 0.9290 - val_macro_f1: 0.5542
# Epoch 58/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8591 - loss: 0.3813 - macro_f1: 0.8441 - val_accuracy: 0.6552 - val_loss: 0.9358 - val_macro_f1: 0.5548
# Epoch 59/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8602 - loss: 0.3788 - macro_f1: 0.8452 - val_accuracy: 0.6543 - val_loss: 0.9565 - val_macro_f1: 0.5555
# Epoch 60/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8610 - loss: 0.3765 - macro_f1: 0.8460 - val_accuracy: 0.6560 - val_loss: 0.9372 - val_macro_f1: 0.5545
# Epoch 61/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8622 - loss: 0.3738 - macro_f1: 0.8473 - val_accuracy: 0.6538 - val_loss: 0.9432 - val_macro_f1: 0.5547
# Epoch 62/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8629 - loss: 0.3722 - macro_f1: 0.8480 - val_accuracy: 0.6553 - val_loss: 0.9459 - val_macro_f1: 0.5554
# Epoch 63/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8637 - loss: 0.3693 - macro_f1: 0.8489 - val_accuracy: 0.6538 - val_loss: 0.9659 - val_macro_f1: 0.5545
# Epoch 64/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8648 - loss: 0.3676 - macro_f1: 0.8502 - val_accuracy: 0.6531 - val_loss: 0.9714 - val_macro_f1: 0.5554
# Epoch 65/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8661 - loss: 0.3654 - macro_f1: 0.8514 - val_accuracy: 0.6558 - val_loss: 0.9437 - val_macro_f1: 0.5554
# Epoch 66/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8664 - loss: 0.3628 - macro_f1: 0.8517 - val_accuracy: 0.6563 - val_loss: 0.9636 - val_macro_f1: 0.5574
# Epoch 67/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8666 - loss: 0.3619 - macro_f1: 0.8520 - val_accuracy: 0.6526 - val_loss: 0.9718 - val_macro_f1: 0.5526
# Epoch 68/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8680 - loss: 0.3592 - macro_f1: 0.8534 - val_accuracy: 0.6530 - val_loss: 0.9706 - val_macro_f1: 0.5530
# Epoch 69/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8692 - loss: 0.3568 - macro_f1: 0.8545 - val_accuracy: 0.6505 - val_loss: 0.9795 - val_macro_f1: 0.5497
# Epoch 70/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8700 - loss: 0.3548 - macro_f1: 0.8552 - val_accuracy: 0.6528 - val_loss: 0.9831 - val_macro_f1: 0.5545
# Epoch 71/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8696 - loss: 0.3533 - macro_f1: 0.8549 - val_accuracy: 0.6494 - val_loss: 0.9780 - val_macro_f1: 0.5515
# Epoch 72/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8710 - loss: 0.3520 - macro_f1: 0.8561 - val_accuracy: 0.6515 - val_loss: 0.9853 - val_macro_f1: 0.5523
# Epoch 73/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8723 - loss: 0.3491 - macro_f1: 0.8578 - val_accuracy: 0.6491 - val_loss: 1.0005 - val_macro_f1: 0.5496
# Epoch 74/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8730 - loss: 0.3475 - macro_f1: 0.8584 - val_accuracy: 0.6503 - val_loss: 0.9982 - val_macro_f1: 0.5516
# Epoch 75/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8733 - loss: 0.3463 - macro_f1: 0.8583 - val_accuracy: 0.6512 - val_loss: 0.9891 - val_macro_f1: 0.5492
# Epoch 76/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8740 - loss: 0.3437 - macro_f1: 0.8591 - val_accuracy: 0.6502 - val_loss: 1.0072 - val_macro_f1: 0.5497
# Epoch 77/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8742 - loss: 0.3435 - macro_f1: 0.8594 - val_accuracy: 0.6492 - val_loss: 1.0023 - val_macro_f1: 0.5497
# Epoch 78/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8756 - loss: 0.3404 - macro_f1: 0.8610 - val_accuracy: 0.6483 - val_loss: 1.0081 - val_macro_f1: 0.5480
# Epoch 79/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8766 - loss: 0.3378 - macro_f1: 0.8621 - val_accuracy: 0.6489 - val_loss: 1.0356 - val_macro_f1: 0.5509
# Epoch 80/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8768 - loss: 0.3371 - macro_f1: 0.8622 - val_accuracy: 0.6469 - val_loss: 1.0157 - val_macro_f1: 0.5457
# Epoch 81/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8775 - loss: 0.3357 - macro_f1: 0.8630 - val_accuracy: 0.6461 - val_loss: 1.0232 - val_macro_f1: 0.5467
# Epoch 82/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8786 - loss: 0.3331 - macro_f1: 0.8639 - val_accuracy: 0.6497 - val_loss: 1.0281 - val_macro_f1: 0.5489
# Epoch 83/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8789 - loss: 0.3316 - macro_f1: 0.8644 - val_accuracy: 0.6488 - val_loss: 1.0483 - val_macro_f1: 0.5494
# Epoch 84/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8800 - loss: 0.3289 - macro_f1: 0.8657 - val_accuracy: 0.6451 - val_loss: 1.0416 - val_macro_f1: 0.5455
# Epoch 85/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8799 - loss: 0.3282 - macro_f1: 0.8653 - val_accuracy: 0.6436 - val_loss: 1.0492 - val_macro_f1: 0.5457
# Epoch 86/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8793 - loss: 0.3301 - macro_f1: 0.8645 - val_accuracy: 0.6430 - val_loss: 1.0458 - val_macro_f1: 0.5444
# Epoch 87/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8818 - loss: 0.3247 - macro_f1: 0.8675 - val_accuracy: 0.6446 - val_loss: 1.0469 - val_macro_f1: 0.5459
# Epoch 88/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8821 - loss: 0.3237 - macro_f1: 0.8677 - val_accuracy: 0.6469 - val_loss: 1.0542 - val_macro_f1: 0.5489
# Epoch 89/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8822 - loss: 0.3225 - macro_f1: 0.8677 - val_accuracy: 0.6455 - val_loss: 1.0645 - val_macro_f1: 0.5468
# Epoch 90/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8832 - loss: 0.3204 - macro_f1: 0.8690 - val_accuracy: 0.6421 - val_loss: 1.0625 - val_macro_f1: 0.5428
# Epoch 91/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8839 - loss: 0.3185 - macro_f1: 0.8697 - val_accuracy: 0.6448 - val_loss: 1.0695 - val_macro_f1: 0.5464
# Epoch 92/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8841 - loss: 0.3179 - macro_f1: 0.8698 - val_accuracy: 0.6391 - val_loss: 1.0696 - val_macro_f1: 0.5412
# Epoch 93/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8856 - loss: 0.3153 - macro_f1: 0.8713 - val_accuracy: 0.6406 - val_loss: 1.0783 - val_macro_f1: 0.5404
# Epoch 94/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8849 - loss: 0.3151 - macro_f1: 0.8707 - val_accuracy: 0.6430 - val_loss: 1.0751 - val_macro_f1: 0.5446
# Epoch 95/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8857 - loss: 0.3128 - macro_f1: 0.8714 - val_accuracy: 0.6423 - val_loss: 1.0856 - val_macro_f1: 0.5440
# Epoch 96/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8869 - loss: 0.3118 - macro_f1: 0.8727 - val_accuracy: 0.6426 - val_loss: 1.0948 - val_macro_f1: 0.5465
# Epoch 97/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8872 - loss: 0.3101 - macro_f1: 0.8731 - val_accuracy: 0.6447 - val_loss: 1.0843 - val_macro_f1: 0.5449
# Epoch 98/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8873 - loss: 0.3082 - macro_f1: 0.8732 - val_accuracy: 0.6400 - val_loss: 1.1052 - val_macro_f1: 0.5438
# Epoch 99/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8882 - loss: 0.3074 - macro_f1: 0.8741 - val_accuracy: 0.6420 - val_loss: 1.1109 - val_macro_f1: 0.5455
# Epoch 100/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8877 - loss: 0.3068 - macro_f1: 0.8737 - val_accuracy: 0.6415 - val_loss: 1.1028 - val_macro_f1: 0.5438
# Epoch 101/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8891 - loss: 0.3047 - macro_f1: 0.8751 - val_accuracy: 0.6434 - val_loss: 1.1024 - val_macro_f1: 0.5462
# Epoch 102/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8897 - loss: 0.3046 - macro_f1: 0.8756 - val_accuracy: 0.6441 - val_loss: 1.1142 - val_macro_f1: 0.5463
# Epoch 103/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8901 - loss: 0.3022 - macro_f1: 0.8762 - val_accuracy: 0.6392 - val_loss: 1.1505 - val_macro_f1: 0.5442
# Epoch 104/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8909 - loss: 0.2998 - macro_f1: 0.8773 - val_accuracy: 0.6392 - val_loss: 1.1228 - val_macro_f1: 0.5405
# Epoch 105/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8906 - loss: 0.2999 - macro_f1: 0.8769 - val_accuracy: 0.6319 - val_loss: 1.1183 - val_macro_f1: 0.5361
# Epoch 106/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8915 - loss: 0.2985 - macro_f1: 0.8775 - val_accuracy: 0.6373 - val_loss: 1.1497 - val_macro_f1: 0.5409
# Epoch 107/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8925 - loss: 0.2962 - macro_f1: 0.8787 - val_accuracy: 0.6404 - val_loss: 1.1582 - val_macro_f1: 0.5431
# Epoch 108/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8926 - loss: 0.2956 - macro_f1: 0.8786 - val_accuracy: 0.6410 - val_loss: 1.1541 - val_macro_f1: 0.5440
# Epoch 109/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8940 - loss: 0.2934 - macro_f1: 0.8802 - val_accuracy: 0.6386 - val_loss: 1.1355 - val_macro_f1: 0.5434
# Epoch 110/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8938 - loss: 0.2915 - macro_f1: 0.8800 - val_accuracy: 0.6395 - val_loss: 1.1572 - val_macro_f1: 0.5448
# Epoch 111/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8937 - loss: 0.2920 - macro_f1: 0.8800 - val_accuracy: 0.6388 - val_loss: 1.1426 - val_macro_f1: 0.5428
# Epoch 112/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8948 - loss: 0.2898 - macro_f1: 0.8811 - val_accuracy: 0.6400 - val_loss: 1.1574 - val_macro_f1: 0.5440
# Epoch 113/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8954 - loss: 0.2893 - macro_f1: 0.8818 - val_accuracy: 0.6380 - val_loss: 1.1557 - val_macro_f1: 0.5417
# Epoch 114/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8963 - loss: 0.2876 - macro_f1: 0.8826 - val_accuracy: 0.6369 - val_loss: 1.1665 - val_macro_f1: 0.5405
# Epoch 115/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8961 - loss: 0.2869 - macro_f1: 0.8823 - val_accuracy: 0.6389 - val_loss: 1.1796 - val_macro_f1: 0.5436
# Epoch 116/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8964 - loss: 0.2852 - macro_f1: 0.8827 - val_accuracy: 0.6392 - val_loss: 1.1704 - val_macro_f1: 0.5441
# Epoch 117/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8970 - loss: 0.2843 - macro_f1: 0.8834 - val_accuracy: 0.6396 - val_loss: 1.1594 - val_macro_f1: 0.5444
# Epoch 118/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8972 - loss: 0.2833 - macro_f1: 0.8837 - val_accuracy: 0.6377 - val_loss: 1.1727 - val_macro_f1: 0.5421
# Epoch 119/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8973 - loss: 0.2832 - macro_f1: 0.8836 - val_accuracy: 0.6368 - val_loss: 1.1708 - val_macro_f1: 0.5405
# Epoch 120/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8989 - loss: 0.2811 - macro_f1: 0.8855 - val_accuracy: 0.6391 - val_loss: 1.1568 - val_macro_f1: 0.5432
# Epoch 121/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8987 - loss: 0.2804 - macro_f1: 0.8852 - val_accuracy: 0.6365 - val_loss: 1.1874 - val_macro_f1: 0.5413
# Epoch 122/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8993 - loss: 0.2790 - macro_f1: 0.8860 - val_accuracy: 0.6385 - val_loss: 1.1850 - val_macro_f1: 0.5429
# Epoch 123/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8997 - loss: 0.2771 - macro_f1: 0.8863 - val_accuracy: 0.6327 - val_loss: 1.2164 - val_macro_f1: 0.5409
# Epoch 124/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9001 - loss: 0.2767 - macro_f1: 0.8870 - val_accuracy: 0.6369 - val_loss: 1.2097 - val_macro_f1: 0.5435
# Epoch 125/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9005 - loss: 0.2753 - macro_f1: 0.8874 - val_accuracy: 0.6372 - val_loss: 1.2019 - val_macro_f1: 0.5421
# Epoch 126/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9006 - loss: 0.2750 - macro_f1: 0.8873 - val_accuracy: 0.6378 - val_loss: 1.2005 - val_macro_f1: 0.5434
# Epoch 127/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9015 - loss: 0.2727 - macro_f1: 0.8883 - val_accuracy: 0.6365 - val_loss: 1.2045 - val_macro_f1: 0.5409
# Epoch 128/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9019 - loss: 0.2718 - macro_f1: 0.8889 - val_accuracy: 0.6383 - val_loss: 1.1954 - val_macro_f1: 0.5412
# Epoch 129/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9021 - loss: 0.2714 - macro_f1: 0.8889 - val_accuracy: 0.6388 - val_loss: 1.2147 - val_macro_f1: 0.5437
# Epoch 130/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9017 - loss: 0.2704 - macro_f1: 0.8885 - val_accuracy: 0.6333 - val_loss: 1.2243 - val_macro_f1: 0.5379
# Epoch 131/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9030 - loss: 0.2692 - macro_f1: 0.8898 - val_accuracy: 0.6374 - val_loss: 1.2080 - val_macro_f1: 0.5416
# Epoch 132/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9034 - loss: 0.2668 - macro_f1: 0.8901 - val_accuracy: 0.6356 - val_loss: 1.2099 - val_macro_f1: 0.5393
# Epoch 133/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9028 - loss: 0.2677 - macro_f1: 0.8896 - val_accuracy: 0.6387 - val_loss: 1.2059 - val_macro_f1: 0.5425
# Epoch 134/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9038 - loss: 0.2659 - macro_f1: 0.8905 - val_accuracy: 0.6381 - val_loss: 1.2023 - val_macro_f1: 0.5410
# Epoch 135/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9039 - loss: 0.2659 - macro_f1: 0.8907 - val_accuracy: 0.6334 - val_loss: 1.2351 - val_macro_f1: 0.5399
# Epoch 136/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9046 - loss: 0.2639 - macro_f1: 0.8912 - val_accuracy: 0.6395 - val_loss: 1.2043 - val_macro_f1: 0.5440
# Epoch 137/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9049 - loss: 0.2631 - macro_f1: 0.8919 - val_accuracy: 0.6344 - val_loss: 1.2514 - val_macro_f1: 0.5404
# Epoch 138/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9054 - loss: 0.2622 - macro_f1: 0.8922 - val_accuracy: 0.6363 - val_loss: 1.2420 - val_macro_f1: 0.5405
# Epoch 139/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9056 - loss: 0.2621 - macro_f1: 0.8926 - val_accuracy: 0.6357 - val_loss: 1.2392 - val_macro_f1: 0.5398
# Epoch 140/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9059 - loss: 0.2602 - macro_f1: 0.8930 - val_accuracy: 0.6333 - val_loss: 1.2468 - val_macro_f1: 0.5405
# Epoch 141/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9056 - loss: 0.2599 - macro_f1: 0.8925 - val_accuracy: 0.6355 - val_loss: 1.2336 - val_macro_f1: 0.5401
# Epoch 142/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9065 - loss: 0.2594 - macro_f1: 0.8938 - val_accuracy: 0.6327 - val_loss: 1.2589 - val_macro_f1: 0.5400
# Epoch 143/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9068 - loss: 0.2578 - macro_f1: 0.8939 - val_accuracy: 0.6385 - val_loss: 1.2416 - val_macro_f1: 0.5438
# Epoch 144/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9065 - loss: 0.2572 - macro_f1: 0.8933 - val_accuracy: 0.6318 - val_loss: 1.2563 - val_macro_f1: 0.5366
# Epoch 145/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9073 - loss: 0.2573 - macro_f1: 0.8945 - val_accuracy: 0.6337 - val_loss: 1.2492 - val_macro_f1: 0.5389
# Epoch 146/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9078 - loss: 0.2544 - macro_f1: 0.8949 - val_accuracy: 0.6349 - val_loss: 1.2396 - val_macro_f1: 0.5396
# Epoch 147/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9076 - loss: 0.2546 - macro_f1: 0.8946 - val_accuracy: 0.6333 - val_loss: 1.2752 - val_macro_f1: 0.5404
# Epoch 148/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9075 - loss: 0.2542 - macro_f1: 0.8946 - val_accuracy: 0.6318 - val_loss: 1.2684 - val_macro_f1: 0.5364
# Epoch 149/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9082 - loss: 0.2529 - macro_f1: 0.8953 - val_accuracy: 0.6340 - val_loss: 1.2653 - val_macro_f1: 0.5401
# Epoch 150/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9089 - loss: 0.2514 - macro_f1: 0.8960 - val_accuracy: 0.6325 - val_loss: 1.2586 - val_macro_f1: 0.5384
# Epoch 151/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9094 - loss: 0.2507 - macro_f1: 0.8965 - val_accuracy: 0.6300 - val_loss: 1.2649 - val_macro_f1: 0.5351
# Epoch 152/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9095 - loss: 0.2503 - macro_f1: 0.8966 - val_accuracy: 0.6328 - val_loss: 1.2791 - val_macro_f1: 0.5388
# Epoch 153/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9098 - loss: 0.2497 - macro_f1: 0.8971 - val_accuracy: 0.6320 - val_loss: 1.2712 - val_macro_f1: 0.5394
# Epoch 154/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9103 - loss: 0.2480 - macro_f1: 0.8974 - val_accuracy: 0.6305 - val_loss: 1.2898 - val_macro_f1: 0.5375
# Epoch 155/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9104 - loss: 0.2475 - macro_f1: 0.8974 - val_accuracy: 0.6306 - val_loss: 1.3132 - val_macro_f1: 0.5377
# Epoch 156/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9108 - loss: 0.2456 - macro_f1: 0.8979 - val_accuracy: 0.6340 - val_loss: 1.2941 - val_macro_f1: 0.5410
# Epoch 157/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9116 - loss: 0.2458 - macro_f1: 0.8990 - val_accuracy: 0.6297 - val_loss: 1.2940 - val_macro_f1: 0.5358
# Epoch 158/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9111 - loss: 0.2455 - macro_f1: 0.8981 - val_accuracy: 0.6345 - val_loss: 1.3143 - val_macro_f1: 0.5402
# Epoch 159/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9113 - loss: 0.2448 - macro_f1: 0.8985 - val_accuracy: 0.6343 - val_loss: 1.2881 - val_macro_f1: 0.5407
# Epoch 160/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9120 - loss: 0.2426 - macro_f1: 0.8994 - val_accuracy: 0.6304 - val_loss: 1.3114 - val_macro_f1: 0.5373
# Epoch 161/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9124 - loss: 0.2435 - macro_f1: 0.8997 - val_accuracy: 0.6319 - val_loss: 1.3030 - val_macro_f1: 0.5389
# Epoch 162/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9126 - loss: 0.2421 - macro_f1: 0.8997 - val_accuracy: 0.6295 - val_loss: 1.3099 - val_macro_f1: 0.5358
# Epoch 163/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9126 - loss: 0.2409 - macro_f1: 0.8998 - val_accuracy: 0.6289 - val_loss: 1.3249 - val_macro_f1: 0.5375
# Epoch 164/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9129 - loss: 0.2411 - macro_f1: 0.9003 - val_accuracy: 0.6300 - val_loss: 1.3327 - val_macro_f1: 0.5373
# Epoch 165/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9129 - loss: 0.2407 - macro_f1: 0.9004 - val_accuracy: 0.6332 - val_loss: 1.2995 - val_macro_f1: 0.5402
# Epoch 166/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9131 - loss: 0.2392 - macro_f1: 0.9004 - val_accuracy: 0.6289 - val_loss: 1.3119 - val_macro_f1: 0.5364
# Epoch 167/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9136 - loss: 0.2384 - macro_f1: 0.9011 - val_accuracy: 0.6318 - val_loss: 1.3269 - val_macro_f1: 0.5392
# Epoch 168/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9146 - loss: 0.2372 - macro_f1: 0.9019 - val_accuracy: 0.6292 - val_loss: 1.3402 - val_macro_f1: 0.5373
# Epoch 169/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9133 - loss: 0.2378 - macro_f1: 0.9005 - val_accuracy: 0.6321 - val_loss: 1.3230 - val_macro_f1: 0.5402
# Epoch 170/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9147 - loss: 0.2356 - macro_f1: 0.9020 - val_accuracy: 0.6300 - val_loss: 1.3410 - val_macro_f1: 0.5403
# Epoch 171/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9153 - loss: 0.2347 - macro_f1: 0.9029 - val_accuracy: 0.6268 - val_loss: 1.3587 - val_macro_f1: 0.5369
# Epoch 172/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9146 - loss: 0.2346 - macro_f1: 0.9021 - val_accuracy: 0.6289 - val_loss: 1.3504 - val_macro_f1: 0.5378
# Epoch 173/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9146 - loss: 0.2341 - macro_f1: 0.9021 - val_accuracy: 0.6266 - val_loss: 1.3799 - val_macro_f1: 0.5360
# Epoch 174/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9154 - loss: 0.2331 - macro_f1: 0.9030 - val_accuracy: 0.6290 - val_loss: 1.3611 - val_macro_f1: 0.5384
# Epoch 175/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9156 - loss: 0.2324 - macro_f1: 0.9031 - val_accuracy: 0.6264 - val_loss: 1.3446 - val_macro_f1: 0.5337
# Epoch 176/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9153 - loss: 0.2335 - macro_f1: 0.9027 - val_accuracy: 0.6290 - val_loss: 1.3587 - val_macro_f1: 0.5389
# Epoch 177/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9153 - loss: 0.2329 - macro_f1: 0.9027 - val_accuracy: 0.6259 - val_loss: 1.3679 - val_macro_f1: 0.5347
# Epoch 178/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9163 - loss: 0.2311 - macro_f1: 0.9038 - val_accuracy: 0.6277 - val_loss: 1.3280 - val_macro_f1: 0.5372
# Epoch 179/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9162 - loss: 0.2305 - macro_f1: 0.9036 - val_accuracy: 0.6283 - val_loss: 1.3572 - val_macro_f1: 0.5376
# Epoch 180/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9169 - loss: 0.2303 - macro_f1: 0.9047 - val_accuracy: 0.6240 - val_loss: 1.3578 - val_macro_f1: 0.5336
# Epoch 181/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9175 - loss: 0.2279 - macro_f1: 0.9052 - val_accuracy: 0.6241 - val_loss: 1.3889 - val_macro_f1: 0.5343
# Epoch 182/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9162 - loss: 0.2297 - macro_f1: 0.9036 - val_accuracy: 0.6252 - val_loss: 1.3471 - val_macro_f1: 0.5353
# Epoch 183/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9147 - loss: 0.2343 - macro_f1: 0.9019 - val_accuracy: 0.6268 - val_loss: 1.3630 - val_macro_f1: 0.5369
# Epoch 184/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9173 - loss: 0.2271 - macro_f1: 0.9049 - val_accuracy: 0.6271 - val_loss: 1.3875 - val_macro_f1: 0.5361
# Epoch 185/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9172 - loss: 0.2277 - macro_f1: 0.9049 - val_accuracy: 0.6230 - val_loss: 1.3945 - val_macro_f1: 0.5329
# Epoch 186/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9186 - loss: 0.2246 - macro_f1: 0.9061 - val_accuracy: 0.6250 - val_loss: 1.3923 - val_macro_f1: 0.5355
# Epoch 187/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9187 - loss: 0.2245 - macro_f1: 0.9065 - val_accuracy: 0.6241 - val_loss: 1.4087 - val_macro_f1: 0.5345
# Epoch 188/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9182 - loss: 0.2252 - macro_f1: 0.9056 - val_accuracy: 0.6239 - val_loss: 1.3968 - val_macro_f1: 0.5342
# Epoch 189/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9188 - loss: 0.2238 - macro_f1: 0.9065 - val_accuracy: 0.6233 - val_loss: 1.4057 - val_macro_f1: 0.5341
# Epoch 190/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9186 - loss: 0.2231 - macro_f1: 0.9064 - val_accuracy: 0.6248 - val_loss: 1.4177 - val_macro_f1: 0.5349
# Epoch 191/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9194 - loss: 0.2226 - macro_f1: 0.9070 - val_accuracy: 0.6217 - val_loss: 1.4306 - val_macro_f1: 0.5325
# Epoch 192/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9195 - loss: 0.2215 - macro_f1: 0.9072 - val_accuracy: 0.6235 - val_loss: 1.4092 - val_macro_f1: 0.5337
# Epoch 193/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9197 - loss: 0.2216 - macro_f1: 0.9074 - val_accuracy: 0.6254 - val_loss: 1.4112 - val_macro_f1: 0.5360
# Epoch 194/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9199 - loss: 0.2207 - macro_f1: 0.9077 - val_accuracy: 0.6277 - val_loss: 1.3928 - val_macro_f1: 0.5380
# Epoch 195/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9195 - loss: 0.2200 - macro_f1: 0.9072 - val_accuracy: 0.6268 - val_loss: 1.4237 - val_macro_f1: 0.5377
# Epoch 196/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9205 - loss: 0.2191 - macro_f1: 0.9086 - val_accuracy: 0.6247 - val_loss: 1.4359 - val_macro_f1: 0.5356
# Epoch 197/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9205 - loss: 0.2178 - macro_f1: 0.9084 - val_accuracy: 0.6230 - val_loss: 1.4598 - val_macro_f1: 0.5340
# Epoch 198/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9211 - loss: 0.2181 - macro_f1: 0.9089 - val_accuracy: 0.6254 - val_loss: 1.4299 - val_macro_f1: 0.5359
# Epoch 199/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9209 - loss: 0.2175 - macro_f1: 0.9088 - val_accuracy: 0.6221 - val_loss: 1.4485 - val_macro_f1: 0.5339
# Epoch 200/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.9210 - loss: 0.2172 - macro_f1: 0.9091 - val_accuracy: 0.6223 - val_loss: 1.4371 - val_macro_f1: 0.5341

# %%
print(accuracy_score(np.argmax(testY_CNN, axis=1), np.argmax(model.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step
# 0.7116311080523056

# %%
print(classification_report(np.argmax(testY_CNN, axis=1), np.argmax(model.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70     47915
#            1       0.77      0.71      0.74     48050
#            2       0.68      0.70      0.69     43523
#
#     accuracy                           0.71    139488
#    macro avg       0.71      0.71      0.71    139488
# weighted avg       0.71      0.71      0.71    139488

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = model.predict(testX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(testY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step

# %%
print(accuracy_score(np.argmax(trainY_CNN, axis=1), np.argmax(model.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step
# 0.9233189822337642

# %%
print(classification_report(np.argmax(trainY_CNN, axis=1), np.argmax(model.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93     84426
#            1       0.88      0.86      0.87     36210
#            2       0.93      0.94      0.94     83065
#
#     accuracy                           0.92    203701
#    macro avg       0.91      0.91      0.91    203701
# weighted avg       0.92      0.92      0.92    203701

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = model.predict(trainX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(trainY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TEST DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = model.predict(testX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    """
    Implements trading strategy using the FI-2010 paper's methodology

    Args:
        predictions: numpy array of model predictions (n_samples, 3)
        dec_data: numpy array of decoded price data
        budget: amount to invest per trade
        prob_threshold: probability threshold for trading
        k: prediction horizon (number of steps to look ahead)
        alpha: threshold for determining price movement direction
    """
    # Get normalized ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        # Calculate m+ (future average) according to paper
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        # Calculate actual price movement using paper's method
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:  # not stable
            # Determine actual direction using same threshold as training
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)

            # Long trade (UP prediction)
            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })

            # Short trade (DOWN prediction)
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        # Print performance metrics
        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_test,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 74543
# Win rate: 0.51%
# Total profit: $379.58
# Average profit per trade: $0.0051
#
# Direction Analysis:
#
# UP trades:
# Count: 35299
# Win rate: 0.52%
# Total profit: $258.00
# Average profit: $0.0073
#
# DOWN trades:
# Count: 39244
# Win rate: 0.50%
# Total profit: $121.58
# Average profit: $0.0031
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 70692
# Win rate: 0.51%
# Total profit: $382.21
# Average profit per trade: $0.0054
#
# Direction Analysis:
#
# UP trades:
# Count: 33499
# Win rate: 0.53%
# Total profit: $257.60
# Average profit: $0.0077
#
# DOWN trades:
# Count: 37193
# Win rate: 0.50%
# Total profit: $124.61
# Average profit: $0.0034
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 65583
# Win rate: 0.51%
# Total profit: $379.14
# Average profit per trade: $0.0058
#
# Direction Analysis:
#
# UP trades:
# Count: 31130
# Win rate: 0.53%
# Total profit: $254.54
# Average profit: $0.0082
#
# DOWN trades:
# Count: 34453
# Win rate: 0.50%
# Total profit: $124.60
# Average profit: $0.0036
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 58062
# Win rate: 0.51%
# Total profit: $301.41
# Average profit per trade: $0.0052
#
# Direction Analysis:
#
# UP trades:
# Count: 27701
# Win rate: 0.53%
# Total profit: $172.56
# Average profit: $0.0062
#
# DOWN trades:
# Count: 30361
# Win rate: 0.50%
# Total profit: $128.86
# Average profit: $0.0042
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 42670
# Win rate: 0.52%
# Total profit: $-3.05
# Average profit per trade: $-0.0001
#
# Direction Analysis:
#
# UP trades:
# Count: 20296
# Win rate: 0.55%
# Total profit: $-193.07
# Average profit: $-0.0095
#
# DOWN trades:
# Count: 22374
# Win rate: 0.49%
# Total profit: $190.02
# Average profit: $0.0085
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000    379.582033       74543  0.508431    0.005092        35299
# 1   0.850000    382.207344       70692  0.514910    0.005407        33499
# 2   0.900000    379.142122       65583  0.513853    0.005781        31130
# 3   0.950000    301.414502       58062  0.514967    0.005191        27701
# 4   0.990000     -3.047184       42670  0.520272   -0.000071        20296
#
#    short_trades
# 0         39244
# 1         37193
# 2         34453
# 3         30361
# 4         22374

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TRAIN DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = model.predict(trainX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    """
    Implements trading strategy using the FI-2010 paper's methodology

    Args:
        predictions: numpy array of model predictions (n_samples, 3)
        dec_data: numpy array of decoded price data
        budget: amount to invest per trade
        prob_threshold: probability threshold for trading
        k: prediction horizon (number of steps to look ahead)
        alpha: threshold for determining price movement direction
    """
    # Get normalized ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        # Calculate m+ (future average) according to paper
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        # Calculate actual price movement using paper's method
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:  # not stable
            # Determine actual direction using same threshold as training
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)

            # Long trade (UP prediction)
            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })

            # Short trade (DOWN prediction)
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        # Print performance metrics
        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_train,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 145390
# Win rate: 0.72%
# Total profit: $-254.89
# Average profit per trade: $-0.0018
#
# Direction Analysis:
#
# UP trades:
# Count: 72459
# Win rate: 0.76%
# Total profit: $88.08
# Average profit: $0.0012
#
# DOWN trades:
# Count: 72931
# Win rate: 0.68%
# Total profit: $-342.97
# Average profit: $-0.0047
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 140354
# Win rate: 0.72%
# Total profit: $-268.31
# Average profit per trade: $-0.0019
#
# Direction Analysis:
#
# UP trades:
# Count: 69962
# Win rate: 0.75%
# Total profit: $77.14
# Average profit: $0.0011
#
# DOWN trades:
# Count: 70392
# Win rate: 0.68%
# Total profit: $-345.45
# Average profit: $-0.0049
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 133626
# Win rate: 0.72%
# Total profit: $-235.93
# Average profit per trade: $-0.0018
#
# Direction Analysis:
#
# UP trades:
# Count: 66652
# Win rate: 0.76%
# Total profit: $109.70
# Average profit: $0.0016
#
# DOWN trades:
# Count: 66974
# Win rate: 0.68%
# Total profit: $-345.63
# Average profit: $-0.0052
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 122212
# Win rate: 0.71%
# Total profit: $-266.85
# Average profit per trade: $-0.0022
#
# Direction Analysis:
#
# UP trades:
# Count: 61094
# Win rate: 0.75%
# Total profit: $74.81
# Average profit: $0.0012
#
# DOWN trades:
# Count: 61118
# Win rate: 0.68%
# Total profit: $-341.66
# Average profit: $-0.0056
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 94711
# Win rate: 0.70%
# Total profit: $-309.98
# Average profit per trade: $-0.0033
#
# Direction Analysis:
#
# UP trades:
# Count: 47687
# Win rate: 0.74%
# Total profit: $40.74
# Average profit: $0.0009
#
# DOWN trades:
# Count: 47024
# Win rate: 0.67%
# Total profit: $-350.72
# Average profit: $-0.0075
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000   -254.890879      145390  0.718756   -0.001753        72459
# 1   0.850000   -268.313966      140354  0.716759   -0.001912        69962
# 2   0.900000   -235.929880      133626  0.717675   -0.001766        66652
# 3   0.950000   -266.854443      122212  0.712696   -0.002184        61094
# 4   0.990000   -309.983396       94711  0.704248   -0.003273        47687
#
#    short_trades
# 0         72931
# 1         70392
# 2         66974
# 3         61118
# 4         47024

# %%
def calculate_perturbation_volume(original, perturbed):
    original_flat = original.reshape(original.shape[0], -1)
    perturbed_flat = perturbed.reshape(perturbed.shape[0], -1)
    perturbation = np.linalg.norm(original_flat - perturbed_flat, ord=2, axis=1)
    avg_perturbation = np.mean(perturbation)
    return avg_perturbation

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
num_iterations = 5
step_size = 0.01

# Define your model
model = model

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}
avg_accuracies3 = {}
perturbed_volumes3 = {}
avg_precision3 = {}
avg_recall3 = {}
avg_roc_auc3 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def fgsm_attack(images, labels, epsilon):
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
    gradient = tape.gradient(loss, images)
    signed_grad = tf.sign(gradient)

    signed_masked = signed_grad.numpy()
    signed_masked[:, :99, :, :] = 0
    signed_masked[:, 99:, ::2, :] = 0
    signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

    perturbed_images = images + epsilon * signed_masked
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images
"""
with tf.GradientTape() as tape: automatically tracks operations for gradient calculation
tape.watch(images): Explicitly tells the gradient tape to watch the images tensor for gradient calculation
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions):
Calculates the loss between the true labels and the model's predictions
Uses categorical cross-entropy loss because this is a classification problem
from_logits=False indicates that the predictions are already probabilities (softmax has been applied)
gradient = tape.gradient(loss, images)
Calculates the gradient of the loss with respect to the input images
This tells us how to change the input to maximize the loss (i.e., make the model more likely to misclassify)
signed_grad = tf.sign(gradient)
Applies the sign function to the gradient to get the direction of the gradient
signed_masked[:, :99, :, :] = 0:
Sets the gradients for the first 99 time steps to zero
This ensures we only perturb the last time step (t=99), which is what the model primarily bases its prediction on
Within the last time step (t=99), this sets gradients for every other feature to zero
The ::2 slice is accessing only even indices, which likely correspond to price data in the LOB
This ensures we only perturb volume data and not price data, making the attack more realistic
signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32):
Converts the masked gradient signs back to a TensorFlow tensor for further operations
perturbed_images = images + epsilon * signed_masked:
Creates adversarial examples by adding the perturbation to the original images
The perturbation is the sign of the gradient scaled by epsilon
perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
Clips the perturbed values to ensure they stay within valid range [0,1]
"""
def pgd_attack(images, labels, epsilon, trainX_CNN, start_idx, end_idx):
    perturbed_images = tf.identity(images)

    for _ in range(num_iterations):
        # Gradient step
        with tf.GradientTape() as tape:
            tape.watch(perturbed_images)
            predictions = model(perturbed_images)
            loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
        gradient = tape.gradient(loss, perturbed_images)
        signed_grad = tf.sign(gradient)

        # Apply masking to gradient
        signed_masked = signed_grad.numpy()
        signed_masked[:, :99, :, :] = 0
        signed_masked[:, 99:, ::2, :] = 0
        signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

        # Apply gradient step
        perturbed_images = perturbed_images + step_size * signed_masked

        # Step 1: Apply volume constraint
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

    return perturbed_images

def random_noise_attack(images, epsilon, trainX_CNN, start_idx, end_idx):
    """Random noise baseline attack: uniform noise within [-epsilon, epsilon]."""
    noise = tf.random.uniform(tf.shape(images), -epsilon, epsilon)
    noise = noise.numpy()
    noise[:, :99, :, :] = 0
    noise[:, 99:, ::2, :] = 0
    noise = tf.convert_to_tensor(noise, dtype=tf.float32)
    perturbed_images = images + noise
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    # Apply volume constraint
    perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)
    return perturbed_images


def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_accuracy3 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    total_perturbation3 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []
    all_predicted_labels3 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []
    epsilon_pred_probs_random = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon, trainX_CNN, start_idx, end_idx)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)
        perturbed_images3 = random_noise_attack(batch_images, epsilon, trainX_CNN, start_idx, end_idx)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())
        perturbation3 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images3.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2
        total_perturbation3 += perturbation3

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()
        X_perturbed3 = perturbed_images3.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)
        adversarial_probs3 = model.predict(X_perturbed3)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)
        adversarial_predictions3 = np.argmax(adversarial_probs3, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)
        epsilon_pred_probs_random.append(adversarial_probs3)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)
        all_predicted_labels3.extend(adversarial_predictions3)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2
        accuracy3 = accuracy_score(true_labels_batch, adversarial_predictions3)
        total_accuracy3 += accuracy3

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    average_accuracy3 = total_accuracy3 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches
    avg_perturbation3 = total_perturbation3 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)
    epsilon_pred_probs_random = np.vstack(epsilon_pred_probs_random)

    # Calculate and plot ROC curve

    # Compute macro-average ROC AUC for Random Noise
    fpr3 = dict()
    tpr3 = dict()
    roc_auc3_per_class = dict()
    for i in range(3):
        fpr3[i], tpr3[i], _ = roc_curve(epsilon_true_labels_onehot[:, i], epsilon_pred_probs_random[:, i])
        roc_auc3_per_class[i] = auc(fpr3[i], tpr3[i])
    all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(3)]))
    mean_tpr3 = np.zeros_like(all_fpr3)
    for i in range(3):
        mean_tpr3 += np.interp(all_fpr3, fpr3[i], tpr3[i])
    mean_tpr3 /= 3
    roc_auc3 = auc(all_fpr3, mean_tpr3)
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2
    avg_roc_auc3[epsilon] = roc_auc3

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')
    precision3 = precision_score(all_true_labels, all_predicted_labels3, average='macro')
    recall3 = recall_score(all_true_labels, all_predicted_labels3, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2
    avg_precision3[epsilon] = precision3
    avg_recall3[epsilon] = recall3

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)
    random_report = classification_report(all_true_labels, all_predicted_labels3, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    avg_accuracies3[epsilon] = average_accuracy3
    print(f"Average accuracy of Random Noise attack for epsilon value {epsilon}: {average_accuracy3}")
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2
    perturbed_volumes3[epsilon] = avg_perturbation3
    print(f"Average perturbation volume for Random Noise attack with epsilon {epsilon}: {avg_perturbation3}")

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")
    print(f"Average precision of Random Noise attack for epsilon value {epsilon}: {precision3}")
    print(f"Average recall of Random Noise attack for epsilon value {epsilon}: {recall3}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")
    print(f"ROC AUC of Random Noise attack for epsilon value {epsilon}: {roc_auc3}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))
    print(f"\nClassification Report for Random Noise Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels3))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 1e-06
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1e-06: 0.21486231884057966
# Average accuracy of FGSM attack for epsilon value 1e-06: 0.6950217391304349
# Average accuracy of Random Noise attack for epsilon value 1e-06: 0.46294202898550724
# Average perturbation volume for PGD attack with epsilon 1e-06: 2.2699191570281982
# Average perturbation volume for FGSM attack with epsilon 1e-06: 4.471045940590557e-06
# Average perturbation volume for Random Noise attack with epsilon 1e-06: 2.264003276824951
# Average precision of PGD attack for epsilon value 1e-06: 0.1905356845064794
# Average recall of PGD attack for epsilon value 1e-06: 0.21742158810710388
# Average precision of FGSM attack for epsilon value 1e-06: 0.694407573806465
# Average recall of FGSM attack for epsilon value 1e-06: 0.6943503088983026
# Average precision of Random Noise attack for epsilon value 1e-06: 0.47439260801271216
# Average recall of Random Noise attack for epsilon value 1e-06: 0.4648398201090708
# ROC AUC of PGD attack for epsilon value 1e-06: 0.34461890702290604
# ROC AUC of FGSM attack for epsilon value 1e-06: 0.8416802253816598
# ROC AUC of Random Noise attack for epsilon value 1e-06: 0.6245749550240561
#
# Classification Report for PGD Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27     47512
#            1       0.12      0.03      0.05     47269
#            2       0.21      0.31      0.25     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.19      0.22      0.19    138000
# weighted avg       0.19      0.21      0.19    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68     47512
#            1       0.73      0.73      0.73     47269
#            2       0.67      0.67      0.67     43219
#
#     accuracy                           0.70    138000
#    macro avg       0.69      0.69      0.69    138000
# weighted avg       0.70      0.70      0.70    138000
#
#
# Classification Report for Random Noise Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.46      0.53      0.49     47512
#            1       0.54      0.33      0.41     47269
#            2       0.43      0.53      0.48     43219
#
#     accuracy                           0.46    138000
#    macro avg       0.47      0.46      0.46    138000
# weighted avg       0.48      0.46      0.46    138000
#
# Epsilon value: 1e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1e-05: 0.2144130434782609
# Average accuracy of FGSM attack for epsilon value 1e-05: 0.6945652173913044
# Average accuracy of Random Noise attack for epsilon value 1e-05: 0.4629130434782608
# Average perturbation volume for PGD attack with epsilon 1e-05: 2.2699215412139893
# Average perturbation volume for FGSM attack with epsilon 1e-05: 4.472057844395749e-05
# Average perturbation volume for Random Noise attack with epsilon 1e-05: 2.264003276824951
# Average precision of PGD attack for epsilon value 1e-05: 0.1907715739042566
# Average recall of PGD attack for epsilon value 1e-05: 0.21699580243836183
# Average precision of FGSM attack for epsilon value 1e-05: 0.6939563960960274
# Average recall of FGSM attack for epsilon value 1e-05: 0.6938973686976174
# Average precision of Random Noise attack for epsilon value 1e-05: 0.47435443720088416
# Average recall of Random Noise attack for epsilon value 1e-05: 0.4648109880042515
# ROC AUC of PGD attack for epsilon value 1e-05: 0.3441079622937038
# ROC AUC of FGSM attack for epsilon value 1e-05: 0.8411636164386024
# ROC AUC of Random Noise attack for epsilon value 1e-05: 0.624574820997914
#
# Classification Report for PGD Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.23      0.31      0.27     47512
#            1       0.13      0.03      0.05     47269
#            2       0.21      0.31      0.25     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.19      0.22      0.19    138000
# weighted avg       0.19      0.21      0.19    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68     47512
#            1       0.73      0.73      0.73     47269
#            2       0.67      0.67      0.67     43219
#
#     accuracy                           0.69    138000
#    macro avg       0.69      0.69      0.69    138000
# weighted avg       0.69      0.69      0.69    138000
#
#
# Classification Report for Random Noise Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.46      0.53      0.49     47512
#            1       0.54      0.33      0.41     47269
#            2       0.43      0.53      0.48     43219
#
#     accuracy                           0.46    138000
#    macro avg       0.47      0.46      0.46    138000
# weighted avg       0.48      0.46      0.46    138000
#
# Epsilon value: 0.0001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.0001: 0.21365217391304345
# Average accuracy of FGSM attack for epsilon value 0.0001: 0.6890144927536233
# Average accuracy of Random Noise attack for epsilon value 0.0001: 0.4629057971014493
# Average perturbation volume for PGD attack with epsilon 0.0001: 2.2699222564697266
# Average perturbation volume for FGSM attack with epsilon 0.0001: 0.000447065249318257
# Average perturbation volume for Random Noise attack with epsilon 0.0001: 2.264003276824951
# Average precision of PGD attack for epsilon value 0.0001: 0.19003728405027898
# Average recall of PGD attack for epsilon value 0.0001: 0.2162144375454412
# Average precision of FGSM attack for epsilon value 0.0001: 0.6884245627061483
# Average recall of FGSM attack for epsilon value 0.0001: 0.6883554288391264
# Average precision of Random Noise attack for epsilon value 0.0001: 0.47434676379037694
# Average recall of Random Noise attack for epsilon value 0.0001: 0.46480463305197756
# ROC AUC of PGD attack for epsilon value 0.0001: 0.3441403092299266
# ROC AUC of FGSM attack for epsilon value 0.0001: 0.8359927016676741
# ROC AUC of Random Noise attack for epsilon value 0.0001: 0.624571805926952
#
# Classification Report for PGD Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.23      0.31      0.27     47512
#            1       0.12      0.03      0.05     47269
#            2       0.21      0.31      0.25     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.19      0.22      0.19    138000
# weighted avg       0.19      0.21      0.19    138000
#
#
# Classification Report for FGSM Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.67      0.68      0.67     47512
#            1       0.73      0.72      0.73     47269
#            2       0.67      0.67      0.67     43219
#
#     accuracy                           0.69    138000
#    macro avg       0.69      0.69      0.69    138000
# weighted avg       0.69      0.69      0.69    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.46      0.53      0.49     47512
#            1       0.54      0.33      0.41     47269
#            2       0.43      0.53      0.48     43219
#
#     accuracy                           0.46    138000
#    macro avg       0.47      0.46      0.46    138000
# weighted avg       0.48      0.46      0.46    138000
#
# Epsilon value: 0.001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.001: 0.2143550724637681
# Average accuracy of FGSM attack for epsilon value 0.001: 0.6319130434782608
# Average accuracy of Random Noise attack for epsilon value 0.001: 0.46277536231884064
# Average perturbation volume for PGD attack with epsilon 0.001: 2.269914150238037
# Average perturbation volume for FGSM attack with epsilon 0.001: 0.00445581553503871
# Average perturbation volume for Random Noise attack with epsilon 0.001: 2.2640042304992676
# Average precision of PGD attack for epsilon value 0.001: 0.1908092054519377
# Average recall of PGD attack for epsilon value 0.001: 0.21688480262254675
# Average precision of FGSM attack for epsilon value 0.001: 0.6326936604820493
# Average recall of FGSM attack for epsilon value 0.001: 0.6315979269769146
# Average precision of Random Noise attack for epsilon value 0.001: 0.47417608326244687
# Average recall of Random Noise attack for epsilon value 0.001: 0.46467487635711135
# ROC AUC of PGD attack for epsilon value 0.001: 0.3446463096290498
# ROC AUC of FGSM attack for epsilon value 0.001: 0.7857151227985754
# ROC AUC of Random Noise attack for epsilon value 0.001: 0.6245319828264372
#
# Classification Report for PGD Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.24      0.31      0.27     47512
#            1       0.13      0.03      0.05     47269
#            2       0.21      0.31      0.25     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.19      0.22      0.19    138000
# weighted avg       0.19      0.21      0.19    138000
#
#
# Classification Report for FGSM Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.61      0.63      0.62     47512
#            1       0.69      0.64      0.66     47269
#            2       0.60      0.62      0.61     43219
#
#     accuracy                           0.63    138000
#    macro avg       0.63      0.63      0.63    138000
# weighted avg       0.63      0.63      0.63    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.46      0.53      0.49     47512
#            1       0.54      0.33      0.41     47269
#            2       0.43      0.53      0.48     43219
#
#     accuracy                           0.46    138000
#    macro avg       0.47      0.46      0.46    138000
# weighted avg       0.48      0.46      0.46    138000

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.01, 0.1, 1, 10]
num_iterations = 5
step_size = 0.01

# Define your model
model = model

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}
avg_accuracies3 = {}
perturbed_volumes3 = {}
avg_precision3 = {}
avg_recall3 = {}
avg_roc_auc3 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def fgsm_attack(images, labels, epsilon):
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
    gradient = tape.gradient(loss, images)
    signed_grad = tf.sign(gradient)

    signed_masked = signed_grad.numpy()
    signed_masked[:, :99, :, :] = 0
    signed_masked[:, 99:, ::2, :] = 0
    signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

    perturbed_images = images + epsilon * signed_masked
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images

def pgd_attack(images, labels, epsilon, trainX_CNN, start_idx, end_idx):
    perturbed_images = tf.identity(images)

    for _ in range(num_iterations):
        # Gradient step
        with tf.GradientTape() as tape:
            tape.watch(perturbed_images)
            predictions = model(perturbed_images)
            loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
        gradient = tape.gradient(loss, perturbed_images)
        signed_grad = tf.sign(gradient)

        # Apply masking to gradient
        signed_masked = signed_grad.numpy()
        signed_masked[:, :99, :, :] = 0
        signed_masked[:, 99:, ::2, :] = 0
        signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

        # Apply gradient step
        perturbed_images = perturbed_images + step_size * signed_masked

        # Step 1: Apply volume constraint
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

        # Step 2: Apply L2 norm constraint (projection step)
        delta = perturbed_images - images  # Calculate current perturbation

        # Reshape to flatten all dimensions except batch
        delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

        # Calculate L2 norm on the flattened dimensions
        norm = tf.norm(delta_flat, axis=1, keepdims=True)

        # Reshape norm for broadcasting
        norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

        # Scale perturbation
        scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
        delta = delta * scaling

        perturbed_images = images + delta  # Apply constrained perturbation

        # Step 3: Apply clipping to valid range [0,1]
        perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

        # Step 4: Re-apply volume constraint after all other constraints
        # This ensures volume constraint takes precedence if there's a conflict
        perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)

    return perturbed_images

def random_noise_attack(images, epsilon, trainX_CNN, start_idx, end_idx):
    """Random noise baseline attack: uniform noise within [-epsilon, epsilon]."""
    noise = tf.random.uniform(tf.shape(images), -epsilon, epsilon)
    noise = noise.numpy()
    noise[:, :99, :, :] = 0
    noise[:, 99:, ::2, :] = 0
    noise = tf.convert_to_tensor(noise, dtype=tf.float32)
    perturbed_images = images + noise
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    # Apply volume constraint
    perturbed_images = volume_constraint(perturbed_images, trainX_CNN, 2, start_idx, end_idx)
    return perturbed_images


def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_accuracy3 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    total_perturbation3 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []
    all_predicted_labels3 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []
    epsilon_pred_probs_random = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon, trainX_CNN, start_idx, end_idx)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)
        perturbed_images3 = random_noise_attack(batch_images, epsilon, trainX_CNN, start_idx, end_idx)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())
        perturbation3 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images3.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2
        total_perturbation3 += perturbation3

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()
        X_perturbed3 = perturbed_images3.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)
        adversarial_probs3 = model.predict(X_perturbed3)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)
        adversarial_predictions3 = np.argmax(adversarial_probs3, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)
        epsilon_pred_probs_random.append(adversarial_probs3)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)
        all_predicted_labels3.extend(adversarial_predictions3)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2
        accuracy3 = accuracy_score(true_labels_batch, adversarial_predictions3)
        total_accuracy3 += accuracy3

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    average_accuracy3 = total_accuracy3 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches
    avg_perturbation3 = total_perturbation3 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)
    epsilon_pred_probs_random = np.vstack(epsilon_pred_probs_random)

    # Calculate and plot ROC curve

    # Compute macro-average ROC AUC for Random Noise
    fpr3 = dict()
    tpr3 = dict()
    roc_auc3_per_class = dict()
    for i in range(3):
        fpr3[i], tpr3[i], _ = roc_curve(epsilon_true_labels_onehot[:, i], epsilon_pred_probs_random[:, i])
        roc_auc3_per_class[i] = auc(fpr3[i], tpr3[i])
    all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(3)]))
    mean_tpr3 = np.zeros_like(all_fpr3)
    for i in range(3):
        mean_tpr3 += np.interp(all_fpr3, fpr3[i], tpr3[i])
    mean_tpr3 /= 3
    roc_auc3 = auc(all_fpr3, mean_tpr3)
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2
    avg_roc_auc3[epsilon] = roc_auc3

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')
    precision3 = precision_score(all_true_labels, all_predicted_labels3, average='macro')
    recall3 = recall_score(all_true_labels, all_predicted_labels3, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2
    avg_precision3[epsilon] = precision3
    avg_recall3[epsilon] = recall3

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)
    random_report = classification_report(all_true_labels, all_predicted_labels3, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    avg_accuracies3[epsilon] = average_accuracy3
    print(f"Average accuracy of Random Noise attack for epsilon value {epsilon}: {average_accuracy3}")
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2
    perturbed_volumes3[epsilon] = avg_perturbation3
    print(f"Average perturbation volume for Random Noise attack with epsilon {epsilon}: {avg_perturbation3}")

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")
    print(f"Average precision of Random Noise attack for epsilon value {epsilon}: {precision3}")
    print(f"Average recall of Random Noise attack for epsilon value {epsilon}: {recall3}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")
    print(f"ROC AUC of Random Noise attack for epsilon value {epsilon}: {roc_auc3}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))
    print(f"\nClassification Report for Random Noise Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels3))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 0.01
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.01: 0.4619492753623188
# Average accuracy of FGSM attack for epsilon value 0.01: 0.41297101449275375
# Average accuracy of Random Noise attack for epsilon value 0.01: 0.45739855072463753
# Average perturbation volume for PGD attack with epsilon 0.01: 2.2640035152435303
# Average perturbation volume for FGSM attack with epsilon 0.01: 0.04038495570421219
# Average perturbation volume for Random Noise attack with epsilon 0.01: 2.264094829559326
# Average precision of PGD attack for epsilon value 0.01: 0.47339573061653756
# Average recall of PGD attack for epsilon value 0.01: 0.46384291346527884
# Average precision of FGSM attack for epsilon value 0.01: 0.41293590071774783
# Average recall of FGSM attack for epsilon value 0.01: 0.4172860669253573
# Average precision of Random Noise attack for epsilon value 0.01: 0.4697567460316563
# Average recall of Random Noise attack for epsilon value 0.01: 0.4595262014933872
# ROC AUC of PGD attack for epsilon value 0.01: 0.6235410977241206
# ROC AUC of FGSM attack for epsilon value 0.01: 0.5999172013689331
# ROC AUC of Random Noise attack for epsilon value 0.01: 0.6216196106758886
#
# Classification Report for PGD Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.46      0.53      0.49     47512
#            1       0.54      0.33      0.41     47269
#            2       0.43      0.53      0.47     43219
#
#     accuracy                           0.46    138000
#    macro avg       0.47      0.46      0.46    138000
# weighted avg       0.47      0.46      0.46    138000
#
#
# Classification Report for FGSM Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.43      0.58      0.49     47512
#            1       0.41      0.10      0.16     47269
#            2       0.40      0.57      0.47     43219
#
#     accuracy                           0.41    138000
#    macro avg       0.41      0.42      0.37    138000
# weighted avg       0.41      0.41      0.37    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.45      0.53      0.49     47512
#            1       0.53      0.31      0.39     47269
#            2       0.42      0.54      0.47     43219
#
#     accuracy                           0.46    138000
#    macro avg       0.47      0.46      0.45    138000
# weighted avg       0.47      0.46      0.45    138000
#
# Epsilon value: 0.1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.1: 0.4527753623188405
# Average accuracy of FGSM attack for epsilon value 0.1: 0.4422898550724636
# Average accuracy of Random Noise attack for epsilon value 0.1: 0.40010144927536223
# Average perturbation volume for PGD attack with epsilon 0.1: 2.2640774250030518
# Average perturbation volume for FGSM attack with epsilon 0.1: 0.3265312612056732
# Average perturbation volume for Random Noise attack with epsilon 0.1: 2.2743637561798096
# Average precision of PGD attack for epsilon value 0.1: 0.46480093487150115
# Average recall of PGD attack for epsilon value 0.1: 0.45464881969553433
# Average precision of FGSM attack for epsilon value 0.1: 0.4484906994749471
# Average recall of FGSM attack for epsilon value 0.1: 0.44935848122184135
# Average precision of Random Noise attack for epsilon value 0.1: 0.4019179181420691
# Average recall of Random Noise attack for epsilon value 0.1: 0.40448719438191255
# ROC AUC of PGD attack for epsilon value 0.1: 0.6143750572737112
# ROC AUC of FGSM attack for epsilon value 0.1: 0.618192996917136
# ROC AUC of Random Noise attack for epsilon value 0.1: 0.5770698852569643
#
# Classification Report for PGD Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.45      0.52      0.48     47512
#            1       0.53      0.33      0.40     47269
#            2       0.42      0.52      0.46     43219
#
#     accuracy                           0.45    138000
#    macro avg       0.46      0.45      0.45    138000
# weighted avg       0.47      0.45      0.45    138000
#
#
# Classification Report for FGSM Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.46      0.61      0.53     47512
#            1       0.46      0.04      0.07     47269
#            2       0.42      0.70      0.53     43219
#
#     accuracy                           0.44    138000
#    macro avg       0.45      0.45      0.38    138000
# weighted avg       0.45      0.44      0.37    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.41      0.56      0.47     47512
#            1       0.41      0.09      0.15     47269
#            2       0.39      0.56      0.46     43219
#
#     accuracy                           0.40    138000
#    macro avg       0.40      0.40      0.36    138000
# weighted avg       0.40      0.40      0.36    138000
#
# Epsilon value: 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1: 0.3581231884057972
# Average accuracy of FGSM attack for epsilon value 1: 0.4151376811594203
# Average accuracy of Random Noise attack for epsilon value 1: 0.35794202898550725
# Average perturbation volume for PGD attack with epsilon 1: 2.2657132148742676
# Average perturbation volume for FGSM attack with epsilon 1: 3.073240280151367
# Average perturbation volume for Random Noise attack with epsilon 1: 3.0104668140411377
# Average precision of PGD attack for epsilon value 1: 0.3732337413484251
# Average recall of PGD attack for epsilon value 1: 0.3600806103704761
# Average precision of FGSM attack for epsilon value 1: 0.4149683380088695
# Average recall of FGSM attack for epsilon value 1: 0.4167367229326642
# Average precision of Random Noise attack for epsilon value 1: 0.363473409764161
# Average recall of Random Noise attack for epsilon value 1: 0.3619049531483783
# ROC AUC of PGD attack for epsilon value 1: 0.5081050102317791
# ROC AUC of FGSM attack for epsilon value 1: 0.5962017552412591
# ROC AUC of Random Noise attack for epsilon value 1: 0.5310418082924551
#
# Classification Report for PGD Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.35      0.43      0.39     47512
#            1       0.44      0.22      0.29     47269
#            2       0.33      0.43      0.37     43219
#
#     accuracy                           0.36    138000
#    macro avg       0.37      0.36      0.35    138000
# weighted avg       0.37      0.36      0.35    138000
#
#
# Classification Report for FGSM Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.41      0.70      0.52     47512
#            1       0.41      0.06      0.11     47269
#            2       0.42      0.49      0.45     43219
#
#     accuracy                           0.42    138000
#    macro avg       0.41      0.42      0.36    138000
# weighted avg       0.41      0.42      0.36    138000
#
#
# Classification Report for Random Noise Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.37      0.54      0.44     47512
#            1       0.38      0.04      0.06     47269
#            2       0.35      0.51      0.41     43219
#
#     accuracy                           0.36    138000
#    macro avg       0.36      0.36      0.30    138000
# weighted avg       0.36      0.36      0.30    138000
#
# Epsilon value: 10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 10: 0.21383333333333332
# Average accuracy of FGSM attack for epsilon value 10: 0.41530434782608694
# Average accuracy of Random Noise attack for epsilon value 10: 0.34960869565217384
# Average perturbation volume for PGD attack with epsilon 10: 2.269922971725464
# Average perturbation volume for FGSM attack with epsilon 10: 3.072432041168213
# Average perturbation volume for Random Noise attack with epsilon 10: 3.891310214996338
# Average precision of PGD attack for epsilon value 10: 0.19002978029346798
# Average recall of PGD attack for epsilon value 10: 0.216435129407989
# Average precision of FGSM attack for epsilon value 10: 0.4147242441642178
# Average recall of FGSM attack for epsilon value 10: 0.4169287125841572
# Average precision of Random Noise attack for epsilon value 10: 0.3531947388569813
# Average recall of Random Noise attack for epsilon value 10: 0.3504265695817894
# ROC AUC of PGD attack for epsilon value 10: 0.3447275131587702
# ROC AUC of FGSM attack for epsilon value 10: 0.5967934848825671
# ROC AUC of Random Noise attack for epsilon value 10: 0.5193993398292058
#
# Classification Report for PGD Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.23      0.31      0.26     47512
#            1       0.12      0.03      0.05     47269
#            2       0.21      0.31      0.25     43219
#
#     accuracy                           0.21    138000
#    macro avg       0.19      0.22      0.19    138000
# weighted avg       0.19      0.21      0.19    138000
#
#
# Classification Report for FGSM Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.42      0.70      0.52     47512
#            1       0.41      0.06      0.11     47269
#            2       0.42      0.49      0.45     43219
#
#     accuracy                           0.42    138000
#    macro avg       0.41      0.42      0.36    138000
# weighted avg       0.41      0.42      0.36    138000
#
#
# Classification Report for Random Noise Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.36      0.60      0.45     47512
#            1       0.37      0.06      0.10     47269
#            2       0.33      0.39      0.36     43219
#
#     accuracy                           0.35    138000
#    macro avg       0.35      0.35      0.30    138000
# weighted avg       0.35      0.35      0.30    138000

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    # Define constants needed for PGD attack
    num_iterations = 5
    step_size = 0.01

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    def fgsm_attack(images, labels, epsilon):
        """Implement FGSM attack"""
        try:
            with tf.GradientTape() as tape:
                tape.watch(images)
                predictions = model(images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy()(labels, predictions)

            gradient = tape.gradient(loss, images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = images + epsilon * signed_masked
            return tf.clip_by_value(perturbed_images, 0, 1)
        except Exception as e:
            print(f"Error in FGSM attack: {str(e)}")
            return None

    def pgd_attack(images, labels, epsilon, test_data, start_idx, end_idx):
        """Implement PGD attack with volume constraint"""
        perturbed_images = tf.identity(images)

        for _ in range(num_iterations):
            # Gradient step
            with tf.GradientTape() as tape:
                tape.watch(perturbed_images)
                predictions = model(perturbed_images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
            gradient = tape.gradient(loss, perturbed_images)
            signed_grad = tf.sign(gradient)

            # Apply masking to gradient
            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            # Apply gradient step
            perturbed_images = perturbed_images + step_size * signed_masked

            # Step 1: Apply volume constraint
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

            # Step 2: Apply L2 norm constraint (projection step)
            delta = perturbed_images - images  # Calculate current perturbation

            # Reshape to flatten all dimensions except batch
            delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

            # Calculate L2 norm on the flattened dimensions
            norm = tf.norm(delta_flat, axis=1, keepdims=True)

            # Reshape norm for broadcasting
            norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

            # Scale perturbation
            scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
            delta = delta * scaling

            perturbed_images = images + delta  # Apply constrained perturbation

            # Step 3: Apply clipping to valid range [0,1]
            perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

            # Step 4: Re-apply volume constraint after all other constraints
            # This ensures volume constraint takes precedence if there's a conflict
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

        return perturbed_images

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon, testX_CNN, start_idx, end_idx)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=model,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 1e-06
# Batch 1/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 2/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 3/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 4/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 5/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 6/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 7/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 8/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 9/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 10/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 11/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 12/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 13/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 14/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 15/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 16/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 17/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 18/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 19/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 20/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 21/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 22/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 23/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 24/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 25/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 26/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 27/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 28/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 29/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 30/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 31/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 32/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 33/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 34/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 35/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 36/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 37/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 38/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 39/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 40/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 41/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 42/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 43/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 44/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 45/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 46/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 47/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 48/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 49/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 50/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 51/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 52/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 53/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 54/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 55/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 56/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 57/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 58/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 59/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 60/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 61/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 62/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 63/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 64/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 65/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 66/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 67/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 68/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 69/69 - PGD volume: 0.000001, FGSM volume: 0.000004
#
# Analyzing epsilon: 1e-05
# Batch 1/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 2/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 3/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 4/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 5/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 6/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 7/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 8/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 9/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 10/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 11/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 12/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 13/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 14/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 15/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 16/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 17/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 18/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 19/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 20/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 21/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 22/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 23/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 24/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 25/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 26/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 27/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 28/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 29/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 30/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 31/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 32/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 33/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 34/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 35/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 36/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 37/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 38/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 39/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 40/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 41/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 42/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 43/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 44/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 45/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 46/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 47/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 48/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 49/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 50/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 51/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 52/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 53/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 54/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 55/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 56/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 57/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 58/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 59/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 60/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 61/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 62/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 63/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 64/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 65/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 66/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 67/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 68/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 69/69 - PGD volume: 0.000010, FGSM volume: 0.000045
#
# Analyzing epsilon: 0.0001
# Batch 1/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 2/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 3/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 4/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 5/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 6/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 7/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 8/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 9/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 10/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 11/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 12/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 13/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 14/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 15/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 16/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 17/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 18/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 19/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 20/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 21/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 22/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 23/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 24/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 25/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 26/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 27/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 28/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 29/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 30/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 31/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 32/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 33/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 34/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 35/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 36/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 37/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 38/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 39/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 40/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 41/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 42/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 43/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 44/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 45/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 46/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 47/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 48/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 49/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 50/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 51/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 52/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 53/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 54/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 55/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 56/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 57/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 58/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 59/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 60/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 61/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 62/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 63/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 64/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 65/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 66/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 67/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 68/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 69/69 - PGD volume: 0.000100, FGSM volume: 0.000447
#
# Analyzing epsilon: 0.001
# Batch 1/69 - PGD volume: 0.001000, FGSM volume: 0.004375
# Batch 2/69 - PGD volume: 0.001000, FGSM volume: 0.004447
# Batch 3/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 4/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 5/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 6/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 7/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 8/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 9/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 10/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 11/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 12/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 13/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 14/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 15/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 16/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 17/69 - PGD volume: 0.001000, FGSM volume: 0.004457
# Batch 18/69 - PGD volume: 0.001000, FGSM volume: 0.004461
# Batch 19/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 20/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 21/69 - PGD volume: 0.001000, FGSM volume: 0.004454
# Batch 22/69 - PGD volume: 0.001000, FGSM volume: 0.004434
# Batch 23/69 - PGD volume: 0.001000, FGSM volume: 0.004452
# Batch 24/69 - PGD volume: 0.001000, FGSM volume: 0.004449
# Batch 25/69 - PGD volume: 0.001000, FGSM volume: 0.004437
# Batch 26/69 - PGD volume: 0.001000, FGSM volume: 0.004459
# Batch 27/69 - PGD volume: 0.001000, FGSM volume: 0.004448
# Batch 28/69 - PGD volume: 0.001000, FGSM volume: 0.004425
# Batch 29/69 - PGD volume: 0.001000, FGSM volume: 0.004406
# Batch 30/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 31/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 32/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 33/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 34/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 35/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 36/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 37/69 - PGD volume: 0.001000, FGSM volume: 0.004457
# Batch 38/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 39/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 40/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 41/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 42/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 43/69 - PGD volume: 0.001000, FGSM volume: 0.004459
# Batch 44/69 - PGD volume: 0.001000, FGSM volume: 0.004461
# Batch 45/69 - PGD volume: 0.001000, FGSM volume: 0.004446
# Batch 46/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 47/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 48/69 - PGD volume: 0.001000, FGSM volume: 0.004435
# Batch 49/69 - PGD volume: 0.001000, FGSM volume: 0.004439
# Batch 50/69 - PGD volume: 0.001000, FGSM volume: 0.004419
# Batch 51/69 - PGD volume: 0.001000, FGSM volume: 0.004455
# Batch 52/69 - PGD volume: 0.001000, FGSM volume: 0.004445
# Batch 53/69 - PGD volume: 0.001000, FGSM volume: 0.004459
# Batch 54/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 55/69 - PGD volume: 0.001000, FGSM volume: 0.004400
# Batch 56/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 57/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 58/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 59/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 60/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 61/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 62/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 63/69 - PGD volume: 0.001000, FGSM volume: 0.004463
# Batch 64/69 - PGD volume: 0.001000, FGSM volume: 0.004455
# Batch 65/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 66/69 - PGD volume: 0.001000, FGSM volume: 0.004461
# Batch 67/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 68/69 - PGD volume: 0.001000, FGSM volume: 0.004447
# Batch 69/69 - PGD volume: 0.001000, FGSM volume: 0.004443
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         579.5735  66886.0000    0.4859
# 0.9000         547.3995  62147.0000    0.5069
# 0.9500         439.9453  54819.0000    0.5089
# 0.9900         253.3945  40064.0000    0.5142
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         579.5381  66886.0000    0.4859
# 0.9000         547.2914  62148.0000    0.5069
# 0.9500         439.9122  54815.0000    0.5090
# 0.9900         253.3333  40070.0000    0.5141
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         579.3831  66897.0000    0.4858
# 0.9000         546.7872  62154.0000    0.5052
# 0.9500         440.3401  54804.0000    0.5073
# 0.9900         253.8670  40053.0000    0.5143
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         506.8237  67024.0000    0.4864
# 0.9000         514.8336  62130.0000    0.5054
# 0.9500         439.8769  54725.0000    0.5043
# 0.9900         253.7564  39708.0000    0.5163
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         579.5727  66888.0000    0.4859
# 0.9000         547.3966  62153.0000    0.5068
# 0.9500         439.8931  54816.0000    0.5090
# 0.9900         253.4101  40066.0000    0.5142
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         579.3453  66886.0000    0.4844
# 0.9000         546.9844  62159.0000    0.5068
# 0.9500         440.0494  54809.0000    0.5090
# 0.9900         253.7223  40057.0000    0.5143
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         560.1869  66979.0000    0.4852
# 0.9000         546.5095  62172.0000    0.5067
# 0.9500         440.9170  54769.0000    0.5058
# 0.9900         253.8619  39826.0000    0.5173
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         338.0793  68473.0000    0.4703
# 0.9000         394.7793  63253.0000    0.4743
# 0.9500         235.7628  55140.0000    0.4878
# 0.9900         245.2440  38849.0000    0.4994

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    # Define constants needed for PGD attack
    num_iterations = 5
    step_size = 0.01

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    def fgsm_attack(images, labels, epsilon):
        """Implement FGSM attack"""
        try:
            with tf.GradientTape() as tape:
                tape.watch(images)
                predictions = model(images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy()(labels, predictions)

            gradient = tape.gradient(loss, images)
            signed_grad = tf.sign(gradient)

            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            perturbed_images = images + epsilon * signed_masked
            return tf.clip_by_value(perturbed_images, 0, 1)
        except Exception as e:
            print(f"Error in FGSM attack: {str(e)}")
            return None

    def pgd_attack(images, labels, epsilon, test_data, start_idx, end_idx):
        """Implement PGD attack with volume constraint"""
        perturbed_images = tf.identity(images)

        for _ in range(num_iterations):
            # Gradient step
            with tf.GradientTape() as tape:
                tape.watch(perturbed_images)
                predictions = model(perturbed_images, training=False)
                loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
            gradient = tape.gradient(loss, perturbed_images)
            signed_grad = tf.sign(gradient)

            # Apply masking to gradient
            signed_masked = signed_grad.numpy()
            signed_masked[:, :99, :, :] = 0
            signed_masked[:, 99:, ::2, :] = 0
            signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

            # Apply gradient step
            perturbed_images = perturbed_images + step_size * signed_masked

            # Step 1: Apply volume constraint
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

            # Step 2: Apply L2 norm constraint (projection step)
            delta = perturbed_images - images  # Calculate current perturbation

            # Reshape to flatten all dimensions except batch
            delta_flat = tf.reshape(delta, [tf.shape(delta)[0], -1])

            # Calculate L2 norm on the flattened dimensions
            norm = tf.norm(delta_flat, axis=1, keepdims=True)

            # Reshape norm for broadcasting
            norm = tf.reshape(norm, [tf.shape(delta)[0], 1, 1, 1])

            # Scale perturbation
            scaling = tf.clip_by_value(epsilon / (norm + 1e-12), 0, 1)
            delta = delta * scaling

            perturbed_images = images + delta  # Apply constrained perturbation

            # Step 3: Apply clipping to valid range [0,1]
            perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

            # Step 4: Re-apply volume constraint after all other constraints
            # This ensures volume constraint takes precedence if there's a conflict
            perturbed_images = volume_constraint(perturbed_images, test_data, 2, start_idx, end_idx)

        return perturbed_images

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon, testX_CNN, start_idx, end_idx)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

epsilon_values = [0.01, 0.1, 1, 10]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=model,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 0.01
# Batch 1/69 - PGD volume: 0.010000, FGSM volume: 0.035902
# Batch 2/69 - PGD volume: 0.010000, FGSM volume: 0.040887
# Batch 3/69 - PGD volume: 0.010000, FGSM volume: 0.042959
# Batch 4/69 - PGD volume: 0.010000, FGSM volume: 0.042988
# Batch 5/69 - PGD volume: 0.010000, FGSM volume: 0.043294
# Batch 6/69 - PGD volume: 0.010000, FGSM volume: 0.043432
# Batch 7/69 - PGD volume: 0.010000, FGSM volume: 0.043847
# Batch 8/69 - PGD volume: 0.010000, FGSM volume: 0.043724
# Batch 9/69 - PGD volume: 0.010000, FGSM volume: 0.043684
# Batch 10/69 - PGD volume: 0.010000, FGSM volume: 0.043991
# Batch 11/69 - PGD volume: 0.010000, FGSM volume: 0.043146
# Batch 12/69 - PGD volume: 0.010000, FGSM volume: 0.043220
# Batch 13/69 - PGD volume: 0.010000, FGSM volume: 0.042957
# Batch 14/69 - PGD volume: 0.010000, FGSM volume: 0.043388
# Batch 15/69 - PGD volume: 0.010000, FGSM volume: 0.043341
# Batch 16/69 - PGD volume: 0.010000, FGSM volume: 0.043785
# Batch 17/69 - PGD volume: 0.010000, FGSM volume: 0.040363
# Batch 18/69 - PGD volume: 0.010000, FGSM volume: 0.036134
# Batch 19/69 - PGD volume: 0.010000, FGSM volume: 0.035922
# Batch 20/69 - PGD volume: 0.010000, FGSM volume: 0.035625
# Batch 21/69 - PGD volume: 0.010000, FGSM volume: 0.036416
# Batch 22/69 - PGD volume: 0.010000, FGSM volume: 0.036194
# Batch 23/69 - PGD volume: 0.010000, FGSM volume: 0.035553
# Batch 24/69 - PGD volume: 0.010000, FGSM volume: 0.037492
# Batch 25/69 - PGD volume: 0.010000, FGSM volume: 0.037335
# Batch 26/69 - PGD volume: 0.010000, FGSM volume: 0.037512
# Batch 27/69 - PGD volume: 0.010000, FGSM volume: 0.036414
# Batch 28/69 - PGD volume: 0.010000, FGSM volume: 0.035294
# Batch 29/69 - PGD volume: 0.010000, FGSM volume: 0.038541
# Batch 30/69 - PGD volume: 0.010000, FGSM volume: 0.043377
# Batch 31/69 - PGD volume: 0.010000, FGSM volume: 0.042583
# Batch 32/69 - PGD volume: 0.010000, FGSM volume: 0.043052
# Batch 33/69 - PGD volume: 0.010000, FGSM volume: 0.042396
# Batch 34/69 - PGD volume: 0.010000, FGSM volume: 0.043921
# Batch 35/69 - PGD volume: 0.010000, FGSM volume: 0.043988
# Batch 36/69 - PGD volume: 0.010000, FGSM volume: 0.043846
# Batch 37/69 - PGD volume: 0.010000, FGSM volume: 0.043535
# Batch 38/69 - PGD volume: 0.010000, FGSM volume: 0.043783
# Batch 39/69 - PGD volume: 0.010000, FGSM volume: 0.043568
# Batch 40/69 - PGD volume: 0.010000, FGSM volume: 0.043223
# Batch 41/69 - PGD volume: 0.010000, FGSM volume: 0.043535
# Batch 42/69 - PGD volume: 0.010000, FGSM volume: 0.043595
# Batch 43/69 - PGD volume: 0.010000, FGSM volume: 0.043360
# Batch 44/69 - PGD volume: 0.010000, FGSM volume: 0.043392
# Batch 45/69 - PGD volume: 0.010000, FGSM volume: 0.040856
# Batch 46/69 - PGD volume: 0.010000, FGSM volume: 0.035791
# Batch 47/69 - PGD volume: 0.010000, FGSM volume: 0.036195
# Batch 48/69 - PGD volume: 0.010000, FGSM volume: 0.036461
# Batch 49/69 - PGD volume: 0.010000, FGSM volume: 0.035414
# Batch 50/69 - PGD volume: 0.010000, FGSM volume: 0.035851
# Batch 51/69 - PGD volume: 0.010000, FGSM volume: 0.036348
# Batch 52/69 - PGD volume: 0.010000, FGSM volume: 0.036501
# Batch 53/69 - PGD volume: 0.010000, FGSM volume: 0.035983
# Batch 54/69 - PGD volume: 0.010000, FGSM volume: 0.036273
# Batch 55/69 - PGD volume: 0.010000, FGSM volume: 0.038166
# Batch 56/69 - PGD volume: 0.010000, FGSM volume: 0.043550
# Batch 57/69 - PGD volume: 0.010000, FGSM volume: 0.043503
# Batch 58/69 - PGD volume: 0.010000, FGSM volume: 0.043777
# Batch 59/69 - PGD volume: 0.010000, FGSM volume: 0.044073
# Batch 60/69 - PGD volume: 0.010000, FGSM volume: 0.044121
# Batch 61/69 - PGD volume: 0.010000, FGSM volume: 0.043466
# Batch 62/69 - PGD volume: 0.010000, FGSM volume: 0.043451
# Batch 63/69 - PGD volume: 0.010000, FGSM volume: 0.043710
# Batch 64/69 - PGD volume: 0.010000, FGSM volume: 0.036591
# Batch 65/69 - PGD volume: 0.010000, FGSM volume: 0.036664
# Batch 66/69 - PGD volume: 0.010000, FGSM volume: 0.036410
# Batch 67/69 - PGD volume: 0.010000, FGSM volume: 0.036413
# Batch 68/69 - PGD volume: 0.010000, FGSM volume: 0.035992
# Batch 69/69 - PGD volume: 0.010000, FGSM volume: 0.036399
#
# Analyzing epsilon: 0.1
# Batch 1/69 - PGD volume: 0.085589, FGSM volume: 0.312744
# Batch 2/69 - PGD volume: 0.091305, FGSM volume: 0.331759
# Batch 3/69 - PGD volume: 0.092629, FGSM volume: 0.335923
# Batch 4/69 - PGD volume: 0.092747, FGSM volume: 0.338536
# Batch 5/69 - PGD volume: 0.091474, FGSM volume: 0.332452
# Batch 6/69 - PGD volume: 0.092627, FGSM volume: 0.335786
# Batch 7/69 - PGD volume: 0.093051, FGSM volume: 0.341118
# Batch 8/69 - PGD volume: 0.093216, FGSM volume: 0.333346
# Batch 9/69 - PGD volume: 0.092241, FGSM volume: 0.336193
# Batch 10/69 - PGD volume: 0.092471, FGSM volume: 0.334797
# Batch 11/69 - PGD volume: 0.091046, FGSM volume: 0.331835
# Batch 12/69 - PGD volume: 0.091116, FGSM volume: 0.332239
# Batch 13/69 - PGD volume: 0.091988, FGSM volume: 0.329071
# Batch 14/69 - PGD volume: 0.091134, FGSM volume: 0.334956
# Batch 15/69 - PGD volume: 0.091556, FGSM volume: 0.331615
# Batch 16/69 - PGD volume: 0.091472, FGSM volume: 0.329683
# Batch 17/69 - PGD volume: 0.089610, FGSM volume: 0.322151
# Batch 18/69 - PGD volume: 0.087448, FGSM volume: 0.317482
# Batch 19/69 - PGD volume: 0.086387, FGSM volume: 0.313022
# Batch 20/69 - PGD volume: 0.087638, FGSM volume: 0.315212
# Batch 21/69 - PGD volume: 0.087912, FGSM volume: 0.312874
# Batch 22/69 - PGD volume: 0.088370, FGSM volume: 0.314766
# Batch 23/69 - PGD volume: 0.087925, FGSM volume: 0.313343
# Batch 24/69 - PGD volume: 0.088793, FGSM volume: 0.312026
# Batch 25/69 - PGD volume: 0.088803, FGSM volume: 0.312875
# Batch 26/69 - PGD volume: 0.088874, FGSM volume: 0.309069
# Batch 27/69 - PGD volume: 0.087503, FGSM volume: 0.311712
# Batch 28/69 - PGD volume: 0.086747, FGSM volume: 0.311864
# Batch 29/69 - PGD volume: 0.088748, FGSM volume: 0.324564
# Batch 30/69 - PGD volume: 0.092852, FGSM volume: 0.340312
# Batch 31/69 - PGD volume: 0.091549, FGSM volume: 0.334248
# Batch 32/69 - PGD volume: 0.091282, FGSM volume: 0.333165
# Batch 33/69 - PGD volume: 0.091279, FGSM volume: 0.334898
# Batch 34/69 - PGD volume: 0.091178, FGSM volume: 0.335571
# Batch 35/69 - PGD volume: 0.092415, FGSM volume: 0.338077
# Batch 36/69 - PGD volume: 0.093611, FGSM volume: 0.335683
# Batch 37/69 - PGD volume: 0.093032, FGSM volume: 0.340133
# Batch 38/69 - PGD volume: 0.091426, FGSM volume: 0.332977
# Batch 39/69 - PGD volume: 0.091117, FGSM volume: 0.341121
# Batch 40/69 - PGD volume: 0.092574, FGSM volume: 0.334475
# Batch 41/69 - PGD volume: 0.094825, FGSM volume: 0.331149
# Batch 42/69 - PGD volume: 0.093760, FGSM volume: 0.335597
# Batch 43/69 - PGD volume: 0.094181, FGSM volume: 0.334934
# Batch 44/69 - PGD volume: 0.091531, FGSM volume: 0.331775
# Batch 45/69 - PGD volume: 0.089290, FGSM volume: 0.325903
# Batch 46/69 - PGD volume: 0.087091, FGSM volume: 0.314669
# Batch 47/69 - PGD volume: 0.086732, FGSM volume: 0.315359
# Batch 48/69 - PGD volume: 0.089238, FGSM volume: 0.312883
# Batch 49/69 - PGD volume: 0.087714, FGSM volume: 0.315280
# Batch 50/69 - PGD volume: 0.087823, FGSM volume: 0.313087
# Batch 51/69 - PGD volume: 0.087383, FGSM volume: 0.314080
# Batch 52/69 - PGD volume: 0.087810, FGSM volume: 0.314113
# Batch 53/69 - PGD volume: 0.088278, FGSM volume: 0.312493
# Batch 54/69 - PGD volume: 0.087578, FGSM volume: 0.314913
# Batch 55/69 - PGD volume: 0.087574, FGSM volume: 0.319707
# Batch 56/69 - PGD volume: 0.091791, FGSM volume: 0.337451
# Batch 57/69 - PGD volume: 0.093039, FGSM volume: 0.341883
# Batch 58/69 - PGD volume: 0.093614, FGSM volume: 0.342117
# Batch 59/69 - PGD volume: 0.092284, FGSM volume: 0.342692
# Batch 60/69 - PGD volume: 0.092552, FGSM volume: 0.349990
# Batch 61/69 - PGD volume: 0.089175, FGSM volume: 0.333090
# Batch 62/69 - PGD volume: 0.090773, FGSM volume: 0.333362
# Batch 63/69 - PGD volume: 0.092146, FGSM volume: 0.330519
# Batch 64/69 - PGD volume: 0.088557, FGSM volume: 0.317390
# Batch 65/69 - PGD volume: 0.087762, FGSM volume: 0.312598
# Batch 66/69 - PGD volume: 0.087520, FGSM volume: 0.314409
# Batch 67/69 - PGD volume: 0.088323, FGSM volume: 0.314661
# Batch 68/69 - PGD volume: 0.087956, FGSM volume: 0.314940
# Batch 69/69 - PGD volume: 0.088159, FGSM volume: 0.314823
#
# Analyzing epsilon: 1
# Batch 1/69 - PGD volume: 0.087453, FGSM volume: 3.102329
# Batch 2/69 - PGD volume: 0.099024, FGSM volume: 3.068035
# Batch 3/69 - PGD volume: 0.101167, FGSM volume: 3.073233
# Batch 4/69 - PGD volume: 0.102024, FGSM volume: 3.043815
# Batch 5/69 - PGD volume: 0.099200, FGSM volume: 3.054415
# Batch 6/69 - PGD volume: 0.100929, FGSM volume: 3.050002
# Batch 7/69 - PGD volume: 0.102791, FGSM volume: 3.018872
# Batch 8/69 - PGD volume: 0.102133, FGSM volume: 2.988742
# Batch 9/69 - PGD volume: 0.100162, FGSM volume: 3.019781
# Batch 10/69 - PGD volume: 0.101063, FGSM volume: 2.985985
# Batch 11/69 - PGD volume: 0.098464, FGSM volume: 3.087110
# Batch 12/69 - PGD volume: 0.098724, FGSM volume: 3.072721
# Batch 13/69 - PGD volume: 0.098988, FGSM volume: 3.073434
# Batch 14/69 - PGD volume: 0.099670, FGSM volume: 3.089684
# Batch 15/69 - PGD volume: 0.098466, FGSM volume: 3.068681
# Batch 16/69 - PGD volume: 0.098512, FGSM volume: 3.066102
# Batch 17/69 - PGD volume: 0.095047, FGSM volume: 3.078127
# Batch 18/69 - PGD volume: 0.090446, FGSM volume: 3.147897
# Batch 19/69 - PGD volume: 0.088977, FGSM volume: 3.106230
# Batch 20/69 - PGD volume: 0.090393, FGSM volume: 3.132210
# Batch 21/69 - PGD volume: 0.090821, FGSM volume: 3.100688
# Batch 22/69 - PGD volume: 0.091391, FGSM volume: 3.122074
# Batch 23/69 - PGD volume: 0.090606, FGSM volume: 3.112125
# Batch 24/69 - PGD volume: 0.092056, FGSM volume: 3.084242
# Batch 25/69 - PGD volume: 0.092228, FGSM volume: 3.095717
# Batch 26/69 - PGD volume: 0.091784, FGSM volume: 3.052989
# Batch 27/69 - PGD volume: 0.090104, FGSM volume: 3.091729
# Batch 28/69 - PGD volume: 0.089305, FGSM volume: 3.095599
# Batch 29/69 - PGD volume: 0.093797, FGSM volume: 3.100208
# Batch 30/69 - PGD volume: 0.101422, FGSM volume: 3.053040
# Batch 31/69 - PGD volume: 0.099390, FGSM volume: 3.071606
# Batch 32/69 - PGD volume: 0.098729, FGSM volume: 3.052074
# Batch 33/69 - PGD volume: 0.099578, FGSM volume: 3.068494
# Batch 34/69 - PGD volume: 0.098750, FGSM volume: 3.027328
# Batch 35/69 - PGD volume: 0.101217, FGSM volume: 2.994078
# Batch 36/69 - PGD volume: 0.103100, FGSM volume: 2.972443
# Batch 37/69 - PGD volume: 0.101602, FGSM volume: 3.047800
# Batch 38/69 - PGD volume: 0.098558, FGSM volume: 3.044759
# Batch 39/69 - PGD volume: 0.099798, FGSM volume: 3.051329
# Batch 40/69 - PGD volume: 0.100434, FGSM volume: 3.058092
# Batch 41/69 - PGD volume: 0.105268, FGSM volume: 3.028661
# Batch 42/69 - PGD volume: 0.104234, FGSM volume: 3.052373
# Batch 43/69 - PGD volume: 0.103945, FGSM volume: 3.063391
# Batch 44/69 - PGD volume: 0.100253, FGSM volume: 3.051941
# Batch 45/69 - PGD volume: 0.095559, FGSM volume: 3.066187
# Batch 46/69 - PGD volume: 0.089775, FGSM volume: 3.120655
# Batch 47/69 - PGD volume: 0.089322, FGSM volume: 3.127460
# Batch 48/69 - PGD volume: 0.092679, FGSM volume: 3.101415
# Batch 49/69 - PGD volume: 0.090469, FGSM volume: 3.129122
# Batch 50/69 - PGD volume: 0.090525, FGSM volume: 3.106038
# Batch 51/69 - PGD volume: 0.090448, FGSM volume: 3.111456
# Batch 52/69 - PGD volume: 0.090817, FGSM volume: 3.114370
# Batch 53/69 - PGD volume: 0.090855, FGSM volume: 3.100976
# Batch 54/69 - PGD volume: 0.090536, FGSM volume: 3.121048
# Batch 55/69 - PGD volume: 0.091189, FGSM volume: 3.088148
# Batch 56/69 - PGD volume: 0.099565, FGSM volume: 3.038106
# Batch 57/69 - PGD volume: 0.102644, FGSM volume: 3.023997
# Batch 58/69 - PGD volume: 0.104046, FGSM volume: 2.993438
# Batch 59/69 - PGD volume: 0.101273, FGSM volume: 3.029060
# Batch 60/69 - PGD volume: 0.102421, FGSM volume: 2.991258
# Batch 61/69 - PGD volume: 0.095498, FGSM volume: 3.050524
# Batch 62/69 - PGD volume: 0.097339, FGSM volume: 3.044552
# Batch 63/69 - PGD volume: 0.100361, FGSM volume: 3.042607
# Batch 64/69 - PGD volume: 0.092496, FGSM volume: 3.127337
# Batch 65/69 - PGD volume: 0.090951, FGSM volume: 3.095001
# Batch 66/69 - PGD volume: 0.090515, FGSM volume: 3.109231
# Batch 67/69 - PGD volume: 0.091813, FGSM volume: 3.119416
# Batch 68/69 - PGD volume: 0.090626, FGSM volume: 3.128265
# Batch 69/69 - PGD volume: 0.091859, FGSM volume: 3.120084
#
# Analyzing epsilon: 10
# Batch 1/69 - PGD volume: 0.087453, FGSM volume: 3.102329
# Batch 2/69 - PGD volume: 0.099024, FGSM volume: 3.068035
# Batch 3/69 - PGD volume: 0.101167, FGSM volume: 3.073233
# Batch 4/69 - PGD volume: 0.102024, FGSM volume: 3.043815
# Batch 5/69 - PGD volume: 0.099200, FGSM volume: 3.054415
# Batch 6/69 - PGD volume: 0.100929, FGSM volume: 3.050002
# Batch 7/69 - PGD volume: 0.102791, FGSM volume: 3.018872
# Batch 8/69 - PGD volume: 0.102133, FGSM volume: 2.988742
# Batch 9/69 - PGD volume: 0.100162, FGSM volume: 3.019781
# Batch 10/69 - PGD volume: 0.101063, FGSM volume: 2.985985
# Batch 11/69 - PGD volume: 0.098464, FGSM volume: 3.087110
# Batch 12/69 - PGD volume: 0.098724, FGSM volume: 3.072721
# Batch 13/69 - PGD volume: 0.098988, FGSM volume: 3.073434
# Batch 14/69 - PGD volume: 0.099670, FGSM volume: 3.089684
# Batch 15/69 - PGD volume: 0.098466, FGSM volume: 3.068681
# Batch 16/69 - PGD volume: 0.098512, FGSM volume: 3.066102
# Batch 17/69 - PGD volume: 0.095047, FGSM volume: 3.078127
# Batch 18/69 - PGD volume: 0.090446, FGSM volume: 3.147897
# Batch 19/69 - PGD volume: 0.088977, FGSM volume: 3.106230
# Batch 20/69 - PGD volume: 0.090393, FGSM volume: 3.132210
# Batch 21/69 - PGD volume: 0.090821, FGSM volume: 3.100688
# Batch 22/69 - PGD volume: 0.091391, FGSM volume: 3.122074
# Batch 23/69 - PGD volume: 0.090606, FGSM volume: 3.112125
# Batch 24/69 - PGD volume: 0.092056, FGSM volume: 3.084242
# Batch 25/69 - PGD volume: 0.092228, FGSM volume: 3.095717
# Batch 26/69 - PGD volume: 0.091784, FGSM volume: 3.052989
# Batch 27/69 - PGD volume: 0.090104, FGSM volume: 3.091729
# Batch 28/69 - PGD volume: 0.089305, FGSM volume: 3.095599
# Batch 29/69 - PGD volume: 0.093797, FGSM volume: 3.100208
# Batch 30/69 - PGD volume: 0.101422, FGSM volume: 3.053040
# Batch 31/69 - PGD volume: 0.099390, FGSM volume: 3.071606
# Batch 32/69 - PGD volume: 0.098729, FGSM volume: 3.052074
# Batch 33/69 - PGD volume: 0.099578, FGSM volume: 3.068494
# Batch 34/69 - PGD volume: 0.098750, FGSM volume: 3.027328
# Batch 35/69 - PGD volume: 0.101217, FGSM volume: 2.994078
# Batch 36/69 - PGD volume: 0.103100, FGSM volume: 2.972443
# Batch 37/69 - PGD volume: 0.101602, FGSM volume: 3.047800
# Batch 38/69 - PGD volume: 0.098558, FGSM volume: 3.044759
# Batch 39/69 - PGD volume: 0.099798, FGSM volume: 3.051329
# Batch 40/69 - PGD volume: 0.100434, FGSM volume: 3.058092
# Batch 41/69 - PGD volume: 0.105268, FGSM volume: 3.028661
# Batch 42/69 - PGD volume: 0.104234, FGSM volume: 3.052373
# Batch 43/69 - PGD volume: 0.103945, FGSM volume: 3.063391
# Batch 44/69 - PGD volume: 0.100253, FGSM volume: 3.051941
# Batch 45/69 - PGD volume: 0.095559, FGSM volume: 3.066187
# Batch 46/69 - PGD volume: 0.089775, FGSM volume: 3.120655
# Batch 47/69 - PGD volume: 0.089322, FGSM volume: 3.127460
# Batch 48/69 - PGD volume: 0.092679, FGSM volume: 3.101415
# Batch 49/69 - PGD volume: 0.090469, FGSM volume: 3.129122
# Batch 50/69 - PGD volume: 0.090525, FGSM volume: 3.106038
# Batch 51/69 - PGD volume: 0.090448, FGSM volume: 3.111456
# Batch 52/69 - PGD volume: 0.090817, FGSM volume: 3.114370
# Batch 53/69 - PGD volume: 0.090855, FGSM volume: 3.100976
# Batch 54/69 - PGD volume: 0.090536, FGSM volume: 3.121048
# Batch 55/69 - PGD volume: 0.091189, FGSM volume: 3.088148
# Batch 56/69 - PGD volume: 0.099565, FGSM volume: 3.038106
# Batch 57/69 - PGD volume: 0.102644, FGSM volume: 3.023997
# Batch 58/69 - PGD volume: 0.104046, FGSM volume: 2.993438
# Batch 59/69 - PGD volume: 0.101273, FGSM volume: 3.029060
# Batch 60/69 - PGD volume: 0.102421, FGSM volume: 2.991258
# Batch 61/69 - PGD volume: 0.095498, FGSM volume: 3.050524
# Batch 62/69 - PGD volume: 0.097339, FGSM volume: 3.044552
# Batch 63/69 - PGD volume: 0.100361, FGSM volume: 3.042607
# Batch 64/69 - PGD volume: 0.092496, FGSM volume: 3.127337
# Batch 65/69 - PGD volume: 0.090951, FGSM volume: 3.095001
# Batch 66/69 - PGD volume: 0.090515, FGSM volume: 3.109231
# Batch 67/69 - PGD volume: 0.091813, FGSM volume: 3.119416
# Batch 68/69 - PGD volume: 0.090626, FGSM volume: 3.128265
# Batch 69/69 - PGD volume: 0.091859, FGSM volume: 3.120084
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         245.1499  73068.0000    0.4571
# 0.9000         130.9148  67204.0000    0.4524
# 0.9500         222.7010  57931.0000    0.4678
# 0.9900         108.9295  39793.0000    0.4825
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -549.2206 108702.0000    0.3661
# 0.9000        -586.7891 103504.0000    0.3555
# 0.9500        -609.0091  94677.0000    0.3401
# 0.9900        -313.6771  72627.0000    0.3305
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -548.1501 108801.0000    0.3667
# 0.9000        -592.7189 103604.0000    0.3581
# 0.9500        -597.4774  94809.0000    0.3396
# 0.9900        -313.0294  72971.0000    0.3316
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -548.1501 108801.0000    0.3667
# 0.9000        -592.7189 103604.0000    0.3581
# 0.9500        -597.4774  94809.0000    0.3396
# 0.9900        -313.0294  72971.0000    0.3316
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         663.6445  93019.0000    0.4074
# 0.9000         447.8291  85450.0000    0.4108
# 0.9500         238.1171  73281.0000    0.3916
# 0.9900         139.8317  47572.0000    0.4036
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         960.9059 105027.0000    0.3904
# 0.9000        1012.4623  98004.0000    0.3857
# 0.9500        1050.0763  86026.0000    0.3894
# 0.9900         869.8995  58155.0000    0.4007
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         731.7742  97001.0000    0.4289
# 0.9000         752.5582  89008.0000    0.4427
# 0.9500         716.0411  76157.0000    0.4464
# 0.9900         523.5184  47826.0000    0.4684
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         731.7742  97001.0000    0.4289
# 0.9000         752.5582  89008.0000    0.4427
# 0.9500         716.0411  76157.0000    0.4464
# 0.9900         523.5184  47826.0000    0.4684
