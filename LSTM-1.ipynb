# %%
import pandas as pd
import pickle
import numpy as np
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import load_model, Model
from keras.layers import Flatten, Dense, Dropout, Activation, Input, LSTM, Reshape, Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.layers import LeakyReLU
#!pip install np_utils
from keras import utils

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score

RANDOM_SEED = 0

# set random seeds
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing Dataset

# %%
import os
import zipfile

# Define the target directory in Google Drive for the unzipped files
UNZIPPED_DATA_DIR = '/content/drive/MyDrive/LOBCNN/data/'

# Check if the unzipped data directory already exists and contains files
if not os.path.exists(UNZIPPED_DATA_DIR) or not os.listdir(UNZIPPED_DATA_DIR):
    print(f"Data not found in {UNZIPPED_DATA_DIR}. Attempting to download and unzip.")

    # Create the target directory if it doesn't exist
    os.makedirs(UNZIPPED_DATA_DIR, exist_ok=True)

    # Define a temporary path for the downloaded zip file in /content/
    TEMP_ZIP_PATH = '/content/data.zip'

    # Download the data.zip file to /content/
    # !wget -q https://raw.githubusercontent.com/zcakhaa/DeepLOB-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books/master/data/data.zip -O {TEMP_ZIP_PATH}

    # Unzip the downloaded file directly into the target directory in Google Drive
    with zipfile.ZipFile(TEMP_ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(UNZIPPED_DATA_DIR)

    # Optionally, remove the temporary zip file to save space
    os.remove(TEMP_ZIP_PATH)

    print('Data downloaded and unzipped to Google Drive.')
else:
    print('Data already existed and is ready in Google Drive.')
# Out:
# Data already existed and is ready in Google Drive.

# %% [markdown]
# # Functions for pre-processing:

# %%
def prepare_x(data):
    df1 = data[:40, :].T
    return np.array(df1)

def get_label(data):
    lob = data[-5:, :].T
    return lob

def data_classification(X, Y, T):
    [N, D] = X.shape
    df = np.array(X)
    dY = np.array(Y)
    dataY = dY[T - 1:N]
    dataX = np.zeros((N - T + 1, T, D))
    for i in range(T, N + 1):
        dataX[i - T] = df[i - T:i, :]
    return dataX.reshape(dataX.shape + (1,)), dataY

def prepare_x_y(data, k, T):
    x = prepare_x(data)
    y = get_label(data)
    x, y = data_classification(x, y, T=T)
    y = y[:,k] - 1
    y = utils.to_categorical(y, 3)
    return x, y


def macro_f1(y_true, y_pred):
    """Macro-averaged F1 score for multi-class classification."""
    y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)
    y_true = tf.cast(tf.argmax(y_true, axis=-1), tf.int32)

    f1_scores = []
    for i in range(3):
        y_true_i = tf.cast(tf.equal(y_true, i), tf.float32)
        y_pred_i = tf.cast(tf.equal(y_pred, i), tf.float32)

        tp = tf.reduce_sum(y_true_i * y_pred_i)
        fp = tf.reduce_sum((1.0 - y_true_i) * y_pred_i)
        fn = tf.reduce_sum(y_true_i * (1.0 - y_pred_i))

        precision = tp / (tp + fp + tf.keras.backend.epsilon())
        recall = tp / (tp + fn + tf.keras.backend.epsilon())
        f1 = 2.0 * precision * recall / (precision + recall + tf.keras.backend.epsilon())
        f1_scores.append(f1)

    return tf.reduce_mean(tf.stack(f1_scores))

# %%
dec_data = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Train_Dst_NoAuction_DecPre_CF_7.txt'))
dec_train = dec_data[:, :int(np.floor(dec_data.shape[1] * 0.8))]
dec_val = dec_data[:, int(np.floor(dec_data.shape[1] * 0.8)):]

dec_test1 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_7.txt'))
dec_test2 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_8.txt'))
dec_test3 = np.loadtxt(os.path.join(UNZIPPED_DATA_DIR, 'Test_Dst_NoAuction_DecPre_CF_9.txt'))
dec_test = np.hstack((dec_test1, dec_test2, dec_test3))

k = 4 # which prediction horizon
T = 100 # the length of a single input
n_hiddens = 64

trainX_CNN, trainY_CNN = prepare_x_y(dec_train, k, T)
valX_CNN, valY_CNN = prepare_x_y(dec_val, k, T)
testX_CNN, testY_CNN = prepare_x_y(dec_test, k, T)

print(trainX_CNN.shape, trainY_CNN.shape)
print(valX_CNN.shape, valY_CNN.shape)
print(testX_CNN.shape, testY_CNN.shape)
# Out:
# (203701, 100, 40, 1) (203701, 3)
# (50851, 100, 40, 1) (50851, 3)
# (139488, 100, 40, 1) (139488, 3)

# %% [markdown]
# # Model

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Dropout, Reshape

def create_lstm1(T, NF, number_of_lstm):
    input_lmd = Input(shape=(T, NF))

    # build the LSTM layers
    lstm_layer = LSTM(number_of_lstm, return_sequences=True)(input_lmd)
    lstm_layer = LSTM(number_of_lstm, return_sequences=True)(lstm_layer)

    # reshape for compatibility with dense layer
    lstm_reshape = Reshape((T * number_of_lstm,))(lstm_layer)
    lstm_reshape = Dropout(0.2)(lstm_reshape, training=True)

    # build the output layer
    out = Dense(3, activation='softmax')(lstm_reshape)

    model = Model(inputs=input_lmd, outputs=out)
    adam = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', macro_f1])

    return model

# Assuming trainX_CNN.shape[1] is T, trainX_CNN.shape[2] is NF, and n_hiddens is the number of LSTM units
lstm1 = create_lstm1(trainX_CNN.shape[1], trainX_CNN.shape[2], n_hiddens)
lstm1.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100, 40)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 100, 64)        │        26,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 64)        │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │        19,203 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,107 (309.01 KB)
#  Trainable params: 79,107 (309.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%time
checkpoint_filepath = f'/content/drive/MyDrive/LOBCNN/models/LSTM_1_{RANDOM_SEED}.weights.h5'

if os.path.exists(checkpoint_filepath):
    lstm1.load_weights(checkpoint_filepath)
    print("Loaded saved weights.")
else:
    print("No saved weights found. Starting training from scratch.")
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_macro_f1',
        mode='max',
        save_best_only=True)
    lstm1.fit(trainX_CNN, trainY_CNN, validation_data=(valX_CNN, valY_CNN),
              epochs=200, batch_size=128, verbose=1, callbacks=[model_checkpoint_callback])
# Out:
# No saved weights found. Starting training from scratch.
# Epoch 1/200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━
200
# 1592/1592 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - accuracy: 0.7894 - loss: 0.5134 - macro_f1: 0.7667 - val_accuracy: 0.4641 - val_loss: 1.1744 - val_macro_f1: 0.3694
# CPU times: user 1h 37min 47s, sys: 6min 58s, total: 1h 44min 46s
# Wall time: 1h 11min 22s

# %%
print(accuracy_score(np.argmax(testY_CNN, axis=1), np.argmax(lstm1.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step
# 0.4790376233080982

# %%
print(classification_report(np.argmax(testY_CNN, axis=1), np.argmax(lstm1.predict(testX_CNN), axis=1)))
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.48      0.54      0.51     47915
#            1       0.50      0.35      0.41     48050
#            2       0.46      0.55      0.50     43523
#
#     accuracy                           0.48    139488
#    macro avg       0.48      0.48      0.47    139488
# weighted avg       0.48      0.48      0.47    139488

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = lstm1.predict(testX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(testY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step

# %%
print(accuracy_score(np.argmax(trainY_CNN, axis=1), np.argmax(lstm1.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step
# 0.7957987442378781

# %%
print(classification_report(np.argmax(trainY_CNN, axis=1), np.argmax(lstm1.predict(trainX_CNN), axis=1)))
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81     84426
#            1       0.81      0.62      0.70     36210
#            2       0.79      0.83      0.81     83065
#
#     accuracy                           0.80    203701
#    macro avg       0.80      0.76      0.78    203701
# weighted avg       0.80      0.80      0.79    203701

# %%
from sklearn.metrics import precision_recall_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba = lstm1.predict(trainX_CNN)[:, 1]

# Calculate precision and recall
precision, recall, thresholds = precision_recall_curve(trainY_CNN[:, 1], y_pred_proba)

# Calculate area under the curve
auc_score = auc(recall, precision)

# Plot the precision-recall curve
plt.plot(recall, precision, label=f'AUC = {auc_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TEST DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = lstm1.predict(testX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    # Get average ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)


            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_test,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 4359/4359 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 44094
# Win rate: 0.50%
# Total profit: $-54.04
# Average profit per trade: $-0.0012
#
# Direction Analysis:
#
# UP trades:
# Count: 21575
# Win rate: 0.53%
# Total profit: $73.57
# Average profit: $0.0034
#
# DOWN trades:
# Count: 22519
# Win rate: 0.47%
# Total profit: $-127.60
# Average profit: $-0.0057
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 37148
# Win rate: 0.49%
# Total profit: $146.90
# Average profit per trade: $0.0040
#
# Direction Analysis:
#
# UP trades:
# Count: 18140
# Win rate: 0.54%
# Total profit: $120.59
# Average profit: $0.0066
#
# DOWN trades:
# Count: 19008
# Win rate: 0.45%
# Total profit: $26.31
# Average profit: $0.0014
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 29849
# Win rate: 0.53%
# Total profit: $314.65
# Average profit per trade: $0.0105
#
# Direction Analysis:
#
# UP trades:
# Count: 14477
# Win rate: 0.53%
# Total profit: $116.03
# Average profit: $0.0080
#
# DOWN trades:
# Count: 15372
# Win rate: 0.53%
# Total profit: $198.62
# Average profit: $0.0129
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 21359
# Win rate: 0.51%
# Total profit: $275.09
# Average profit per trade: $0.0129
#
# Direction Analysis:
#
# UP trades:
# Count: 10284
# Win rate: 0.50%
# Total profit: $80.20
# Average profit: $0.0078
#
# DOWN trades:
# Count: 11075
# Win rate: 0.52%
# Total profit: $194.90
# Average profit: $0.0176
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 10514
# Win rate: 0.46%
# Total profit: $122.13
# Average profit per trade: $0.0116
#
# Direction Analysis:
#
# UP trades:
# Count: 5022
# Win rate: 0.42%
# Total profit: $1.62
# Average profit: $0.0003
#
# DOWN trades:
# Count: 5492
# Win rate: 0.49%
# Total profit: $120.51
# Average profit: $0.0219
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000    -54.036120       44094  0.496666   -0.001225        21575
# 1   0.850000    146.899989       37148  0.492624    0.003954        18140
# 2   0.900000    314.651400       29849  0.529331    0.010541        14477
# 3   0.950000    275.094578       21359  0.510324    0.012880        10284
# 4   0.990000    122.133338       10514  0.456534    0.011616         5022
#
#    short_trades
# 0         22519
# 1         19008
# 2         15372
# 3         11075
# 4          5492

# %%
""" TRADING STRATEGY BEFORE ATTACK ON TRAIN DATA"""
import numpy as np
import pandas as pd

print("Getting predictions...")
train_predictions = lstm1.predict(trainX_CNN)

# First define our strategy function
def implement_fi2010_strategy(predictions, dec_data, budget=100, prob_threshold=0.5, k=4, alpha=0.001):
    """
    Implements trading strategy using the FI-2010 paper's methodology

    Args:
        predictions: numpy array of model predictions (n_samples, 3)
        dec_data: numpy array of decoded price data
        budget: amount to invest per trade
        prob_threshold: probability threshold for trading
        k: prediction horizon (number of steps to look ahead)
        alpha: threshold for determining price movement direction
    """
    # Get normalized ask and bid prices
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]

    trades_info = []

    for i in range(k, min_length):
        # Calculate m+ (future average) according to paper
        m_plus = np.mean(mid_prices[i+1:i+k+1])

        # Calculate actual price movement using paper's method
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax([predictions[i, 0], predictions[i, 1], predictions[i, 2]])
        max_prob = np.max([predictions[i, 0], predictions[i, 1], predictions[i, 2]])

        if max_prob > prob_threshold and pred_class != 1:  # not stable
            # Determine actual direction using same threshold as training
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)

            # Long trade (UP prediction)
            if pred_class == 2:
                shares = budget / mid_prices[i]
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'up',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 2],
                    'correct': actual_direction == 1,
                    'index': i
                })

            # Short trade (DOWN prediction)
            elif pred_class == 0:
                shares = budget / mid_prices[i]
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost

                trades_info.append({
                    'movement': 'down',
                    'entry_price': mid_prices[i],
                    'exit_price': m_plus,
                    'shares': shares,
                    'price_change': m_plus - mid_prices[i],
                    'price_change_pct': lt,
                    'cost': cost,
                    'proceeds': proceeds,
                    'profit': profit,
                    'prob': predictions[i, 0],
                    'correct': actual_direction == -1,
                    'index': i
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)

        # Print performance metrics
        print("\nTrading Performance:")
        print(f"Total trades: {len(trades_df)}")
        print(f"Win rate: {(trades_df['correct'].mean() * 100):.2f}%")
        print(f"Total profit: ${trades_df['profit'].sum():.2f}")
        print(f"Average profit per trade: ${trades_df['profit'].mean():.4f}")

        print("\nDirection Analysis:")
        for direction in ['up', 'down']:
            mask = trades_df['movement'] == direction
            if mask.any():
                direction_df = trades_df[mask]
                print(f"\n{direction.upper()} trades:")
                print(f"Count: {len(direction_df)}")
                print(f"Win rate: {(direction_df['correct'].mean() * 100):.2f}%")
                print(f"Total profit: ${direction_df['profit'].sum():.2f}")
                print(f"Average profit: ${direction_df['profit'].mean():.4f}")

        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

# Test different probability thresholds
thresholds = [0.8, 0.85, 0.9, 0.95, 0.99]
results = []

print("Testing strategy with different thresholds...")
for threshold in thresholds:
    print(f"\nTesting threshold: {threshold}")
    result = implement_fi2010_strategy(
        predictions=train_predictions,
        dec_data=dec_train,
        prob_threshold=threshold,
        k=4,
        alpha=0.001
    )
    if result:
        results.append(result)

# Create summary table
if results:
    results_df = pd.DataFrame(results)
    print("\nSummary of results for different probability thresholds:")
    pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
    print(results_df)
# Out:
# Getting predictions...
# 6366/6366 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step
# Testing strategy with different thresholds...
#
# Testing threshold: 0.8
#
# Trading Performance:
# Total trades: 93591
# Win rate: 0.68%
# Total profit: $-112.61
# Average profit per trade: $-0.0012
#
# Direction Analysis:
#
# UP trades:
# Count: 46608
# Win rate: 0.75%
# Total profit: $72.87
# Average profit: $0.0016
#
# DOWN trades:
# Count: 46983
# Win rate: 0.62%
# Total profit: $-185.49
# Average profit: $-0.0039
#
# Testing threshold: 0.85
#
# Trading Performance:
# Total trades: 82524
# Win rate: 0.67%
# Total profit: $-134.34
# Average profit per trade: $-0.0016
#
# Direction Analysis:
#
# UP trades:
# Count: 41090
# Win rate: 0.73%
# Total profit: $70.62
# Average profit: $0.0017
#
# DOWN trades:
# Count: 41434
# Win rate: 0.61%
# Total profit: $-204.96
# Average profit: $-0.0049
#
# Testing threshold: 0.9
#
# Trading Performance:
# Total trades: 69759
# Win rate: 0.66%
# Total profit: $4.20
# Average profit per trade: $0.0001
#
# Direction Analysis:
#
# UP trades:
# Count: 34650
# Win rate: 0.69%
# Total profit: $82.00
# Average profit: $0.0024
#
# DOWN trades:
# Count: 35109
# Win rate: 0.62%
# Total profit: $-77.80
# Average profit: $-0.0022
#
# Testing threshold: 0.95
#
# Trading Performance:
# Total trades: 53144
# Win rate: 0.65%
# Total profit: $119.29
# Average profit per trade: $0.0022
#
# Direction Analysis:
#
# UP trades:
# Count: 26402
# Win rate: 0.66%
# Total profit: $84.30
# Average profit: $0.0032
#
# DOWN trades:
# Count: 26742
# Win rate: 0.64%
# Total profit: $35.00
# Average profit: $0.0013
#
# Testing threshold: 0.99
#
# Trading Performance:
# Total trades: 28086
# Win rate: 0.58%
# Total profit: $11.76
# Average profit per trade: $0.0004
#
# Direction Analysis:
#
# UP trades:
# Count: 14021
# Win rate: 0.61%
# Total profit: $0.85
# Average profit: $0.0001
#
# DOWN trades:
# Count: 14065
# Win rate: 0.55%
# Total profit: $10.91
# Average profit: $0.0008
#
# Summary of results for different probability thresholds:
#    threshold  total_profit  num_trades  win_rate  avg_profit  long_trades  \
# 0   0.800000   -112.613445       93591  0.683826   -0.001203        46608
# 1   0.850000   -134.343894       82524  0.671320   -0.001628        41090
# 2   0.900000      4.197017       69759  0.655113    0.000060        34650
# 3   0.950000    119.293596       53144  0.647298    0.002245        26402
# 4   0.990000     11.760188       28086  0.576800    0.000419        14021
#
#    short_trades
# 0         46983
# 1         41434
# 2         35109
# 3         26742
# 4         14065

# %%
def calculate_perturbation_volume(original, perturbed):
    original_flat = original.reshape(original.shape[0], -1)
    perturbed_flat = perturbed.reshape(perturbed.shape[0], -1)
    perturbation = np.linalg.norm(original_flat - perturbed_flat, ord=2, axis=1)
    avg_perturbation = np.mean(perturbation)
    return avg_perturbation

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
num_iterations = 5
step_size = 0.01

# Define your model
model = lstm1

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}
avg_accuracies3 = {}
perturbed_volumes3 = {}
avg_precision3 = {}
avg_recall3 = {}
avg_roc_auc3 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def fgsm_attack(images, labels, epsilon):
    with tf.GradientTape() as tape:
        tape.watch(images)
        predictions = model(images)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
    gradient = tape.gradient(loss, images)
    signed_grad = tf.sign(gradient)

    signed_masked = signed_grad.numpy()
    signed_masked[:, :99, :, :] = 0
    signed_masked[:, 99:, ::2, :] = 0
    signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

    perturbed_images = images + epsilon * signed_masked
    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images
"""
with tf.GradientTape() as tape: automatically tracks operations for gradient calculation
tape.watch(images): Explicitly tells the gradient tape to watch the images tensor for gradient calculation
loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions):
Calculates the loss between the true labels and the model's predictions
Uses categorical cross-entropy loss because this is a classification problem
from_logits=False indicates that the predictions are already probabilities (softmax has been applied)
gradient = tape.gradient(loss, images)
Calculates the gradient of the loss with respect to the input images
This tells us how to change the input to maximize the loss (i.e., make the model more likely to misclassify)
signed_grad = tf.sign(gradient)
Applies the sign function to the gradient to get the direction of the gradient
signed_masked[:, :99, :, :] = 0:
Sets the gradients for the first 99 time steps to zero
This ensures we only perturb the last time step (t=99), which is what the model primarily bases its prediction on
Within the last time step (t=99), this sets gradients for every other feature to zero
The ::2 slice is accessing only even indices, which likely correspond to price data in the LOB
This ensures we only perturb volume data and not price data, making the attack more realistic
signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32):
Converts the masked gradient signs back to a TensorFlow tensor for further operations
perturbed_images = images + epsilon * signed_masked:
Creates adversarial examples by adding the perturbation to the original images
The perturbation is the sign of the gradient scaled by epsilon
perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
Clips the perturbed values to ensure they stay within valid range [0,1]
"""
def pgd_attack(images, labels, epsilon):
    perturbed_images = tf.identity(images)
    alpha = 2.5 * epsilon / num_iterations

    for _ in range(num_iterations):
        with tf.GradientTape() as tape:
            tape.watch(perturbed_images)
            predictions = model(perturbed_images)
            loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(labels, predictions)
        gradient = tape.gradient(loss, perturbed_images)
        signed_grad = tf.sign(gradient)

        # mask: only perturb volume features at the last timestep
        signed_masked = signed_grad.numpy()
        signed_masked[:, :99, :, :] = 0
        signed_masked[:, 99:, ::2, :] = 0
        signed_masked = tf.convert_to_tensor(signed_masked, dtype=tf.float32)

        # gradient step
        perturbed_images = perturbed_images + alpha * signed_masked

        # L-infinity projection + volume floor: delta in [0, epsilon]
        delta = perturbed_images - images
        delta = tf.clip_by_value(delta, 0, epsilon)
        perturbed_images = images + delta

        # clip to valid range
        perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)

    return perturbed_images
def random_noise_attack(images, epsilon):
    """Random noise baseline attack: uniform noise, L-inf + volume floor."""
    noise = tf.random.uniform(tf.shape(images), -epsilon, epsilon)
    noise = noise.numpy()
    noise[:, :99, :, :] = 0
    noise[:, 99:, ::2, :] = 0
    noise = tf.convert_to_tensor(noise, dtype=tf.float32)
    perturbed_images = images + noise

    # L-infinity projection + volume floor: delta in [0, epsilon]
    delta = perturbed_images - images
    delta = tf.clip_by_value(delta, 0, epsilon)
    perturbed_images = images + delta

    perturbed_images = tf.clip_by_value(perturbed_images, 0, 1)
    return perturbed_images
def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_accuracy3 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    total_perturbation3 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []
    all_predicted_labels3 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []
    epsilon_pred_probs_random = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)
        perturbed_images3 = random_noise_attack(batch_images, epsilon)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())
        perturbation3 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images3.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2
        total_perturbation3 += perturbation3

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()
        X_perturbed3 = perturbed_images3.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)
        adversarial_probs3 = model.predict(X_perturbed3)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)
        adversarial_predictions3 = np.argmax(adversarial_probs3, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)
        epsilon_pred_probs_random.append(adversarial_probs3)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)
        all_predicted_labels3.extend(adversarial_predictions3)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2
        accuracy3 = accuracy_score(true_labels_batch, adversarial_predictions3)
        total_accuracy3 += accuracy3

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    average_accuracy3 = total_accuracy3 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches
    avg_perturbation3 = total_perturbation3 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)
    epsilon_pred_probs_random = np.vstack(epsilon_pred_probs_random)

    # Calculate and plot ROC curve

    # Compute macro-average ROC AUC for Random Noise
    fpr3 = dict()
    tpr3 = dict()
    roc_auc3_per_class = dict()
    for i in range(3):
        fpr3[i], tpr3[i], _ = roc_curve(epsilon_true_labels_onehot[:, i], epsilon_pred_probs_random[:, i])
        roc_auc3_per_class[i] = auc(fpr3[i], tpr3[i])
    all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(3)]))
    mean_tpr3 = np.zeros_like(all_fpr3)
    for i in range(3):
        mean_tpr3 += np.interp(all_fpr3, fpr3[i], tpr3[i])
    mean_tpr3 /= 3
    roc_auc3 = auc(all_fpr3, mean_tpr3)
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2
    avg_roc_auc3[epsilon] = roc_auc3

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')
    precision3 = precision_score(all_true_labels, all_predicted_labels3, average='macro')
    recall3 = recall_score(all_true_labels, all_predicted_labels3, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2
    avg_precision3[epsilon] = precision3
    avg_recall3[epsilon] = recall3

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)
    random_report = classification_report(all_true_labels, all_predicted_labels3, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    avg_accuracies3[epsilon] = average_accuracy3
    print(f"Average accuracy of Random Noise attack for epsilon value {epsilon}: {average_accuracy3}")
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2
    perturbed_volumes3[epsilon] = avg_perturbation3
    print(f"Average perturbation volume for Random Noise attack with epsilon {epsilon}: {avg_perturbation3}")

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")
    print(f"Average precision of Random Noise attack for epsilon value {epsilon}: {precision3}")
    print(f"Average recall of Random Noise attack for epsilon value {epsilon}: {recall3}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")
    print(f"ROC AUC of Random Noise attack for epsilon value {epsilon}: {roc_auc3}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))
    print(f"\nClassification Report for Random Noise Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels3))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 1e-06
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1e-06: 0.3124347826086957
# Average accuracy of FGSM attack for epsilon value 1e-06: 0.48424637681159427
# Average accuracy of Random Noise attack for epsilon value 1e-06: 0.3889347826086955
# Average perturbation volume for PGD attack with epsilon 1e-06: 2.2742691040039062
# Average perturbation volume for FGSM attack with epsilon 1e-06: 4.471045485843206e-06
# Average perturbation volume for Random Noise attack with epsilon 1e-06: 2.264003276824951
# Average precision of PGD attack for epsilon value 1e-06: 0.3180819336228162
# Average recall of PGD attack for epsilon value 1e-06: 0.3134884555596702
# Average precision of FGSM attack for epsilon value 1e-06: 0.4872181597665049
# Average recall of FGSM attack for epsilon value 1e-06: 0.4861470528341463
# Average precision of Random Noise attack for epsilon value 1e-06: 0.3901995468211765
# Average recall of Random Noise attack for epsilon value 1e-06: 0.39046444813995446
# ROC AUC of PGD attack for epsilon value 1e-06: 0.48354650976514163
# ROC AUC of FGSM attack for epsilon value 1e-06: 0.6701693653595774
# ROC AUC of Random Noise attack for epsilon value 1e-06: 0.5594399565525656
#
# Classification Report for PGD Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.32      0.40      0.35     47512
#            1       0.35      0.19      0.24     47269
#            2       0.29      0.35      0.32     43219
#
#     accuracy                           0.31    138000
#    macro avg       0.32      0.31      0.31    138000
# weighted avg       0.32      0.31      0.31    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.52     47512
#            1       0.51      0.34      0.41     47269
#            2       0.47      0.56      0.51     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.49      0.48    138000
# weighted avg       0.49      0.48      0.48    138000
#
#
# Classification Report for Random Noise Attack (ε = 1e-06):
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44     47512
#            1       0.40      0.23      0.30     47269
#            2       0.37      0.45      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000
#
# Epsilon value: 1e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1e-05: 0.3122898550724638
# Average accuracy of FGSM attack for epsilon value 1e-05: 0.4841739130434784
# Average accuracy of Random Noise attack for epsilon value 1e-05: 0.3889057971014491
# Average perturbation volume for PGD attack with epsilon 1e-05: 2.2742762565612793
# Average perturbation volume for FGSM attack with epsilon 1e-05: 4.47205820819363e-05
# Average perturbation volume for Random Noise attack with epsilon 1e-05: 2.264003276824951
# Average precision of PGD attack for epsilon value 1e-05: 0.31799602528395327
# Average recall of PGD attack for epsilon value 1e-05: 0.3133322560239009
# Average precision of FGSM attack for epsilon value 1e-05: 0.48715247650781474
# Average recall of FGSM attack for epsilon value 1e-05: 0.48607469626241917
# Average precision of Random Noise attack for epsilon value 1e-05: 0.3901711496481309
# Average recall of Random Noise attack for epsilon value 1e-05: 0.3904342583301675
# ROC AUC of PGD attack for epsilon value 1e-05: 0.48353124312245094
# ROC AUC of FGSM attack for epsilon value 1e-05: 0.6701218027442095
# ROC AUC of Random Noise attack for epsilon value 1e-05: 0.5594398345637618
#
# Classification Report for PGD Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.32      0.40      0.35     47512
#            1       0.35      0.19      0.24     47269
#            2       0.29      0.35      0.32     43219
#
#     accuracy                           0.31    138000
#    macro avg       0.32      0.31      0.31    138000
# weighted avg       0.32      0.31      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.52     47512
#            1       0.51      0.34      0.41     47269
#            2       0.47      0.56      0.51     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.49      0.48    138000
# weighted avg       0.49      0.48      0.48    138000
#
#
# Classification Report for Random Noise Attack (ε = 1e-05):
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44     47512
#            1       0.40      0.23      0.30     47269
#            2       0.37      0.45      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000
#
# Epsilon value: 0.0001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.0001: 0.3122101449275362
# Average accuracy of FGSM attack for epsilon value 0.0001: 0.48368840579710143
# Average accuracy of Random Noise attack for epsilon value 0.0001: 0.3889275362318839
# Average perturbation volume for PGD attack with epsilon 0.0001: 2.2742645740509033
# Average perturbation volume for FGSM attack with epsilon 0.0001: 0.00044705960317514837
# Average perturbation volume for Random Noise attack with epsilon 0.0001: 2.264003276824951
# Average precision of PGD attack for epsilon value 0.0001: 0.31775980091294637
# Average recall of PGD attack for epsilon value 0.0001: 0.3132600805584872
# Average precision of FGSM attack for epsilon value 0.0001: 0.48668610615058405
# Average recall of FGSM attack for epsilon value 0.0001: 0.4855886228221194
# Average precision of Random Noise attack for epsilon value 0.0001: 0.3901894764007155
# Average recall of Random Noise attack for epsilon value 0.0001: 0.39045669941610534
# ROC AUC of PGD attack for epsilon value 0.0001: 0.4835602711475235
# ROC AUC of FGSM attack for epsilon value 0.0001: 0.6696478250332728
# ROC AUC of Random Noise attack for epsilon value 0.0001: 0.5594398918847603
#
# Classification Report for PGD Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.32      0.40      0.35     47512
#            1       0.35      0.19      0.24     47269
#            2       0.29      0.35      0.32     43219
#
#     accuracy                           0.31    138000
#    macro avg       0.32      0.31      0.31    138000
# weighted avg       0.32      0.31      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.52     47512
#            1       0.51      0.34      0.41     47269
#            2       0.47      0.55      0.51     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.49      0.49      0.48    138000
# weighted avg       0.49      0.48      0.48    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.0001):
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44     47512
#            1       0.40      0.23      0.30     47269
#            2       0.37      0.45      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000
#
# Epsilon value: 0.001
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.001: 0.3122536231884059
# Average accuracy of FGSM attack for epsilon value 0.001: 0.47759420289855065
# Average accuracy of Random Noise attack for epsilon value 0.001: 0.38897826086956505
# Average perturbation volume for PGD attack with epsilon 0.001: 2.274277687072754
# Average perturbation volume for FGSM attack with epsilon 0.001: 0.004455672577023506
# Average perturbation volume for Random Noise attack with epsilon 0.001: 2.2640039920806885
# Average precision of PGD attack for epsilon value 0.001: 0.3178925468880541
# Average recall of PGD attack for epsilon value 0.001: 0.31330455437743415
# Average precision of FGSM attack for epsilon value 0.001: 0.4807500253094574
# Average recall of FGSM attack for epsilon value 0.001: 0.4794820643922872
# Average precision of Random Noise attack for epsilon value 0.001: 0.3902547253019011
# Average recall of Random Noise attack for epsilon value 0.001: 0.3905072396544675
# ROC AUC of PGD attack for epsilon value 0.001: 0.4835416299089239
# ROC AUC of FGSM attack for epsilon value 0.001: 0.6649342419039234
# ROC AUC of Random Noise attack for epsilon value 0.001: 0.5594394868834045
#
# Classification Report for PGD Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.32      0.40      0.35     47512
#            1       0.35      0.19      0.24     47269
#            2       0.29      0.35      0.32     43219
#
#     accuracy                           0.31    138000
#    macro avg       0.32      0.31      0.31    138000
# weighted avg       0.32      0.31      0.30    138000
#
#
# Classification Report for FGSM Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.48      0.55      0.51     47512
#            1       0.50      0.34      0.40     47269
#            2       0.46      0.55      0.50     43219
#
#     accuracy                           0.48    138000
#    macro avg       0.48      0.48      0.47    138000
# weighted avg       0.48      0.48      0.47    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.001):
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44     47512
#            1       0.40      0.23      0.30     47269
#            2       0.37      0.45      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000

# %%
""" ADVERSARIAL ATTACK ON TEST DATA ON 4 EPSILON VALUES"""
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, roc_curve, auc, classification_report
import matplotlib.pyplot as plt

# Define constants
max_test_size = testX_CNN.shape[0]
batch_size = 2000
num_batches = max_test_size // batch_size
epsilon_values = [0.01, 0.1, 1, 10]
num_iterations = 5
step_size = 0.01

# Define your model
model = lstm1

avg_accuracies1 = {}
avg_accuracies2 = {}
perturbed_volumes1 = {}
perturbed_volumes2 = {}
# Define dictionaries to hold precision and recall
avg_precision1 = {}
avg_recall1 = {}
avg_precision2 = {}
avg_recall2 = {}
# Define dictionaries to hold ROC AUC scores
avg_roc_auc1 = {}
avg_roc_auc2 = {}
avg_accuracies3 = {}
perturbed_volumes3 = {}
avg_precision3 = {}
avg_recall3 = {}
avg_roc_auc3 = {}


def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)(label, prediction)
    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    return signed_grad

def data_set(testX_CNN, start_idx, end_idx):
    shifted_testX_CNN = tf.concat([testX_CNN[start_idx:end_idx, 1:100, :, :], testX_CNN[start_idx:end_idx, 99:, :, :]], axis=1)
    return shifted_testX_CNN

def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
    images = images.numpy()
    slices = [slice(None)] * images.ndim
    testX_CNN = testX_CNN[start_idx:end_idx]
    for idx in range(images.shape[dimension]):
        slices[dimension] = idx
        images[tuple(slices)] = np.maximum(images[tuple(slices)], testX_CNN[tuple(slices)])
    images = tf.convert_to_tensor(images, dtype=tf.float32)
    return images

def plot_roc_curve(y_true, y_score1, y_score2, epsilon):
    """
    Plot ROC curve for both attacks at a specific epsilon value
    """
    # Get number of classes
    n_classes = y_score1.shape[1]

    # Compute ROC curve and ROC area for each class for PGD
    fpr1 = dict()
    tpr1 = dict()
    roc_auc1 = dict()
    for i in range(n_classes):
        fpr1[i], tpr1[i], _ = roc_curve(y_true[:, i], y_score1[:, i])
        roc_auc1[i] = auc(fpr1[i], tpr1[i])

    # Compute ROC curve and ROC area for each class for FGSM
    fpr2 = dict()
    tpr2 = dict()
    roc_auc2 = dict()
    for i in range(n_classes):
        fpr2[i], tpr2[i], _ = roc_curve(y_true[:, i], y_score2[:, i])
        roc_auc2[i] = auc(fpr2[i], tpr2[i])

    # Calculate macro average ROC curve and ROC area
    all_fpr1 = np.unique(np.concatenate([fpr1[i] for i in range(n_classes)]))
    all_fpr2 = np.unique(np.concatenate([fpr2[i] for i in range(n_classes)]))

    mean_tpr1 = np.zeros_like(all_fpr1)
    mean_tpr2 = np.zeros_like(all_fpr2)
    for i in range(n_classes):
        mean_tpr1 += np.interp(all_fpr1, fpr1[i], tpr1[i])
        mean_tpr2 += np.interp(all_fpr2, fpr2[i], tpr2[i])

    mean_tpr1 /= n_classes
    mean_tpr2 /= n_classes

    macro_roc_auc1 = auc(all_fpr1, mean_tpr1)
    macro_roc_auc2 = auc(all_fpr2, mean_tpr2)

    # Plot ROC curve only as per the requirement
    plt.figure(figsize=(10, 8))
    plt.plot(all_fpr1, mean_tpr1, label=f'PGD Attack - Macro-average ROC (AUC = {macro_roc_auc1:.2f})',
             color='blue', linestyle='solid', linewidth=2)
    plt.plot(all_fpr2, mean_tpr2, label=f'FGSM Attack - Macro-average ROC (AUC = {macro_roc_auc2:.2f})',
             color='red', linestyle='dashed', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for PGD and FGSM Attacks with ε = {epsilon}')
    plt.legend(loc="lower right")
    plt.grid(True, linestyle='--', alpha=0.7)

    # Save the figure
    plt.savefig(f'roc_curve_epsilon_{epsilon}.png', dpi=300, bbox_inches='tight')
    plt.close()

    return macro_roc_auc1, macro_roc_auc2

# Lists to store all prediction probabilities and true labels for ROC curves
all_true_labels_onehot = []
all_pred_probs_pgd = []
all_pred_probs_fgsm = []

for epsilon in epsilon_values:
    print(f"Epsilon value: {epsilon}")
    total_accuracy1 = 0.0
    total_accuracy2 = 0.0
    total_accuracy3 = 0.0
    total_perturbation1 = 0.0
    total_perturbation2 = 0.0
    total_perturbation3 = 0.0
    all_true_labels = []
    all_predicted_labels1 = []
    all_predicted_labels2 = []
    all_predicted_labels3 = []

    # For this epsilon, collect all prediction probabilities
    epsilon_true_labels_onehot = []
    epsilon_pred_probs_pgd = []
    epsilon_pred_probs_fgsm = []
    epsilon_pred_probs_random = []

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = (i + 1) * batch_size

        batch_images = data_set(testX_CNN, start_idx, end_idx)
        batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
        batch_labels = testY_CNN[start_idx:end_idx]

        perturbed_images1 = pgd_attack(batch_images, batch_labels, epsilon)
        perturbed_images2 = fgsm_attack(batch_images, batch_labels, epsilon)
        perturbed_images3 = random_noise_attack(batch_images, epsilon)

        perturbation1 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images1.numpy())
        perturbation2 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images2.numpy())
        perturbation3 = calculate_perturbation_volume(batch_images.numpy(), perturbed_images3.numpy())

        total_perturbation1 += perturbation1
        total_perturbation2 += perturbation2
        total_perturbation3 += perturbation3

        X_perturbed1 = perturbed_images1.numpy()
        X_perturbed2 = perturbed_images2.numpy()
        X_perturbed3 = perturbed_images3.numpy()

        # Get raw probabilities for ROC curve
        adversarial_probs1 = model.predict(X_perturbed1)
        adversarial_probs2 = model.predict(X_perturbed2)
        adversarial_probs3 = model.predict(X_perturbed3)

        # Get predicted labels
        adversarial_predictions1 = np.argmax(adversarial_probs1, axis=1)
        adversarial_predictions2 = np.argmax(adversarial_probs2, axis=1)
        adversarial_predictions3 = np.argmax(adversarial_probs3, axis=1)

        # Collect data for ROC curve
        epsilon_true_labels_onehot.append(batch_labels)
        epsilon_pred_probs_pgd.append(adversarial_probs1)
        epsilon_pred_probs_fgsm.append(adversarial_probs2)
        epsilon_pred_probs_random.append(adversarial_probs3)

        # Append results for precision and recall calculation
        true_labels_batch = np.argmax(batch_labels, axis=1)
        all_true_labels.extend(true_labels_batch)
        all_predicted_labels1.extend(adversarial_predictions1)
        all_predicted_labels2.extend(adversarial_predictions2)
        all_predicted_labels3.extend(adversarial_predictions3)

        accuracy1 = accuracy_score(true_labels_batch, adversarial_predictions1)
        accuracy2 = accuracy_score(true_labels_batch, adversarial_predictions2)
        total_accuracy1 += accuracy1
        total_accuracy2 += accuracy2
        accuracy3 = accuracy_score(true_labels_batch, adversarial_predictions3)
        total_accuracy3 += accuracy3

    average_accuracy1 = total_accuracy1 / num_batches
    average_accuracy2 = total_accuracy2 / num_batches
    average_accuracy3 = total_accuracy3 / num_batches
    avg_perturbation1 = total_perturbation1 / num_batches
    avg_perturbation2 = total_perturbation2 / num_batches
    avg_perturbation3 = total_perturbation3 / num_batches

    # Concatenate all batches for this epsilon
    epsilon_true_labels_onehot = np.vstack(epsilon_true_labels_onehot)
    epsilon_pred_probs_pgd = np.vstack(epsilon_pred_probs_pgd)
    epsilon_pred_probs_fgsm = np.vstack(epsilon_pred_probs_fgsm)
    epsilon_pred_probs_random = np.vstack(epsilon_pred_probs_random)

    # Calculate and plot ROC curve

    # Compute macro-average ROC AUC for Random Noise
    fpr3 = dict()
    tpr3 = dict()
    roc_auc3_per_class = dict()
    for i in range(3):
        fpr3[i], tpr3[i], _ = roc_curve(epsilon_true_labels_onehot[:, i], epsilon_pred_probs_random[:, i])
        roc_auc3_per_class[i] = auc(fpr3[i], tpr3[i])
    all_fpr3 = np.unique(np.concatenate([fpr3[i] for i in range(3)]))
    mean_tpr3 = np.zeros_like(all_fpr3)
    for i in range(3):
        mean_tpr3 += np.interp(all_fpr3, fpr3[i], tpr3[i])
    mean_tpr3 /= 3
    roc_auc3 = auc(all_fpr3, mean_tpr3)
    roc_auc1, roc_auc2 = plot_roc_curve(
        epsilon_true_labels_onehot,
        epsilon_pred_probs_pgd,
        epsilon_pred_probs_fgsm,
        epsilon
    )

    avg_roc_auc1[epsilon] = roc_auc1
    avg_roc_auc2[epsilon] = roc_auc2
    avg_roc_auc3[epsilon] = roc_auc3

    # Calculate precision and recall
    precision1 = precision_score(all_true_labels, all_predicted_labels1, average='macro')
    recall1 = recall_score(all_true_labels, all_predicted_labels1, average='macro')
    precision2 = precision_score(all_true_labels, all_predicted_labels2, average='macro')
    recall2 = recall_score(all_true_labels, all_predicted_labels2, average='macro')
    precision3 = precision_score(all_true_labels, all_predicted_labels3, average='macro')
    recall3 = recall_score(all_true_labels, all_predicted_labels3, average='macro')

    avg_precision1[epsilon] = precision1
    avg_recall1[epsilon] = recall1
    avg_precision2[epsilon] = precision2
    avg_recall2[epsilon] = recall2
    avg_precision3[epsilon] = precision3
    avg_recall3[epsilon] = recall3

    # Generate classification reports
    pgd_report = classification_report(all_true_labels, all_predicted_labels1, output_dict=True)
    fgsm_report = classification_report(all_true_labels, all_predicted_labels2, output_dict=True)
    random_report = classification_report(all_true_labels, all_predicted_labels3, output_dict=True)

    print(f"Average accuracy of PGD attack for epsilon value {epsilon}: {average_accuracy1}")
    avg_accuracies1[epsilon] = average_accuracy1
    print(f"Average accuracy of FGSM attack for epsilon value {epsilon}: {average_accuracy2}")
    avg_accuracies2[epsilon] = average_accuracy2
    avg_accuracies3[epsilon] = average_accuracy3
    print(f"Average accuracy of Random Noise attack for epsilon value {epsilon}: {average_accuracy3}")
    print(f"Average perturbation volume for PGD attack with epsilon {epsilon}: {avg_perturbation1}")
    perturbed_volumes1[epsilon] = avg_perturbation1
    print(f"Average perturbation volume for FGSM attack with epsilon {epsilon}: {avg_perturbation2}")
    perturbed_volumes2[epsilon] = avg_perturbation2
    perturbed_volumes3[epsilon] = avg_perturbation3
    print(f"Average perturbation volume for Random Noise attack with epsilon {epsilon}: {avg_perturbation3}")

    # Print precision and recall
    print(f"Average precision of PGD attack for epsilon value {epsilon}: {precision1}")
    print(f"Average recall of PGD attack for epsilon value {epsilon}: {recall1}")
    print(f"Average precision of FGSM attack for epsilon value {epsilon}: {precision2}")
    print(f"Average recall of FGSM attack for epsilon value {epsilon}: {recall2}")
    print(f"Average precision of Random Noise attack for epsilon value {epsilon}: {precision3}")
    print(f"Average recall of Random Noise attack for epsilon value {epsilon}: {recall3}")

    # Print ROC AUC
    print(f"ROC AUC of PGD attack for epsilon value {epsilon}: {roc_auc1}")
    print(f"ROC AUC of FGSM attack for epsilon value {epsilon}: {roc_auc2}")
    print(f"ROC AUC of Random Noise attack for epsilon value {epsilon}: {roc_auc3}")

    # Print classification reports
    print(f"\nClassification Report for PGD Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels1))

    print(f"\nClassification Report for FGSM Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels2))
    print(f"\nClassification Report for Random Noise Attack (ε = {epsilon}):")
    print(classification_report(all_true_labels, all_predicted_labels3))

    # Clean up
    tf.keras.backend.clear_session()
# Out:
# Epsilon value: 0.01
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.01: 0.3888260869565216
# Average accuracy of FGSM attack for epsilon value 0.01: 0.4331304347826087
# Average accuracy of Random Noise attack for epsilon value 0.01: 0.38913043478260867
# Average perturbation volume for PGD attack with epsilon 0.01: 2.2640035152435303
# Average perturbation volume for FGSM attack with epsilon 0.01: 0.04049726575613022
# Average perturbation volume for Random Noise attack with epsilon 0.01: 2.2640953063964844
# Average precision of PGD attack for epsilon value 0.01: 0.3900911918107952
# Average recall of PGD attack for epsilon value 0.01: 0.39035418910119857
# Average precision of FGSM attack for epsilon value 0.01: 0.43851381824113406
# Average recall of FGSM attack for epsilon value 0.01: 0.43488658009532455
# Average precision of Random Noise attack for epsilon value 0.01: 0.39044252831317033
# Average recall of Random Noise attack for epsilon value 0.01: 0.3906629334844571
# ROC AUC of PGD attack for epsilon value 0.01: 0.5593600188218325
# ROC AUC of FGSM attack for epsilon value 0.01: 0.6258658403294285
# ROC AUC of Random Noise attack for epsilon value 0.01: 0.5594239575893887
#
# Classification Report for PGD Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44     47512
#            1       0.40      0.23      0.30     47269
#            2       0.37      0.45      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000
#
#
# Classification Report for FGSM Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46     47512
#            1       0.47      0.30      0.37     47269
#            2       0.41      0.50      0.45     43219
#
#     accuracy                           0.43    138000
#    macro avg       0.44      0.43      0.43    138000
# weighted avg       0.44      0.43      0.43    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.01):
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44     47512
#            1       0.40      0.23      0.30     47269
#            2       0.37      0.45      0.41     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000
#
# Epsilon value: 0.1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 0.1: 0.3871376811594202
# Average accuracy of FGSM attack for epsilon value 0.1: 0.22021014492753627
# Average accuracy of Random Noise attack for epsilon value 0.1: 0.38889130434782615
# Average perturbation volume for PGD attack with epsilon 0.1: 2.2641141414642334
# Average perturbation volume for FGSM attack with epsilon 0.1: 0.3288739025592804
# Average perturbation volume for Random Noise attack with epsilon 0.1: 2.2743639945983887
# Average precision of PGD attack for epsilon value 0.1: 0.38863268708702553
# Average recall of PGD attack for epsilon value 0.1: 0.3886465693645602
# Average precision of FGSM attack for epsilon value 0.1: 0.24682606313205616
# Average recall of FGSM attack for epsilon value 0.1: 0.22084759914736993
# Average precision of Random Noise attack for epsilon value 0.1: 0.3901660057177026
# Average recall of Random Noise attack for epsilon value 0.1: 0.390200477332554
# ROC AUC of PGD attack for epsilon value 0.1: 0.5582952171265422
# ROC AUC of FGSM attack for epsilon value 0.1: 0.42144327189337105
# ROC AUC of Random Noise attack for epsilon value 0.1: 0.5587424146205918
#
# Classification Report for PGD Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.40      0.49      0.44     47512
#            1       0.40      0.23      0.30     47269
#            2       0.37      0.45      0.40     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000
#
#
# Classification Report for FGSM Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.21      0.27      0.23     47512
#            1       0.34      0.15      0.21     47269
#            2       0.19      0.25      0.21     43219
#
#     accuracy                           0.22    138000
#    macro avg       0.25      0.22      0.22    138000
# weighted avg       0.25      0.22      0.22    138000
#
#
# Classification Report for Random Noise Attack (ε = 0.1):
#               precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44     47512
#            1       0.40      0.23      0.29     47269
#            2       0.37      0.44      0.40     43219
#
#     accuracy                           0.39    138000
#    macro avg       0.39      0.39      0.38    138000
# weighted avg       0.39      0.39      0.38    138000
#
# Epsilon value: 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 1: 0.3622463768115944
# Average accuracy of FGSM attack for epsilon value 1: 0.07977536231884058
# Average accuracy of Random Noise attack for epsilon value 1: 0.3780434782608696
# Average perturbation volume for PGD attack with epsilon 1: 2.2673349380493164
# Average perturbation volume for FGSM attack with epsilon 1: 3.0959558486938477
# Average perturbation volume for Random Noise attack with epsilon 1: 3.010068893432617
# Average precision of PGD attack for epsilon value 1: 0.3658443663196442
# Average recall of PGD attack for epsilon value 1: 0.36355943915986955
# Average precision of FGSM attack for epsilon value 1: 0.10948288168669205
# Average recall of FGSM attack for epsilon value 1: 0.08104428055189604
# Average precision of Random Noise attack for epsilon value 1: 0.3797896266834313
# Average recall of Random Noise attack for epsilon value 1: 0.3786434551516937
# ROC AUC of PGD attack for epsilon value 1: 0.536086594328865
# ROC AUC of FGSM attack for epsilon value 1: 0.28639171670023933
# ROC AUC of Random Noise attack for epsilon value 1: 0.5514134771897602
#
# Classification Report for PGD Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.37      0.45      0.41     47512
#            1       0.39      0.22      0.28     47269
#            2       0.34      0.41      0.37     43219
#
#     accuracy                           0.36    138000
#    macro avg       0.37      0.36      0.35    138000
# weighted avg       0.37      0.36      0.35    138000
#
#
# Classification Report for FGSM Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.06      0.08      0.07     47512
#            1       0.19      0.04      0.06     47269
#            2       0.08      0.12      0.10     43219
#
#     accuracy                           0.08    138000
#    macro avg       0.11      0.08      0.08    138000
# weighted avg       0.11      0.08      0.08    138000
#
#
# Classification Report for Random Noise Attack (ε = 1):
#               precision    recall  f1-score   support
#
#            0       0.38      0.52      0.44     47512
#            1       0.39      0.21      0.27     47269
#            2       0.37      0.41      0.39     43219
#
#     accuracy                           0.38    138000
#    macro avg       0.38      0.38      0.37    138000
# weighted avg       0.38      0.38      0.37    138000
#
# Epsilon value: 10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Average accuracy of PGD attack for epsilon value 10: 0.31249999999999983
# Average accuracy of FGSM attack for epsilon value 10: 0.07973913043478265
# Average accuracy of Random Noise attack for epsilon value 10: 0.37663043478260877
# Average perturbation volume for PGD attack with epsilon 10: 2.2742702960968018
# Average perturbation volume for FGSM attack with epsilon 10: 3.0961720943450928
# Average perturbation volume for Random Noise attack with epsilon 10: 3.8922371864318848
# Average precision of PGD attack for epsilon value 10: 0.31829607217260164
# Average recall of PGD attack for epsilon value 10: 0.31354126524187875
# Average precision of FGSM attack for epsilon value 10: 0.10859183569528447
# Average recall of FGSM attack for epsilon value 10: 0.08102854578388775
# Average precision of Random Noise attack for epsilon value 10: 0.37883764446030127
# Average recall of Random Noise attack for epsilon value 10: 0.3767305264112588
# ROC AUC of PGD attack for epsilon value 10: 0.4835360095478991
# ROC AUC of FGSM attack for epsilon value 10: 0.2864170966174151
# ROC AUC of Random Noise attack for epsilon value 10: 0.5487456667509827
#
# Classification Report for PGD Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.32      0.40      0.35     47512
#            1       0.35      0.19      0.24     47269
#            2       0.29      0.35      0.32     43219
#
#     accuracy                           0.31    138000
#    macro avg       0.32      0.31      0.31    138000
# weighted avg       0.32      0.31      0.31    138000
#
#
# Classification Report for FGSM Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.06      0.08      0.07     47512
#            1       0.18      0.04      0.06     47269
#            2       0.08      0.12      0.10     43219
#
#     accuracy                           0.08    138000
#    macro avg       0.11      0.08      0.08    138000
# weighted avg       0.11      0.08      0.08    138000
#
#
# Classification Report for Random Noise Attack (ε = 10):
#               precision    recall  f1-score   support
#
#            0       0.38      0.54      0.45     47512
#            1       0.39      0.20      0.26     47269
#            2       0.36      0.39      0.38     43219
#
#     accuracy                           0.38    138000
#    macro avg       0.38      0.38      0.36    138000
# weighted avg       0.38      0.38      0.36    138000

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    # Define constants needed for PGD attack
    num_iterations = 5
    step_size = 0.01

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None

epsilon_values = [0.000001, 0.00001, 0.0001, 0.001]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=lstm1,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 1e-06
# Batch 1/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 2/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 3/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 4/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 5/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 6/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 7/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 8/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 9/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 10/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 11/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 12/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 13/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 14/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 15/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 16/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 17/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 18/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 19/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 20/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 21/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 22/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 23/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 24/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 25/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 26/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 27/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 28/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 29/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 30/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 31/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 32/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 33/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 34/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 35/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 36/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 37/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 38/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 39/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 40/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 41/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 42/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 43/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 44/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 45/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 46/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 47/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 48/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 49/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 50/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 51/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 52/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 53/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 54/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 55/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 56/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 57/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 58/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 59/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 60/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 61/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 62/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 63/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 64/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 65/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 66/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 67/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 68/69 - PGD volume: 0.000001, FGSM volume: 0.000004
# Batch 69/69 - PGD volume: 0.000001, FGSM volume: 0.000004
#
# Analyzing epsilon: 1e-05
# Batch 1/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 2/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 3/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 4/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 5/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 6/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 7/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 8/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 9/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 10/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 11/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 12/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 13/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 14/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 15/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 16/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 17/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 18/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 19/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 20/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 21/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 22/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 23/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 24/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 25/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 26/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 27/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 28/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 29/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 30/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 31/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 32/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 33/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 34/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 35/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 36/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 37/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 38/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 39/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 40/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 41/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 42/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 43/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 44/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 45/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 46/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 47/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 48/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 49/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 50/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 51/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 52/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 53/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 54/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 55/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 56/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 57/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 58/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 59/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 60/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 61/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 62/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 63/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 64/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 65/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 66/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 67/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 68/69 - PGD volume: 0.000010, FGSM volume: 0.000045
# Batch 69/69 - PGD volume: 0.000010, FGSM volume: 0.000045
#
# Analyzing epsilon: 0.0001
# Batch 1/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 2/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 3/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 4/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 5/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 6/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 7/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 8/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 9/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 10/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 11/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 12/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 13/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 14/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 15/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 16/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 17/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 18/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 19/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 20/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 21/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 22/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 23/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 24/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 25/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 26/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 27/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 28/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 29/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 30/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 31/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 32/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 33/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 34/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 35/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 36/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 37/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 38/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 39/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 40/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 41/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 42/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 43/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 44/69 - PGD volume: 0.000100, FGSM volume: 0.000446
# Batch 45/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 46/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 47/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 48/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 49/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 50/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 51/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 52/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 53/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 54/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 55/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 56/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 57/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 58/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 59/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 60/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 61/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 62/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 63/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 64/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 65/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 66/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 67/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 68/69 - PGD volume: 0.000100, FGSM volume: 0.000447
# Batch 69/69 - PGD volume: 0.000100, FGSM volume: 0.000447
#
# Analyzing epsilon: 0.001
# Batch 1/69 - PGD volume: 0.001000, FGSM volume: 0.004378
# Batch 2/69 - PGD volume: 0.001000, FGSM volume: 0.004449
# Batch 3/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 4/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 5/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 6/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 7/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 8/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 9/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 10/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 11/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 12/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 13/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 14/69 - PGD volume: 0.001000, FGSM volume: 0.004464
# Batch 15/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 16/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 17/69 - PGD volume: 0.001000, FGSM volume: 0.004455
# Batch 18/69 - PGD volume: 0.001000, FGSM volume: 0.004459
# Batch 19/69 - PGD volume: 0.001000, FGSM volume: 0.004462
# Batch 20/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 21/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 22/69 - PGD volume: 0.001000, FGSM volume: 0.004434
# Batch 23/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 24/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 25/69 - PGD volume: 0.001000, FGSM volume: 0.004433
# Batch 26/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 27/69 - PGD volume: 0.001000, FGSM volume: 0.004448
# Batch 28/69 - PGD volume: 0.001000, FGSM volume: 0.004428
# Batch 29/69 - PGD volume: 0.001000, FGSM volume: 0.004408
# Batch 30/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 31/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 32/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 33/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 34/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 35/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 36/69 - PGD volume: 0.001000, FGSM volume: 0.004455
# Batch 37/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 38/69 - PGD volume: 0.001000, FGSM volume: 0.004468
# Batch 39/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 40/69 - PGD volume: 0.001000, FGSM volume: 0.004465
# Batch 41/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 42/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 43/69 - PGD volume: 0.001000, FGSM volume: 0.004460
# Batch 44/69 - PGD volume: 0.001000, FGSM volume: 0.004458
# Batch 45/69 - PGD volume: 0.001000, FGSM volume: 0.004443
# Batch 46/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 47/69 - PGD volume: 0.001000, FGSM volume: 0.004450
# Batch 48/69 - PGD volume: 0.001000, FGSM volume: 0.004429
# Batch 49/69 - PGD volume: 0.001000, FGSM volume: 0.004438
# Batch 50/69 - PGD volume: 0.001000, FGSM volume: 0.004423
# Batch 51/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 52/69 - PGD volume: 0.001000, FGSM volume: 0.004444
# Batch 53/69 - PGD volume: 0.001000, FGSM volume: 0.004456
# Batch 54/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 55/69 - PGD volume: 0.001000, FGSM volume: 0.004401
# Batch 56/69 - PGD volume: 0.001000, FGSM volume: 0.004469
# Batch 57/69 - PGD volume: 0.001000, FGSM volume: 0.004467
# Batch 58/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 59/69 - PGD volume: 0.001000, FGSM volume: 0.004470
# Batch 60/69 - PGD volume: 0.001000, FGSM volume: 0.004471
# Batch 61/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 62/69 - PGD volume: 0.001000, FGSM volume: 0.004466
# Batch 63/69 - PGD volume: 0.001000, FGSM volume: 0.004460
# Batch 64/69 - PGD volume: 0.001000, FGSM volume: 0.004453
# Batch 65/69 - PGD volume: 0.001000, FGSM volume: 0.004457
# Batch 66/69 - PGD volume: 0.001000, FGSM volume: 0.004458
# Batch 67/69 - PGD volume: 0.001000, FGSM volume: 0.004452
# Batch 68/69 - PGD volume: 0.001000, FGSM volume: 0.004445
# Batch 69/69 - PGD volume: 0.001000, FGSM volume: 0.004442
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         115.8257  39589.0000    0.4926
# 0.9000         284.3163  31738.0000    0.5136
# 0.9500         281.1065  22550.0000    0.5455
# 0.9900         211.2924  11018.0000    0.6081
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         115.8257  39588.0000    0.4926
# 0.9000         284.3163  31738.0000    0.5136
# 0.9500         281.1274  22551.0000    0.5454
# 0.9900         211.2924  11018.0000    0.6081
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         115.7446  39593.0000    0.4925
# 0.9000         284.3997  31738.0000    0.5136
# 0.9500         281.1730  22549.0000    0.5455
# 0.9900         211.3558  11017.0000    0.6082
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         116.0310  39624.0000    0.4921
# 0.9000         284.4527  31721.0000    0.5139
# 0.9500         281.1320  22541.0000    0.5457
# 0.9900         211.1173  11012.0000    0.6084
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 1e-06
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         115.8257  39588.0000    0.4926
# 0.9000         284.2968  31737.0000    0.5136
# 0.9500         281.1065  22550.0000    0.5455
# 0.9900         211.2924  11018.0000    0.6081
#
# Epsilon: 1e-05
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         115.7458  39589.0000    0.4926
# 0.9000         284.3249  31739.0000    0.5136
# 0.9500         281.1874  22548.0000    0.5455
# 0.9900         211.2924  11018.0000    0.6081
#
# Epsilon: 0.0001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         115.6621  39618.0000    0.4922
# 0.9000         284.3870  31734.0000    0.5136
# 0.9500         281.0912  22543.0000    0.5456
# 0.9900         211.2844  11011.0000    0.6085
#
# Epsilon: 0.001
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         115.6137  39608.0000    0.4873
# 0.9000         284.6854  31700.0000    0.5079
# 0.9500         281.0876  22504.0000    0.5466
# 0.9900         235.1980  10972.0000    0.6198

# %%
"""TRADING STRATEGY AFTER ATTACK ON 4 EPSILON VALUES"""
import numpy as np
import pandas as pd
import tensorflow as tf

def run_adversarial_trading_analysis(model, testX_CNN, testY_CNN, dec_test, epsilon_values, batch_size=2000):
    """Run trading strategy analysis with adversarial attacks"""
    results_pgd = []
    results_fgsm = []
    thresholds = [0.85, 0.90, 0.95, 0.99]  # Explicit thresholds

    # Define constants needed for PGD attack
    num_iterations = 5
    step_size = 0.01

    def data_set(testX_CNN, start_idx, end_idx):
        """Prepare the dataset by shifting"""
        shifted_testX_CNN = tf.concat([
            testX_CNN[start_idx:end_idx, 1:100, :, :],
            testX_CNN[start_idx:end_idx, 99:, :, :]
        ], axis=1)
        return tf.cast(shifted_testX_CNN, tf.float32)

    def volume_constraint(images, testX_CNN, dimension, start_idx, end_idx):
        """Apply volume constraints to the images"""
        images = images.numpy()
        slices = [slice(None)] * images.ndim
        testX_CNN_batch = testX_CNN[start_idx:end_idx]
        for idx in range(images.shape[dimension]):
            slices[dimension] = idx
            images[tuple(slices)] = np.maximum(
                images[tuple(slices)],
                testX_CNN_batch[tuple(slices)]
            )
        return tf.convert_to_tensor(images, dtype=tf.float32)

    def get_model_predictions(perturbed_images):
        """Get model predictions with error handling"""
        try:
            with tf.device('/CPU:0'):
                predictions = model(perturbed_images, training=False)
                return predictions.numpy()
        except Exception as e:
            print(f"Error in model prediction: {str(e)}")
            return None

    max_test_size = testX_CNN.shape[0]
    num_batches = max_test_size // batch_size

    for epsilon in epsilon_values:
        print(f"\nAnalyzing epsilon: {epsilon}")

        pgd_predictions = []
        fgsm_predictions = []

        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, max_test_size)

            try:
                # Prepare batch data
                batch_images = data_set(testX_CNN, start_idx, end_idx)
                batch_images = volume_constraint(batch_images, testX_CNN, 2, start_idx, end_idx)
                batch_labels = testY_CNN[start_idx:end_idx]

                # Generate adversarial examples
                perturbed_images_pgd = pgd_attack(batch_images, batch_labels, epsilon)
                perturbed_images_fgsm = fgsm_attack(batch_images, batch_labels, epsilon)

                if perturbed_images_pgd is not None and perturbed_images_fgsm is not None:
                    # Calculate perturbation volumes
                    pgd_volume = np.mean(np.linalg.norm(
                        (perturbed_images_pgd - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    fgsm_volume = np.mean(np.linalg.norm(
                        (perturbed_images_fgsm - batch_images).numpy().reshape(batch_images.shape[0], -1),
                        axis=1
                    ))
                    print(f"Batch {i+1}/{num_batches} - PGD volume: {pgd_volume:.6f}, FGSM volume: {fgsm_volume:.6f}")

                    # Get predictions
                    pgd_pred = get_model_predictions(perturbed_images_pgd)
                    fgsm_pred = get_model_predictions(perturbed_images_fgsm)

                    if pgd_pred is not None:
                        pgd_predictions.append(pgd_pred)
                    if fgsm_pred is not None:
                        fgsm_predictions.append(fgsm_pred)

            except Exception as e:
                print(f"Error processing batch {i}: {str(e)}")
                continue

            tf.keras.backend.clear_session()

        if pgd_predictions and fgsm_predictions:
            pgd_predictions = np.vstack(pgd_predictions)
            fgsm_predictions = np.vstack(fgsm_predictions)

            # Process for each threshold
            for threshold in thresholds:
                # Process PGD results
                pgd_result = implement_fi2010_strategy(
                    predictions=pgd_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if pgd_result:
                    pgd_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'PGD'
                    })
                    results_pgd.append(pgd_result)

                # Process FGSM results
                fgsm_result = implement_fi2010_strategy(
                    predictions=fgsm_predictions,
                    dec_data=dec_test,
                    prob_threshold=threshold
                )
                if fgsm_result:
                    fgsm_result.update({
                        'epsilon': epsilon,
                        'threshold': threshold,
                        'attack_type': 'FGSM'
                    })
                    results_fgsm.append(fgsm_result)

    # Create DataFrames
    pgd_df = pd.DataFrame(results_pgd) if results_pgd else pd.DataFrame()
    fgsm_df = pd.DataFrame(results_fgsm) if results_fgsm else pd.DataFrame()

    # Display detailed summaries
    if not pgd_df.empty:
        print("\nPGD Attack Summary by Threshold:")
        summary_pgd = pgd_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        # Format the display
        pd.set_option('display.float_format', lambda x: '%.4f' % x)
        print("\nPGD Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_pgd.loc[eps])

    if not fgsm_df.empty:
        print("\nFGSM Attack Summary by Threshold:")
        summary_fgsm = fgsm_df.groupby(['epsilon', 'threshold'])[
            ['total_profit', 'num_trades', 'win_rate']
        ].mean().round(4)

        print("\nFGSM Analysis Results:")
        for eps in epsilon_values:
            print(f"\nEpsilon: {eps}")
            print(summary_fgsm.loc[eps])

    return pgd_df, fgsm_df

def implement_fi2010_strategy(predictions, dec_data, prob_threshold=0.5, k=4, alpha=0.001):
    """Implementation of the FI-2010 trading strategy"""
    ask_prices = dec_data[0, :]
    bid_prices = dec_data[2, :]
    mid_prices = (ask_prices + bid_prices) / 2

    min_length = min(len(predictions), len(mid_prices) - k)
    predictions = predictions[:min_length]
    trades_info = []
    budget = 100

    for i in range(k, min_length):
        m_plus = np.mean(mid_prices[i+1:i+k+1])
        lt = (m_plus - mid_prices[i]) / mid_prices[i]

        pred_class = np.argmax(predictions[i])
        max_prob = np.max(predictions[i])

        if max_prob > prob_threshold and pred_class != 1:
            actual_direction = 1 if lt > alpha else (-1 if lt < -alpha else 0)
            shares = budget / mid_prices[i]

            if pred_class == 2:  # Long trade
                cost = shares * mid_prices[i]
                proceeds = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'up',
                    'profit': profit,
                    'correct': actual_direction == 1
                })
            elif pred_class == 0:  # Short trade
                proceeds = shares * mid_prices[i]
                cost = shares * m_plus
                profit = proceeds - cost
                trades_info.append({
                    'movement': 'down',
                    'profit': profit,
                    'correct': actual_direction == -1
                })

    if trades_info:
        trades_df = pd.DataFrame(trades_info)
        return {
            'threshold': prob_threshold,
            'total_profit': trades_df['profit'].sum(),
            'num_trades': len(trades_df),
            'win_rate': trades_df['correct'].mean() * 100,
            'avg_profit': trades_df['profit'].mean(),
            'long_trades': len(trades_df[trades_df['movement'] == 'up']),
            'short_trades': len(trades_df[trades_df['movement'] == 'down'])
        }
    return None


epsilon_values = [0.01, 0.1, 1, 10]
results_pgd, results_fgsm = run_adversarial_trading_analysis(
    model=lstm1,
    testX_CNN=testX_CNN,
    testY_CNN=testY_CNN,
    dec_test=dec_test,
    epsilon_values=epsilon_values,
    batch_size=2000
)
# Out:
# Analyzing epsilon: 0.01
# Batch 1/69 - PGD volume: 0.155796, FGSM volume: 0.036345
# Batch 2/69 - PGD volume: 0.155668, FGSM volume: 0.040986
# Batch 3/69 - PGD volume: 0.157226, FGSM volume: 0.043210
# Batch 4/69 - PGD volume: 0.156857, FGSM volume: 0.043031
# Batch 5/69 - PGD volume: 0.158072, FGSM volume: 0.043388
# Batch 6/69 - PGD volume: 0.157667, FGSM volume: 0.043563
# Batch 7/69 - PGD volume: 0.156617, FGSM volume: 0.043927
# Batch 8/69 - PGD volume: 0.157283, FGSM volume: 0.043781
# Batch 9/69 - PGD volume: 0.158167, FGSM volume: 0.043755
# Batch 10/69 - PGD volume: 0.157536, FGSM volume: 0.044033
# Batch 11/69 - PGD volume: 0.156188, FGSM volume: 0.043005
# Batch 12/69 - PGD volume: 0.156581, FGSM volume: 0.043243
# Batch 13/69 - PGD volume: 0.155804, FGSM volume: 0.042887
# Batch 14/69 - PGD volume: 0.156006, FGSM volume: 0.043365
# Batch 15/69 - PGD volume: 0.156529, FGSM volume: 0.043249
# Batch 16/69 - PGD volume: 0.156207, FGSM volume: 0.043916
# Batch 17/69 - PGD volume: 0.156918, FGSM volume: 0.040369
# Batch 18/69 - PGD volume: 0.157605, FGSM volume: 0.036278
# Batch 19/69 - PGD volume: 0.156406, FGSM volume: 0.036357
# Batch 20/69 - PGD volume: 0.157092, FGSM volume: 0.035960
# Batch 21/69 - PGD volume: 0.154881, FGSM volume: 0.036918
# Batch 22/69 - PGD volume: 0.154694, FGSM volume: 0.036098
# Batch 23/69 - PGD volume: 0.155649, FGSM volume: 0.035756
# Batch 24/69 - PGD volume: 0.155813, FGSM volume: 0.037726
# Batch 25/69 - PGD volume: 0.157357, FGSM volume: 0.037650
# Batch 26/69 - PGD volume: 0.156286, FGSM volume: 0.037610
# Batch 27/69 - PGD volume: 0.157045, FGSM volume: 0.036775
# Batch 28/69 - PGD volume: 0.156957, FGSM volume: 0.035845
# Batch 29/69 - PGD volume: 0.157681, FGSM volume: 0.038656
# Batch 30/69 - PGD volume: 0.157477, FGSM volume: 0.043422
# Batch 31/69 - PGD volume: 0.157365, FGSM volume: 0.042645
# Batch 32/69 - PGD volume: 0.157602, FGSM volume: 0.043115
# Batch 33/69 - PGD volume: 0.158130, FGSM volume: 0.042580
# Batch 34/69 - PGD volume: 0.157129, FGSM volume: 0.043963
# Batch 35/69 - PGD volume: 0.158037, FGSM volume: 0.044000
# Batch 36/69 - PGD volume: 0.158208, FGSM volume: 0.043895
# Batch 37/69 - PGD volume: 0.157511, FGSM volume: 0.043509
# Batch 38/69 - PGD volume: 0.156637, FGSM volume: 0.043820
# Batch 39/69 - PGD volume: 0.157321, FGSM volume: 0.043599
# Batch 40/69 - PGD volume: 0.157782, FGSM volume: 0.043299
# Batch 41/69 - PGD volume: 0.153191, FGSM volume: 0.043696
# Batch 42/69 - PGD volume: 0.157732, FGSM volume: 0.043588
# Batch 43/69 - PGD volume: 0.155532, FGSM volume: 0.043292
# Batch 44/69 - PGD volume: 0.157117, FGSM volume: 0.043336
# Batch 45/69 - PGD volume: 0.155939, FGSM volume: 0.041031
# Batch 46/69 - PGD volume: 0.158575, FGSM volume: 0.036156
# Batch 47/69 - PGD volume: 0.156310, FGSM volume: 0.036212
# Batch 48/69 - PGD volume: 0.157387, FGSM volume: 0.036923
# Batch 49/69 - PGD volume: 0.157320, FGSM volume: 0.035763
# Batch 50/69 - PGD volume: 0.156876, FGSM volume: 0.036161
# Batch 51/69 - PGD volume: 0.156953, FGSM volume: 0.036612
# Batch 52/69 - PGD volume: 0.157121, FGSM volume: 0.036731
# Batch 53/69 - PGD volume: 0.155755, FGSM volume: 0.036218
# Batch 54/69 - PGD volume: 0.157121, FGSM volume: 0.036694
# Batch 55/69 - PGD volume: 0.156094, FGSM volume: 0.038308
# Batch 56/69 - PGD volume: 0.156632, FGSM volume: 0.043572
# Batch 57/69 - PGD volume: 0.156687, FGSM volume: 0.043522
# Batch 58/69 - PGD volume: 0.157743, FGSM volume: 0.043802
# Batch 59/69 - PGD volume: 0.157091, FGSM volume: 0.044105
# Batch 60/69 - PGD volume: 0.156378, FGSM volume: 0.044183
# Batch 61/69 - PGD volume: 0.155868, FGSM volume: 0.043562
# Batch 62/69 - PGD volume: 0.156674, FGSM volume: 0.043505
# Batch 63/69 - PGD volume: 0.156842, FGSM volume: 0.043660
# Batch 64/69 - PGD volume: 0.157023, FGSM volume: 0.036455
# Batch 65/69 - PGD volume: 0.156172, FGSM volume: 0.036864
# Batch 66/69 - PGD volume: 0.156292, FGSM volume: 0.036440
# Batch 67/69 - PGD volume: 0.157156, FGSM volume: 0.036666
# Batch 68/69 - PGD volume: 0.157650, FGSM volume: 0.036187
# Batch 69/69 - PGD volume: 0.156181, FGSM volume: 0.036645
#
# Analyzing epsilon: 0.1
# Batch 1/69 - PGD volume: 0.155796, FGSM volume: 0.313401
# Batch 2/69 - PGD volume: 0.155668, FGSM volume: 0.332167
# Batch 3/69 - PGD volume: 0.157226, FGSM volume: 0.337645
# Batch 4/69 - PGD volume: 0.156857, FGSM volume: 0.341082
# Batch 5/69 - PGD volume: 0.158072, FGSM volume: 0.336760
# Batch 6/69 - PGD volume: 0.157667, FGSM volume: 0.339206
# Batch 7/69 - PGD volume: 0.156617, FGSM volume: 0.343036
# Batch 8/69 - PGD volume: 0.157283, FGSM volume: 0.339822
# Batch 9/69 - PGD volume: 0.158167, FGSM volume: 0.342459
# Batch 10/69 - PGD volume: 0.157536, FGSM volume: 0.343113
# Batch 11/69 - PGD volume: 0.156188, FGSM volume: 0.330058
# Batch 12/69 - PGD volume: 0.156581, FGSM volume: 0.332447
# Batch 13/69 - PGD volume: 0.155804, FGSM volume: 0.328089
# Batch 14/69 - PGD volume: 0.156006, FGSM volume: 0.333409
# Batch 15/69 - PGD volume: 0.156529, FGSM volume: 0.332102
# Batch 16/69 - PGD volume: 0.156207, FGSM volume: 0.329738
# Batch 17/69 - PGD volume: 0.156918, FGSM volume: 0.324290
# Batch 18/69 - PGD volume: 0.157605, FGSM volume: 0.317533
# Batch 19/69 - PGD volume: 0.156406, FGSM volume: 0.316875
# Batch 20/69 - PGD volume: 0.157092, FGSM volume: 0.319344
# Batch 21/69 - PGD volume: 0.154881, FGSM volume: 0.316404
# Batch 22/69 - PGD volume: 0.154694, FGSM volume: 0.313491
# Batch 23/69 - PGD volume: 0.155649, FGSM volume: 0.316424
# Batch 24/69 - PGD volume: 0.155813, FGSM volume: 0.316863
# Batch 25/69 - PGD volume: 0.157357, FGSM volume: 0.319256
# Batch 26/69 - PGD volume: 0.156286, FGSM volume: 0.318547
# Batch 27/69 - PGD volume: 0.157045, FGSM volume: 0.319892
# Batch 28/69 - PGD volume: 0.156957, FGSM volume: 0.317078
# Batch 29/69 - PGD volume: 0.157681, FGSM volume: 0.326131
# Batch 30/69 - PGD volume: 0.157477, FGSM volume: 0.341553
# Batch 31/69 - PGD volume: 0.157365, FGSM volume: 0.335536
# Batch 32/69 - PGD volume: 0.157602, FGSM volume: 0.335798
# Batch 33/69 - PGD volume: 0.158130, FGSM volume: 0.337547
# Batch 34/69 - PGD volume: 0.157129, FGSM volume: 0.337768
# Batch 35/69 - PGD volume: 0.158037, FGSM volume: 0.343399
# Batch 36/69 - PGD volume: 0.158208, FGSM volume: 0.343849
# Batch 37/69 - PGD volume: 0.157511, FGSM volume: 0.341933
# Batch 38/69 - PGD volume: 0.156637, FGSM volume: 0.334912
# Batch 39/69 - PGD volume: 0.157321, FGSM volume: 0.343538
# Batch 40/69 - PGD volume: 0.157782, FGSM volume: 0.336956
# Batch 41/69 - PGD volume: 0.153191, FGSM volume: 0.332421
# Batch 42/69 - PGD volume: 0.157732, FGSM volume: 0.339014
# Batch 43/69 - PGD volume: 0.155532, FGSM volume: 0.335188
# Batch 44/69 - PGD volume: 0.157117, FGSM volume: 0.335740
# Batch 45/69 - PGD volume: 0.155939, FGSM volume: 0.326357
# Batch 46/69 - PGD volume: 0.158575, FGSM volume: 0.319376
# Batch 47/69 - PGD volume: 0.156310, FGSM volume: 0.315072
# Batch 48/69 - PGD volume: 0.157387, FGSM volume: 0.319326
# Batch 49/69 - PGD volume: 0.157320, FGSM volume: 0.317682
# Batch 50/69 - PGD volume: 0.156876, FGSM volume: 0.317280
# Batch 51/69 - PGD volume: 0.156953, FGSM volume: 0.317854
# Batch 52/69 - PGD volume: 0.157121, FGSM volume: 0.319138
# Batch 53/69 - PGD volume: 0.155755, FGSM volume: 0.318061
# Batch 54/69 - PGD volume: 0.157121, FGSM volume: 0.317612
# Batch 55/69 - PGD volume: 0.156094, FGSM volume: 0.319992
# Batch 56/69 - PGD volume: 0.156632, FGSM volume: 0.338332
# Batch 57/69 - PGD volume: 0.156687, FGSM volume: 0.343556
# Batch 58/69 - PGD volume: 0.157743, FGSM volume: 0.347573
# Batch 59/69 - PGD volume: 0.157091, FGSM volume: 0.343675
# Batch 60/69 - PGD volume: 0.156378, FGSM volume: 0.352149
# Batch 61/69 - PGD volume: 0.155868, FGSM volume: 0.333043
# Batch 62/69 - PGD volume: 0.156674, FGSM volume: 0.334503
# Batch 63/69 - PGD volume: 0.156842, FGSM volume: 0.332767
# Batch 64/69 - PGD volume: 0.157023, FGSM volume: 0.318279
# Batch 65/69 - PGD volume: 0.156172, FGSM volume: 0.315993
# Batch 66/69 - PGD volume: 0.156292, FGSM volume: 0.316001
# Batch 67/69 - PGD volume: 0.157156, FGSM volume: 0.318355
# Batch 68/69 - PGD volume: 0.157650, FGSM volume: 0.319598
# Batch 69/69 - PGD volume: 0.156181, FGSM volume: 0.316383
#
# Analyzing epsilon: 1
# Batch 1/69 - PGD volume: 0.155796, FGSM volume: 3.109159
# Batch 2/69 - PGD volume: 0.155668, FGSM volume: 3.055507
# Batch 3/69 - PGD volume: 0.157226, FGSM volume: 3.074926
# Batch 4/69 - PGD volume: 0.156857, FGSM volume: 3.057656
# Batch 5/69 - PGD volume: 0.158072, FGSM volume: 3.095659
# Batch 6/69 - PGD volume: 0.157667, FGSM volume: 3.078388
# Batch 7/69 - PGD volume: 0.156617, FGSM volume: 3.035956
# Batch 8/69 - PGD volume: 0.157283, FGSM volume: 3.063056
# Batch 9/69 - PGD volume: 0.158167, FGSM volume: 3.083799
# Batch 10/69 - PGD volume: 0.157536, FGSM volume: 3.076337
# Batch 11/69 - PGD volume: 0.156188, FGSM volume: 3.064340
# Batch 12/69 - PGD volume: 0.156581, FGSM volume: 3.066764
# Batch 13/69 - PGD volume: 0.155804, FGSM volume: 3.061405
# Batch 14/69 - PGD volume: 0.156006, FGSM volume: 3.063009
# Batch 15/69 - PGD volume: 0.156529, FGSM volume: 3.072294
# Batch 16/69 - PGD volume: 0.156207, FGSM volume: 3.062754
# Batch 17/69 - PGD volume: 0.156918, FGSM volume: 3.101587
# Batch 18/69 - PGD volume: 0.157605, FGSM volume: 3.148386
# Batch 19/69 - PGD volume: 0.156406, FGSM volume: 3.145094
# Batch 20/69 - PGD volume: 0.157092, FGSM volume: 3.173605
# Batch 21/69 - PGD volume: 0.154881, FGSM volume: 3.136171
# Batch 22/69 - PGD volume: 0.154694, FGSM volume: 3.109331
# Batch 23/69 - PGD volume: 0.155649, FGSM volume: 3.143204
# Batch 24/69 - PGD volume: 0.155813, FGSM volume: 3.132726
# Batch 25/69 - PGD volume: 0.157357, FGSM volume: 3.159609
# Batch 26/69 - PGD volume: 0.156286, FGSM volume: 3.147913
# Batch 27/69 - PGD volume: 0.157045, FGSM volume: 3.173851
# Batch 28/69 - PGD volume: 0.156957, FGSM volume: 3.147987
# Batch 29/69 - PGD volume: 0.157681, FGSM volume: 3.114697
# Batch 30/69 - PGD volume: 0.157477, FGSM volume: 3.061277
# Batch 31/69 - PGD volume: 0.157365, FGSM volume: 3.081019
# Batch 32/69 - PGD volume: 0.157602, FGSM volume: 3.075521
# Batch 33/69 - PGD volume: 0.158130, FGSM volume: 3.088929
# Batch 34/69 - PGD volume: 0.157129, FGSM volume: 3.057808
# Batch 35/69 - PGD volume: 0.158037, FGSM volume: 3.069777
# Batch 36/69 - PGD volume: 0.158208, FGSM volume: 3.082779
# Batch 37/69 - PGD volume: 0.157511, FGSM volume: 3.066646
# Batch 38/69 - PGD volume: 0.156637, FGSM volume: 3.058135
# Batch 39/69 - PGD volume: 0.157321, FGSM volume: 3.061905
# Batch 40/69 - PGD volume: 0.157782, FGSM volume: 3.082868
# Batch 41/69 - PGD volume: 0.153191, FGSM volume: 3.031204
# Batch 42/69 - PGD volume: 0.157732, FGSM volume: 3.091245
# Batch 43/69 - PGD volume: 0.155532, FGSM volume: 3.057703
# Batch 44/69 - PGD volume: 0.157117, FGSM volume: 3.084555
# Batch 45/69 - PGD volume: 0.155939, FGSM volume: 3.068249
# Batch 46/69 - PGD volume: 0.158575, FGSM volume: 3.167979
# Batch 47/69 - PGD volume: 0.156310, FGSM volume: 3.124743
# Batch 48/69 - PGD volume: 0.157387, FGSM volume: 3.166342
# Batch 49/69 - PGD volume: 0.157320, FGSM volume: 3.153383
# Batch 50/69 - PGD volume: 0.156876, FGSM volume: 3.148141
# Batch 51/69 - PGD volume: 0.156953, FGSM volume: 3.149318
# Batch 52/69 - PGD volume: 0.157121, FGSM volume: 3.164696
# Batch 53/69 - PGD volume: 0.155755, FGSM volume: 3.157168
# Batch 54/69 - PGD volume: 0.157121, FGSM volume: 3.148295
# Batch 55/69 - PGD volume: 0.156094, FGSM volume: 3.093433
# Batch 56/69 - PGD volume: 0.156632, FGSM volume: 3.050066
# Batch 57/69 - PGD volume: 0.156687, FGSM volume: 3.036856
# Batch 58/69 - PGD volume: 0.157743, FGSM volume: 3.057148
# Batch 59/69 - PGD volume: 0.157091, FGSM volume: 3.041594
# Batch 60/69 - PGD volume: 0.156378, FGSM volume: 3.018379
# Batch 61/69 - PGD volume: 0.155868, FGSM volume: 3.041858
# Batch 62/69 - PGD volume: 0.156674, FGSM volume: 3.059910
# Batch 63/69 - PGD volume: 0.156842, FGSM volume: 3.068726
# Batch 64/69 - PGD volume: 0.157023, FGSM volume: 3.136158
# Batch 65/69 - PGD volume: 0.156172, FGSM volume: 3.128880
# Batch 66/69 - PGD volume: 0.156292, FGSM volume: 3.125457
# Batch 67/69 - PGD volume: 0.157156, FGSM volume: 3.156310
# Batch 68/69 - PGD volume: 0.157650, FGSM volume: 3.174935
# Batch 69/69 - PGD volume: 0.156181, FGSM volume: 3.135981
#
# Analyzing epsilon: 10
# Batch 1/69 - PGD volume: 0.155796, FGSM volume: 3.109159
# Batch 2/69 - PGD volume: 0.155668, FGSM volume: 3.055507
# Batch 3/69 - PGD volume: 0.157226, FGSM volume: 3.074926
# Batch 4/69 - PGD volume: 0.156857, FGSM volume: 3.057656
# Batch 5/69 - PGD volume: 0.158072, FGSM volume: 3.095659
# Batch 6/69 - PGD volume: 0.157667, FGSM volume: 3.078388
# Batch 7/69 - PGD volume: 0.156617, FGSM volume: 3.035956
# Batch 8/69 - PGD volume: 0.157283, FGSM volume: 3.063056
# Batch 9/69 - PGD volume: 0.158167, FGSM volume: 3.083799
# Batch 10/69 - PGD volume: 0.157536, FGSM volume: 3.076337
# Batch 11/69 - PGD volume: 0.156188, FGSM volume: 3.064340
# Batch 12/69 - PGD volume: 0.156581, FGSM volume: 3.066764
# Batch 13/69 - PGD volume: 0.155804, FGSM volume: 3.061405
# Batch 14/69 - PGD volume: 0.156006, FGSM volume: 3.063009
# Batch 15/69 - PGD volume: 0.156529, FGSM volume: 3.072294
# Batch 16/69 - PGD volume: 0.156207, FGSM volume: 3.062754
# Batch 17/69 - PGD volume: 0.156918, FGSM volume: 3.101587
# Batch 18/69 - PGD volume: 0.157605, FGSM volume: 3.148386
# Batch 19/69 - PGD volume: 0.156406, FGSM volume: 3.145094
# Batch 20/69 - PGD volume: 0.157092, FGSM volume: 3.173605
# Batch 21/69 - PGD volume: 0.154881, FGSM volume: 3.136171
# Batch 22/69 - PGD volume: 0.154694, FGSM volume: 3.109331
# Batch 23/69 - PGD volume: 0.155649, FGSM volume: 3.143204
# Batch 24/69 - PGD volume: 0.155813, FGSM volume: 3.132726
# Batch 25/69 - PGD volume: 0.157357, FGSM volume: 3.159609
# Batch 26/69 - PGD volume: 0.156286, FGSM volume: 3.147913
# Batch 27/69 - PGD volume: 0.157045, FGSM volume: 3.173851
# Batch 28/69 - PGD volume: 0.156957, FGSM volume: 3.147987
# Batch 29/69 - PGD volume: 0.157681, FGSM volume: 3.114697
# Batch 30/69 - PGD volume: 0.157477, FGSM volume: 3.061277
# Batch 31/69 - PGD volume: 0.157365, FGSM volume: 3.081019
# Batch 32/69 - PGD volume: 0.157602, FGSM volume: 3.075521
# Batch 33/69 - PGD volume: 0.158130, FGSM volume: 3.088929
# Batch 34/69 - PGD volume: 0.157129, FGSM volume: 3.057808
# Batch 35/69 - PGD volume: 0.158037, FGSM volume: 3.069777
# Batch 36/69 - PGD volume: 0.158208, FGSM volume: 3.082779
# Batch 37/69 - PGD volume: 0.157511, FGSM volume: 3.066646
# Batch 38/69 - PGD volume: 0.156637, FGSM volume: 3.058135
# Batch 39/69 - PGD volume: 0.157321, FGSM volume: 3.061905
# Batch 40/69 - PGD volume: 0.157782, FGSM volume: 3.082868
# Batch 41/69 - PGD volume: 0.153191, FGSM volume: 3.031204
# Batch 42/69 - PGD volume: 0.157732, FGSM volume: 3.091245
# Batch 43/69 - PGD volume: 0.155532, FGSM volume: 3.057703
# Batch 44/69 - PGD volume: 0.157117, FGSM volume: 3.084555
# Batch 45/69 - PGD volume: 0.155939, FGSM volume: 3.068249
# Batch 46/69 - PGD volume: 0.158575, FGSM volume: 3.167979
# Batch 47/69 - PGD volume: 0.156310, FGSM volume: 3.124743
# Batch 48/69 - PGD volume: 0.157387, FGSM volume: 3.166342
# Batch 49/69 - PGD volume: 0.157320, FGSM volume: 3.153383
# Batch 50/69 - PGD volume: 0.156876, FGSM volume: 3.148141
# Batch 51/69 - PGD volume: 0.156953, FGSM volume: 3.149318
# Batch 52/69 - PGD volume: 0.157121, FGSM volume: 3.164696
# Batch 53/69 - PGD volume: 0.155755, FGSM volume: 3.157168
# Batch 54/69 - PGD volume: 0.157121, FGSM volume: 3.148295
# Batch 55/69 - PGD volume: 0.156094, FGSM volume: 3.093433
# Batch 56/69 - PGD volume: 0.156632, FGSM volume: 3.050066
# Batch 57/69 - PGD volume: 0.156687, FGSM volume: 3.036856
# Batch 58/69 - PGD volume: 0.157743, FGSM volume: 3.057148
# Batch 59/69 - PGD volume: 0.157091, FGSM volume: 3.041594
# Batch 60/69 - PGD volume: 0.156378, FGSM volume: 3.018379
# Batch 61/69 - PGD volume: 0.155868, FGSM volume: 3.041858
# Batch 62/69 - PGD volume: 0.156674, FGSM volume: 3.059910
# Batch 63/69 - PGD volume: 0.156842, FGSM volume: 3.068726
# Batch 64/69 - PGD volume: 0.157023, FGSM volume: 3.136158
# Batch 65/69 - PGD volume: 0.156172, FGSM volume: 3.128880
# Batch 66/69 - PGD volume: 0.156292, FGSM volume: 3.125457
# Batch 67/69 - PGD volume: 0.157156, FGSM volume: 3.156310
# Batch 68/69 - PGD volume: 0.157650, FGSM volume: 3.174935
# Batch 69/69 - PGD volume: 0.156181, FGSM volume: 3.135981
#
# PGD Attack Summary by Threshold:
#
# PGD Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -179.8294  45219.0000    0.4578
# 0.9000         -79.0166  35363.0000    0.4722
# 0.9500         294.2139  23927.0000    0.5182
# 0.9900         252.7266  10651.0000    0.5727
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -179.8294  45219.0000    0.4578
# 0.9000         -79.0166  35363.0000    0.4722
# 0.9500         294.2139  23927.0000    0.5182
# 0.9900         252.7266  10651.0000    0.5727
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -179.8294  45219.0000    0.4578
# 0.9000         -79.0166  35363.0000    0.4722
# 0.9500         294.2139  23927.0000    0.5182
# 0.9900         252.7266  10651.0000    0.5727
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -179.8294  45219.0000    0.4578
# 0.9000         -79.0166  35363.0000    0.4722
# 0.9500         294.2139  23927.0000    0.5182
# 0.9900         252.7266  10651.0000    0.5727
#
# FGSM Attack Summary by Threshold:
#
# FGSM Analysis Results:
#
# Epsilon: 0.01
#            total_profit  num_trades  win_rate
# threshold
# 0.8500         -33.0079  40137.0000    0.4858
# 0.9000         284.8999  31863.0000    0.4959
# 0.9500         308.8964  22419.0000    0.5531
# 0.9900         214.4012  10584.0000    0.5952
#
# Epsilon: 0.1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -127.9703  58032.0000    0.4274
# 0.9000        -150.6390  46627.0000    0.4161
# 0.9500        -139.8758  31980.0000    0.4503
# 0.9900         193.1591  13301.0000    0.5488
#
# Epsilon: 1
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -345.0911  96616.0000    0.4192
# 0.9000        -430.3472  87415.0000    0.4233
# 0.9500        -400.5415  72261.0000    0.4332
# 0.9900        -274.8611  39172.0000    0.4161
#
# Epsilon: 10
#            total_profit  num_trades  win_rate
# threshold
# 0.8500        -345.0911  96616.0000    0.4192
# 0.9000        -430.3472  87415.0000    0.4233
# 0.9500        -400.5415  72261.0000    0.4332
# 0.9900        -274.8611  39172.0000    0.4161
